# %% [markdown]
# ###

# %% [markdown]
# # Deep Learning (RNN) Demo for Load Forecasting

# %% [markdown]
# ## SEC 1: Import all the packages needed

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mp
import random as rd
import argparse
import os, sys
import csv
import math
import time
import matplotlib.pyplot as pl

# %% [markdown]
# ## SEC 2: Load demand data from excel file

# %% [markdown]
# define class for dataset

# %%
class County:
    def __init__(self,parsename):
        self.parsename = parsename
        dataframe = xls.parse(parsename)
        self.date = dataframe['Date']
        self.hour = dataframe['Hr_End']
        self.demand = dataframe['RT_Demand']
        self.drybulb = dataframe['Dry_Bulb']
        self.dewpnt = dataframe['Dew_Point']
    def disp_all(self):
        print self.dataframe
    def get_all(self):
        return self.dataframe

# %% [markdown]
# load data

# %%
xls = pd.ExcelFile('smd_hourly.xls')
INC = County('ISO NE CA')
ME = County('ME')
NH = County('NH')
VT = County('VT')
CT = County('CT')
RI = County('RI')
SEMA = County('SEMA')
WCMA = County('WCMA')
NEMA = County('NEMA')

# %%
#print INC.date[-8*24:-1]

# %% [markdown]
# ## SEC 3: setting all global parameters

# %%
data_dir = './data/' # directory contains input data
num_epoches = 50000 # training epoches for each customer samples
day_steps = 24
n_steps = day_steps # input size
test_batch_size = 4*7*day_steps # days of a batch
validation_batch_size = 0*day_steps
train_batch_size = 7*day_steps
feature_size = 1 # same time of a week
n_hidden = 30 # input size
num_layers = 2
n_output = 1
totalen = np.array(INC.demand).shape[0]

# %% [markdown]
# ## SEC 4: split dataset into training, cross-validation, and test

# %% [markdown]
# concatenate data into database

# %%
# DEMAND MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.demand)
demand_mat = tmp.reshape([1,tmp.shape[0],1])
demand_mat = demand_mat/25000
#demand_mat = np.concatenate([demand_mat,np.array(ME.demand).reshape([1,np.array(ME.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NH.demand).reshape([1,np.array(NH.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(VT.demand).reshape([1,np.array(VT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(CT.demand).reshape([1,np.array(CT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(RI.demand).reshape([1,np.array(RI.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(SEMA.demand).reshape([1,np.array(SEMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(WCMA.demand).reshape([1,np.array(WCMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NEMA.demand).reshape([1,np.array(NEMA.demand).shape[0],1])],axis = 0)
print demand_mat.shape
# DRY BULB MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.drybulb)
drybulb_mat = tmp.reshape([1,tmp.shape[0],1])
drybulb_mat = drybulb_mat/100
#drybulb_mat = np.concatenate([drybulb_mat,np.array(ME.drybulb).reshape([1,np.array(ME.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NH.drybulb).reshape([1,np.array(NH.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(VT.drybulb).reshape([1,np.array(VT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(CT.drybulb).reshape([1,np.array(CT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(RI.drybulb).reshape([1,np.array(RI.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(SEMA.drybulb).reshape([1,np.array(SEMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(WCMA.drybulb).reshape([1,np.array(WCMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NEMA.drybulb).reshape([1,np.array(NEMA.drybulb).shape[0],1])],axis = 0)
#print drybulb_mat.shape
# DEW PNT MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.dewpnt)
dewpnt_mat = tmp.reshape([1,tmp.shape[0],1])
dewpnt_mat = dewpnt_mat/100
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(ME.dewpnt).reshape([1,np.array(ME.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NH.dewpnt).reshape([1,np.array(NH.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(VT.dewpnt).reshape([1,np.array(VT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(CT.dewpnt).reshape([1,np.array(CT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(RI.dewpnt).reshape([1,np.array(RI.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(SEMA.dewpnt).reshape([1,np.array(SEMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(WCMA.dewpnt).reshape([1,np.array(WCMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NEMA.dewpnt).reshape([1,np.array(NEMA.dewpnt).shape[0],1])],axis = 0)
#print dewpnt_mat.shape

#db = np.concatenate([demand_mat,dewpnt_mat,drybulb_mat],axis = 2)
#db = np.concatenate([demand_mat,dewpnt_mat],axis = 2)
db = demand_mat

print db.shape
# Out:
# (1, 5856, 1)
# (1, 5856, 1)

# %% [markdown]
# split into 3 parts using part array

# %%
#define id arrays
test_id = np.array(test_batch_size)
valid_id = np.array(validation_batch_size)
train_id = np.array(totalen-test_batch_size-validation_batch_size-n_steps)

#give values to id arrays
rang = range(n_steps,totalen-test_batch_size)
valid_id = rd.sample(rang,validation_batch_size)
test_id = np.array(range(totalen-test_batch_size,totalen))
train_id = set(range(n_steps,totalen-test_batch_size))-set(valid_id)

#sort three id array
valid_id = np.sort(valid_id)
test_id = np.sort(test_id)
train_id = np.array(list(train_id))

# %% [markdown]
# ### Step 4: define data generating function code.
# which generate a batch of batch-size large sequence data. the data is feature_size dims width and is a time series of float32 of steps steps. inputs and outputs are:
#
# inputs:
# ----n_batch: number of samples in a batch
# ----steps: the sequence length of a sample data
# ----feature_size: dimensions of a single time step data frame
#
# outputs:
# ----X inputs, shape(n_batch,steps,feature_size)
# ----Y outputs should be, shape(n_batch,)

# %%
def train_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps,train_id.shape[0])
    train_rd = rd.sample(rang,train_batch_size)
    train_rd = np.sort(train_rd)
    for i in train_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
def valid_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps,valid_id.shape[0])
    valid_rd = rd.sample(rang,train_batch_size)
    valid_rd = np.sort(valid_rd)
    for i in valid_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
def test_data_gen():
    X = np.zeros((test_batch_size,n_steps,feature_size))
    Y = np.zeros((test_batch_size,feature_size))
    count = 0
    for i in test_id:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
# code testing
"""
(x,y) = test_data_gen()
print x.shape
x = x.reshape(test_batch_size,n_steps,feature_size)
print x[0,:,:]
"""
"""
count = 0
X = np.zeros((test_batch_size,n_steps,feature_size))
Y = np.zeros((test_batch_size,feature_size))
for i in test_id:
    print i
    Y[0] = db[:,i,:]
    X[0] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
"""
X = np.zeros((train_batch_size,n_steps,feature_size))
Y = np.zeros((train_batch_size,feature_size))
count = 0
rang = range(n_steps,train_id.shape[0])
train_rd = rd.sample(rang,train_batch_size)
train_rd = np.sort(train_rd)
for i in train_id:
    Y[count] = db[:,i,:]
    X[count] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
# Out:
# '\nX = np.zeros((train_batch_size,n_steps,feature_size))\nY = np.zeros((train_batch_size,feature_size))\ncount = 0\nrang = range(n_steps,train_id.shape[0])\ntrain_rd = rd.sample(rang,train_batch_size)\ntrain_rd = np.sort(train_rd)\nfor i in train_id:\n    Y[count] = db[:,i,:]\n    X[count] = db[:,i-n_steps:i,:]\n    count = count + 1\n    if count == 3:\n        break\nprint Y\nprint Y.shape\nprint X\nprint X.shape\n'

# %% [markdown]
# ### Step 5: construct RNN model

# %%
# create placeholder for x and y
#with tf.device('/gpu:0'):
x = tf.placeholder("float",[None,n_steps,feature_size])
istate = tf.placeholder("float",[None,num_layers*2*n_hidden])
y = tf.placeholder("float",[None,n_output])


# Define weights
weights = {
    'hidden': tf.Variable(tf.random_normal([feature_size, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_output]))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_output]))
}
def RNN(_X, _istate, _weights, _biases):
    # input shape: (batch_size, n_steps, n_input)
    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    # Reshape to prepare input to hidden activation
    _X = tf.reshape(_X, [-1, feature_size]) # (n_steps*batch_size, n_input)
    # Linear activation
    _X = tf.matmul(_X, _weights['hidden']) + _biases['hidden']

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    stacked_lstm_cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell]*num_layers)

    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(0, n_steps, _X) # n_steps * (batch_size, n_hidden)

    # Get lstm cell output
    outputs, states = tf.nn.rnn(stacked_lstm_cell, _X, initial_state=_istate)

    # Linear activation
    # Get inner loop last output
    return tf.matmul(outputs[-1], _weights['out']) + _biases['out']

pred = RNN(x, istate, weights, biases)
#cost function 
cost = tf.reduce_mean(tf.pow(pred[:,0]-y[:,0],2)) # cost function of this batch of data
#compute parameter updates
#optimizer = tf.train.GradientDescentOptimizer(0.2).minimize(cost)
optimizer = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(cost)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7f24621abd90>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
def maxe(predictions, targets):
    return max(abs(predictions-targets))

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
def mape(predictions, targets):
    return np.mean(abs(predictions-targets)/targets)

# %%
outlist = np.zeros([(num_epoches/10),test_batch_size])
kind = 0
time1 = time.time()
# generate test data
test_x,test_y = test_data_gen()
test_x = test_x.reshape(test_batch_size,n_steps,feature_size)
print test_x
print test_y
### Execute
# Initializing the variables
init = tf.initialize_all_variables()
# Out:
# [[[ 0.47207204]
#   [ 0.44668224]
#   [ 0.43117464]
#   ...,
#   [ 0.65928008]
#   [ 0.59640664]
#   [ 0.53463524]]
#
#  [[ 0.44668224]
#   [ 0.43117464]
#   [ 0.42555116]
#   ...,
#   [ 0.59640664]
#   [ 0.53463524]
#   [ 0.4898016 ]]
#
#  [[ 0.43117464]
#   [ 0.42555116]
#   [ 0.43154176]
#   ...,
#   [ 0.53463524]
#   [ 0.4898016 ]
#   [ 0.46070932]]
#
#  ...,
#  [[ 0.67518636]
#   [ 0.61018304]
#   [ 0.55081196]
#   ...,
#   [ 0.75913292]
#   [ 0.76808968]
#   [ 0.75854976]]
#
#  [[ 0.61018304]
#   [ 0.55081196]
#   [ 0.50914032]
#   ...,
#   [ 0.76808968]
#   [ 0.75854976]
#   [ 0.71185484]]
#
#  [[ 0.55081196]
#   [ 0.50914032]
#   [ 0.48262376]
#   ...,
#   [ 0.75854976]
#   [ 0.71185484]
#   [ 0.64936732]]]
# [[ 0.4898016 ]
#  [ 0.46070932]
#  [ 0.44249152]
#  [ 0.43373724]
#  [ 0.4389696 ]
#  [ 0.46344364]
#  [ 0.50917344]
#  [ 0.56697972]
#  [ 0.60859296]
#  [ 0.6414948 ]
#  [ 0.6721058 ]
#  [ 0.69683464]
#  [ 0.71638608]
#  [ 0.73826088]
#  [ 0.755046  ]
#  [ 0.76875724]
#  [ 0.78053276]
#  [ 0.78213004]
#  [ 0.7633164 ]
#  [ 0.73364112]
#  [ 0.72129312]
#  [ 0.68481204]
#  [ 0.62016868]
#  [ 0.55856868]
#  [ 0.5115566 ]
#  [ 0.48144072]
#  [ 0.46225668]
#  [ 0.4522264 ]
#  [ 0.45611736]
#  [ 0.47998168]
#  [ 0.52345344]
#  [ 0.58295244]
#  [ 0.6301512 ]
#  [ 0.66802072]
#  [ 0.70300328]
#  [ 0.73234212]
#  [ 0.75541912]
#  [ 0.77909384]
#  [ 0.79627232]
#  [ 0.80585364]
#  [ 0.81520336]
#  [ 0.81229484]
#  [ 0.78742252]
#  [ 0.75372912]
#  [ 0.73955604]
#  [ 0.70635172]
#  [ 0.65185088]
#  [ 0.59370536]
#  [ 0.5476018 ]
#  [ 0.5151112 ]
#  [ 0.49430336]
#  [ 0.4821128 ]
#  [ 0.47955944]
#  [ 0.48787324]
#  [ 0.507065  ]
#  [ 0.54924584]
#  [ 0.6003568 ]
#  [ 0.6454686 ]
#  [ 0.68175388]
#  [ 0.70977904]
#  [ 0.73377284]
#  [ 0.75723488]
#  [ 0.7755774 ]
#  [ 0.79194156]
#  [ 0.80472736]
#  [ 0.80712384]
#  [ 0.7858186 ]
#  [ 0.7595332 ]
#  [ 0.74727244]
#  [ 0.7133008 ]
#  [ 0.65804404]
#  [ 0.59839684]
#  [ 0.54953104]
#  [ 0.5131464 ]
#  [ 0.48792016]
#  [ 0.47103164]
#  [ 0.46141736]
#  [ 0.457427  ]
#  [ 0.46400288]
#  [ 0.50033184]
#  [ 0.54965608]
#  [ 0.59456448]
#  [ 0.63134384]
#  [ 0.66233332]
#  [ 0.68552264]
#  [ 0.69918956]
#  [ 0.7102338 ]
#  [ 0.72452288]
#  [ 0.74076688]
#  [ 0.75086952]
#  [ 0.74456148]
#  [ 0.7216634 ]
#  [ 0.71250044]
#  [ 0.67836612]
#  [ 0.6189372 ]
#  [ 0.56038924]
#  [ 0.51560368]
#  [ 0.48534932]
#  [ 0.46676376]
#  [ 0.457944  ]
#  [ 0.46343736]
#  [ 0.48775356]
#  [ 0.53237356]
#  [ 0.59086636]
#  [ 0.63431636]
#  [ 0.6675054 ]
#  [ 0.69681132]
#  [ 0.72231924]
#  [ 0.74300376]
#  [ 0.76346168]
#  [ 0.7790466 ]
#  [ 0.79087752]
#  [ 0.80350556]
#  [ 0.80828648]
#  [ 0.79292852]
#  [ 0.76224256]
#  [ 0.74584896]
#  [ 0.69965048]
#  [ 0.62863944]
#  [ 0.56313196]
#  [ 0.51458764]
#  [ 0.48358364]
#  [ 0.4636768 ]
#  [ 0.45332588]
#  [ 0.45689548]
#  [ 0.48163532]
#  [ 0.52639424]
#  [ 0.5849152 ]
#  [ 0.62646816]
#  [ 0.65840924]
#  [ 0.69077436]
#  [ 0.71999364]
#  [ 0.74517172]
#  [ 0.77446292]
#  [ 0.79652672]
#  [ 0.81475692]
#  [ 0.82674572]
#  [ 0.82850092]
#  [ 0.80800996]
#  [ 0.7803856 ]
#  [ 0.76731672]
#  [ 0.72277948]
#  [ 0.656405  ]
#  [ 0.59212004]
#  [ 0.54409884]
#  [ 0.51326788]
#  [ 0.4945412 ]
#  [ 0.4871234 ]
#  [ 0.49421312]
#  [ 0.52743096]
#  [ 0.58174884]
#  [ 0.64089512]
#  [ 0.68363628]
#  [ 0.7112112 ]
#  [ 0.73154084]
#  [ 0.74236344]
#  [ 0.74476576]
#  [ 0.74965096]
#  [ 0.7564156 ]
#  [ 0.76911176]
#  [ 0.78519292]
#  [ 0.79610172]
#  [ 0.79411564]
#  [ 0.7866516 ]
#  [ 0.7928522 ]
#  [ 0.75952096]
#  [ 0.70134484]
#  [ 0.64248468]
#  [ 0.59873568]
#  [ 0.56873444]
#  [ 0.55144984]
#  [ 0.54359716]
#  [ 0.55039996]
#  [ 0.58290008]
#  [ 0.63632788]
#  [ 0.70566444]
#  [ 0.76302248]
#  [ 0.810348  ]
#  [ 0.8556134 ]
#  [ 0.89629368]
#  [ 0.92925412]
#  [ 0.96108092]
#  [ 0.97492864]
#  [ 0.98027296]
#  [ 0.987154  ]
#  [ 0.98453932]
#  [ 0.96386028]
#  [ 0.94427004]
#  [ 0.93205924]
#  [ 0.87970684]
#  [ 0.80367244]
#  [ 0.73110864]
#  [ 0.67587636]
#  [ 0.63698252]
#  [ 0.6123186 ]
#  [ 0.59879844]
#  [ 0.60072964]
#  [ 0.62728216]
#  [ 0.67468724]
#  [ 0.73713784]
#  [ 0.79353084]
#  [ 0.84504708]
#  [ 0.89589992]
#  [ 0.93947188]
#  [ 0.970653  ]
#  [ 0.9934394 ]
#  [ 1.00562804]
#  [ 1.00468612]
#  [ 0.98830184]
#  [ 0.96336076]
#  [ 0.92942608]
#  [ 0.90120288]
#  [ 0.88396412]
#  [ 0.83470572]
#  [ 0.77060668]
#  [ 0.70620812]
#  [ 0.65490204]
#  [ 0.6189662 ]
#  [ 0.59490776]
#  [ 0.5786182 ]
#  [ 0.5685182 ]
#  [ 0.56870144]
#  [ 0.58189176]
#  [ 0.62045952]
#  [ 0.67083916]
#  [ 0.7161366 ]
#  [ 0.75373744]
#  [ 0.78050596]
#  [ 0.79896592]
#  [ 0.80949464]
#  [ 0.8163348 ]
#  [ 0.821509  ]
#  [ 0.8240218 ]
#  [ 0.81765304]
#  [ 0.80024584]
#  [ 0.78356084]
#  [ 0.77576616]
#  [ 0.73691952]
#  [ 0.6800608 ]
#  [ 0.62441988]
#  [ 0.57907372]
#  [ 0.54806172]
#  [ 0.52743984]
#  [ 0.51764112]
#  [ 0.51429772]
#  [ 0.51913792]
#  [ 0.53075356]
#  [ 0.570662  ]
#  [ 0.63185796]
#  [ 0.70196712]
#  [ 0.76922108]
#  [ 0.82241204]
#  [ 0.86115268]
#  [ 0.88727852]
#  [ 0.9041648 ]
#  [ 0.92042372]
#  [ 0.93608908]
#  [ 0.94719636]
#  [ 0.93444732]
#  [ 0.91074324]
#  [ 0.8957456 ]
#  [ 0.84363176]
#  [ 0.77457136]
#  [ 0.70619808]
#  [ 0.65338076]
#  [ 0.61736408]
#  [ 0.59114868]
#  [ 0.57513292]
#  [ 0.57584932]
#  [ 0.59963536]
#  [ 0.64250992]
#  [ 0.70048828]
#  [ 0.74740604]
#  [ 0.7870206 ]
#  [ 0.82292428]
#  [ 0.85060232]
#  [ 0.87134616]
#  [ 0.89385588]
#  [ 0.90870512]
#  [ 0.91711308]
#  [ 0.92202488]
#  [ 0.91530952]
#  [ 0.88954412]
#  [ 0.85716708]
#  [ 0.83904192]
#  [ 0.78200124]
#  [ 0.70713776]
#  [ 0.63635212]
#  [ 0.58341712]
#  [ 0.54921268]
#  [ 0.52677868]
#  [ 0.51574392]
#  [ 0.52033752]
#  [ 0.54908232]
#  [ 0.59731612]
#  [ 0.65167156]
#  [ 0.69326376]
#  [ 0.7257168 ]
#  [ 0.75957148]
#  [ 0.79262752]
#  [ 0.81932796]
#  [ 0.8428104 ]
#  [ 0.84999764]
#  [ 0.84970112]
#  [ 0.85190776]
#  [ 0.85480072]
#  [ 0.84376968]
#  [ 0.83370176]
#  [ 0.83054336]
#  [ 0.78830388]
#  [ 0.72791756]
#  [ 0.67307272]
#  [ 0.633236  ]
#  [ 0.60974048]
#  [ 0.5956132 ]
#  [ 0.58998936]
#  [ 0.59780944]
#  [ 0.62919772]
#  [ 0.67769388]
#  [ 0.73115588]
#  [ 0.7624536 ]
#  [ 0.77748024]
#  [ 0.79740748]
#  [ 0.808235  ]
#  [ 0.81107788]
#  [ 0.81936892]
#  [ 0.82639476]
#  [ 0.82996332]
#  [ 0.83063152]
#  [ 0.82143576]
#  [ 0.79372168]
#  [ 0.77026432]
#  [ 0.76276496]
#  [ 0.71706844]
#  [ 0.6504506 ]
#  [ 0.5875012 ]
#  [ 0.53938208]
#  [ 0.50826048]
#  [ 0.4894202 ]
#  [ 0.48115516]
#  [ 0.48704464]
#  [ 0.51555764]
#  [ 0.56493096]
#  [ 0.61429476]
#  [ 0.64821988]
#  [ 0.68201692]
#  [ 0.72267712]
#  [ 0.75661464]
#  [ 0.78686904]
#  [ 0.81956356]
#  [ 0.84445404]
#  [ 0.85979168]
#  [ 0.8702224 ]
#  [ 0.8716366 ]
#  [ 0.85222448]
#  [ 0.82697692]
#  [ 0.81789316]
#  [ 0.77174264]
#  [ 0.70376744]
#  [ 0.6367192 ]
#  [ 0.58634084]
#  [ 0.55205816]
#  [ 0.53015904]
#  [ 0.518695  ]
#  [ 0.52082296]
#  [ 0.54648032]
#  [ 0.59051256]
#  [ 0.646607  ]
#  [ 0.69231928]
#  [ 0.72825164]
#  [ 0.7615826 ]
#  [ 0.78972772]
#  [ 0.80888856]
#  [ 0.82782068]
#  [ 0.83974068]
#  [ 0.84697524]
#  [ 0.84888656]
#  [ 0.83702508]
#  [ 0.80698592]
#  [ 0.77535736]
#  [ 0.76131028]
#  [ 0.71746128]
#  [ 0.65830416]
#  [ 0.59678764]
#  [ 0.54835356]
#  [ 0.5153906 ]
#  [ 0.4934174 ]
#  [ 0.47964648]
#  [ 0.47542704]
#  [ 0.48272636]
#  [ 0.49724692]
#  [ 0.53541672]
#  [ 0.5834308 ]
#  [ 0.62593308]
#  [ 0.66485856]
#  [ 0.69423708]
#  [ 0.71410648]
#  [ 0.72215048]
#  [ 0.72741964]
#  [ 0.7340838 ]
#  [ 0.74089804]
#  [ 0.74379212]
#  [ 0.72657068]
#  [ 0.70519168]
#  [ 0.7004978 ]
#  [ 0.66704088]
#  [ 0.61861452]
#  [ 0.56904732]
#  [ 0.52765896]
#  [ 0.50019004]
#  [ 0.48215324]
#  [ 0.47100836]
#  [ 0.46718044]
#  [ 0.47116272]
#  [ 0.47906884]
#  [ 0.51187444]
#  [ 0.55802416]
#  [ 0.59953024]
#  [ 0.633783  ]
#  [ 0.6639762 ]
#  [ 0.68802632]
#  [ 0.70554948]
#  [ 0.72159504]
#  [ 0.73660356]
#  [ 0.74744532]
#  [ 0.75184756]
#  [ 0.74262548]
#  [ 0.73858152]
#  [ 0.73782664]
#  [ 0.70258684]
#  [ 0.65099728]
#  [ 0.59993092]
#  [ 0.56166712]
#  [ 0.53543356]
#  [ 0.51808876]
#  [ 0.5091738 ]
#  [ 0.50930136]
#  [ 0.53396616]
#  [ 0.57361968]
#  [ 0.62064872]
#  [ 0.65820232]
#  [ 0.6839694 ]
#  [ 0.6997512 ]
#  [ 0.70950736]
#  [ 0.71376568]
#  [ 0.716986  ]
#  [ 0.71743952]
#  [ 0.71831616]
#  [ 0.71801192]
#  [ 0.71065312]
#  [ 0.68573776]
#  [ 0.6612584 ]
#  [ 0.65119824]
#  [ 0.60492312]
#  [ 0.54555568]
#  [ 0.4895358 ]
#  [ 0.45073584]
#  [ 0.4283498 ]
#  [ 0.41469228]
#  [ 0.40860552]
#  [ 0.4159504 ]
#  [ 0.4436426 ]
#  [ 0.48731304]
#  [ 0.53626816]
#  [ 0.56994304]
#  [ 0.59280116]
#  [ 0.61352824]
#  [ 0.62868048]
#  [ 0.64001   ]
#  [ 0.65666968]
#  [ 0.66919772]
#  [ 0.68078928]
#  [ 0.6944128 ]
#  [ 0.7009298 ]
#  [ 0.68831396]
#  [ 0.67429888]
#  [ 0.66883412]
#  [ 0.62607192]
#  [ 0.56810056]
#  [ 0.51285116]
#  [ 0.47321956]
#  [ 0.449367  ]
#  [ 0.4348232 ]
#  [ 0.42814452]
#  [ 0.43559716]
#  [ 0.46534868]
#  [ 0.51035048]
#  [ 0.56185948]
#  [ 0.60316208]
#  [ 0.63761572]
#  [ 0.67051456]
#  [ 0.69940448]
#  [ 0.72505324]
#  [ 0.7522682 ]
#  [ 0.77502856]
#  [ 0.7927888 ]
#  [ 0.80743856]
#  [ 0.80675036]
#  [ 0.784714  ]
#  [ 0.76752032]
#  [ 0.758078  ]
#  [ 0.70795056]
#  [ 0.641455  ]
#  [ 0.57787996]
#  [ 0.53067248]
#  [ 0.501537  ]
#  [ 0.48320132]
#  [ 0.47516948]
#  [ 0.48079028]
#  [ 0.51124968]
#  [ 0.55777816]
#  [ 0.61470124]
#  [ 0.65998924]
#  [ 0.6973184 ]
#  [ 0.7326106 ]
#  [ 0.76394732]
#  [ 0.78948552]
#  [ 0.81141452]
#  [ 0.82107344]
#  [ 0.82459344]
#  [ 0.82977772]
#  [ 0.82066004]
#  [ 0.7973226 ]
#  [ 0.78913636]
#  [ 0.7806292 ]
#  [ 0.73793664]
#  [ 0.67693008]
#  [ 0.61645296]
#  [ 0.5716998 ]
#  [ 0.54248416]
#  [ 0.52528932]
#  [ 0.51767692]
#  [ 0.52418064]
#  [ 0.554664  ]
#  [ 0.60671772]
#  [ 0.666464  ]
#  [ 0.71557404]
#  [ 0.75369176]
#  [ 0.78901432]
#  [ 0.82227636]
#  [ 0.85180448]
#  [ 0.87655036]
#  [ 0.890422  ]
#  [ 0.90440188]
#  [ 0.91234576]
#  [ 0.90445388]
#  [ 0.87232   ]
#  [ 0.84002272]
#  [ 0.81782128]
#  [ 0.76423312]
#  [ 0.69684044]
#  [ 0.62946776]
#  [ 0.57562268]
#  [ 0.53773044]
#  [ 0.51111592]
#  [ 0.4928292 ]
#  [ 0.4843436 ]
#  [ 0.48807812]
#  [ 0.49986924]
#  [ 0.5381912 ]
#  [ 0.58932584]
#  [ 0.6357264 ]
#  [ 0.67332064]
#  [ 0.70202556]
#  [ 0.72471156]
#  [ 0.73981552]
#  [ 0.751078  ]
#  [ 0.7613622 ]
#  [ 0.76770752]
#  [ 0.76597644]
#  [ 0.74416272]
#  [ 0.72349596]
#  [ 0.711934  ]
#  [ 0.67281968]
#  [ 0.62099372]
#  [ 0.56807772]
#  [ 0.52596536]
#  [ 0.49537024]
#  [ 0.47485904]
#  [ 0.46157684]
#  [ 0.45519248]
#  [ 0.45712544]
#  [ 0.46322256]
#  [ 0.49385024]
#  [ 0.54304964]
#  [ 0.58541916]
#  [ 0.62155084]
#  [ 0.65244144]
#  [ 0.6797488 ]
#  [ 0.70194784]
#  [ 0.72232032]
#  [ 0.74046444]
#  [ 0.75527408]
#  [ 0.76193592]
#  [ 0.74713724]
#  [ 0.73328152]
#  [ 0.7231118 ]
#  [ 0.67797   ]
#  [ 0.61943964]
#  [ 0.56468556]
#  [ 0.52502024]
#  [ 0.50013936]
#  [ 0.48680068]
#  [ 0.48255836]
#  [ 0.49409788]
#  [ 0.53254956]
#  [ 0.588774  ]
#  [ 0.64290408]
#  [ 0.68217304]
#  [ 0.71557756]
#  [ 0.7553532 ]
#  [ 0.7883494 ]
#  [ 0.81067632]
#  [ 0.83050392]
#  [ 0.84198944]
#  [ 0.847325  ]
#  [ 0.8484446 ]
#  [ 0.83972024]
#  [ 0.80960152]
#  [ 0.78104988]
#  [ 0.75838968]
#  [ 0.69651888]
#  [ 0.62194328]
#  [ 0.55489728]
#  [ 0.50779676]
#  [ 0.47691452]
#  [ 0.45675592]
#  [ 0.44659712]
#  [ 0.4508632 ]
#  [ 0.4793486 ]
#  [ 0.52753132]
#  [ 0.57414736]
#  [ 0.60938116]
#  [ 0.63808456]
#  [ 0.66420216]
#  [ 0.68564644]
#  [ 0.70495484]
#  [ 0.72811248]
#  [ 0.74498508]
#  [ 0.75781272]
#  [ 0.7699124 ]
#  [ 0.77084108]
#  [ 0.75361976]
#  [ 0.74286156]
#  [ 0.72822212]
#  [ 0.67518636]
#  [ 0.61018304]
#  [ 0.55081196]
#  [ 0.50914032]
#  [ 0.48262376]
#  [ 0.46657396]
#  [ 0.46027908]
#  [ 0.46893376]
#  [ 0.50680452]
#  [ 0.56862272]
#  [ 0.61705748]
#  [ 0.65234116]
#  [ 0.68192928]
#  [ 0.7086584 ]
#  [ 0.7277596 ]
#  [ 0.74110092]
#  [ 0.75264128]
#  [ 0.75467176]
#  [ 0.75852872]
#  [ 0.76490432]
#  [ 0.76593828]
#  [ 0.75913292]
#  [ 0.76808968]
#  [ 0.75854976]
#  [ 0.71185484]
#  [ 0.64936732]
#  [ 0.5907738 ]]

# %%
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    # Create a summary to monitor cost function
    #tf.scalar_summary("loss", cost)
    # Merge all summaries to a single operator
    #merged_summary_op = tf.merge_all_summaries()

    # tensorboard info.# Set logs writer into folder /tmp/tensorflow_logs
    #summary_writer = tf.train.SummaryWriter('/tmp/tensorflow_logs', graph_def=sess.graph_def)

    #initialize all variables in the model
    sess.run(init)
    for k in range(num_epoches):
        #Generate Data for each epoch
        #What this does is it creates a list of of elements of length seq_len, each of size [batch_size,input_size]
        #this is required to feed data into rnn.rnn
        #print traindays
        X,Y = train_data_gen()
        X = X.reshape(train_batch_size,n_steps,feature_size)


        #Create the dictionary of inputs to feed into sess.run
        #if k < 0:
        #    sess.run(optimizer2,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})
        #else:
        sess.run(optimizer,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})   
        #perform an update on the parameters
        #cost1 = sess.run(cost,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #print "Iter " + str(k) + ", Minibatch Loss ---- Train = " + str(cost1)
        # Write logs at every iteration
        #if k>50 & k%10 == 0:
        #    summary_str = sess.run(merged_summary_op, feed_dict={x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #    summary_writer.add_summary(summary_str, k)

        #if k % 10 == 0:
        if k % 10 == 0:
            #print test_x
            output_tmp_ex = sess.run(pred,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )  
            print "Iter " + str(k) + " ---- Process: " + "{:.2f}".format(100*float(k)/float(num_epoches)) + "%"
            outp_test = output_tmp_ex[:,0]
            #print outp_test[0:3]
            outlist[kind,:] = outp_test.copy().T
            kind = kind + 1
        #    print ktmp
        #if k % 10 == 0:
        #    output_tmp_ex = sess.run(pred,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #    print "Iter " + str(k) + ", Minibatch Loss ---- Train = " + "{:.6f}".format(cost) # + "; Test = " + "{:.6f}".format(loss2)
    #print "haha{}".format(outp)
        #    ktmp = np.corrcoef(output_tmp_ex.T,test_y.T)[0,1]
        #    accuracy1.append(ktmp)
        #    print ktmp
# Out:
# Iter 0 ---- Process: 0.00%
# Iter 10 ---- Process: 0.02%
# Iter 20 ---- Process: 0.04%
# Iter 30 ---- Process: 0.06%
# Iter 40 ---- Process: 0.08%
# Iter 50 ---- Process: 0.10%
# Iter 60 ---- Process: 0.12%
# Iter 70 ---- Process: 0.14%
# Iter 80 ---- Process: 0.16%
# Iter 90 ---- Process: 0.18%
# Iter 100 ---- Process: 0.20%
# Iter 110 ---- Process: 0.22%
# Iter 120 ---- Process: 0.24%
# Iter 130 ---- Process: 0.26%
# Iter 140 ---- Process: 0.28%
# Iter 150 ---- Process: 0.30%
# Iter 160 ---- Process: 0.32%
# Iter 170 ---- Process: 0.34%
# Iter 180 ---- Process: 0.36%
# Iter 190 ---- Process: 0.38%
# Iter 200 ---- Process: 0.40%
# Iter 210 ---- Process: 0.42%
# Iter 220 ---- Process: 0.44%
# Iter 230 ---- Process: 0.46%
# Iter 240 ---- Process: 0.48%
# Iter 250 ---- Process: 0.50%
# Iter 260 ---- Process: 0.52%
# Iter 270 ---- Process: 0.54%
# Iter 280 ---- Process: 0.56%
# Iter 290 ---- Process: 0.58%
# Iter 300 ---- Process: 0.60%
# Iter 310 ---- Process: 0.62%
# Iter 320 ---- Process: 0.64%
# Iter 330 ---- Process: 0.66%
# Iter 340 ---- Process: 0.68%
# Iter 350 ---- Process: 0.70%
# Iter 360 ---- Process: 0.72%
# Iter 370 ---- Process: 0.74%
# Iter 380 ---- Process: 0.76%
# Iter 390 ---- Process: 0.78%
# Iter 400 ---- Process: 0.80%
# Iter 410 ---- Process: 0.82%
# Iter 420 ---- Process: 0.84%
# Iter 430 ---- Process: 0.86%
# Iter 440 ---- Process: 0.88%
# Iter 450 ---- Process: 0.90%
# Iter 460 ---- Process: 0.92%
# Iter 470 ---- Process: 0.94%
# Iter 480 ---- Process: 0.96%
# Iter 490 ---- Process: 0.98%
# Iter 500 ---- Process: 1.00%
# Iter 510 ---- Process: 1.02%
# Iter 520 ---- Process: 1.04%
# Iter 530 ---- Process: 1.06%
# Iter 540 ---- Process: 1.08%
# Iter 550 ---- Process: 1.10%
# Iter 560 ---- Process: 1.12%
# Iter 570 ---- Process: 1.14%
# Iter 580 ---- Process: 1.16%
# Iter 590 ---- Process: 1.18%
# Iter 600 ---- Process: 1.20%
# Iter 610 ---- Process: 1.22%
# Iter 620 ---- Process: 1.24%
# Iter 630 ---- Process: 1.26%
# Iter 640 ---- Process: 1.28%
# Iter 650 ---- Process: 1.30%
# Iter 660 ---- Process: 1.32%
# Iter 670 ---- Process: 1.34%
# Iter 680 ---- Process: 1.36%
# Iter 690 ---- Process: 1.38%
# Iter 700 ---- Process: 1.40%
# Iter 710 ---- Process: 1.42%
# Iter 720 ---- Process: 1.44%
# Iter 730 ---- Process: 1.46%
# Iter 740 ---- Process: 1.48%
# Iter 750 ---- Process: 1.50%
# Iter 760 ---- Process: 1.52%
# Iter 770 ---- Process: 1.54%
# Iter 780 ---- Process: 1.56%
# Iter 790 ---- Process: 1.58%
# Iter 800 ---- Process: 1.60%
# Iter 810 ---- Process: 1.62%
# Iter 820 ---- Process: 1.64%
# Iter 830 ---- Process: 1.66%
# Iter 840 ---- Process: 1.68%
# Iter 850 ---- Process: 1.70%
# Iter 860 ---- Process: 1.72%
# Iter 870 ---- Process: 1.74%
# Iter 880 ---- Process: 1.76%
# Iter 890 ---- Process: 1.78%
# Iter 900 ---- Process: 1.80%
# Iter 910 ---- Process: 1.82%
# Iter 920 ---- Process: 1.84%
# Iter 930 ---- Process: 1.86%
# Iter 940 ---- Process: 1.88%
# Iter 950 ---- Process: 1.90%
# Iter 960 ---- Process: 1.92%
# Iter 970 ---- Process: 1.94%
# Iter 980 ---- Process: 1.96%
# Iter 990 ---- Process: 1.98%
# Iter 1000 ---- Process: 2.00%
# Iter 1010 ---- Process: 2.02%
# Iter 1020 ---- Process: 2.04%
# Iter 1030 ---- Process: 2.06%
# Iter 1040 ---- Process: 2.08%
# Iter 1050 ---- Process: 2.10%
# Iter 1060 ---- Process: 2.12%
# Iter 1070 ---- Process: 2.14%
# Iter 1080 ---- Process: 2.16%
# Iter 1090 ---- Process: 2.18%
# Iter 1100 ---- Process: 2.20%
# Iter 1110 ---- Process: 2.22%
# Iter 1120 ---- Process: 2.24%
# Iter 1130 ---- Process: 2.26%
# Iter 1140 ---- Process: 2.28%
# Iter 1150 ---- Process: 2.30%
# Iter 1160 ---- Process: 2.32%
# Iter 1170 ---- Process: 2.34%
# Iter 1180 ---- Process: 2.36%
# Iter 1190 ---- Process: 2.38%
# Iter 1200 ---- Process: 2.40%
# Iter 1210 ---- Process: 2.42%
# Iter 1220 ---- Process: 2.44%
# Iter 1230 ---- Process: 2.46%
# Iter 1240 ---- Process: 2.48%
# Iter 1250 ---- Process: 2.50%
# Iter 1260 ---- Process: 2.52%
# Iter 1270 ---- Process: 2.54%
# Iter 1280 ---- Process: 2.56%
# Iter 1290 ---- Process: 2.58%
# Iter 1300 ---- Process: 2.60%
# Iter 1310 ---- Process: 2.62%
# Iter 1320 ---- Process: 2.64%
# Iter 1330 ---- Process: 2.66%
# Iter 1340 ---- Process: 2.68%
# Iter 1350 ---- Process: 2.70%
# Iter 1360 ---- Process: 2.72%
# Iter 1370 ---- Process: 2.74%
# Iter 1380 ---- Process: 2.76%
# Iter 1390 ---- Process: 2.78%
# Iter 1400 ---- Process: 2.80%
# Iter 1410 ---- Process: 2.82%
# Iter 1420 ---- Process: 2.84%
# Iter 1430 ---- Process: 2.86%
# Iter 1440 ---- Process: 2.88%
# Iter 1450 ---- Process: 2.90%
# Iter 1460 ---- Process: 2.92%
# Iter 1470 ---- Process: 2.94%
# Iter 1480 ---- Process: 2.96%
# Iter 1490 ---- Process: 2.98%
# Iter 1500 ---- Process: 3.00%
# Iter 1510 ---- Process: 3.02%
# Iter 1520 ---- Process: 3.04%
# Iter 1530 ---- Process: 3.06%
# Iter 1540 ---- Process: 3.08%
# Iter 1550 ---- Process: 3.10%
# Iter 1560 ---- Process: 3.12%
# Iter 1570 ---- Process: 3.14%
# Iter 1580 ---- Process: 3.16%
# Iter 1590 ---- Process: 3.18%
# Iter 1600 ---- Process: 3.20%
# Iter 1610 ---- Process: 3.22%
# Iter 1620 ---- Process: 3.24%
# Iter 1630 ---- Process: 3.26%
# Iter 1640 ---- Process: 3.28%
# Iter 1650 ---- Process: 3.30%
# Iter 1660 ---- Process: 3.32%
# Iter 1670 ---- Process: 3.34%
# Iter 1680 ---- Process: 3.36%
# Iter 1690 ---- Process: 3.38%
# Iter 1700 ---- Process: 3.40%
# Iter 1710 ---- Process: 3.42%
# Iter 1720 ---- Process: 3.44%
# Iter 1730 ---- Process: 3.46%
# Iter 1740 ---- Process: 3.48%
# Iter 1750 ---- Process: 3.50%
# Iter 1760 ---- Process: 3.52%
# Iter 1770 ---- Process: 3.54%
# Iter 1780 ---- Process: 3.56%
# Iter 1790 ---- Process: 3.58%
# Iter 1800 ---- Process: 3.60%
# Iter 1810 ---- Process: 3.62%
# Iter 1820 ---- Process: 3.64%
# Iter 1830 ---- Process: 3.66%
# Iter 1840 ---- Process: 3.68%
# Iter 1850 ---- Process: 3.70%
# Iter 1860 ---- Process: 3.72%
# Iter 1870 ---- Process: 3.74%
# Iter 1880 ---- Process: 3.76%
# Iter 1890 ---- Process: 3.78%
# Iter 1900 ---- Process: 3.80%
# Iter 1910 ---- Process: 3.82%
# Iter 1920 ---- Process: 3.84%
# Iter 1930 ---- Process: 3.86%
# Iter 1940 ---- Process: 3.88%
# Iter 1950 ---- Process: 3.90%
# Iter 1960 ---- Process: 3.92%
# Iter 1970 ---- Process: 3.94%
# Iter 1980 ---- Process: 3.96%
# Iter 1990 ---- Process: 3.98%
# Iter 2000 ---- Process: 4.00%
# Iter 2010 ---- Process: 4.02%
# Iter 2020 ---- Process: 4.04%
# Iter 2030 ---- Process: 4.06%
# Iter 2040 ---- Process: 4.08%
# Iter 2050 ---- Process: 4.10%
# Iter 2060 ---- Process: 4.12%
# Iter 2070 ---- Process: 4.14%
# Iter 2080 ---- Process: 4.16%
# Iter 2090 ---- Process: 4.18%
# Iter 2100 ---- Process: 4.20%
# Iter 2110 ---- Process: 4.22%
# Iter 2120 ---- Process: 4.24%
# Iter 2130 ---- Process: 4.26%
# Iter 2140 ---- Process: 4.28%
# Iter 2150 ---- Process: 4.30%
# Iter 2160 ---- Process: 4.32%
# Iter 2170 ---- Process: 4.34%
# Iter 2180 ---- Process: 4.36%
# Iter 2190 ---- Process: 4.38%
# Iter 2200 ---- Process: 4.40%
# Iter 2210 ---- Process: 4.42%
# Iter 2220 ---- Process: 4.44%
# Iter 2230 ---- Process: 4.46%
# Iter 2240 ---- Process: 4.48%
# Iter 2250 ---- Process: 4.50%
# Iter 2260 ---- Process: 4.52%
# Iter 2270 ---- Process: 4.54%
# Iter 2280 ---- Process: 4.56%
# Iter 2290 ---- Process: 4.58%
# Iter 2300 ---- Process: 4.60%
# Iter 2310 ---- Process: 4.62%
# Iter 2320 ---- Process: 4.64%
# Iter 2330 ---- Process: 4.66%
# Iter 2340 ---- Process: 4.68%
# Iter 2350 ---- Process: 4.70%
# Iter 2360 ---- Process: 4.72%
# Iter 2370 ---- Process: 4.74%
# Iter 2380 ---- Process: 4.76%
# Iter 2390 ---- Process: 4.78%
# Iter 2400 ---- Process: 4.80%
# Iter 2410 ---- Process: 4.82%
# Iter 2420 ---- Process: 4.84%
# Iter 2430 ---- Process: 4.86%
# Iter 2440 ---- Process: 4.88%
# Iter 2450 ---- Process: 4.90%
# Iter 2460 ---- Process: 4.92%
# Iter 2470 ---- Process: 4.94%
# Iter 2480 ---- Process: 4.96%
# Iter 2490 ---- Process: 4.98%
# Iter 2500 ---- Process: 5.00%
# Iter 2510 ---- Process: 5.02%
# Iter 2520 ---- Process: 5.04%
# Iter 2530 ---- Process: 5.06%
# Iter 2540 ---- Process: 5.08%
# Iter 2550 ---- Process: 5.10%
# Iter 2560 ---- Process: 5.12%
# Iter 2570 ---- Process: 5.14%
# Iter 2580 ---- Process: 5.16%
# Iter 2590 ---- Process: 5.18%
# Iter 2600 ---- Process: 5.20%
# Iter 2610 ---- Process: 5.22%
# Iter 2620 ---- Process: 5.24%
# Iter 2630 ---- Process: 5.26%
# Iter 2640 ---- Process: 5.28%
# Iter 2650 ---- Process: 5.30%
# Iter 2660 ---- Process: 5.32%
# Iter 2670 ---- Process: 5.34%
# Iter 2680 ---- Process: 5.36%
# Iter 2690 ---- Process: 5.38%
# Iter 2700 ---- Process: 5.40%
# Iter 2710 ---- Process: 5.42%
# Iter 2720 ---- Process: 5.44%
# Iter 2730 ---- Process: 5.46%
# Iter 2740 ---- Process: 5.48%
# Iter 2750 ---- Process: 5.50%
# Iter 2760 ---- Process: 5.52%
# Iter 2770 ---- Process: 5.54%
# Iter 2780 ---- Process: 5.56%
# Iter 2790 ---- Process: 5.58%
# Iter 2800 ---- Process: 5.60%
# Iter 2810 ---- Process: 5.62%
# Iter 2820 ---- Process: 5.64%
# Iter 2830 ---- Process: 5.66%
# Iter 2840 ---- Process: 5.68%
# Iter 2850 ---- Process: 5.70%
# Iter 2860 ---- Process: 5.72%
# Iter 2870 ---- Process: 5.74%
# Iter 2880 ---- Process: 5.76%
# Iter 2890 ---- Process: 5.78%
# Iter 2900 ---- Process: 5.80%
# Iter 2910 ---- Process: 5.82%
# Iter 2920 ---- Process: 5.84%
# Iter 2930 ---- Process: 5.86%
# Iter 2940 ---- Process: 5.88%
# Iter 2950 ---- Process: 5.90%
# Iter 2960 ---- Process: 5.92%
# Iter 2970 ---- Process: 5.94%
# Iter 2980 ---- Process: 5.96%
# Iter 2990 ---- Process: 5.98%
# Iter 3000 ---- Process: 6.00%
# Iter 3010 ---- Process: 6.02%
# Iter 3020 ---- Process: 6.04%
# Iter 3030 ---- Process: 6.06%
# Iter 3040 ---- Process: 6.08%
# Iter 3050 ---- Process: 6.10%
# Iter 3060 ---- Process: 6.12%
# Iter 3070 ---- Process: 6.14%
# Iter 3080 ---- Process: 6.16%
# Iter 3090 ---- Process: 6.18%
# Iter 3100 ---- Process: 6.20%
# Iter 3110 ---- Process: 6.22%
# Iter 3120 ---- Process: 6.24%
# Iter 3130 ---- Process: 6.26%
# Iter 3140 ---- Process: 6.28%
# Iter 3150 ---- Process: 6.30%
# Iter 3160 ---- Process: 6.32%
# Iter 3170 ---- Process: 6.34%
# Iter 3180 ---- Process: 6.36%
# Iter 3190 ---- Process: 6.38%
# Iter 3200 ---- Process: 6.40%
# Iter 3210 ---- Process: 6.42%
# Iter 3220 ---- Process: 6.44%
# Iter 3230 ---- Process: 6.46%
# Iter 3240 ---- Process: 6.48%
# Iter 3250 ---- Process: 6.50%
# Iter 3260 ---- Process: 6.52%
# Iter 3270 ---- Process: 6.54%
# Iter 3280 ---- Process: 6.56%
# Iter 3290 ---- Process: 6.58%
# Iter 3300 ---- Process: 6.60%
# Iter 3310 ---- Process: 6.62%
# Iter 3320 ---- Process: 6.64%
# Iter 3330 ---- Process: 6.66%
# Iter 3340 ---- Process: 6.68%
# Iter 3350 ---- Process: 6.70%
# Iter 3360 ---- Process: 6.72%
# Iter 3370 ---- Process: 6.74%
# Iter 3380 ---- Process: 6.76%
# Iter 3390 ---- Process: 6.78%
# Iter 3400 ---- Process: 6.80%
# Iter 3410 ---- Process: 6.82%
# Iter 3420 ---- Process: 6.84%
# Iter 3430 ---- Process: 6.86%
# Iter 3440 ---- Process: 6.88%
# Iter 3450 ---- Process: 6.90%
# Iter 3460 ---- Process: 6.92%
# Iter 3470 ---- Process: 6.94%
# Iter 3480 ---- Process: 6.96%
# Iter 3490 ---- Process: 6.98%
# Iter 3500 ---- Process: 7.00%
# Iter 3510 ---- Process: 7.02%
# Iter 3520 ---- Process: 7.04%
# Iter 3530 ---- Process: 7.06%
# Iter 3540 ---- Process: 7.08%
# Iter 3550 ---- Process: 7.10%
# Iter 3560 ---- Process: 7.12%
# Iter 3570 ---- Process: 7.14%
# Iter 3580 ---- Process: 7.16%
# Iter 3590 ---- Process: 7.18%
# Iter 3600 ---- Process: 7.20%
# Iter 3610 ---- Process: 7.22%
# Iter 3620 ---- Process: 7.24%
# Iter 3630 ---- Process: 7.26%
# Iter 3640 ---- Process: 7.28%
# Iter 3650 ---- Process: 7.30%
# Iter 3660 ---- Process: 7.32%
# Iter 3670 ---- Process: 7.34%
# Iter 3680 ---- Process: 7.36%
# Iter 3690 ---- Process: 7.38%
# Iter 3700 ---- Process: 7.40%
# Iter 3710 ---- Process: 7.42%
# Iter 3720 ---- Process: 7.44%
# Iter 3730 ---- Process: 7.46%
# Iter 3740 ---- Process: 7.48%
# Iter 3750 ---- Process: 7.50%
# Iter 3760 ---- Process: 7.52%
# Iter 3770 ---- Process: 7.54%
# Iter 3780 ---- Process: 7.56%
# Iter 3790 ---- Process: 7.58%
# Iter 3800 ---- Process: 7.60%
# Iter 3810 ---- Process: 7.62%
# Iter 3820 ---- Process: 7.64%
# Iter 3830 ---- Process: 7.66%
# Iter 3840 ---- Process: 7.68%
# Iter 3850 ---- Process: 7.70%
# Iter 3860 ---- Process: 7.72%
# Iter 3870 ---- Process: 7.74%
# Iter 3880 ---- Process: 7.76%
# Iter 3890 ---- Process: 7.78%
# Iter 3900 ---- Process: 7.80%
# Iter 3910 ---- Process: 7.82%
# Iter 3920 ---- Process: 7.84%
# Iter 3930 ---- Process: 7.86%
# Iter 3940 ---- Process: 7.88%
# Iter 3950 ---- Process: 7.90%
# Iter 3960 ---- Process: 7.92%
# Iter 3970 ---- Process: 7.94%
# Iter 3980 ---- Process: 7.96%
# Iter 3990 ---- Process: 7.98%
# Iter 4000 ---- Process: 8.00%
# Iter 4010 ---- Process: 8.02%
# Iter 4020 ---- Process: 8.04%
# Iter 4030 ---- Process: 8.06%
# Iter 4040 ---- Process: 8.08%
# Iter 4050 ---- Process: 8.10%
# Iter 4060 ---- Process: 8.12%
# Iter 4070 ---- Process: 8.14%
# Iter 4080 ---- Process: 8.16%
# Iter 4090 ---- Process: 8.18%
# Iter 4100 ---- Process: 8.20%
# Iter 4110 ---- Process: 8.22%
# Iter 4120 ---- Process: 8.24%
# Iter 4130 ---- Process: 8.26%
# Iter 4140 ---- Process: 8.28%
# Iter 4150 ---- Process: 8.30%
# Iter 4160 ---- Process: 8.32%
# Iter 4170 ---- Process: 8.34%
# Iter 4180 ---- Process: 8.36%
# Iter 4190 ---- Process: 8.38%
# Iter 4200 ---- Process: 8.40%
# Iter 4210 ---- Process: 8.42%
# Iter 4220 ---- Process: 8.44%
# Iter 4230 ---- Process: 8.46%
# Iter 4240 ---- Process: 8.48%
# Iter 4250 ---- Process: 8.50%
# Iter 4260 ---- Process: 8.52%
# Iter 4270 ---- Process: 8.54%
# Iter 4280 ---- Process: 8.56%
# Iter 4290 ---- Process: 8.58%
# Iter 4300 ---- Process: 8.60%
# Iter 4310 ---- Process: 8.62%
# Iter 4320 ---- Process: 8.64%
# Iter 4330 ---- Process: 8.66%
# Iter 4340 ---- Process: 8.68%
# Iter 4350 ---- Process: 8.70%
# Iter 4360 ---- Process: 8.72%
# Iter 4370 ---- Process: 8.74%
# Iter 4380 ---- Process: 8.76%
# Iter 4390 ---- Process: 8.78%
# Iter 4400 ---- Process: 8.80%
# Iter 4410 ---- Process: 8.82%
# Iter 4420 ---- Process: 8.84%
# Iter 4430 ---- Process: 8.86%
# Iter 4440 ---- Process: 8.88%
# Iter 4450 ---- Process: 8.90%
# Iter 4460 ---- Process: 8.92%
# Iter 4470 ---- Process: 8.94%
# Iter 4480 ---- Process: 8.96%
# Iter 4490 ---- Process: 8.98%
# Iter 4500 ---- Process: 9.00%
# Iter 4510 ---- Process: 9.02%
# Iter 4520 ---- Process: 9.04%
# Iter 4530 ---- Process: 9.06%
# Iter 4540 ---- Process: 9.08%
# Iter 4550 ---- Process: 9.10%
# Iter 4560 ---- Process: 9.12%
# Iter 4570 ---- Process: 9.14%
# Iter 4580 ---- Process: 9.16%
# Iter 4590 ---- Process: 9.18%
# Iter 4600 ---- Process: 9.20%
# Iter 4610 ---- Process: 9.22%
# Iter 4620 ---- Process: 9.24%
# Iter 4630 ---- Process: 9.26%
# Iter 4640 ---- Process: 9.28%
# Iter 4650 ---- Process: 9.30%
# Iter 4660 ---- Process: 9.32%
# Iter 4670 ---- Process: 9.34%
# Iter 4680 ---- Process: 9.36%
# Iter 4690 ---- Process: 9.38%
# Iter 4700 ---- Process: 9.40%
# Iter 4710 ---- Process: 9.42%
# Iter 4720 ---- Process: 9.44%
# Iter 4730 ---- Process: 9.46%
# Iter 4740 ---- Process: 9.48%
# Iter 4750 ---- Process: 9.50%
# Iter 4760 ---- Process: 9.52%
# Iter 4770 ---- Process: 9.54%
# Iter 4780 ---- Process: 9.56%
# Iter 4790 ---- Process: 9.58%
# Iter 4800 ---- Process: 9.60%
# Iter 4810 ---- Process: 9.62%
# Iter 4820 ---- Process: 9.64%
# Iter 4830 ---- Process: 9.66%
# Iter 4840 ---- Process: 9.68%
# Iter 4850 ---- Process: 9.70%
# Iter 4860 ---- Process: 9.72%
# Iter 4870 ---- Process: 9.74%
# Iter 4880 ---- Process: 9.76%
# Iter 4890 ---- Process: 9.78%
# Iter 4900 ---- Process: 9.80%
# Iter 4910 ---- Process: 9.82%
# Iter 4920 ---- Process: 9.84%
# Iter 4930 ---- Process: 9.86%
# Iter 4940 ---- Process: 9.88%
# Iter 4950 ---- Process: 9.90%
# Iter 4960 ---- Process: 9.92%
# Iter 4970 ---- Process: 9.94%
# Iter 4980 ---- Process: 9.96%
# Iter 4990 ---- Process: 9.98%
# Iter 5000 ---- Process: 10.00%
# Iter 5010 ---- Process: 10.02%
# Iter 5020 ---- Process: 10.04%
# Iter 5030 ---- Process: 10.06%
# Iter 5040 ---- Process: 10.08%
# Iter 5050 ---- Process: 10.10%
# Iter 5060 ---- Process: 10.12%
# Iter 5070 ---- Process: 10.14%
# Iter 5080 ---- Process: 10.16%
# Iter 5090 ---- Process: 10.18%
# Iter 5100 ---- Process: 10.20%
# Iter 5110 ---- Process: 10.22%
# Iter 5120 ---- Process: 10.24%
# Iter 5130 ---- Process: 10.26%
# Iter 5140 ---- Process: 10.28%
# Iter 5150 ---- Process: 10.30%
# Iter 5160 ---- Process: 10.32%
# Iter 5170 ---- Process: 10.34%
# Iter 5180 ---- Process: 10.36%
# Iter 5190 ---- Process: 10.38%
# Iter 5200 ---- Process: 10.40%
# Iter 5210 ---- Process: 10.42%
# Iter 5220 ---- Process: 10.44%
# Iter 5230 ---- Process: 10.46%
# Iter 5240 ---- Process: 10.48%
# Iter 5250 ---- Process: 10.50%
# Iter 5260 ---- Process: 10.52%
# Iter 5270 ---- Process: 10.54%
# Iter 5280 ---- Process: 10.56%
# Iter 5290 ---- Process: 10.58%
# Iter 5300 ---- Process: 10.60%
# Iter 5310 ---- Process: 10.62%
# Iter 5320 ---- Process: 10.64%
# Iter 5330 ---- Process: 10.66%
# Iter 5340 ---- Process: 10.68%
# Iter 5350 ---- Process: 10.70%
# Iter 5360 ---- Process: 10.72%
# Iter 5370 ---- Process: 10.74%
# Iter 5380 ---- Process: 10.76%
# Iter 5390 ---- Process: 10.78%
# Iter 5400 ---- Process: 10.80%
# Iter 5410 ---- Process: 10.82%
# Iter 5420 ---- Process: 10.84%
# Iter 5430 ---- Process: 10.86%
# Iter 5440 ---- Process: 10.88%
# Iter 5450 ---- Process: 10.90%
# Iter 5460 ---- Process: 10.92%
# Iter 5470 ---- Process: 10.94%
# Iter 5480 ---- Process: 10.96%
# Iter 5490 ---- Process: 10.98%
# Iter 5500 ---- Process: 11.00%
# Iter 5510 ---- Process: 11.02%
# Iter 5520 ---- Process: 11.04%
# Iter 5530 ---- Process: 11.06%
# Iter 5540 ---- Process: 11.08%
# Iter 5550 ---- Process: 11.10%
# Iter 5560 ---- Process: 11.12%
# Iter 5570 ---- Process: 11.14%
# Iter 5580 ---- Process: 11.16%
# Iter 5590 ---- Process: 11.18%
# Iter 5600 ---- Process: 11.20%
# Iter 5610 ---- Process: 11.22%
# Iter 5620 ---- Process: 11.24%
# Iter 5630 ---- Process: 11.26%
# Iter 5640 ---- Process: 11.28%
# Iter 5650 ---- Process: 11.30%
# Iter 5660 ---- Process: 11.32%
# Iter 5670 ---- Process: 11.34%
# Iter 5680 ---- Process: 11.36%
# Iter 5690 ---- Process: 11.38%
# Iter 5700 ---- Process: 11.40%
# Iter 5710 ---- Process: 11.42%
# Iter 5720 ---- Process: 11.44%
# Iter 5730 ---- Process: 11.46%
# Iter 5740 ---- Process: 11.48%
# Iter 5750 ---- Process: 11.50%
# Iter 5760 ---- Process: 11.52%
# Iter 5770 ---- Process: 11.54%
# Iter 5780 ---- Process: 11.56%
# Iter 5790 ---- Process: 11.58%
# Iter 5800 ---- Process: 11.60%
# Iter 5810 ---- Process: 11.62%
# Iter 5820 ---- Process: 11.64%
# Iter 5830 ---- Process: 11.66%
# Iter 5840 ---- Process: 11.68%
# Iter 5850 ---- Process: 11.70%
# Iter 5860 ---- Process: 11.72%
# Iter 5870 ---- Process: 11.74%
# Iter 5880 ---- Process: 11.76%
# Iter 5890 ---- Process: 11.78%
# Iter 5900 ---- Process: 11.80%
# Iter 5910 ---- Process: 11.82%
# Iter 5920 ---- Process: 11.84%
# Iter 5930 ---- Process: 11.86%
# Iter 5940 ---- Process: 11.88%
# Iter 5950 ---- Process: 11.90%
# Iter 5960 ---- Process: 11.92%
# Iter 5970 ---- Process: 11.94%
# Iter 5980 ---- Process: 11.96%
# Iter 5990 ---- Process: 11.98%
# Iter 6000 ---- Process: 12.00%
# Iter 6010 ---- Process: 12.02%
# Iter 6020 ---- Process: 12.04%
# Iter 6030 ---- Process: 12.06%
# Iter 6040 ---- Process: 12.08%
# Iter 6050 ---- Process: 12.10%
# Iter 6060 ---- Process: 12.12%
# Iter 6070 ---- Process: 12.14%
# Iter 6080 ---- Process: 12.16%
# Iter 6090 ---- Process: 12.18%
# Iter 6100 ---- Process: 12.20%
# Iter 6110 ---- Process: 12.22%
# Iter 6120 ---- Process: 12.24%
# Iter 6130 ---- Process: 12.26%
# Iter 6140 ---- Process: 12.28%
# Iter 6150 ---- Process: 12.30%
# Iter 6160 ---- Process: 12.32%
# Iter 6170 ---- Process: 12.34%
# Iter 6180 ---- Process: 12.36%
# Iter 6190 ---- Process: 12.38%
# Iter 6200 ---- Process: 12.40%
# Iter 6210 ---- Process: 12.42%
# Iter 6220 ---- Process: 12.44%
# Iter 6230 ---- Process: 12.46%
# Iter 6240 ---- Process: 12.48%
# Iter 6250 ---- Process: 12.50%
# Iter 6260 ---- Process: 12.52%
# Iter 6270 ---- Process: 12.54%
# Iter 6280 ---- Process: 12.56%
# Iter 6290 ---- Process: 12.58%
# Iter 6300 ---- Process: 12.60%
# Iter 6310 ---- Process: 12.62%
# Iter 6320 ---- Process: 12.64%
# Iter 6330 ---- Process: 12.66%
# Iter 6340 ---- Process: 12.68%
# Iter 6350 ---- Process: 12.70%
# Iter 6360 ---- Process: 12.72%
# Iter 6370 ---- Process: 12.74%
# Iter 6380 ---- Process: 12.76%
# Iter 6390 ---- Process: 12.78%
# Iter 6400 ---- Process: 12.80%
# Iter 6410 ---- Process: 12.82%
# Iter 6420 ---- Process: 12.84%
# Iter 6430 ---- Process: 12.86%
# Iter 6440 ---- Process: 12.88%
# Iter 6450 ---- Process: 12.90%
# Iter 6460 ---- Process: 12.92%
# Iter 6470 ---- Process: 12.94%
# Iter 6480 ---- Process: 12.96%
# Iter 6490 ---- Process: 12.98%
# Iter 6500 ---- Process: 13.00%
# Iter 6510 ---- Process: 13.02%
# Iter 6520 ---- Process: 13.04%
# Iter 6530 ---- Process: 13.06%
# Iter 6540 ---- Process: 13.08%
# Iter 6550 ---- Process: 13.10%
# Iter 6560 ---- Process: 13.12%
# Iter 6570 ---- Process: 13.14%
# Iter 6580 ---- Process: 13.16%
# Iter 6590 ---- Process: 13.18%
# Iter 6600 ---- Process: 13.20%
# Iter 6610 ---- Process: 13.22%
# Iter 6620 ---- Process: 13.24%
# Iter 6630 ---- Process: 13.26%
# Iter 6640 ---- Process: 13.28%
# Iter 6650 ---- Process: 13.30%
# Iter 6660 ---- Process: 13.32%
# Iter 6670 ---- Process: 13.34%
# Iter 6680 ---- Process: 13.36%
# Iter 6690 ---- Process: 13.38%
# Iter 6700 ---- Process: 13.40%
# Iter 6710 ---- Process: 13.42%
# Iter 6720 ---- Process: 13.44%
# Iter 6730 ---- Process: 13.46%
# Iter 6740 ---- Process: 13.48%
# Iter 6750 ---- Process: 13.50%
# Iter 6760 ---- Process: 13.52%
# Iter 6770 ---- Process: 13.54%
# Iter 6780 ---- Process: 13.56%
# Iter 6790 ---- Process: 13.58%
# Iter 6800 ---- Process: 13.60%
# Iter 6810 ---- Process: 13.62%
# Iter 6820 ---- Process: 13.64%
# Iter 6830 ---- Process: 13.66%
# Iter 6840 ---- Process: 13.68%
# Iter 6850 ---- Process: 13.70%
# Iter 6860 ---- Process: 13.72%
# Iter 6870 ---- Process: 13.74%
# Iter 6880 ---- Process: 13.76%
# Iter 6890 ---- Process: 13.78%
# Iter 6900 ---- Process: 13.80%
# Iter 6910 ---- Process: 13.82%
# Iter 6920 ---- Process: 13.84%
# Iter 6930 ---- Process: 13.86%
# Iter 6940 ---- Process: 13.88%
# Iter 6950 ---- Process: 13.90%
# Iter 6960 ---- Process: 13.92%
# Iter 6970 ---- Process: 13.94%
# Iter 6980 ---- Process: 13.96%
# Iter 6990 ---- Process: 13.98%
# Iter 7000 ---- Process: 14.00%
# Iter 7010 ---- Process: 14.02%
# Iter 7020 ---- Process: 14.04%
# Iter 7030 ---- Process: 14.06%
# Iter 7040 ---- Process: 14.08%
# Iter 7050 ---- Process: 14.10%
# Iter 7060 ---- Process: 14.12%
# Iter 7070 ---- Process: 14.14%
# Iter 7080 ---- Process: 14.16%
# Iter 7090 ---- Process: 14.18%
# Iter 7100 ---- Process: 14.20%
# Iter 7110 ---- Process: 14.22%
# Iter 7120 ---- Process: 14.24%
# Iter 7130 ---- Process: 14.26%
# Iter 7140 ---- Process: 14.28%
# Iter 7150 ---- Process: 14.30%
# Iter 7160 ---- Process: 14.32%
# Iter 7170 ---- Process: 14.34%
# Iter 7180 ---- Process: 14.36%
# Iter 7190 ---- Process: 14.38%
# Iter 7200 ---- Process: 14.40%
# Iter 7210 ---- Process: 14.42%
# Iter 7220 ---- Process: 14.44%
# Iter 7230 ---- Process: 14.46%
# Iter 7240 ---- Process: 14.48%
# Iter 7250 ---- Process: 14.50%
# Iter 7260 ---- Process: 14.52%
# Iter 7270 ---- Process: 14.54%
# Iter 7280 ---- Process: 14.56%
# Iter 7290 ---- Process: 14.58%
# Iter 7300 ---- Process: 14.60%
# Iter 7310 ---- Process: 14.62%
# Iter 7320 ---- Process: 14.64%
# Iter 7330 ---- Process: 14.66%
# Iter 7340 ---- Process: 14.68%
# Iter 7350 ---- Process: 14.70%
# Iter 7360 ---- Process: 14.72%
# Iter 7370 ---- Process: 14.74%
# Iter 7380 ---- Process: 14.76%
# Iter 7390 ---- Process: 14.78%
# Iter 7400 ---- Process: 14.80%
# Iter 7410 ---- Process: 14.82%
# Iter 7420 ---- Process: 14.84%
# Iter 7430 ---- Process: 14.86%
# Iter 7440 ---- Process: 14.88%
# Iter 7450 ---- Process: 14.90%
# Iter 7460 ---- Process: 14.92%
# Iter 7470 ---- Process: 14.94%
# Iter 7480 ---- Process: 14.96%
# Iter 7490 ---- Process: 14.98%
# Iter 7500 ---- Process: 15.00%
# Iter 7510 ---- Process: 15.02%
# Iter 7520 ---- Process: 15.04%
# Iter 7530 ---- Process: 15.06%
# Iter 7540 ---- Process: 15.08%
# Iter 7550 ---- Process: 15.10%
# Iter 7560 ---- Process: 15.12%
# Iter 7570 ---- Process: 15.14%
# Iter 7580 ---- Process: 15.16%
# Iter 7590 ---- Process: 15.18%
# Iter 7600 ---- Process: 15.20%
# Iter 7610 ---- Process: 15.22%
# Iter 7620 ---- Process: 15.24%
# Iter 7630 ---- Process: 15.26%
# Iter 7640 ---- Process: 15.28%
# Iter 7650 ---- Process: 15.30%
# Iter 7660 ---- Process: 15.32%
# Iter 7670 ---- Process: 15.34%
# Iter 7680 ---- Process: 15.36%
# Iter 7690 ---- Process: 15.38%
# Iter 7700 ---- Process: 15.40%
# Iter 7710 ---- Process: 15.42%
# Iter 7720 ---- Process: 15.44%
# Iter 7730 ---- Process: 15.46%
# Iter 7740 ---- Process: 15.48%
# Iter 7750 ---- Process: 15.50%
# Iter 7760 ---- Process: 15.52%
# Iter 7770 ---- Process: 15.54%
# Iter 7780 ---- Process: 15.56%
# Iter 7790 ---- Process: 15.58%
# Iter 7800 ---- Process: 15.60%
# Iter 7810 ---- Process: 15.62%
# Iter 7820 ---- Process: 15.64%
# Iter 7830 ---- Process: 15.66%
# Iter 7840 ---- Process: 15.68%
# Iter 7850 ---- Process: 15.70%
# Iter 7860 ---- Process: 15.72%
# Iter 7870 ---- Process: 15.74%
# Iter 7880 ---- Process: 15.76%
# Iter 7890 ---- Process: 15.78%
# Iter 7900 ---- Process: 15.80%
# Iter 7910 ---- Process: 15.82%
# Iter 7920 ---- Process: 15.84%
# Iter 7930 ---- Process: 15.86%
# Iter 7940 ---- Process: 15.88%
# Iter 7950 ---- Process: 15.90%
# Iter 7960 ---- Process: 15.92%
# Iter 7970 ---- Process: 15.94%
# Iter 7980 ---- Process: 15.96%
# Iter 7990 ---- Process: 15.98%
# Iter 8000 ---- Process: 16.00%
# Iter 8010 ---- Process: 16.02%
# Iter 8020 ---- Process: 16.04%
# Iter 8030 ---- Process: 16.06%
# Iter 8040 ---- Process: 16.08%
# Iter 8050 ---- Process: 16.10%
# Iter 8060 ---- Process: 16.12%
# Iter 8070 ---- Process: 16.14%
# Iter 8080 ---- Process: 16.16%
# Iter 8090 ---- Process: 16.18%
# Iter 8100 ---- Process: 16.20%
# Iter 8110 ---- Process: 16.22%
# Iter 8120 ---- Process: 16.24%
# Iter 8130 ---- Process: 16.26%
# Iter 8140 ---- Process: 16.28%
# Iter 8150 ---- Process: 16.30%
# Iter 8160 ---- Process: 16.32%
# Iter 8170 ---- Process: 16.34%
# Iter 8180 ---- Process: 16.36%
# Iter 8190 ---- Process: 16.38%
# Iter 8200 ---- Process: 16.40%
# Iter 8210 ---- Process: 16.42%
# Iter 8220 ---- Process: 16.44%
# Iter 8230 ---- Process: 16.46%
# Iter 8240 ---- Process: 16.48%
# Iter 8250 ---- Process: 16.50%
# Iter 8260 ---- Process: 16.52%
# Iter 8270 ---- Process: 16.54%
# Iter 8280 ---- Process: 16.56%
# Iter 8290 ---- Process: 16.58%
# Iter 8300 ---- Process: 16.60%
# Iter 8310 ---- Process: 16.62%
# Iter 8320 ---- Process: 16.64%
# Iter 8330 ---- Process: 16.66%
# Iter 8340 ---- Process: 16.68%
# Iter 8350 ---- Process: 16.70%
# Iter 8360 ---- Process: 16.72%
# Iter 8370 ---- Process: 16.74%
# Iter 8380 ---- Process: 16.76%
# Iter 8390 ---- Process: 16.78%
# Iter 8400 ---- Process: 16.80%
# Iter 8410 ---- Process: 16.82%
# Iter 8420 ---- Process: 16.84%
# Iter 8430 ---- Process: 16.86%
# Iter 8440 ---- Process: 16.88%
# Iter 8450 ---- Process: 16.90%
# Iter 8460 ---- Process: 16.92%
# Iter 8470 ---- Process: 16.94%
# Iter 8480 ---- Process: 16.96%
# Iter 8490 ---- Process: 16.98%
# Iter 8500 ---- Process: 17.00%
# Iter 8510 ---- Process: 17.02%
# Iter 8520 ---- Process: 17.04%
# Iter 8530 ---- Process: 17.06%
# Iter 8540 ---- Process: 17.08%
# Iter 8550 ---- Process: 17.10%
# Iter 8560 ---- Process: 17.12%
# Iter 8570 ---- Process: 17.14%
# Iter 8580 ---- Process: 17.16%
# Iter 8590 ---- Process: 17.18%
# Iter 8600 ---- Process: 17.20%
# Iter 8610 ---- Process: 17.22%
# Iter 8620 ---- Process: 17.24%
# Iter 8630 ---- Process: 17.26%
# Iter 8640 ---- Process: 17.28%
# Iter 8650 ---- Process: 17.30%
# Iter 8660 ---- Process: 17.32%
# Iter 8670 ---- Process: 17.34%
# Iter 8680 ---- Process: 17.36%
# Iter 8690 ---- Process: 17.38%
# Iter 8700 ---- Process: 17.40%
# Iter 8710 ---- Process: 17.42%
# Iter 8720 ---- Process: 17.44%
# Iter 8730 ---- Process: 17.46%
# Iter 8740 ---- Process: 17.48%
# Iter 8750 ---- Process: 17.50%
# Iter 8760 ---- Process: 17.52%
# Iter 8770 ---- Process: 17.54%
# Iter 8780 ---- Process: 17.56%
# Iter 8790 ---- Process: 17.58%
# Iter 8800 ---- Process: 17.60%
# Iter 8810 ---- Process: 17.62%
# Iter 8820 ---- Process: 17.64%
# Iter 8830 ---- Process: 17.66%
# Iter 8840 ---- Process: 17.68%
# Iter 8850 ---- Process: 17.70%
# Iter 8860 ---- Process: 17.72%
# Iter 8870 ---- Process: 17.74%
# Iter 8880 ---- Process: 17.76%
# Iter 8890 ---- Process: 17.78%
# Iter 8900 ---- Process: 17.80%
# Iter 8910 ---- Process: 17.82%
# Iter 8920 ---- Process: 17.84%
# Iter 8930 ---- Process: 17.86%
# Iter 8940 ---- Process: 17.88%
# Iter 8950 ---- Process: 17.90%
# Iter 8960 ---- Process: 17.92%
# Iter 8970 ---- Process: 17.94%
# Iter 8980 ---- Process: 17.96%
# Iter 8990 ---- Process: 17.98%
# Iter 9000 ---- Process: 18.00%
# Iter 9010 ---- Process: 18.02%
# Iter 9020 ---- Process: 18.04%
# Iter 9030 ---- Process: 18.06%
# Iter 9040 ---- Process: 18.08%
# Iter 9050 ---- Process: 18.10%
# Iter 9060 ---- Process: 18.12%
# Iter 9070 ---- Process: 18.14%
# Iter 9080 ---- Process: 18.16%
# Iter 9090 ---- Process: 18.18%
# Iter 9100 ---- Process: 18.20%
# Iter 9110 ---- Process: 18.22%
# Iter 9120 ---- Process: 18.24%
# Iter 9130 ---- Process: 18.26%
# Iter 9140 ---- Process: 18.28%
# Iter 9150 ---- Process: 18.30%
# Iter 9160 ---- Process: 18.32%
# Iter 9170 ---- Process: 18.34%
# Iter 9180 ---- Process: 18.36%
# Iter 9190 ---- Process: 18.38%
# Iter 9200 ---- Process: 18.40%
# Iter 9210 ---- Process: 18.42%
# Iter 9220 ---- Process: 18.44%
# Iter 9230 ---- Process: 18.46%
# Iter 9240 ---- Process: 18.48%
# Iter 9250 ---- Process: 18.50%
# Iter 9260 ---- Process: 18.52%
# Iter 9270 ---- Process: 18.54%
# Iter 9280 ---- Process: 18.56%
# Iter 9290 ---- Process: 18.58%
# Iter 9300 ---- Process: 18.60%
# Iter 9310 ---- Process: 18.62%
# Iter 9320 ---- Process: 18.64%
# Iter 9330 ---- Process: 18.66%
# Iter 9340 ---- Process: 18.68%
# Iter 9350 ---- Process: 18.70%
# Iter 9360 ---- Process: 18.72%
# Iter 9370 ---- Process: 18.74%
# Iter 9380 ---- Process: 18.76%
# Iter 9390 ---- Process: 18.78%
# Iter 9400 ---- Process: 18.80%
# Iter 9410 ---- Process: 18.82%
# Iter 9420 ---- Process: 18.84%
# Iter 9430 ---- Process: 18.86%
# Iter 9440 ---- Process: 18.88%
# Iter 9450 ---- Process: 18.90%
# Iter 9460 ---- Process: 18.92%
# Iter 9470 ---- Process: 18.94%
# Iter 9480 ---- Process: 18.96%
# Iter 9490 ---- Process: 18.98%
# Iter 9500 ---- Process: 19.00%
# Iter 9510 ---- Process: 19.02%
# Iter 9520 ---- Process: 19.04%
# Iter 9530 ---- Process: 19.06%
# Iter 9540 ---- Process: 19.08%
# Iter 9550 ---- Process: 19.10%
# Iter 9560 ---- Process: 19.12%
# Iter 9570 ---- Process: 19.14%
# Iter 9580 ---- Process: 19.16%
# Iter 9590 ---- Process: 19.18%
# Iter 9600 ---- Process: 19.20%
# Iter 9610 ---- Process: 19.22%
# Iter 9620 ---- Process: 19.24%
# Iter 9630 ---- Process: 19.26%
# Iter 9640 ---- Process: 19.28%
# Iter 9650 ---- Process: 19.30%
# Iter 9660 ---- Process: 19.32%
# Iter 9670 ---- Process: 19.34%
# Iter 9680 ---- Process: 19.36%
# Iter 9690 ---- Process: 19.38%
# Iter 9700 ---- Process: 19.40%
# Iter 9710 ---- Process: 19.42%
# Iter 9720 ---- Process: 19.44%
# Iter 9730 ---- Process: 19.46%
# Iter 9740 ---- Process: 19.48%
# Iter 9750 ---- Process: 19.50%
# Iter 9760 ---- Process: 19.52%
# Iter 9770 ---- Process: 19.54%
# Iter 9780 ---- Process: 19.56%
# Iter 9790 ---- Process: 19.58%
# Iter 9800 ---- Process: 19.60%
# Iter 9810 ---- Process: 19.62%
# Iter 9820 ---- Process: 19.64%
# Iter 9830 ---- Process: 19.66%
# Iter 9840 ---- Process: 19.68%
# Iter 9850 ---- Process: 19.70%
# Iter 9860 ---- Process: 19.72%
# Iter 9870 ---- Process: 19.74%
# Iter 9880 ---- Process: 19.76%
# Iter 9890 ---- Process: 19.78%
# Iter 9900 ---- Process: 19.80%
# Iter 9910 ---- Process: 19.82%
# Iter 9920 ---- Process: 19.84%
# Iter 9930 ---- Process: 19.86%
# Iter 9940 ---- Process: 19.88%
# Iter 9950 ---- Process: 19.90%
# Iter 9960 ---- Process: 19.92%
# Iter 9970 ---- Process: 19.94%
# Iter 9980 ---- Process: 19.96%
# Iter 9990 ---- Process: 19.98%
# Iter 10000 ---- Process: 20.00%
# Iter 10010 ---- Process: 20.02%
# Iter 10020 ---- Process: 20.04%
# Iter 10030 ---- Process: 20.06%
# Iter 10040 ---- Process: 20.08%
# Iter 10050 ---- Process: 20.10%
# Iter 10060 ---- Process: 20.12%
# Iter 10070 ---- Process: 20.14%
# Iter 10080 ---- Process: 20.16%
# Iter 10090 ---- Process: 20.18%
# Iter 10100 ---- Process: 20.20%
# Iter 10110 ---- Process: 20.22%
# Iter 10120 ---- Process: 20.24%
# Iter 10130 ---- Process: 20.26%
# Iter 10140 ---- Process: 20.28%
# Iter 10150 ---- Process: 20.30%
# Iter 10160 ---- Process: 20.32%
# Iter 10170 ---- Process: 20.34%
# Iter 10180 ---- Process: 20.36%
# Iter 10190 ---- Process: 20.38%
# Iter 10200 ---- Process: 20.40%
# Iter 10210 ---- Process: 20.42%
# Iter 10220 ---- Process: 20.44%
# Iter 10230 ---- Process: 20.46%
# Iter 10240 ---- Process: 20.48%
# Iter 10250 ---- Process: 20.50%
# Iter 10260 ---- Process: 20.52%
# Iter 10270 ---- Process: 20.54%
# Iter 10280 ---- Process: 20.56%
# Iter 10290 ---- Process: 20.58%
# Iter 10300 ---- Process: 20.60%
# Iter 10310 ---- Process: 20.62%
# Iter 10320 ---- Process: 20.64%
# Iter 10330 ---- Process: 20.66%
# Iter 10340 ---- Process: 20.68%
# Iter 10350 ---- Process: 20.70%
# Iter 10360 ---- Process: 20.72%
# Iter 10370 ---- Process: 20.74%
# Iter 10380 ---- Process: 20.76%
# Iter 10390 ---- Process: 20.78%
# Iter 10400 ---- Process: 20.80%
# Iter 10410 ---- Process: 20.82%
# Iter 10420 ---- Process: 20.84%
# Iter 10430 ---- Process: 20.86%
# Iter 10440 ---- Process: 20.88%
# Iter 10450 ---- Process: 20.90%
# Iter 10460 ---- Process: 20.92%
# Iter 10470 ---- Process: 20.94%
# Iter 10480 ---- Process: 20.96%
# Iter 10490 ---- Process: 20.98%
# Iter 10500 ---- Process: 21.00%
# Iter 10510 ---- Process: 21.02%
# Iter 10520 ---- Process: 21.04%
# Iter 10530 ---- Process: 21.06%
# Iter 10540 ---- Process: 21.08%
# Iter 10550 ---- Process: 21.10%
# Iter 10560 ---- Process: 21.12%
# Iter 10570 ---- Process: 21.14%
# Iter 10580 ---- Process: 21.16%
# Iter 10590 ---- Process: 21.18%
# Iter 10600 ---- Process: 21.20%
# Iter 10610 ---- Process: 21.22%
# Iter 10620 ---- Process: 21.24%
# Iter 10630 ---- Process: 21.26%
# Iter 10640 ---- Process: 21.28%
# Iter 10650 ---- Process: 21.30%
# Iter 10660 ---- Process: 21.32%
# Iter 10670 ---- Process: 21.34%
# Iter 10680 ---- Process: 21.36%
# Iter 10690 ---- Process: 21.38%
# Iter 10700 ---- Process: 21.40%
# Iter 10710 ---- Process: 21.42%
# Iter 10720 ---- Process: 21.44%
# Iter 10730 ---- Process: 21.46%
# Iter 10740 ---- Process: 21.48%
# Iter 10750 ---- Process: 21.50%
# Iter 10760 ---- Process: 21.52%
# Iter 10770 ---- Process: 21.54%
# Iter 10780 ---- Process: 21.56%
# Iter 10790 ---- Process: 21.58%
# Iter 10800 ---- Process: 21.60%
# Iter 10810 ---- Process: 21.62%
# Iter 10820 ---- Process: 21.64%
# Iter 10830 ---- Process: 21.66%
# Iter 10840 ---- Process: 21.68%
# Iter 10850 ---- Process: 21.70%
# Iter 10860 ---- Process: 21.72%
# Iter 10870 ---- Process: 21.74%
# Iter 10880 ---- Process: 21.76%
# Iter 10890 ---- Process: 21.78%
# Iter 10900 ---- Process: 21.80%
# Iter 10910 ---- Process: 21.82%
# Iter 10920 ---- Process: 21.84%
# Iter 10930 ---- Process: 21.86%
# Iter 10940 ---- Process: 21.88%
# Iter 10950 ---- Process: 21.90%
# Iter 10960 ---- Process: 21.92%
# Iter 10970 ---- Process: 21.94%
# Iter 10980 ---- Process: 21.96%
# Iter 10990 ---- Process: 21.98%
# Iter 11000 ---- Process: 22.00%
# Iter 11010 ---- Process: 22.02%
# Iter 11020 ---- Process: 22.04%
# Iter 11030 ---- Process: 22.06%
# Iter 11040 ---- Process: 22.08%
# Iter 11050 ---- Process: 22.10%
# Iter 11060 ---- Process: 22.12%
# Iter 11070 ---- Process: 22.14%
# Iter 11080 ---- Process: 22.16%
# Iter 11090 ---- Process: 22.18%
# Iter 11100 ---- Process: 22.20%
# Iter 11110 ---- Process: 22.22%
# Iter 11120 ---- Process: 22.24%
# Iter 11130 ---- Process: 22.26%
# Iter 11140 ---- Process: 22.28%
# Iter 11150 ---- Process: 22.30%
# Iter 11160 ---- Process: 22.32%
# Iter 11170 ---- Process: 22.34%
# Iter 11180 ---- Process: 22.36%
# Iter 11190 ---- Process: 22.38%
# Iter 11200 ---- Process: 22.40%
# Iter 11210 ---- Process: 22.42%
# Iter 11220 ---- Process: 22.44%
# Iter 11230 ---- Process: 22.46%
# Iter 11240 ---- Process: 22.48%
# Iter 11250 ---- Process: 22.50%
# Iter 11260 ---- Process: 22.52%
# Iter 11270 ---- Process: 22.54%
# Iter 11280 ---- Process: 22.56%
# Iter 11290 ---- Process: 22.58%
# Iter 11300 ---- Process: 22.60%
# Iter 11310 ---- Process: 22.62%
# Iter 11320 ---- Process: 22.64%
# Iter 11330 ---- Process: 22.66%
# Iter 11340 ---- Process: 22.68%
# Iter 11350 ---- Process: 22.70%
# Iter 11360 ---- Process: 22.72%
# Iter 11370 ---- Process: 22.74%
# Iter 11380 ---- Process: 22.76%
# Iter 11390 ---- Process: 22.78%
# Iter 11400 ---- Process: 22.80%
# Iter 11410 ---- Process: 22.82%
# Iter 11420 ---- Process: 22.84%
# Iter 11430 ---- Process: 22.86%
# Iter 11440 ---- Process: 22.88%
# Iter 11450 ---- Process: 22.90%
# Iter 11460 ---- Process: 22.92%
# Iter 11470 ---- Process: 22.94%
# Iter 11480 ---- Process: 22.96%
# Iter 11490 ---- Process: 22.98%
# Iter 11500 ---- Process: 23.00%
# Iter 11510 ---- Process: 23.02%
# Iter 11520 ---- Process: 23.04%
# Iter 11530 ---- Process: 23.06%
# Iter 11540 ---- Process: 23.08%
# Iter 11550 ---- Process: 23.10%
# Iter 11560 ---- Process: 23.12%
# Iter 11570 ---- Process: 23.14%
# Iter 11580 ---- Process: 23.16%
# Iter 11590 ---- Process: 23.18%
# Iter 11600 ---- Process: 23.20%
# Iter 11610 ---- Process: 23.22%
# Iter 11620 ---- Process: 23.24%
# Iter 11630 ---- Process: 23.26%
# Iter 11640 ---- Process: 23.28%
# Iter 11650 ---- Process: 23.30%
# Iter 11660 ---- Process: 23.32%
# Iter 11670 ---- Process: 23.34%
# Iter 11680 ---- Process: 23.36%
# Iter 11690 ---- Process: 23.38%
# Iter 11700 ---- Process: 23.40%
# Iter 11710 ---- Process: 23.42%
# Iter 11720 ---- Process: 23.44%
# Iter 11730 ---- Process: 23.46%
# Iter 11740 ---- Process: 23.48%
# Iter 11750 ---- Process: 23.50%
# Iter 11760 ---- Process: 23.52%
# Iter 11770 ---- Process: 23.54%
# Iter 11780 ---- Process: 23.56%
# Iter 11790 ---- Process: 23.58%
# Iter 11800 ---- Process: 23.60%
# Iter 11810 ---- Process: 23.62%
# Iter 11820 ---- Process: 23.64%
# Iter 11830 ---- Process: 23.66%
# Iter 11840 ---- Process: 23.68%
# Iter 11850 ---- Process: 23.70%
# Iter 11860 ---- Process: 23.72%
# Iter 11870 ---- Process: 23.74%
# Iter 11880 ---- Process: 23.76%
# Iter 11890 ---- Process: 23.78%
# Iter 11900 ---- Process: 23.80%
# Iter 11910 ---- Process: 23.82%
# Iter 11920 ---- Process: 23.84%
# Iter 11930 ---- Process: 23.86%
# Iter 11940 ---- Process: 23.88%
# Iter 11950 ---- Process: 23.90%
# Iter 11960 ---- Process: 23.92%
# Iter 11970 ---- Process: 23.94%
# Iter 11980 ---- Process: 23.96%
# Iter 11990 ---- Process: 23.98%
# Iter 12000 ---- Process: 24.00%
# Iter 12010 ---- Process: 24.02%
# Iter 12020 ---- Process: 24.04%
# Iter 12030 ---- Process: 24.06%
# Iter 12040 ---- Process: 24.08%
# Iter 12050 ---- Process: 24.10%
# Iter 12060 ---- Process: 24.12%
# Iter 12070 ---- Process: 24.14%
# Iter 12080 ---- Process: 24.16%
# Iter 12090 ---- Process: 24.18%
# Iter 12100 ---- Process: 24.20%
# Iter 12110 ---- Process: 24.22%
# Iter 12120 ---- Process: 24.24%
# Iter 12130 ---- Process: 24.26%
# Iter 12140 ---- Process: 24.28%
# Iter 12150 ---- Process: 24.30%
# Iter 12160 ---- Process: 24.32%
# Iter 12170 ---- Process: 24.34%
# Iter 12180 ---- Process: 24.36%
# Iter 12190 ---- Process: 24.38%
# Iter 12200 ---- Process: 24.40%
# Iter 12210 ---- Process: 24.42%
# Iter 12220 ---- Process: 24.44%
# Iter 12230 ---- Process: 24.46%
# Iter 12240 ---- Process: 24.48%
# Iter 12250 ---- Process: 24.50%
# Iter 12260 ---- Process: 24.52%
# Iter 12270 ---- Process: 24.54%
# Iter 12280 ---- Process: 24.56%
# Iter 12290 ---- Process: 24.58%
# Iter 12300 ---- Process: 24.60%
# Iter 12310 ---- Process: 24.62%
# Iter 12320 ---- Process: 24.64%
# Iter 12330 ---- Process: 24.66%
# Iter 12340 ---- Process: 24.68%
# Iter 12350 ---- Process: 24.70%
# Iter 12360 ---- Process: 24.72%
# Iter 12370 ---- Process: 24.74%
# Iter 12380 ---- Process: 24.76%
# Iter 12390 ---- Process: 24.78%
# Iter 12400 ---- Process: 24.80%
# Iter 12410 ---- Process: 24.82%
# Iter 12420 ---- Process: 24.84%
# Iter 12430 ---- Process: 24.86%
# Iter 12440 ---- Process: 24.88%
# Iter 12450 ---- Process: 24.90%
# Iter 12460 ---- Process: 24.92%
# Iter 12470 ---- Process: 24.94%
# Iter 12480 ---- Process: 24.96%
# Iter 12490 ---- Process: 24.98%
# Iter 12500 ---- Process: 25.00%
# Iter 12510 ---- Process: 25.02%
# Iter 12520 ---- Process: 25.04%
# Iter 12530 ---- Process: 25.06%
# Iter 12540 ---- Process: 25.08%
# Iter 12550 ---- Process: 25.10%
# Iter 12560 ---- Process: 25.12%
# Iter 12570 ---- Process: 25.14%
# Iter 12580 ---- Process: 25.16%
# Iter 12590 ---- Process: 25.18%
# Iter 12600 ---- Process: 25.20%
# Iter 12610 ---- Process: 25.22%
# Iter 12620 ---- Process: 25.24%
# Iter 12630 ---- Process: 25.26%
# Iter 12640 ---- Process: 25.28%
# Iter 12650 ---- Process: 25.30%
# Iter 12660 ---- Process: 25.32%
# Iter 12670 ---- Process: 25.34%
# Iter 12680 ---- Process: 25.36%
# Iter 12690 ---- Process: 25.38%
# Iter 12700 ---- Process: 25.40%
# Iter 12710 ---- Process: 25.42%
# Iter 12720 ---- Process: 25.44%
# Iter 12730 ---- Process: 25.46%
# Iter 12740 ---- Process: 25.48%
# Iter 12750 ---- Process: 25.50%
# Iter 12760 ---- Process: 25.52%
# Iter 12770 ---- Process: 25.54%
# Iter 12780 ---- Process: 25.56%
# Iter 12790 ---- Process: 25.58%
# Iter 12800 ---- Process: 25.60%
# Iter 12810 ---- Process: 25.62%
# Iter 12820 ---- Process: 25.64%
# Iter 12830 ---- Process: 25.66%
# Iter 12840 ---- Process: 25.68%
# Iter 12850 ---- Process: 25.70%
# Iter 12860 ---- Process: 25.72%
# Iter 12870 ---- Process: 25.74%
# Iter 12880 ---- Process: 25.76%
# Iter 12890 ---- Process: 25.78%
# Iter 12900 ---- Process: 25.80%
# Iter 12910 ---- Process: 25.82%
# Iter 12920 ---- Process: 25.84%
# Iter 12930 ---- Process: 25.86%
# Iter 12940 ---- Process: 25.88%
# Iter 12950 ---- Process: 25.90%
# Iter 12960 ---- Process: 25.92%
# Iter 12970 ---- Process: 25.94%
# Iter 12980 ---- Process: 25.96%
# Iter 12990 ---- Process: 25.98%
# Iter 13000 ---- Process: 26.00%
# Iter 13010 ---- Process: 26.02%
# Iter 13020 ---- Process: 26.04%
# Iter 13030 ---- Process: 26.06%
# Iter 13040 ---- Process: 26.08%
# Iter 13050 ---- Process: 26.10%
# Iter 13060 ---- Process: 26.12%
# Iter 13070 ---- Process: 26.14%
# Iter 13080 ---- Process: 26.16%
# Iter 13090 ---- Process: 26.18%
# Iter 13100 ---- Process: 26.20%
# Iter 13110 ---- Process: 26.22%
# Iter 13120 ---- Process: 26.24%
# Iter 13130 ---- Process: 26.26%
# Iter 13140 ---- Process: 26.28%
# Iter 13150 ---- Process: 26.30%
# Iter 13160 ---- Process: 26.32%
# Iter 13170 ---- Process: 26.34%
# Iter 13180 ---- Process: 26.36%
# Iter 13190 ---- Process: 26.38%
# Iter 13200 ---- Process: 26.40%
# Iter 13210 ---- Process: 26.42%
# Iter 13220 ---- Process: 26.44%
# Iter 13230 ---- Process: 26.46%
# Iter 13240 ---- Process: 26.48%
# Iter 13250 ---- Process: 26.50%
# Iter 13260 ---- Process: 26.52%
# Iter 13270 ---- Process: 26.54%
# Iter 13280 ---- Process: 26.56%
# Iter 13290 ---- Process: 26.58%
# Iter 13300 ---- Process: 26.60%
# Iter 13310 ---- Process: 26.62%
# Iter 13320 ---- Process: 26.64%
# Iter 13330 ---- Process: 26.66%
# Iter 13340 ---- Process: 26.68%
# Iter 13350 ---- Process: 26.70%
# Iter 13360 ---- Process: 26.72%
# Iter 13370 ---- Process: 26.74%
# Iter 13380 ---- Process: 26.76%
# Iter 13390 ---- Process: 26.78%
# Iter 13400 ---- Process: 26.80%
# Iter 13410 ---- Process: 26.82%
# Iter 13420 ---- Process: 26.84%
# Iter 13430 ---- Process: 26.86%
# Iter 13440 ---- Process: 26.88%
# Iter 13450 ---- Process: 26.90%
# Iter 13460 ---- Process: 26.92%
# Iter 13470 ---- Process: 26.94%
# Iter 13480 ---- Process: 26.96%
# Iter 13490 ---- Process: 26.98%
# Iter 13500 ---- Process: 27.00%
# Iter 13510 ---- Process: 27.02%
# Iter 13520 ---- Process: 27.04%
# Iter 13530 ---- Process: 27.06%
# Iter 13540 ---- Process: 27.08%
# Iter 13550 ---- Process: 27.10%
# Iter 13560 ---- Process: 27.12%
# Iter 13570 ---- Process: 27.14%
# Iter 13580 ---- Process: 27.16%
# Iter 13590 ---- Process: 27.18%
# Iter 13600 ---- Process: 27.20%
# Iter 13610 ---- Process: 27.22%
# Iter 13620 ---- Process: 27.24%
# Iter 13630 ---- Process: 27.26%
# Iter 13640 ---- Process: 27.28%
# Iter 13650 ---- Process: 27.30%
# Iter 13660 ---- Process: 27.32%
# Iter 13670 ---- Process: 27.34%
# Iter 13680 ---- Process: 27.36%
# Iter 13690 ---- Process: 27.38%
# Iter 13700 ---- Process: 27.40%
# Iter 13710 ---- Process: 27.42%
# Iter 13720 ---- Process: 27.44%
# Iter 13730 ---- Process: 27.46%
# Iter 13740 ---- Process: 27.48%
# Iter 13750 ---- Process: 27.50%
# Iter 13760 ---- Process: 27.52%
# Iter 13770 ---- Process: 27.54%
# Iter 13780 ---- Process: 27.56%
# Iter 13790 ---- Process: 27.58%
# Iter 13800 ---- Process: 27.60%
# Iter 13810 ---- Process: 27.62%
# Iter 13820 ---- Process: 27.64%
# Iter 13830 ---- Process: 27.66%
# Iter 13840 ---- Process: 27.68%
# Iter 13850 ---- Process: 27.70%
# Iter 13860 ---- Process: 27.72%
# Iter 13870 ---- Process: 27.74%
# Iter 13880 ---- Process: 27.76%
# Iter 13890 ---- Process: 27.78%
# Iter 13900 ---- Process: 27.80%
# Iter 13910 ---- Process: 27.82%
# Iter 13920 ---- Process: 27.84%
# Iter 13930 ---- Process: 27.86%
# Iter 13940 ---- Process: 27.88%
# Iter 13950 ---- Process: 27.90%
# Iter 13960 ---- Process: 27.92%
# Iter 13970 ---- Process: 27.94%
# Iter 13980 ---- Process: 27.96%
# Iter 13990 ---- Process: 27.98%
# Iter 14000 ---- Process: 28.00%
# Iter 14010 ---- Process: 28.02%
# Iter 14020 ---- Process: 28.04%
# Iter 14030 ---- Process: 28.06%
# Iter 14040 ---- Process: 28.08%
# Iter 14050 ---- Process: 28.10%
# Iter 14060 ---- Process: 28.12%
# Iter 14070 ---- Process: 28.14%
# Iter 14080 ---- Process: 28.16%
# Iter 14090 ---- Process: 28.18%
# Iter 14100 ---- Process: 28.20%
# Iter 14110 ---- Process: 28.22%
# Iter 14120 ---- Process: 28.24%
# Iter 14130 ---- Process: 28.26%
# Iter 14140 ---- Process: 28.28%
# Iter 14150 ---- Process: 28.30%
# Iter 14160 ---- Process: 28.32%
# Iter 14170 ---- Process: 28.34%
# Iter 14180 ---- Process: 28.36%
# Iter 14190 ---- Process: 28.38%
# Iter 14200 ---- Process: 28.40%
# Iter 14210 ---- Process: 28.42%
# Iter 14220 ---- Process: 28.44%
# Iter 14230 ---- Process: 28.46%
# Iter 14240 ---- Process: 28.48%
# Iter 14250 ---- Process: 28.50%
# Iter 14260 ---- Process: 28.52%
# Iter 14270 ---- Process: 28.54%
# Iter 14280 ---- Process: 28.56%
# Iter 14290 ---- Process: 28.58%
# Iter 14300 ---- Process: 28.60%
# Iter 14310 ---- Process: 28.62%
# Iter 14320 ---- Process: 28.64%
# Iter 14330 ---- Process: 28.66%
# Iter 14340 ---- Process: 28.68%
# Iter 14350 ---- Process: 28.70%
# Iter 14360 ---- Process: 28.72%
# Iter 14370 ---- Process: 28.74%
# Iter 14380 ---- Process: 28.76%
# Iter 14390 ---- Process: 28.78%
# Iter 14400 ---- Process: 28.80%
# Iter 14410 ---- Process: 28.82%
# Iter 14420 ---- Process: 28.84%
# Iter 14430 ---- Process: 28.86%
# Iter 14440 ---- Process: 28.88%
# Iter 14450 ---- Process: 28.90%
# Iter 14460 ---- Process: 28.92%
# Iter 14470 ---- Process: 28.94%
# Iter 14480 ---- Process: 28.96%
# Iter 14490 ---- Process: 28.98%
# Iter 14500 ---- Process: 29.00%
# Iter 14510 ---- Process: 29.02%
# Iter 14520 ---- Process: 29.04%
# Iter 14530 ---- Process: 29.06%
# Iter 14540 ---- Process: 29.08%
# Iter 14550 ---- Process: 29.10%
# Iter 14560 ---- Process: 29.12%
# Iter 14570 ---- Process: 29.14%
# Iter 14580 ---- Process: 29.16%
# Iter 14590 ---- Process: 29.18%
# Iter 14600 ---- Process: 29.20%
# Iter 14610 ---- Process: 29.22%
# Iter 14620 ---- Process: 29.24%
# Iter 14630 ---- Process: 29.26%
# Iter 14640 ---- Process: 29.28%
# Iter 14650 ---- Process: 29.30%
# Iter 14660 ---- Process: 29.32%
# Iter 14670 ---- Process: 29.34%
# Iter 14680 ---- Process: 29.36%
# Iter 14690 ---- Process: 29.38%
# Iter 14700 ---- Process: 29.40%
# Iter 14710 ---- Process: 29.42%
# Iter 14720 ---- Process: 29.44%
# Iter 14730 ---- Process: 29.46%
# Iter 14740 ---- Process: 29.48%
# Iter 14750 ---- Process: 29.50%
# Iter 14760 ---- Process: 29.52%
# Iter 14770 ---- Process: 29.54%
# Iter 14780 ---- Process: 29.56%
# Iter 14790 ---- Process: 29.58%
# Iter 14800 ---- Process: 29.60%
# Iter 14810 ---- Process: 29.62%
# Iter 14820 ---- Process: 29.64%
# Iter 14830 ---- Process: 29.66%
# Iter 14840 ---- Process: 29.68%
# Iter 14850 ---- Process: 29.70%
# Iter 14860 ---- Process: 29.72%
# Iter 14870 ---- Process: 29.74%
# Iter 14880 ---- Process: 29.76%
# Iter 14890 ---- Process: 29.78%
# Iter 14900 ---- Process: 29.80%
# Iter 14910 ---- Process: 29.82%
# Iter 14920 ---- Process: 29.84%
# Iter 14930 ---- Process: 29.86%
# Iter 14940 ---- Process: 29.88%
# Iter 14950 ---- Process: 29.90%
# Iter 14960 ---- Process: 29.92%
# Iter 14970 ---- Process: 29.94%
# Iter 14980 ---- Process: 29.96%
# Iter 14990 ---- Process: 29.98%
# Iter 15000 ---- Process: 30.00%
# Iter 15010 ---- Process: 30.02%
# Iter 15020 ---- Process: 30.04%
# Iter 15030 ---- Process: 30.06%
# Iter 15040 ---- Process: 30.08%
# Iter 15050 ---- Process: 30.10%
# Iter 15060 ---- Process: 30.12%
# Iter 15070 ---- Process: 30.14%
# Iter 15080 ---- Process: 30.16%
# Iter 15090 ---- Process: 30.18%
# Iter 15100 ---- Process: 30.20%
# Iter 15110 ---- Process: 30.22%
# Iter 15120 ---- Process: 30.24%
# Iter 15130 ---- Process: 30.26%
# Iter 15140 ---- Process: 30.28%
# Iter 15150 ---- Process: 30.30%
# Iter 15160 ---- Process: 30.32%
# Iter 15170 ---- Process: 30.34%
# Iter 15180 ---- Process: 30.36%
# Iter 15190 ---- Process: 30.38%
# Iter 15200 ---- Process: 30.40%
# Iter 15210 ---- Process: 30.42%
# Iter 15220 ---- Process: 30.44%
# Iter 15230 ---- Process: 30.46%
# Iter 15240 ---- Process: 30.48%
# Iter 15250 ---- Process: 30.50%
# Iter 15260 ---- Process: 30.52%
# Iter 15270 ---- Process: 30.54%
# Iter 15280 ---- Process: 30.56%
# Iter 15290 ---- Process: 30.58%
# Iter 15300 ---- Process: 30.60%
# Iter 15310 ---- Process: 30.62%
# Iter 15320 ---- Process: 30.64%
# Iter 15330 ---- Process: 30.66%
# Iter 15340 ---- Process: 30.68%
# Iter 15350 ---- Process: 30.70%
# Iter 15360 ---- Process: 30.72%
# Iter 15370 ---- Process: 30.74%
# Iter 15380 ---- Process: 30.76%
# Iter 15390 ---- Process: 30.78%
# Iter 15400 ---- Process: 30.80%
# Iter 15410 ---- Process: 30.82%
# Iter 15420 ---- Process: 30.84%
# Iter 15430 ---- Process: 30.86%
# Iter 15440 ---- Process: 30.88%
# Iter 15450 ---- Process: 30.90%
# Iter 15460 ---- Process: 30.92%
# Iter 15470 ---- Process: 30.94%
# Iter 15480 ---- Process: 30.96%
# Iter 15490 ---- Process: 30.98%
# ...
# Iter 45000 ---- Process: 90.00%
# Iter 45010 ---- Process: 90.02%
# Iter 45020 ---- Process: 90.04%
# Iter 45030 ---- Process: 90.06%
# Iter 45040 ---- Process: 90.08%
# Iter 45050 ---- Process: 90.10%
# Iter 45060 ---- Process: 90.12%
# Iter 45070 ---- Process: 90.14%
# Iter 45080 ---- Process: 90.16%
# Iter 45090 ---- Process: 90.18%
# Iter 45100 ---- Process: 90.20%
# Iter 45110 ---- Process: 90.22%
# Iter 45120 ---- Process: 90.24%
# Iter 45130 ---- Process: 90.26%
# Iter 45140 ---- Process: 90.28%
# Iter 45150 ---- Process: 90.30%
# Iter 45160 ---- Process: 90.32%
# Iter 45170 ---- Process: 90.34%
# Iter 45180 ---- Process: 90.36%
# Iter 45190 ---- Process: 90.38%
# Iter 45200 ---- Process: 90.40%
# Iter 45210 ---- Process: 90.42%
# Iter 45220 ---- Process: 90.44%
# Iter 45230 ---- Process: 90.46%
# Iter 45240 ---- Process: 90.48%
# Iter 45250 ---- Process: 90.50%
# Iter 45260 ---- Process: 90.52%
# Iter 45270 ---- Process: 90.54%
# Iter 45280 ---- Process: 90.56%
# Iter 45290 ---- Process: 90.58%
# Iter 45300 ---- Process: 90.60%
# Iter 45310 ---- Process: 90.62%
# Iter 45320 ---- Process: 90.64%
# Iter 45330 ---- Process: 90.66%
# Iter 45340 ---- Process: 90.68%
# Iter 45350 ---- Process: 90.70%
# Iter 45360 ---- Process: 90.72%
# Iter 45370 ---- Process: 90.74%
# Iter 45380 ---- Process: 90.76%
# Iter 45390 ---- Process: 90.78%
# Iter 45400 ---- Process: 90.80%
# Iter 45410 ---- Process: 90.82%
# Iter 45420 ---- Process: 90.84%
# Iter 45430 ---- Process: 90.86%
# Iter 45440 ---- Process: 90.88%
# Iter 45450 ---- Process: 90.90%
# Iter 45460 ---- Process: 90.92%
# Iter 45470 ---- Process: 90.94%
# Iter 45480 ---- Process: 90.96%
# Iter 45490 ---- Process: 90.98%
# Iter 45500 ---- Process: 91.00%
# Iter 45510 ---- Process: 91.02%
# Iter 45520 ---- Process: 91.04%
# Iter 45530 ---- Process: 91.06%
# Iter 45540 ---- Process: 91.08%
# Iter 45550 ---- Process: 91.10%
# Iter 45560 ---- Process: 91.12%
# Iter 45570 ---- Process: 91.14%
# Iter 45580 ---- Process: 91.16%
# Iter 45590 ---- Process: 91.18%
# Iter 45600 ---- Process: 91.20%
# Iter 45610 ---- Process: 91.22%
# Iter 45620 ---- Process: 91.24%
# Iter 45630 ---- Process: 91.26%
# Iter 45640 ---- Process: 91.28%
# Iter 45650 ---- Process: 91.30%
# Iter 45660 ---- Process: 91.32%
# Iter 45670 ---- Process: 91.34%
# Iter 45680 ---- Process: 91.36%
# Iter 45690 ---- Process: 91.38%
# Iter 45700 ---- Process: 91.40%
# Iter 45710 ---- Process: 91.42%
# Iter 45720 ---- Process: 91.44%
# Iter 45730 ---- Process: 91.46%
# Iter 45740 ---- Process: 91.48%
# Iter 45750 ---- Process: 91.50%
# Iter 45760 ---- Process: 91.52%
# Iter 45770 ---- Process: 91.54%
# Iter 45780 ---- Process: 91.56%
# Iter 45790 ---- Process: 91.58%
# Iter 45800 ---- Process: 91.60%
# Iter 45810 ---- Process: 91.62%
# Iter 45820 ---- Process: 91.64%
# Iter 45830 ---- Process: 91.66%
# Iter 45840 ---- Process: 91.68%
# Iter 45850 ---- Process: 91.70%
# Iter 45860 ---- Process: 91.72%
# Iter 45870 ---- Process: 91.74%
# Iter 45880 ---- Process: 91.76%
# Iter 45890 ---- Process: 91.78%
# Iter 45900 ---- Process: 91.80%
# Iter 45910 ---- Process: 91.82%
# Iter 45920 ---- Process: 91.84%
# Iter 45930 ---- Process: 91.86%
# Iter 45940 ---- Process: 91.88%
# Iter 45950 ---- Process: 91.90%
# Iter 45960 ---- Process: 91.92%
# Iter 45970 ---- Process: 91.94%
# Iter 45980 ---- Process: 91.96%
# Iter 45990 ---- Process: 91.98%
# Iter 46000 ---- Process: 92.00%
# Iter 46010 ---- Process: 92.02%
# Iter 46020 ---- Process: 92.04%
# Iter 46030 ---- Process: 92.06%
# Iter 46040 ---- Process: 92.08%
# Iter 46050 ---- Process: 92.10%
# Iter 46060 ---- Process: 92.12%
# Iter 46070 ---- Process: 92.14%
# Iter 46080 ---- Process: 92.16%
# Iter 46090 ---- Process: 92.18%
# Iter 46100 ---- Process: 92.20%
# Iter 46110 ---- Process: 92.22%
# Iter 46120 ---- Process: 92.24%
# Iter 46130 ---- Process: 92.26%
# Iter 46140 ---- Process: 92.28%
# Iter 46150 ---- Process: 92.30%
# Iter 46160 ---- Process: 92.32%
# Iter 46170 ---- Process: 92.34%
# Iter 46180 ---- Process: 92.36%
# Iter 46190 ---- Process: 92.38%
# Iter 46200 ---- Process: 92.40%
# Iter 46210 ---- Process: 92.42%
# Iter 46220 ---- Process: 92.44%
# Iter 46230 ---- Process: 92.46%
# Iter 46240 ---- Process: 92.48%
# Iter 46250 ---- Process: 92.50%
# Iter 46260 ---- Process: 92.52%
# Iter 46270 ---- Process: 92.54%
# Iter 46280 ---- Process: 92.56%
# Iter 46290 ---- Process: 92.58%
# Iter 46300 ---- Process: 92.60%
# Iter 46310 ---- Process: 92.62%
# Iter 46320 ---- Process: 92.64%
# Iter 46330 ---- Process: 92.66%
# Iter 46340 ---- Process: 92.68%
# Iter 46350 ---- Process: 92.70%
# Iter 46360 ---- Process: 92.72%
# Iter 46370 ---- Process: 92.74%
# Iter 46380 ---- Process: 92.76%
# Iter 46390 ---- Process: 92.78%
# Iter 46400 ---- Process: 92.80%
# Iter 46410 ---- Process: 92.82%
# Iter 46420 ---- Process: 92.84%
# Iter 46430 ---- Process: 92.86%
# Iter 46440 ---- Process: 92.88%
# Iter 46450 ---- Process: 92.90%
# Iter 46460 ---- Process: 92.92%
# Iter 46470 ---- Process: 92.94%
# Iter 46480 ---- Process: 92.96%
# Iter 46490 ---- Process: 92.98%
# Iter 46500 ---- Process: 93.00%
# Iter 46510 ---- Process: 93.02%
# Iter 46520 ---- Process: 93.04%
# Iter 46530 ---- Process: 93.06%
# Iter 46540 ---- Process: 93.08%
# Iter 46550 ---- Process: 93.10%
# Iter 46560 ---- Process: 93.12%
# Iter 46570 ---- Process: 93.14%
# Iter 46580 ---- Process: 93.16%
# Iter 46590 ---- Process: 93.18%
# Iter 46600 ---- Process: 93.20%
# Iter 46610 ---- Process: 93.22%
# Iter 46620 ---- Process: 93.24%
# Iter 46630 ---- Process: 93.26%
# Iter 46640 ---- Process: 93.28%
# Iter 46650 ---- Process: 93.30%
# Iter 46660 ---- Process: 93.32%
# Iter 46670 ---- Process: 93.34%
# Iter 46680 ---- Process: 93.36%
# Iter 46690 ---- Process: 93.38%
# Iter 46700 ---- Process: 93.40%
# Iter 46710 ---- Process: 93.42%
# Iter 46720 ---- Process: 93.44%
# Iter 46730 ---- Process: 93.46%
# Iter 46740 ---- Process: 93.48%
# Iter 46750 ---- Process: 93.50%
# Iter 46760 ---- Process: 93.52%
# Iter 46770 ---- Process: 93.54%
# Iter 46780 ---- Process: 93.56%
# Iter 46790 ---- Process: 93.58%
# Iter 46800 ---- Process: 93.60%
# Iter 46810 ---- Process: 93.62%
# Iter 46820 ---- Process: 93.64%
# Iter 46830 ---- Process: 93.66%
# Iter 46840 ---- Process: 93.68%
# Iter 46850 ---- Process: 93.70%
# Iter 46860 ---- Process: 93.72%
# Iter 46870 ---- Process: 93.74%
# Iter 46880 ---- Process: 93.76%
# Iter 46890 ---- Process: 93.78%
# Iter 46900 ---- Process: 93.80%
# Iter 46910 ---- Process: 93.82%
# Iter 46920 ---- Process: 93.84%
# Iter 46930 ---- Process: 93.86%
# Iter 46940 ---- Process: 93.88%
# Iter 46950 ---- Process: 93.90%
# Iter 46960 ---- Process: 93.92%
# Iter 46970 ---- Process: 93.94%
# Iter 46980 ---- Process: 93.96%
# Iter 46990 ---- Process: 93.98%
# Iter 47000 ---- Process: 94.00%
# Iter 47010 ---- Process: 94.02%
# Iter 47020 ---- Process: 94.04%
# Iter 47030 ---- Process: 94.06%
# Iter 47040 ---- Process: 94.08%
# Iter 47050 ---- Process: 94.10%
# Iter 47060 ---- Process: 94.12%
# Iter 47070 ---- Process: 94.14%
# Iter 47080 ---- Process: 94.16%
# Iter 47090 ---- Process: 94.18%
# Iter 47100 ---- Process: 94.20%
# Iter 47110 ---- Process: 94.22%
# Iter 47120 ---- Process: 94.24%
# Iter 47130 ---- Process: 94.26%
# Iter 47140 ---- Process: 94.28%
# Iter 47150 ---- Process: 94.30%
# Iter 47160 ---- Process: 94.32%
# Iter 47170 ---- Process: 94.34%
# Iter 47180 ---- Process: 94.36%
# Iter 47190 ---- Process: 94.38%
# Iter 47200 ---- Process: 94.40%
# Iter 47210 ---- Process: 94.42%
# Iter 47220 ---- Process: 94.44%
# Iter 47230 ---- Process: 94.46%
# Iter 47240 ---- Process: 94.48%
# Iter 47250 ---- Process: 94.50%
# Iter 47260 ---- Process: 94.52%
# Iter 47270 ---- Process: 94.54%
# Iter 47280 ---- Process: 94.56%
# Iter 47290 ---- Process: 94.58%
# Iter 47300 ---- Process: 94.60%
# Iter 47310 ---- Process: 94.62%
# Iter 47320 ---- Process: 94.64%
# Iter 47330 ---- Process: 94.66%
# Iter 47340 ---- Process: 94.68%
# Iter 47350 ---- Process: 94.70%
# Iter 47360 ---- Process: 94.72%
# Iter 47370 ---- Process: 94.74%
# Iter 47380 ---- Process: 94.76%
# Iter 47390 ---- Process: 94.78%
# Iter 47400 ---- Process: 94.80%
# Iter 47410 ---- Process: 94.82%
# Iter 47420 ---- Process: 94.84%
# Iter 47430 ---- Process: 94.86%
# Iter 47440 ---- Process: 94.88%
# Iter 47450 ---- Process: 94.90%
# Iter 47460 ---- Process: 94.92%
# Iter 47470 ---- Process: 94.94%
# Iter 47480 ---- Process: 94.96%
# Iter 47490 ---- Process: 94.98%
# Iter 47500 ---- Process: 95.00%
# Iter 47510 ---- Process: 95.02%
# Iter 47520 ---- Process: 95.04%
# Iter 47530 ---- Process: 95.06%
# Iter 47540 ---- Process: 95.08%
# Iter 47550 ---- Process: 95.10%
# Iter 47560 ---- Process: 95.12%
# Iter 47570 ---- Process: 95.14%
# Iter 47580 ---- Process: 95.16%
# Iter 47590 ---- Process: 95.18%
# Iter 47600 ---- Process: 95.20%
# Iter 47610 ---- Process: 95.22%
# Iter 47620 ---- Process: 95.24%
# Iter 47630 ---- Process: 95.26%
# Iter 47640 ---- Process: 95.28%
# Iter 47650 ---- Process: 95.30%
# Iter 47660 ---- Process: 95.32%
# Iter 47670 ---- Process: 95.34%
# Iter 47680 ---- Process: 95.36%
# Iter 47690 ---- Process: 95.38%
# Iter 47700 ---- Process: 95.40%
# Iter 47710 ---- Process: 95.42%
# Iter 47720 ---- Process: 95.44%
# Iter 47730 ---- Process: 95.46%
# Iter 47740 ---- Process: 95.48%
# Iter 47750 ---- Process: 95.50%
# Iter 47760 ---- Process: 95.52%
# Iter 47770 ---- Process: 95.54%
# Iter 47780 ---- Process: 95.56%
# Iter 47790 ---- Process: 95.58%
# Iter 47800 ---- Process: 95.60%
# Iter 47810 ---- Process: 95.62%
# Iter 47820 ---- Process: 95.64%
# Iter 47830 ---- Process: 95.66%
# Iter 47840 ---- Process: 95.68%
# Iter 47850 ---- Process: 95.70%
# Iter 47860 ---- Process: 95.72%
# Iter 47870 ---- Process: 95.74%
# Iter 47880 ---- Process: 95.76%
# Iter 47890 ---- Process: 95.78%
# Iter 47900 ---- Process: 95.80%
# Iter 47910 ---- Process: 95.82%
# Iter 47920 ---- Process: 95.84%
# Iter 47930 ---- Process: 95.86%
# Iter 47940 ---- Process: 95.88%
# Iter 47950 ---- Process: 95.90%
# Iter 47960 ---- Process: 95.92%
# Iter 47970 ---- Process: 95.94%
# Iter 47980 ---- Process: 95.96%
# Iter 47990 ---- Process: 95.98%
# Iter 48000 ---- Process: 96.00%
# Iter 48010 ---- Process: 96.02%
# Iter 48020 ---- Process: 96.04%
# Iter 48030 ---- Process: 96.06%
# Iter 48040 ---- Process: 96.08%
# Iter 48050 ---- Process: 96.10%
# Iter 48060 ---- Process: 96.12%
# Iter 48070 ---- Process: 96.14%
# Iter 48080 ---- Process: 96.16%
# Iter 48090 ---- Process: 96.18%
# Iter 48100 ---- Process: 96.20%
# Iter 48110 ---- Process: 96.22%
# Iter 48120 ---- Process: 96.24%
# Iter 48130 ---- Process: 96.26%
# Iter 48140 ---- Process: 96.28%
# Iter 48150 ---- Process: 96.30%
# Iter 48160 ---- Process: 96.32%
# Iter 48170 ---- Process: 96.34%
# Iter 48180 ---- Process: 96.36%
# Iter 48190 ---- Process: 96.38%
# Iter 48200 ---- Process: 96.40%
# Iter 48210 ---- Process: 96.42%
# Iter 48220 ---- Process: 96.44%
# Iter 48230 ---- Process: 96.46%
# Iter 48240 ---- Process: 96.48%
# Iter 48250 ---- Process: 96.50%
# Iter 48260 ---- Process: 96.52%
# Iter 48270 ---- Process: 96.54%
# Iter 48280 ---- Process: 96.56%
# Iter 48290 ---- Process: 96.58%
# Iter 48300 ---- Process: 96.60%
# Iter 48310 ---- Process: 96.62%
# Iter 48320 ---- Process: 96.64%
# Iter 48330 ---- Process: 96.66%
# Iter 48340 ---- Process: 96.68%
# Iter 48350 ---- Process: 96.70%
# Iter 48360 ---- Process: 96.72%
# Iter 48370 ---- Process: 96.74%
# Iter 48380 ---- Process: 96.76%
# Iter 48390 ---- Process: 96.78%
# Iter 48400 ---- Process: 96.80%
# Iter 48410 ---- Process: 96.82%
# Iter 48420 ---- Process: 96.84%
# Iter 48430 ---- Process: 96.86%
# Iter 48440 ---- Process: 96.88%
# Iter 48450 ---- Process: 96.90%
# Iter 48460 ---- Process: 96.92%
# Iter 48470 ---- Process: 96.94%
# Iter 48480 ---- Process: 96.96%
# Iter 48490 ---- Process: 96.98%
# Iter 48500 ---- Process: 97.00%
# Iter 48510 ---- Process: 97.02%
# Iter 48520 ---- Process: 97.04%
# Iter 48530 ---- Process: 97.06%
# Iter 48540 ---- Process: 97.08%
# Iter 48550 ---- Process: 97.10%
# Iter 48560 ---- Process: 97.12%
# Iter 48570 ---- Process: 97.14%
# Iter 48580 ---- Process: 97.16%
# Iter 48590 ---- Process: 97.18%
# Iter 48600 ---- Process: 97.20%
# Iter 48610 ---- Process: 97.22%
# Iter 48620 ---- Process: 97.24%
# Iter 48630 ---- Process: 97.26%
# Iter 48640 ---- Process: 97.28%
# Iter 48650 ---- Process: 97.30%
# Iter 48660 ---- Process: 97.32%
# Iter 48670 ---- Process: 97.34%
# Iter 48680 ---- Process: 97.36%
# Iter 48690 ---- Process: 97.38%
# Iter 48700 ---- Process: 97.40%
# Iter 48710 ---- Process: 97.42%
# Iter 48720 ---- Process: 97.44%
# Iter 48730 ---- Process: 97.46%
# Iter 48740 ---- Process: 97.48%
# Iter 48750 ---- Process: 97.50%
# Iter 48760 ---- Process: 97.52%
# Iter 48770 ---- Process: 97.54%
# Iter 48780 ---- Process: 97.56%
# Iter 48790 ---- Process: 97.58%
# Iter 48800 ---- Process: 97.60%
# Iter 48810 ---- Process: 97.62%
# Iter 48820 ---- Process: 97.64%
# Iter 48830 ---- Process: 97.66%
# Iter 48840 ---- Process: 97.68%
# Iter 48850 ---- Process: 97.70%
# Iter 48860 ---- Process: 97.72%
# Iter 48870 ---- Process: 97.74%
# Iter 48880 ---- Process: 97.76%
# Iter 48890 ---- Process: 97.78%
# Iter 48900 ---- Process: 97.80%
# Iter 48910 ---- Process: 97.82%
# Iter 48920 ---- Process: 97.84%
# Iter 48930 ---- Process: 97.86%
# Iter 48940 ---- Process: 97.88%
# Iter 48950 ---- Process: 97.90%
# Iter 48960 ---- Process: 97.92%
# Iter 48970 ---- Process: 97.94%
# Iter 48980 ---- Process: 97.96%
# Iter 48990 ---- Process: 97.98%
# Iter 49000 ---- Process: 98.00%
# Iter 49010 ---- Process: 98.02%
# Iter 49020 ---- Process: 98.04%
# Iter 49030 ---- Process: 98.06%
# Iter 49040 ---- Process: 98.08%
# Iter 49050 ---- Process: 98.10%
# Iter 49060 ---- Process: 98.12%
# Iter 49070 ---- Process: 98.14%
# Iter 49080 ---- Process: 98.16%
# Iter 49090 ---- Process: 98.18%
# Iter 49100 ---- Process: 98.20%
# Iter 49110 ---- Process: 98.22%
# Iter 49120 ---- Process: 98.24%
# Iter 49130 ---- Process: 98.26%
# Iter 49140 ---- Process: 98.28%
# Iter 49150 ---- Process: 98.30%
# Iter 49160 ---- Process: 98.32%
# Iter 49170 ---- Process: 98.34%
# Iter 49180 ---- Process: 98.36%
# Iter 49190 ---- Process: 98.38%
# Iter 49200 ---- Process: 98.40%
# Iter 49210 ---- Process: 98.42%
# Iter 49220 ---- Process: 98.44%
# Iter 49230 ---- Process: 98.46%
# Iter 49240 ---- Process: 98.48%
# Iter 49250 ---- Process: 98.50%
# Iter 49260 ---- Process: 98.52%
# Iter 49270 ---- Process: 98.54%
# Iter 49280 ---- Process: 98.56%
# Iter 49290 ---- Process: 98.58%
# Iter 49300 ---- Process: 98.60%
# Iter 49310 ---- Process: 98.62%
# Iter 49320 ---- Process: 98.64%
# Iter 49330 ---- Process: 98.66%
# Iter 49340 ---- Process: 98.68%
# Iter 49350 ---- Process: 98.70%
# Iter 49360 ---- Process: 98.72%
# Iter 49370 ---- Process: 98.74%
# Iter 49380 ---- Process: 98.76%
# Iter 49390 ---- Process: 98.78%
# Iter 49400 ---- Process: 98.80%
# Iter 49410 ---- Process: 98.82%
# Iter 49420 ---- Process: 98.84%
# Iter 49430 ---- Process: 98.86%
# Iter 49440 ---- Process: 98.88%
# Iter 49450 ---- Process: 98.90%
# Iter 49460 ---- Process: 98.92%
# Iter 49470 ---- Process: 98.94%
# Iter 49480 ---- Process: 98.96%
# Iter 49490 ---- Process: 98.98%
# Iter 49500 ---- Process: 99.00%
# Iter 49510 ---- Process: 99.02%
# Iter 49520 ---- Process: 99.04%
# Iter 49530 ---- Process: 99.06%
# Iter 49540 ---- Process: 99.08%
# Iter 49550 ---- Process: 99.10%
# Iter 49560 ---- Process: 99.12%
# Iter 49570 ---- Process: 99.14%
# Iter 49580 ---- Process: 99.16%
# Iter 49590 ---- Process: 99.18%
# Iter 49600 ---- Process: 99.20%
# Iter 49610 ---- Process: 99.22%
# Iter 49620 ---- Process: 99.24%
# Iter 49630 ---- Process: 99.26%
# Iter 49640 ---- Process: 99.28%
# Iter 49650 ---- Process: 99.30%
# Iter 49660 ---- Process: 99.32%
# Iter 49670 ---- Process: 99.34%
# Iter 49680 ---- Process: 99.36%
# Iter 49690 ---- Process: 99.38%
# Iter 49700 ---- Process: 99.40%
# Iter 49710 ---- Process: 99.42%
# Iter 49720 ---- Process: 99.44%
# Iter 49730 ---- Process: 99.46%
# Iter 49740 ---- Process: 99.48%
# Iter 49750 ---- Process: 99.50%
# Iter 49760 ---- Process: 99.52%
# Iter 49770 ---- Process: 99.54%
# Iter 49780 ---- Process: 99.56%
# Iter 49790 ---- Process: 99.58%
# Iter 49800 ---- Process: 99.60%
# Iter 49810 ---- Process: 99.62%
# Iter 49820 ---- Process: 99.64%
# Iter 49830 ---- Process: 99.66%
# Iter 49840 ---- Process: 99.68%
# Iter 49850 ---- Process: 99.70%
# Iter 49860 ---- Process: 99.72%
# Iter 49870 ---- Process: 99.74%
# Iter 49880 ---- Process: 99.76%
# Iter 49890 ---- Process: 99.78%
# Iter 49900 ---- Process: 99.80%
# Iter 49910 ---- Process: 99.82%
# Iter 49920 ---- Process: 99.84%
# Iter 49930 ---- Process: 99.86%
# Iter 49940 ---- Process: 99.88%
# Iter 49950 ---- Process: 99.90%
# Iter 49960 ---- Process: 99.92%
# Iter 49970 ---- Process: 99.94%
# Iter 49980 ---- Process: 99.96%
# Iter 49990 ---- Process: 99.98%

# %%
RList = np.zeros([(num_epoches/10)])
rmseList = np.zeros([(num_epoches/10)])
maxeList = np.zeros([(num_epoches/10)])
mapeList = np.zeros([(num_epoches/10)])
for i in range(kind):
    out = np.array(outlist[i])
    tmp = out.T.reshape((1,test_batch_size))
    RList[i] = np.corrcoef(tmp[0,:],test_y.T[0,:])[0,1]
    rmseList[i] = rmse(tmp[0,:],test_y.T[0,:])
    maxeList[i] = maxe(tmp[0,:],test_y.T[0,:])
    mapeList[i] = mape(tmp[0,:],test_y.T[0,:])

# %%
prefix = './gefcom-result/INC/'
postfix = '-' + str(num_layers) + '-' + str(n_hidden) + '.csv'
DataFrame(RList).to_csv(prefix + 'R' + postfix)
DataFrame(rmseList).to_csv(prefix + 'RMSE' + postfix)
DataFrame(maxeList).to_csv(prefix + 'MAXE' + postfix)
DataFrame(mapeList).to_csv(prefix + 'MAPE' + postfix)

# %%
out = out * 25000

# %%
#DataFrame(out).to_csv(prefix + 'out-oneoff.csv')

# %%
print np.mean(rmseList[-1001:-1])
rmseList
# Out:
# 0.00981511240684
# array([ 1.99646717,  0.31435449,  0.18647676, ...,  0.01075136,
#         0.01083745,  0.01022616])

# %%
time2 = time.time()
print time2-time1
# Out:
# 1770.02143598
