# %% [markdown]
# ###

# %% [markdown]
# # Deep Learning (RNN) Demo for Load Forecasting

# %% [markdown]
# ## SEC 1: Import all the packages needed

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mp
import random as rd
import argparse
import os, sys
import csv
import math
import time
import matplotlib.pyplot as pl

# %% [markdown]
# ## SEC 2: Load demand data from excel file

# %% [markdown]
# define class for dataset

# %%
class County:
    def __init__(self,parsename):
        self.parsename = parsename
        dataframe = xls.parse(parsename)
        self.date = dataframe['Date']
        self.hour = dataframe['Hr_End']
        self.demand = dataframe['RT_Demand']
        self.drybulb = dataframe['Dry_Bulb']
        self.dewpnt = dataframe['Dew_Point']
    def disp_all(self):
        print self.dataframe
    def get_all(self):
        return self.dataframe

# %% [markdown]
# load data

# %%
xls = pd.ExcelFile('smd_hourly.xls')
INC = County('ISO NE CA')
ME = County('ME')
NH = County('NH')
VT = County('VT')
CT = County('CT')
RI = County('RI')
SEMA = County('SEMA')
WCMA = County('WCMA')
NEMA = County('NEMA')

# %%
#print INC.date[-8*24:-1]

# %% [markdown]
# ## SEC 3: setting all global parameters

# %%
data_dir = './data/' # directory contains input data
num_epoches = 50000 # training epoches for each customer samples
day_steps = 24
n_steps = day_steps # input size
test_batch_size = 2*day_steps # days of a batch
validation_batch_size = 0*day_steps
train_batch_size = 2*day_steps
feature_size = 1 # same time of a week
n_hidden = 30 # input size
num_layers = 3
n_output = 1
totalen = np.array(INC.demand).shape[0]
tao = 0.1

# %% [markdown]
# ## SEC 4: split dataset into training, cross-validation, and test

# %% [markdown]
# concatenate data into database

# %%
# DEMAND MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.demand)
demand_mat = tmp.reshape([1,tmp.shape[0],1])
demand_mat = demand_mat/25000
#demand_mat = np.concatenate([demand_mat,np.array(ME.demand).reshape([1,np.array(ME.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NH.demand).reshape([1,np.array(NH.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(VT.demand).reshape([1,np.array(VT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(CT.demand).reshape([1,np.array(CT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(RI.demand).reshape([1,np.array(RI.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(SEMA.demand).reshape([1,np.array(SEMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(WCMA.demand).reshape([1,np.array(WCMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NEMA.demand).reshape([1,np.array(NEMA.demand).shape[0],1])],axis = 0)
print demand_mat.shape
# DRY BULB MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.drybulb)
drybulb_mat = tmp.reshape([1,tmp.shape[0],1])
drybulb_mat = drybulb_mat/100
#drybulb_mat = np.concatenate([drybulb_mat,np.array(ME.drybulb).reshape([1,np.array(ME.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NH.drybulb).reshape([1,np.array(NH.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(VT.drybulb).reshape([1,np.array(VT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(CT.drybulb).reshape([1,np.array(CT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(RI.drybulb).reshape([1,np.array(RI.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(SEMA.drybulb).reshape([1,np.array(SEMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(WCMA.drybulb).reshape([1,np.array(WCMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NEMA.drybulb).reshape([1,np.array(NEMA.drybulb).shape[0],1])],axis = 0)
#print drybulb_mat.shape
# DEW PNT MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.dewpnt)
dewpnt_mat = tmp.reshape([1,tmp.shape[0],1])
dewpnt_mat = dewpnt_mat/100
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(ME.dewpnt).reshape([1,np.array(ME.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NH.dewpnt).reshape([1,np.array(NH.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(VT.dewpnt).reshape([1,np.array(VT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(CT.dewpnt).reshape([1,np.array(CT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(RI.dewpnt).reshape([1,np.array(RI.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(SEMA.dewpnt).reshape([1,np.array(SEMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(WCMA.dewpnt).reshape([1,np.array(WCMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NEMA.dewpnt).reshape([1,np.array(NEMA.dewpnt).shape[0],1])],axis = 0)
#print dewpnt_mat.shape

#db = np.concatenate([demand_mat,dewpnt_mat,drybulb_mat],axis = 2)
#db = np.concatenate([demand_mat,dewpnt_mat],axis = 2)
db = demand_mat

print db.shape
# Out:
# (1, 5856, 1)
# (1, 5856, 1)

# %% [markdown]
# split into 3 parts using part array

# %%
#define id arrays
test_id = np.array(test_batch_size)
valid_id = np.array(validation_batch_size)
train_id = np.array(totalen-test_batch_size-validation_batch_size-n_steps)

#give values to id arrays
rang = range(n_steps + decay,totalen-test_batch_size)
valid_id = rd.sample(rang,validation_batch_size)
test_id = np.array(range(totalen-test_batch_size,totalen))
train_id = set(range(n_steps + decay,totalen-test_batch_size))-set(valid_id)

#sort three id array
valid_id = np.sort(valid_id)
test_id = np.sort(test_id)
train_id = np.array(list(train_id))

# %% [markdown]
# ### Step 4: define data generating function code.
# which generate a batch of batch-size large sequence data. the data is feature_size dims width and is a time series of float32 of steps steps. inputs and outputs are:
#
# inputs:
# ----n_batch: number of samples in a batch
# ----steps: the sequence length of a sample data
# ----feature_size: dimensions of a single time step data frame
#
# outputs:
# ----X inputs, shape(n_batch,steps,feature_size)
# ----Y outputs should be, shape(n_batch,)

# %%
def train_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps + decay,train_id.shape[0])
    train_rd = rd.sample(rang,train_batch_size)
    train_rd = np.sort(train_rd)
    for i in train_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps-decay:i-decay,:]
        count = count + 1
    return (X,Y)

# %%
def valid_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps + decay,valid_id.shape[0])
    valid_rd = rd.sample(rang,train_batch_size)
    valid_rd = np.sort(valid_rd)
    for i in valid_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps-decay:i-decay,:]
        count = count + 1
    return (X,Y)

# %%
def test_data_gen():
    X = np.zeros((test_batch_size,n_steps,feature_size))
    Y = np.zeros((test_batch_size,feature_size))
    count = 0
    for i in test_id:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps-decay:i-decay,:]
        count = count + 1
    return (X,Y)

# %%
# code testing
"""
(x,y) = test_data_gen()
print x.shape
x = x.reshape(test_batch_size,n_steps,feature_size)
print x[0,:,:]
"""
"""
count = 0
X = np.zeros((test_batch_size,n_steps,feature_size))
Y = np.zeros((test_batch_size,feature_size))
for i in test_id:
    print i
    Y[0] = db[:,i,:]
    X[0] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
"""
X = np.zeros((train_batch_size,n_steps,feature_size))
Y = np.zeros((train_batch_size,feature_size))
count = 0
rang = range(n_steps,train_id.shape[0])
train_rd = rd.sample(rang,train_batch_size)
train_rd = np.sort(train_rd)
for i in train_id:
    Y[count] = db[:,i,:]
    X[count] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
# Out:
# '\nX = np.zeros((train_batch_size,n_steps,feature_size))\nY = np.zeros((train_batch_size,feature_size))\ncount = 0\nrang = range(n_steps,train_id.shape[0])\ntrain_rd = rd.sample(rang,train_batch_size)\ntrain_rd = np.sort(train_rd)\nfor i in train_id:\n    Y[count] = db[:,i,:]\n    X[count] = db[:,i-n_steps:i,:]\n    count = count + 1\n    if count == 3:\n        break\nprint Y\nprint Y.shape\nprint X\nprint X.shape\n'

# %% [markdown]
# ### Step 5: construct RNN model

# %%
# create placeholder for x and y
#with tf.device('/gpu:0'):
x = tf.placeholder("float",[None,n_steps,feature_size])
istate = tf.placeholder("float",[None,num_layers*2*n_hidden])
y = tf.placeholder("float",[None,n_output])


# Define weights
weights = {
    'hidden': tf.Variable(tf.random_normal([feature_size, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_output]))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_output]))
}
def RNN(_X, _istate, _weights, _biases):
    # input shape: (batch_size, n_steps, n_input)
    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    # Reshape to prepare input to hidden activation
    _X = tf.reshape(_X, [-1, feature_size]) # (n_steps*batch_size, n_input)
    # Linear activation
    _X = tf.matmul(_X, _weights['hidden']) + _biases['hidden']

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    stacked_lstm_cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell]*num_layers)

    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(0, n_steps, _X) # n_steps * (batch_size, n_hidden)

    # Get lstm cell output
    outputs, states = tf.nn.rnn(stacked_lstm_cell, _X, initial_state=_istate)

    # Linear activation
    # Get inner loop last output
    return tf.matmul(outputs[-1], _weights['out']) + _biases['out']

pred = RNN(x, istate, weights, biases)
tmp = tf.Variable("float")
L = tf.Variable(initial_value = 0.0)
#cost function 
cost = tf.reduce_mean(tf.pow(pred[:,0]-y[:,0],2)) # cost function of this batch of data
for i in range(test_batch_size):
    tmp = tf.cond(pred[i,0]-y[i,0]>=0, lambda: (pred[i,0]-y[i,0])*tao,lambda:(y[i,0]-pred[i,0])*(1-tao))
    L = tf.add(tmp,L)
#compute parameter updates
#optimizer = tf.train.GradientDescentOptimizer(0.2).minimize(cost)
optimizer = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(L)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7f59a50a2110>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
def maxe(predictions, targets):
    return max(abs(predictions-targets))

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
def mape(predictions, targets):
    return np.mean(abs(predictions-targets)/targets)

# %%
outlist = np.zeros([(num_epoches/10),test_batch_size])
kind = 0
time1 = time.time()
# generate test data
test_x,test_y = test_data_gen()
test_x = test_x.reshape(test_batch_size,n_steps,feature_size)
### Execute
# Initializing the variables
init = tf.initialize_all_variables()

# %%
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    # Create a summary to monitor cost function
    #tf.scalar_summary("loss", cost)
    # Merge all summaries to a single operator
    #merged_summary_op = tf.merge_all_summaries()

    # tensorboard info.# Set logs writer into folder /tmp/tensorflow_logs
    #summary_writer = tf.train.SummaryWriter('/tmp/tensorflow_logs', graph_def=sess.graph_def)

    #initialize all variables in the model
    sess.run(init)
    for k in range(num_epoches):
        #Generate Data for each epoch
        #What this does is it creates a list of of elements of length seq_len, each of size [batch_size,input_size]
        #this is required to feed data into rnn.rnn
        #print traindays
        X,Y = train_data_gen()
        X = X.reshape(train_batch_size,n_steps,feature_size)


        #Create the dictionary of inputs to feed into sess.run
        #if k < 0:
        #    sess.run(optimizer2,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})
        #else:
        sess.run(optimizer,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})   
        #perform an update on the parameters
        #cost1 = sess.run(cost,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #print "Iter " + str(k) + ", Minibatch Loss ---- Train = " + str(cost1)
        # Write logs at every iteration
        #if k>50 & k%10 == 0:
        #    summary_str = sess.run(merged_summary_op, feed_dict={x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #    summary_writer.add_summary(summary_str, k)

        #if k % 10 == 0:
        if k % 10 == 0:
            #print test_x
            output_tmp_ex = sess.run(pred,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )  
            print "Iter " + str(k) + " ---- Process: " + "{:.2f}".format(100*float(k)/float(num_epoches)) + "%"
            outp_test = output_tmp_ex[:,0]
            #print outp_test[0:3]
            outlist[kind,:] = outp_test.copy().T
            kind = kind + 1
# Out:
# Iter 0 ---- Process: 0.00%
# Iter 10 ---- Process: 0.05%
# Iter 20 ---- Process: 0.10%
# Iter 30 ---- Process: 0.15%
# Iter 40 ---- Process: 0.20%
# Iter 50 ---- Process: 0.25%
# Iter 60 ---- Process: 0.30%
# Iter 70 ---- Process: 0.35%
# Iter 80 ---- Process: 0.40%
# Iter 90 ---- Process: 0.45%
# Iter 100 ---- Process: 0.50%
# Iter 110 ---- Process: 0.55%
# Iter 120 ---- Process: 0.60%
# Iter 130 ---- Process: 0.65%
# Iter 140 ---- Process: 0.70%
# Iter 150 ---- Process: 0.75%
# Iter 160 ---- Process: 0.80%
# Iter 170 ---- Process: 0.85%
# Iter 180 ---- Process: 0.90%
# Iter 190 ---- Process: 0.95%
# Iter 200 ---- Process: 1.00%
# Iter 210 ---- Process: 1.05%
# Iter 220 ---- Process: 1.10%
# Iter 230 ---- Process: 1.15%
# Iter 240 ---- Process: 1.20%
# Iter 250 ---- Process: 1.25%
# Iter 260 ---- Process: 1.30%
# Iter 270 ---- Process: 1.35%
# Iter 280 ---- Process: 1.40%
# Iter 290 ---- Process: 1.45%
# Iter 300 ---- Process: 1.50%
# Iter 310 ---- Process: 1.55%
# Iter 320 ---- Process: 1.60%
# Iter 330 ---- Process: 1.65%
# Iter 340 ---- Process: 1.70%
# Iter 350 ---- Process: 1.75%
# Iter 360 ---- Process: 1.80%
# Iter 370 ---- Process: 1.85%
# Iter 380 ---- Process: 1.90%
# Iter 390 ---- Process: 1.95%
# Iter 400 ---- Process: 2.00%
# Iter 410 ---- Process: 2.05%
# Iter 420 ---- Process: 2.10%
# Iter 430 ---- Process: 2.15%
# Iter 440 ---- Process: 2.20%
# Iter 450 ---- Process: 2.25%
# Iter 460 ---- Process: 2.30%
# Iter 470 ---- Process: 2.35%
# Iter 480 ---- Process: 2.40%
# Iter 490 ---- Process: 2.45%
# Iter 500 ---- Process: 2.50%
# Iter 510 ---- Process: 2.55%
# Iter 520 ---- Process: 2.60%
# Iter 530 ---- Process: 2.65%
# Iter 540 ---- Process: 2.70%
# Iter 550 ---- Process: 2.75%
# Iter 560 ---- Process: 2.80%
# Iter 570 ---- Process: 2.85%
# Iter 580 ---- Process: 2.90%
# Iter 590 ---- Process: 2.95%
# Iter 600 ---- Process: 3.00%
# Iter 610 ---- Process: 3.05%
# Iter 620 ---- Process: 3.10%
# Iter 630 ---- Process: 3.15%
# Iter 640 ---- Process: 3.20%
# Iter 650 ---- Process: 3.25%
# Iter 660 ---- Process: 3.30%
# Iter 670 ---- Process: 3.35%
# Iter 680 ---- Process: 3.40%
# Iter 690 ---- Process: 3.45%
# Iter 700 ---- Process: 3.50%
# Iter 710 ---- Process: 3.55%
# Iter 720 ---- Process: 3.60%
# Iter 730 ---- Process: 3.65%
# Iter 740 ---- Process: 3.70%
# Iter 750 ---- Process: 3.75%
# Iter 760 ---- Process: 3.80%
# Iter 770 ---- Process: 3.85%
# Iter 780 ---- Process: 3.90%
# Iter 790 ---- Process: 3.95%
# Iter 800 ---- Process: 4.00%
# Iter 810 ---- Process: 4.05%
# Iter 820 ---- Process: 4.10%
# Iter 830 ---- Process: 4.15%
# Iter 840 ---- Process: 4.20%
# Iter 850 ---- Process: 4.25%
# Iter 860 ---- Process: 4.30%
# Iter 870 ---- Process: 4.35%
# Iter 880 ---- Process: 4.40%
# Iter 890 ---- Process: 4.45%
# Iter 900 ---- Process: 4.50%
# Iter 910 ---- Process: 4.55%
# Iter 920 ---- Process: 4.60%
# Iter 930 ---- Process: 4.65%
# Iter 940 ---- Process: 4.70%
# Iter 950 ---- Process: 4.75%
# Iter 960 ---- Process: 4.80%
# Iter 970 ---- Process: 4.85%
# Iter 980 ---- Process: 4.90%
# Iter 990 ---- Process: 4.95%
# Iter 1000 ---- Process: 5.00%
# Iter 1010 ---- Process: 5.05%
# Iter 1020 ---- Process: 5.10%
# Iter 1030 ---- Process: 5.15%
# Iter 1040 ---- Process: 5.20%
# Iter 1050 ---- Process: 5.25%
# Iter 1060 ---- Process: 5.30%
# Iter 1070 ---- Process: 5.35%
# Iter 1080 ---- Process: 5.40%
# Iter 1090 ---- Process: 5.45%
# Iter 1100 ---- Process: 5.50%
# Iter 1110 ---- Process: 5.55%
# Iter 1120 ---- Process: 5.60%
# Iter 1130 ---- Process: 5.65%
# Iter 1140 ---- Process: 5.70%
# Iter 1150 ---- Process: 5.75%
# Iter 1160 ---- Process: 5.80%
# Iter 1170 ---- Process: 5.85%
# Iter 1180 ---- Process: 5.90%
# Iter 1190 ---- Process: 5.95%
# Iter 1200 ---- Process: 6.00%
# Iter 1210 ---- Process: 6.05%
# Iter 1220 ---- Process: 6.10%
# Iter 1230 ---- Process: 6.15%
# Iter 1240 ---- Process: 6.20%
# Iter 1250 ---- Process: 6.25%
# Iter 1260 ---- Process: 6.30%
# Iter 1270 ---- Process: 6.35%
# Iter 1280 ---- Process: 6.40%
# Iter 1290 ---- Process: 6.45%
# Iter 1300 ---- Process: 6.50%
# Iter 1310 ---- Process: 6.55%
# Iter 1320 ---- Process: 6.60%
# Iter 1330 ---- Process: 6.65%
# Iter 1340 ---- Process: 6.70%
# Iter 1350 ---- Process: 6.75%
# Iter 1360 ---- Process: 6.80%
# Iter 1370 ---- Process: 6.85%
# Iter 1380 ---- Process: 6.90%
# Iter 1390 ---- Process: 6.95%
# Iter 1400 ---- Process: 7.00%
# Iter 1410 ---- Process: 7.05%
# Iter 1420 ---- Process: 7.10%
# Iter 1430 ---- Process: 7.15%
# Iter 1440 ---- Process: 7.20%
# Iter 1450 ---- Process: 7.25%
# Iter 1460 ---- Process: 7.30%
# Iter 1470 ---- Process: 7.35%
# Iter 1480 ---- Process: 7.40%
# Iter 1490 ---- Process: 7.45%
# Iter 1500 ---- Process: 7.50%
# Iter 1510 ---- Process: 7.55%
# Iter 1520 ---- Process: 7.60%
# Iter 1530 ---- Process: 7.65%
# Iter 1540 ---- Process: 7.70%
# Iter 1550 ---- Process: 7.75%
# Iter 1560 ---- Process: 7.80%
# Iter 1570 ---- Process: 7.85%
# Iter 1580 ---- Process: 7.90%
# Iter 1590 ---- Process: 7.95%
# Iter 1600 ---- Process: 8.00%
# Iter 1610 ---- Process: 8.05%
# Iter 1620 ---- Process: 8.10%
# Iter 1630 ---- Process: 8.15%
# Iter 1640 ---- Process: 8.20%
# Iter 1650 ---- Process: 8.25%
# Iter 1660 ---- Process: 8.30%
# Iter 1670 ---- Process: 8.35%
# Iter 1680 ---- Process: 8.40%
# Iter 1690 ---- Process: 8.45%
# Iter 1700 ---- Process: 8.50%
# Iter 1710 ---- Process: 8.55%
# Iter 1720 ---- Process: 8.60%
# Iter 1730 ---- Process: 8.65%
# Iter 1740 ---- Process: 8.70%
# Iter 1750 ---- Process: 8.75%
# Iter 1760 ---- Process: 8.80%
# Iter 1770 ---- Process: 8.85%
# Iter 1780 ---- Process: 8.90%
# Iter 1790 ---- Process: 8.95%
# Iter 1800 ---- Process: 9.00%
# Iter 1810 ---- Process: 9.05%
# Iter 1820 ---- Process: 9.10%
# Iter 1830 ---- Process: 9.15%
# Iter 1840 ---- Process: 9.20%
# Iter 1850 ---- Process: 9.25%
# Iter 1860 ---- Process: 9.30%
# Iter 1870 ---- Process: 9.35%
# Iter 1880 ---- Process: 9.40%
# Iter 1890 ---- Process: 9.45%
# Iter 1900 ---- Process: 9.50%
# Iter 1910 ---- Process: 9.55%
# Iter 1920 ---- Process: 9.60%
# Iter 1930 ---- Process: 9.65%
# Iter 1940 ---- Process: 9.70%
# Iter 1950 ---- Process: 9.75%
# Iter 1960 ---- Process: 9.80%
# Iter 1970 ---- Process: 9.85%
# Iter 1980 ---- Process: 9.90%
# Iter 1990 ---- Process: 9.95%
# Iter 2000 ---- Process: 10.00%
# Iter 2010 ---- Process: 10.05%
# Iter 2020 ---- Process: 10.10%
# Iter 2030 ---- Process: 10.15%
# Iter 2040 ---- Process: 10.20%
# Iter 2050 ---- Process: 10.25%
# Iter 2060 ---- Process: 10.30%
# Iter 2070 ---- Process: 10.35%
# Iter 2080 ---- Process: 10.40%
# Iter 2090 ---- Process: 10.45%
# Iter 2100 ---- Process: 10.50%
# Iter 2110 ---- Process: 10.55%
# Iter 2120 ---- Process: 10.60%
# Iter 2130 ---- Process: 10.65%
# Iter 2140 ---- Process: 10.70%
# Iter 2150 ---- Process: 10.75%
# Iter 2160 ---- Process: 10.80%
# Iter 2170 ---- Process: 10.85%
# Iter 2180 ---- Process: 10.90%
# Iter 2190 ---- Process: 10.95%
# Iter 2200 ---- Process: 11.00%
# Iter 2210 ---- Process: 11.05%
# Iter 2220 ---- Process: 11.10%
# Iter 2230 ---- Process: 11.15%
# Iter 2240 ---- Process: 11.20%
# Iter 2250 ---- Process: 11.25%
# Iter 2260 ---- Process: 11.30%
# Iter 2270 ---- Process: 11.35%
# Iter 2280 ---- Process: 11.40%
# Iter 2290 ---- Process: 11.45%
# Iter 2300 ---- Process: 11.50%
# Iter 2310 ---- Process: 11.55%
# Iter 2320 ---- Process: 11.60%
# Iter 2330 ---- Process: 11.65%
# Iter 2340 ---- Process: 11.70%
# Iter 2350 ---- Process: 11.75%
# Iter 2360 ---- Process: 11.80%
# Iter 2370 ---- Process: 11.85%
# Iter 2380 ---- Process: 11.90%
# Iter 2390 ---- Process: 11.95%
# Iter 2400 ---- Process: 12.00%
# Iter 2410 ---- Process: 12.05%
# Iter 2420 ---- Process: 12.10%
# Iter 2430 ---- Process: 12.15%
# Iter 2440 ---- Process: 12.20%
# Iter 2450 ---- Process: 12.25%
# Iter 2460 ---- Process: 12.30%
# Iter 2470 ---- Process: 12.35%
# Iter 2480 ---- Process: 12.40%
# Iter 2490 ---- Process: 12.45%
# Iter 2500 ---- Process: 12.50%
# Iter 2510 ---- Process: 12.55%
# Iter 2520 ---- Process: 12.60%
# Iter 2530 ---- Process: 12.65%
# Iter 2540 ---- Process: 12.70%
# Iter 2550 ---- Process: 12.75%
# Iter 2560 ---- Process: 12.80%
# Iter 2570 ---- Process: 12.85%
# Iter 2580 ---- Process: 12.90%
# Iter 2590 ---- Process: 12.95%
# Iter 2600 ---- Process: 13.00%
# Iter 2610 ---- Process: 13.05%
# Iter 2620 ---- Process: 13.10%
# Iter 2630 ---- Process: 13.15%
# Iter 2640 ---- Process: 13.20%
# Iter 2650 ---- Process: 13.25%
# Iter 2660 ---- Process: 13.30%
# Iter 2670 ---- Process: 13.35%
# Iter 2680 ---- Process: 13.40%
# Iter 2690 ---- Process: 13.45%
# Iter 2700 ---- Process: 13.50%
# Iter 2710 ---- Process: 13.55%
# Iter 2720 ---- Process: 13.60%
# Iter 2730 ---- Process: 13.65%
# Iter 2740 ---- Process: 13.70%
# Iter 2750 ---- Process: 13.75%
# Iter 2760 ---- Process: 13.80%
# Iter 2770 ---- Process: 13.85%
# Iter 2780 ---- Process: 13.90%
# Iter 2790 ---- Process: 13.95%
# Iter 2800 ---- Process: 14.00%
# Iter 2810 ---- Process: 14.05%
# Iter 2820 ---- Process: 14.10%
# Iter 2830 ---- Process: 14.15%
# Iter 2840 ---- Process: 14.20%
# Iter 2850 ---- Process: 14.25%
# Iter 2860 ---- Process: 14.30%
# Iter 2870 ---- Process: 14.35%
# Iter 2880 ---- Process: 14.40%
# Iter 2890 ---- Process: 14.45%
# Iter 2900 ---- Process: 14.50%
# Iter 2910 ---- Process: 14.55%
# Iter 2920 ---- Process: 14.60%
# Iter 2930 ---- Process: 14.65%
# Iter 2940 ---- Process: 14.70%
# Iter 2950 ---- Process: 14.75%
# Iter 2960 ---- Process: 14.80%
# Iter 2970 ---- Process: 14.85%
# Iter 2980 ---- Process: 14.90%
# Iter 2990 ---- Process: 14.95%
# Iter 3000 ---- Process: 15.00%
# Iter 3010 ---- Process: 15.05%
# Iter 3020 ---- Process: 15.10%
# Iter 3030 ---- Process: 15.15%
# Iter 3040 ---- Process: 15.20%
# Iter 3050 ---- Process: 15.25%
# Iter 3060 ---- Process: 15.30%
# Iter 3070 ---- Process: 15.35%
# Iter 3080 ---- Process: 15.40%
# Iter 3090 ---- Process: 15.45%
# Iter 3100 ---- Process: 15.50%
# Iter 3110 ---- Process: 15.55%
# Iter 3120 ---- Process: 15.60%
# Iter 3130 ---- Process: 15.65%
# Iter 3140 ---- Process: 15.70%
# Iter 3150 ---- Process: 15.75%
# Iter 3160 ---- Process: 15.80%
# Iter 3170 ---- Process: 15.85%
# Iter 3180 ---- Process: 15.90%
# Iter 3190 ---- Process: 15.95%
# Iter 3200 ---- Process: 16.00%
# Iter 3210 ---- Process: 16.05%
# Iter 3220 ---- Process: 16.10%
# Iter 3230 ---- Process: 16.15%
# Iter 3240 ---- Process: 16.20%
# Iter 3250 ---- Process: 16.25%
# Iter 3260 ---- Process: 16.30%
# Iter 3270 ---- Process: 16.35%
# Iter 3280 ---- Process: 16.40%
# Iter 3290 ---- Process: 16.45%
# Iter 3300 ---- Process: 16.50%
# Iter 3310 ---- Process: 16.55%
# Iter 3320 ---- Process: 16.60%
# Iter 3330 ---- Process: 16.65%
# Iter 3340 ---- Process: 16.70%
# Iter 3350 ---- Process: 16.75%
# Iter 3360 ---- Process: 16.80%
# Iter 3370 ---- Process: 16.85%
# Iter 3380 ---- Process: 16.90%
# Iter 3390 ---- Process: 16.95%
# Iter 3400 ---- Process: 17.00%
# Iter 3410 ---- Process: 17.05%
# Iter 3420 ---- Process: 17.10%
# Iter 3430 ---- Process: 17.15%
# Iter 3440 ---- Process: 17.20%
# Iter 3450 ---- Process: 17.25%
# Iter 3460 ---- Process: 17.30%
# Iter 3470 ---- Process: 17.35%
# Iter 3480 ---- Process: 17.40%
# Iter 3490 ---- Process: 17.45%
# Iter 3500 ---- Process: 17.50%
# Iter 3510 ---- Process: 17.55%
# Iter 3520 ---- Process: 17.60%
# Iter 3530 ---- Process: 17.65%
# Iter 3540 ---- Process: 17.70%
# Iter 3550 ---- Process: 17.75%
# Iter 3560 ---- Process: 17.80%
# Iter 3570 ---- Process: 17.85%
# Iter 3580 ---- Process: 17.90%
# Iter 3590 ---- Process: 17.95%
# Iter 3600 ---- Process: 18.00%
# Iter 3610 ---- Process: 18.05%
# Iter 3620 ---- Process: 18.10%
# Iter 3630 ---- Process: 18.15%
# Iter 3640 ---- Process: 18.20%
# Iter 3650 ---- Process: 18.25%
# Iter 3660 ---- Process: 18.30%
# Iter 3670 ---- Process: 18.35%
# Iter 3680 ---- Process: 18.40%
# Iter 3690 ---- Process: 18.45%
# Iter 3700 ---- Process: 18.50%
# Iter 3710 ---- Process: 18.55%
# Iter 3720 ---- Process: 18.60%
# Iter 3730 ---- Process: 18.65%
# Iter 3740 ---- Process: 18.70%
# Iter 3750 ---- Process: 18.75%
# Iter 3760 ---- Process: 18.80%
# Iter 3770 ---- Process: 18.85%
# Iter 3780 ---- Process: 18.90%
# Iter 3790 ---- Process: 18.95%
# Iter 3800 ---- Process: 19.00%
# Iter 3810 ---- Process: 19.05%
# Iter 3820 ---- Process: 19.10%
# Iter 3830 ---- Process: 19.15%
# Iter 3840 ---- Process: 19.20%
# Iter 3850 ---- Process: 19.25%
# Iter 3860 ---- Process: 19.30%
# Iter 3870 ---- Process: 19.35%
# Iter 3880 ---- Process: 19.40%
# Iter 3890 ---- Process: 19.45%
# Iter 3900 ---- Process: 19.50%
# Iter 3910 ---- Process: 19.55%
# Iter 3920 ---- Process: 19.60%
# Iter 3930 ---- Process: 19.65%
# Iter 3940 ---- Process: 19.70%
# Iter 3950 ---- Process: 19.75%
# Iter 3960 ---- Process: 19.80%
# Iter 3970 ---- Process: 19.85%
# Iter 3980 ---- Process: 19.90%
# Iter 3990 ---- Process: 19.95%
# Iter 4000 ---- Process: 20.00%
# Iter 4010 ---- Process: 20.05%
# Iter 4020 ---- Process: 20.10%
# Iter 4030 ---- Process: 20.15%
# Iter 4040 ---- Process: 20.20%
# Iter 4050 ---- Process: 20.25%
# Iter 4060 ---- Process: 20.30%
# Iter 4070 ---- Process: 20.35%
# Iter 4080 ---- Process: 20.40%
# Iter 4090 ---- Process: 20.45%
# Iter 4100 ---- Process: 20.50%
# Iter 4110 ---- Process: 20.55%
# Iter 4120 ---- Process: 20.60%
# Iter 4130 ---- Process: 20.65%
# Iter 4140 ---- Process: 20.70%
# Iter 4150 ---- Process: 20.75%
# Iter 4160 ---- Process: 20.80%
# Iter 4170 ---- Process: 20.85%
# Iter 4180 ---- Process: 20.90%
# Iter 4190 ---- Process: 20.95%
# Iter 4200 ---- Process: 21.00%
# Iter 4210 ---- Process: 21.05%
# Iter 4220 ---- Process: 21.10%
# Iter 4230 ---- Process: 21.15%
# Iter 4240 ---- Process: 21.20%
# Iter 4250 ---- Process: 21.25%
# Iter 4260 ---- Process: 21.30%
# Iter 4270 ---- Process: 21.35%
# Iter 4280 ---- Process: 21.40%
# Iter 4290 ---- Process: 21.45%
# Iter 4300 ---- Process: 21.50%
# Iter 4310 ---- Process: 21.55%
# Iter 4320 ---- Process: 21.60%
# Iter 4330 ---- Process: 21.65%
# Iter 4340 ---- Process: 21.70%
# Iter 4350 ---- Process: 21.75%
# Iter 4360 ---- Process: 21.80%
# Iter 4370 ---- Process: 21.85%
# Iter 4380 ---- Process: 21.90%
# Iter 4390 ---- Process: 21.95%
# Iter 4400 ---- Process: 22.00%
# Iter 4410 ---- Process: 22.05%
# Iter 4420 ---- Process: 22.10%
# Iter 4430 ---- Process: 22.15%
# Iter 4440 ---- Process: 22.20%
# Iter 4450 ---- Process: 22.25%
# Iter 4460 ---- Process: 22.30%
# Iter 4470 ---- Process: 22.35%
# Iter 4480 ---- Process: 22.40%
# Iter 4490 ---- Process: 22.45%
# Iter 4500 ---- Process: 22.50%
# Iter 4510 ---- Process: 22.55%
# Iter 4520 ---- Process: 22.60%
# Iter 4530 ---- Process: 22.65%
# Iter 4540 ---- Process: 22.70%
# Iter 4550 ---- Process: 22.75%
# Iter 4560 ---- Process: 22.80%
# Iter 4570 ---- Process: 22.85%
# Iter 4580 ---- Process: 22.90%
# Iter 4590 ---- Process: 22.95%
# Iter 4600 ---- Process: 23.00%
# Iter 4610 ---- Process: 23.05%
# Iter 4620 ---- Process: 23.10%
# Iter 4630 ---- Process: 23.15%
# Iter 4640 ---- Process: 23.20%
# Iter 4650 ---- Process: 23.25%
# Iter 4660 ---- Process: 23.30%
# Iter 4670 ---- Process: 23.35%
# Iter 4680 ---- Process: 23.40%
# Iter 4690 ---- Process: 23.45%
# Iter 4700 ---- Process: 23.50%
# Iter 4710 ---- Process: 23.55%
# Iter 4720 ---- Process: 23.60%
# Iter 4730 ---- Process: 23.65%
# Iter 4740 ---- Process: 23.70%
# Iter 4750 ---- Process: 23.75%
# Iter 4760 ---- Process: 23.80%
# Iter 4770 ---- Process: 23.85%
# Iter 4780 ---- Process: 23.90%
# Iter 4790 ---- Process: 23.95%
# Iter 4800 ---- Process: 24.00%
# Iter 4810 ---- Process: 24.05%
# Iter 4820 ---- Process: 24.10%
# Iter 4830 ---- Process: 24.15%
# Iter 4840 ---- Process: 24.20%
# Iter 4850 ---- Process: 24.25%
# Iter 4860 ---- Process: 24.30%
# Iter 4870 ---- Process: 24.35%
# Iter 4880 ---- Process: 24.40%
# Iter 4890 ---- Process: 24.45%
# Iter 4900 ---- Process: 24.50%
# Iter 4910 ---- Process: 24.55%
# Iter 4920 ---- Process: 24.60%
# Iter 4930 ---- Process: 24.65%
# Iter 4940 ---- Process: 24.70%
# Iter 4950 ---- Process: 24.75%
# Iter 4960 ---- Process: 24.80%
# Iter 4970 ---- Process: 24.85%
# Iter 4980 ---- Process: 24.90%
# Iter 4990 ---- Process: 24.95%
# Iter 5000 ---- Process: 25.00%
# Iter 5010 ---- Process: 25.05%
# Iter 5020 ---- Process: 25.10%
# Iter 5030 ---- Process: 25.15%
# Iter 5040 ---- Process: 25.20%
# Iter 5050 ---- Process: 25.25%
# Iter 5060 ---- Process: 25.30%
# Iter 5070 ---- Process: 25.35%
# Iter 5080 ---- Process: 25.40%
# Iter 5090 ---- Process: 25.45%
# Iter 5100 ---- Process: 25.50%
# Iter 5110 ---- Process: 25.55%
# Iter 5120 ---- Process: 25.60%
# Iter 5130 ---- Process: 25.65%
# Iter 5140 ---- Process: 25.70%
# Iter 5150 ---- Process: 25.75%
# Iter 5160 ---- Process: 25.80%
# Iter 5170 ---- Process: 25.85%
# Iter 5180 ---- Process: 25.90%
# Iter 5190 ---- Process: 25.95%
# Iter 5200 ---- Process: 26.00%
# Iter 5210 ---- Process: 26.05%
# Iter 5220 ---- Process: 26.10%
# Iter 5230 ---- Process: 26.15%
# Iter 5240 ---- Process: 26.20%
# Iter 5250 ---- Process: 26.25%
# Iter 5260 ---- Process: 26.30%
# Iter 5270 ---- Process: 26.35%
# Iter 5280 ---- Process: 26.40%
# Iter 5290 ---- Process: 26.45%
# Iter 5300 ---- Process: 26.50%
# Iter 5310 ---- Process: 26.55%
# Iter 5320 ---- Process: 26.60%
# Iter 5330 ---- Process: 26.65%
# Iter 5340 ---- Process: 26.70%
# Iter 5350 ---- Process: 26.75%
# Iter 5360 ---- Process: 26.80%
# Iter 5370 ---- Process: 26.85%
# Iter 5380 ---- Process: 26.90%
# Iter 5390 ---- Process: 26.95%
# Iter 5400 ---- Process: 27.00%
# Iter 5410 ---- Process: 27.05%
# Iter 5420 ---- Process: 27.10%
# Iter 5430 ---- Process: 27.15%
# Iter 5440 ---- Process: 27.20%
# Iter 5450 ---- Process: 27.25%
# Iter 5460 ---- Process: 27.30%
# Iter 5470 ---- Process: 27.35%
# Iter 5480 ---- Process: 27.40%
# Iter 5490 ---- Process: 27.45%
# Iter 5500 ---- Process: 27.50%
# Iter 5510 ---- Process: 27.55%
# Iter 5520 ---- Process: 27.60%
# Iter 5530 ---- Process: 27.65%
# Iter 5540 ---- Process: 27.70%
# Iter 5550 ---- Process: 27.75%
# Iter 5560 ---- Process: 27.80%
# Iter 5570 ---- Process: 27.85%
# Iter 5580 ---- Process: 27.90%
# Iter 5590 ---- Process: 27.95%
# Iter 5600 ---- Process: 28.00%
# Iter 5610 ---- Process: 28.05%
# Iter 5620 ---- Process: 28.10%
# Iter 5630 ---- Process: 28.15%
# Iter 5640 ---- Process: 28.20%
# Iter 5650 ---- Process: 28.25%
# Iter 5660 ---- Process: 28.30%
# Iter 5670 ---- Process: 28.35%
# Iter 5680 ---- Process: 28.40%
# Iter 5690 ---- Process: 28.45%
# Iter 5700 ---- Process: 28.50%
# Iter 5710 ---- Process: 28.55%
# Iter 5720 ---- Process: 28.60%
# Iter 5730 ---- Process: 28.65%
# Iter 5740 ---- Process: 28.70%
# Iter 5750 ---- Process: 28.75%
# Iter 5760 ---- Process: 28.80%
# Iter 5770 ---- Process: 28.85%
# Iter 5780 ---- Process: 28.90%
# Iter 5790 ---- Process: 28.95%
# Iter 5800 ---- Process: 29.00%
# Iter 5810 ---- Process: 29.05%
# Iter 5820 ---- Process: 29.10%
# Iter 5830 ---- Process: 29.15%
# Iter 5840 ---- Process: 29.20%
# Iter 5850 ---- Process: 29.25%
# Iter 5860 ---- Process: 29.30%
# Iter 5870 ---- Process: 29.35%
# Iter 5880 ---- Process: 29.40%
# Iter 5890 ---- Process: 29.45%
# Iter 5900 ---- Process: 29.50%
# Iter 5910 ---- Process: 29.55%
# Iter 5920 ---- Process: 29.60%
# Iter 5930 ---- Process: 29.65%
# Iter 5940 ---- Process: 29.70%
# Iter 5950 ---- Process: 29.75%
# Iter 5960 ---- Process: 29.80%
# Iter 5970 ---- Process: 29.85%
# Iter 5980 ---- Process: 29.90%
# Iter 5990 ---- Process: 29.95%
# Iter 6000 ---- Process: 30.00%
# Iter 6010 ---- Process: 30.05%
# Iter 6020 ---- Process: 30.10%
# Iter 6030 ---- Process: 30.15%
# Iter 6040 ---- Process: 30.20%
# Iter 6050 ---- Process: 30.25%
# Iter 6060 ---- Process: 30.30%
# Iter 6070 ---- Process: 30.35%
# Iter 6080 ---- Process: 30.40%
# Iter 6090 ---- Process: 30.45%
# Iter 6100 ---- Process: 30.50%
# Iter 6110 ---- Process: 30.55%
# Iter 6120 ---- Process: 30.60%
# Iter 6130 ---- Process: 30.65%
# Iter 6140 ---- Process: 30.70%
# Iter 6150 ---- Process: 30.75%
# Iter 6160 ---- Process: 30.80%
# Iter 6170 ---- Process: 30.85%
# Iter 6180 ---- Process: 30.90%
# Iter 6190 ---- Process: 30.95%
# Iter 6200 ---- Process: 31.00%
# Iter 6210 ---- Process: 31.05%
# Iter 6220 ---- Process: 31.10%
# Iter 6230 ---- Process: 31.15%
# Iter 6240 ---- Process: 31.20%
# Iter 6250 ---- Process: 31.25%
# Iter 6260 ---- Process: 31.30%
# Iter 6270 ---- Process: 31.35%
# Iter 6280 ---- Process: 31.40%
# Iter 6290 ---- Process: 31.45%
# Iter 6300 ---- Process: 31.50%
# Iter 6310 ---- Process: 31.55%
# Iter 6320 ---- Process: 31.60%
# Iter 6330 ---- Process: 31.65%
# Iter 6340 ---- Process: 31.70%
# Iter 6350 ---- Process: 31.75%
# Iter 6360 ---- Process: 31.80%
# Iter 6370 ---- Process: 31.85%
# Iter 6380 ---- Process: 31.90%
# Iter 6390 ---- Process: 31.95%
# Iter 6400 ---- Process: 32.00%
# Iter 6410 ---- Process: 32.05%
# Iter 6420 ---- Process: 32.10%
# Iter 6430 ---- Process: 32.15%
# Iter 6440 ---- Process: 32.20%
# Iter 6450 ---- Process: 32.25%
# Iter 6460 ---- Process: 32.30%
# Iter 6470 ---- Process: 32.35%
# Iter 6480 ---- Process: 32.40%
# Iter 6490 ---- Process: 32.45%
# Iter 6500 ---- Process: 32.50%
# Iter 6510 ---- Process: 32.55%
# Iter 6520 ---- Process: 32.60%
# Iter 6530 ---- Process: 32.65%
# Iter 6540 ---- Process: 32.70%
# Iter 6550 ---- Process: 32.75%
# Iter 6560 ---- Process: 32.80%
# Iter 6570 ---- Process: 32.85%
# Iter 6580 ---- Process: 32.90%
# Iter 6590 ---- Process: 32.95%
# Iter 6600 ---- Process: 33.00%
# Iter 6610 ---- Process: 33.05%
# Iter 6620 ---- Process: 33.10%
# Iter 6630 ---- Process: 33.15%
# Iter 6640 ---- Process: 33.20%
# Iter 6650 ---- Process: 33.25%
# Iter 6660 ---- Process: 33.30%
# Iter 6670 ---- Process: 33.35%
# Iter 6680 ---- Process: 33.40%
# Iter 6690 ---- Process: 33.45%
# Iter 6700 ---- Process: 33.50%
# Iter 6710 ---- Process: 33.55%
# Iter 6720 ---- Process: 33.60%
# Iter 6730 ---- Process: 33.65%
# Iter 6740 ---- Process: 33.70%
# Iter 6750 ---- Process: 33.75%
# Iter 6760 ---- Process: 33.80%
# Iter 6770 ---- Process: 33.85%
# Iter 6780 ---- Process: 33.90%
# Iter 6790 ---- Process: 33.95%
# Iter 6800 ---- Process: 34.00%
# Iter 6810 ---- Process: 34.05%
# Iter 6820 ---- Process: 34.10%
# Iter 6830 ---- Process: 34.15%
# Iter 6840 ---- Process: 34.20%
# Iter 6850 ---- Process: 34.25%
# Iter 6860 ---- Process: 34.30%
# Iter 6870 ---- Process: 34.35%
# Iter 6880 ---- Process: 34.40%
# Iter 6890 ---- Process: 34.45%
# Iter 6900 ---- Process: 34.50%
# Iter 6910 ---- Process: 34.55%
# Iter 6920 ---- Process: 34.60%
# Iter 6930 ---- Process: 34.65%
# Iter 6940 ---- Process: 34.70%
# Iter 6950 ---- Process: 34.75%
# Iter 6960 ---- Process: 34.80%
# Iter 6970 ---- Process: 34.85%
# Iter 6980 ---- Process: 34.90%
# Iter 6990 ---- Process: 34.95%
# Iter 7000 ---- Process: 35.00%
# Iter 7010 ---- Process: 35.05%
# Iter 7020 ---- Process: 35.10%
# Iter 7030 ---- Process: 35.15%
# Iter 7040 ---- Process: 35.20%
# Iter 7050 ---- Process: 35.25%
# Iter 7060 ---- Process: 35.30%
# Iter 7070 ---- Process: 35.35%
# Iter 7080 ---- Process: 35.40%
# Iter 7090 ---- Process: 35.45%
# Iter 7100 ---- Process: 35.50%
# Iter 7110 ---- Process: 35.55%
# Iter 7120 ---- Process: 35.60%
# Iter 7130 ---- Process: 35.65%
# Iter 7140 ---- Process: 35.70%
# Iter 7150 ---- Process: 35.75%
# Iter 7160 ---- Process: 35.80%
# Iter 7170 ---- Process: 35.85%
# Iter 7180 ---- Process: 35.90%
# Iter 7190 ---- Process: 35.95%
# Iter 7200 ---- Process: 36.00%
# Iter 7210 ---- Process: 36.05%
# Iter 7220 ---- Process: 36.10%
# Iter 7230 ---- Process: 36.15%
# Iter 7240 ---- Process: 36.20%
# Iter 7250 ---- Process: 36.25%
# Iter 7260 ---- Process: 36.30%
# Iter 7270 ---- Process: 36.35%
# Iter 7280 ---- Process: 36.40%
# Iter 7290 ---- Process: 36.45%
# Iter 7300 ---- Process: 36.50%
# Iter 7310 ---- Process: 36.55%
# Iter 7320 ---- Process: 36.60%
# Iter 7330 ---- Process: 36.65%
# Iter 7340 ---- Process: 36.70%
# Iter 7350 ---- Process: 36.75%
# Iter 7360 ---- Process: 36.80%
# Iter 7370 ---- Process: 36.85%
# Iter 7380 ---- Process: 36.90%
# Iter 7390 ---- Process: 36.95%
# Iter 7400 ---- Process: 37.00%
# Iter 7410 ---- Process: 37.05%
# Iter 7420 ---- Process: 37.10%
# Iter 7430 ---- Process: 37.15%
# Iter 7440 ---- Process: 37.20%
# Iter 7450 ---- Process: 37.25%
# Iter 7460 ---- Process: 37.30%
# Iter 7470 ---- Process: 37.35%
# Iter 7480 ---- Process: 37.40%
# Iter 7490 ---- Process: 37.45%
# Iter 7500 ---- Process: 37.50%
# Iter 7510 ---- Process: 37.55%
# Iter 7520 ---- Process: 37.60%
# Iter 7530 ---- Process: 37.65%
# Iter 7540 ---- Process: 37.70%
# Iter 7550 ---- Process: 37.75%
# Iter 7560 ---- Process: 37.80%
# Iter 7570 ---- Process: 37.85%
# Iter 7580 ---- Process: 37.90%
# Iter 7590 ---- Process: 37.95%
# Iter 7600 ---- Process: 38.00%
# Iter 7610 ---- Process: 38.05%
# Iter 7620 ---- Process: 38.10%
# Iter 7630 ---- Process: 38.15%
# Iter 7640 ---- Process: 38.20%
# Iter 7650 ---- Process: 38.25%
# Iter 7660 ---- Process: 38.30%
# Iter 7670 ---- Process: 38.35%
# Iter 7680 ---- Process: 38.40%
# Iter 7690 ---- Process: 38.45%
# Iter 7700 ---- Process: 38.50%
# Iter 7710 ---- Process: 38.55%
# Iter 7720 ---- Process: 38.60%
# Iter 7730 ---- Process: 38.65%
# Iter 7740 ---- Process: 38.70%
# Iter 7750 ---- Process: 38.75%
# Iter 7760 ---- Process: 38.80%
# Iter 7770 ---- Process: 38.85%
# Iter 7780 ---- Process: 38.90%
# Iter 7790 ---- Process: 38.95%
# Iter 7800 ---- Process: 39.00%
# Iter 7810 ---- Process: 39.05%
# Iter 7820 ---- Process: 39.10%
# Iter 7830 ---- Process: 39.15%
# Iter 7840 ---- Process: 39.20%
# Iter 7850 ---- Process: 39.25%
# Iter 7860 ---- Process: 39.30%
# Iter 7870 ---- Process: 39.35%
# Iter 7880 ---- Process: 39.40%
# Iter 7890 ---- Process: 39.45%
# Iter 7900 ---- Process: 39.50%
# Iter 7910 ---- Process: 39.55%
# Iter 7920 ---- Process: 39.60%
# Iter 7930 ---- Process: 39.65%
# Iter 7940 ---- Process: 39.70%
# Iter 7950 ---- Process: 39.75%
# Iter 7960 ---- Process: 39.80%
# Iter 7970 ---- Process: 39.85%
# Iter 7980 ---- Process: 39.90%
# Iter 7990 ---- Process: 39.95%
# Iter 8000 ---- Process: 40.00%
# Iter 8010 ---- Process: 40.05%
# Iter 8020 ---- Process: 40.10%
# Iter 8030 ---- Process: 40.15%
# Iter 8040 ---- Process: 40.20%
# Iter 8050 ---- Process: 40.25%
# Iter 8060 ---- Process: 40.30%
# Iter 8070 ---- Process: 40.35%
# Iter 8080 ---- Process: 40.40%
# Iter 8090 ---- Process: 40.45%
# Iter 8100 ---- Process: 40.50%
# Iter 8110 ---- Process: 40.55%
# Iter 8120 ---- Process: 40.60%
# Iter 8130 ---- Process: 40.65%
# Iter 8140 ---- Process: 40.70%
# Iter 8150 ---- Process: 40.75%
# Iter 8160 ---- Process: 40.80%
# Iter 8170 ---- Process: 40.85%
# Iter 8180 ---- Process: 40.90%
# Iter 8190 ---- Process: 40.95%
# Iter 8200 ---- Process: 41.00%
# Iter 8210 ---- Process: 41.05%
# Iter 8220 ---- Process: 41.10%
# Iter 8230 ---- Process: 41.15%
# Iter 8240 ---- Process: 41.20%
# Iter 8250 ---- Process: 41.25%
# Iter 8260 ---- Process: 41.30%
# Iter 8270 ---- Process: 41.35%
# Iter 8280 ---- Process: 41.40%
# Iter 8290 ---- Process: 41.45%
# Iter 8300 ---- Process: 41.50%
# Iter 8310 ---- Process: 41.55%
# Iter 8320 ---- Process: 41.60%
# Iter 8330 ---- Process: 41.65%
# Iter 8340 ---- Process: 41.70%
# Iter 8350 ---- Process: 41.75%
# Iter 8360 ---- Process: 41.80%
# Iter 8370 ---- Process: 41.85%
# Iter 8380 ---- Process: 41.90%
# Iter 8390 ---- Process: 41.95%
# Iter 8400 ---- Process: 42.00%
# Iter 8410 ---- Process: 42.05%
# Iter 8420 ---- Process: 42.10%
# Iter 8430 ---- Process: 42.15%
# Iter 8440 ---- Process: 42.20%
# Iter 8450 ---- Process: 42.25%
# Iter 8460 ---- Process: 42.30%
# Iter 8470 ---- Process: 42.35%
# Iter 8480 ---- Process: 42.40%
# Iter 8490 ---- Process: 42.45%
# Iter 8500 ---- Process: 42.50%
# Iter 8510 ---- Process: 42.55%
# Iter 8520 ---- Process: 42.60%
# Iter 8530 ---- Process: 42.65%
# Iter 8540 ---- Process: 42.70%
# Iter 8550 ---- Process: 42.75%
# Iter 8560 ---- Process: 42.80%
# Iter 8570 ---- Process: 42.85%
# Iter 8580 ---- Process: 42.90%
# Iter 8590 ---- Process: 42.95%
# Iter 8600 ---- Process: 43.00%
# Iter 8610 ---- Process: 43.05%
# Iter 8620 ---- Process: 43.10%
# Iter 8630 ---- Process: 43.15%
# Iter 8640 ---- Process: 43.20%
# Iter 8650 ---- Process: 43.25%
# Iter 8660 ---- Process: 43.30%
# Iter 8670 ---- Process: 43.35%
# Iter 8680 ---- Process: 43.40%
# Iter 8690 ---- Process: 43.45%
# Iter 8700 ---- Process: 43.50%
# Iter 8710 ---- Process: 43.55%
# Iter 8720 ---- Process: 43.60%
# Iter 8730 ---- Process: 43.65%
# Iter 8740 ---- Process: 43.70%
# Iter 8750 ---- Process: 43.75%
# Iter 8760 ---- Process: 43.80%
# Iter 8770 ---- Process: 43.85%
# Iter 8780 ---- Process: 43.90%
# Iter 8790 ---- Process: 43.95%
# Iter 8800 ---- Process: 44.00%
# Iter 8810 ---- Process: 44.05%
# Iter 8820 ---- Process: 44.10%
# Iter 8830 ---- Process: 44.15%
# Iter 8840 ---- Process: 44.20%
# Iter 8850 ---- Process: 44.25%
# Iter 8860 ---- Process: 44.30%
# Iter 8870 ---- Process: 44.35%
# Iter 8880 ---- Process: 44.40%
# Iter 8890 ---- Process: 44.45%
# Iter 8900 ---- Process: 44.50%
# Iter 8910 ---- Process: 44.55%
# Iter 8920 ---- Process: 44.60%
# Iter 8930 ---- Process: 44.65%
# Iter 8940 ---- Process: 44.70%
# Iter 8950 ---- Process: 44.75%
# Iter 8960 ---- Process: 44.80%
# Iter 8970 ---- Process: 44.85%
# Iter 8980 ---- Process: 44.90%
# Iter 8990 ---- Process: 44.95%
# Iter 9000 ---- Process: 45.00%
# Iter 9010 ---- Process: 45.05%
# Iter 9020 ---- Process: 45.10%
# Iter 9030 ---- Process: 45.15%
# Iter 9040 ---- Process: 45.20%
# Iter 9050 ---- Process: 45.25%
# Iter 9060 ---- Process: 45.30%
# Iter 9070 ---- Process: 45.35%
# Iter 9080 ---- Process: 45.40%
# Iter 9090 ---- Process: 45.45%
# Iter 9100 ---- Process: 45.50%
# Iter 9110 ---- Process: 45.55%
# Iter 9120 ---- Process: 45.60%
# Iter 9130 ---- Process: 45.65%
# Iter 9140 ---- Process: 45.70%
# Iter 9150 ---- Process: 45.75%
# Iter 9160 ---- Process: 45.80%
# Iter 9170 ---- Process: 45.85%
# Iter 9180 ---- Process: 45.90%
# Iter 9190 ---- Process: 45.95%
# Iter 9200 ---- Process: 46.00%
# Iter 9210 ---- Process: 46.05%
# Iter 9220 ---- Process: 46.10%
# Iter 9230 ---- Process: 46.15%
# Iter 9240 ---- Process: 46.20%
# Iter 9250 ---- Process: 46.25%
# Iter 9260 ---- Process: 46.30%
# Iter 9270 ---- Process: 46.35%
# Iter 9280 ---- Process: 46.40%
# Iter 9290 ---- Process: 46.45%
# Iter 9300 ---- Process: 46.50%
# Iter 9310 ---- Process: 46.55%
# Iter 9320 ---- Process: 46.60%
# Iter 9330 ---- Process: 46.65%
# Iter 9340 ---- Process: 46.70%
# Iter 9350 ---- Process: 46.75%
# Iter 9360 ---- Process: 46.80%
# Iter 9370 ---- Process: 46.85%
# Iter 9380 ---- Process: 46.90%
# Iter 9390 ---- Process: 46.95%
# Iter 9400 ---- Process: 47.00%
# Iter 9410 ---- Process: 47.05%
# Iter 9420 ---- Process: 47.10%
# Iter 9430 ---- Process: 47.15%
# Iter 9440 ---- Process: 47.20%
# Iter 9450 ---- Process: 47.25%
# Iter 9460 ---- Process: 47.30%
# Iter 9470 ---- Process: 47.35%
# Iter 9480 ---- Process: 47.40%
# Iter 9490 ---- Process: 47.45%
# Iter 9500 ---- Process: 47.50%
# Iter 9510 ---- Process: 47.55%
# Iter 9520 ---- Process: 47.60%
# Iter 9530 ---- Process: 47.65%
# Iter 9540 ---- Process: 47.70%
# Iter 9550 ---- Process: 47.75%
# Iter 9560 ---- Process: 47.80%
# Iter 9570 ---- Process: 47.85%
# Iter 9580 ---- Process: 47.90%
# Iter 9590 ---- Process: 47.95%
# Iter 9600 ---- Process: 48.00%
# Iter 9610 ---- Process: 48.05%
# Iter 9620 ---- Process: 48.10%
# Iter 9630 ---- Process: 48.15%
# Iter 9640 ---- Process: 48.20%
# Iter 9650 ---- Process: 48.25%
# Iter 9660 ---- Process: 48.30%
# Iter 9670 ---- Process: 48.35%
# Iter 9680 ---- Process: 48.40%
# Iter 9690 ---- Process: 48.45%
# Iter 9700 ---- Process: 48.50%
# Iter 9710 ---- Process: 48.55%
# Iter 9720 ---- Process: 48.60%
# Iter 9730 ---- Process: 48.65%
# Iter 9740 ---- Process: 48.70%
# Iter 9750 ---- Process: 48.75%
# Iter 9760 ---- Process: 48.80%
# Iter 9770 ---- Process: 48.85%
# Iter 9780 ---- Process: 48.90%
# Iter 9790 ---- Process: 48.95%
# Iter 9800 ---- Process: 49.00%
# Iter 9810 ---- Process: 49.05%
# Iter 9820 ---- Process: 49.10%
# Iter 9830 ---- Process: 49.15%
# Iter 9840 ---- Process: 49.20%
# Iter 9850 ---- Process: 49.25%
# Iter 9860 ---- Process: 49.30%
# Iter 9870 ---- Process: 49.35%
# Iter 9880 ---- Process: 49.40%
# Iter 9890 ---- Process: 49.45%
# Iter 9900 ---- Process: 49.50%
# Iter 9910 ---- Process: 49.55%
# Iter 9920 ---- Process: 49.60%
# Iter 9930 ---- Process: 49.65%
# Iter 9940 ---- Process: 49.70%
# Iter 9950 ---- Process: 49.75%
# Iter 9960 ---- Process: 49.80%
# Iter 9970 ---- Process: 49.85%
# Iter 9980 ---- Process: 49.90%
# Iter 9990 ---- Process: 49.95%
# Iter 10000 ---- Process: 50.00%
# Iter 10010 ---- Process: 50.05%
# Iter 10020 ---- Process: 50.10%
# Iter 10030 ---- Process: 50.15%
# Iter 10040 ---- Process: 50.20%
# Iter 10050 ---- Process: 50.25%
# Iter 10060 ---- Process: 50.30%
# Iter 10070 ---- Process: 50.35%
# Iter 10080 ---- Process: 50.40%
# Iter 10090 ---- Process: 50.45%
# Iter 10100 ---- Process: 50.50%
# Iter 10110 ---- Process: 50.55%
# Iter 10120 ---- Process: 50.60%
# Iter 10130 ---- Process: 50.65%
# Iter 10140 ---- Process: 50.70%
# Iter 10150 ---- Process: 50.75%
# Iter 10160 ---- Process: 50.80%
# Iter 10170 ---- Process: 50.85%
# Iter 10180 ---- Process: 50.90%
# Iter 10190 ---- Process: 50.95%
# Iter 10200 ---- Process: 51.00%
# Iter 10210 ---- Process: 51.05%
# Iter 10220 ---- Process: 51.10%
# Iter 10230 ---- Process: 51.15%
# Iter 10240 ---- Process: 51.20%
# Iter 10250 ---- Process: 51.25%
# Iter 10260 ---- Process: 51.30%
# Iter 10270 ---- Process: 51.35%
# Iter 10280 ---- Process: 51.40%
# Iter 10290 ---- Process: 51.45%
# Iter 10300 ---- Process: 51.50%
# Iter 10310 ---- Process: 51.55%
# Iter 10320 ---- Process: 51.60%
# Iter 10330 ---- Process: 51.65%
# Iter 10340 ---- Process: 51.70%
# Iter 10350 ---- Process: 51.75%
# Iter 10360 ---- Process: 51.80%
# Iter 10370 ---- Process: 51.85%
# Iter 10380 ---- Process: 51.90%
# Iter 10390 ---- Process: 51.95%
# Iter 10400 ---- Process: 52.00%
# Iter 10410 ---- Process: 52.05%
# Iter 10420 ---- Process: 52.10%
# Iter 10430 ---- Process: 52.15%
# Iter 10440 ---- Process: 52.20%
# Iter 10450 ---- Process: 52.25%
# Iter 10460 ---- Process: 52.30%
# Iter 10470 ---- Process: 52.35%
# Iter 10480 ---- Process: 52.40%
# Iter 10490 ---- Process: 52.45%
# Iter 10500 ---- Process: 52.50%
# Iter 10510 ---- Process: 52.55%
# Iter 10520 ---- Process: 52.60%
# Iter 10530 ---- Process: 52.65%
# Iter 10540 ---- Process: 52.70%
# Iter 10550 ---- Process: 52.75%
# Iter 10560 ---- Process: 52.80%
# Iter 10570 ---- Process: 52.85%
# Iter 10580 ---- Process: 52.90%
# Iter 10590 ---- Process: 52.95%
# Iter 10600 ---- Process: 53.00%
# Iter 10610 ---- Process: 53.05%
# Iter 10620 ---- Process: 53.10%
# Iter 10630 ---- Process: 53.15%
# Iter 10640 ---- Process: 53.20%
# Iter 10650 ---- Process: 53.25%
# Iter 10660 ---- Process: 53.30%
# Iter 10670 ---- Process: 53.35%
# Iter 10680 ---- Process: 53.40%
# Iter 10690 ---- Process: 53.45%
# Iter 10700 ---- Process: 53.50%
# Iter 10710 ---- Process: 53.55%
# Iter 10720 ---- Process: 53.60%
# Iter 10730 ---- Process: 53.65%
# Iter 10740 ---- Process: 53.70%
# Iter 10750 ---- Process: 53.75%
# Iter 10760 ---- Process: 53.80%
# Iter 10770 ---- Process: 53.85%
# Iter 10780 ---- Process: 53.90%
# Iter 10790 ---- Process: 53.95%
# Iter 10800 ---- Process: 54.00%
# Iter 10810 ---- Process: 54.05%
# Iter 10820 ---- Process: 54.10%
# Iter 10830 ---- Process: 54.15%
# Iter 10840 ---- Process: 54.20%
# Iter 10850 ---- Process: 54.25%
# Iter 10860 ---- Process: 54.30%
# Iter 10870 ---- Process: 54.35%
# Iter 10880 ---- Process: 54.40%
# Iter 10890 ---- Process: 54.45%
# Iter 10900 ---- Process: 54.50%
# Iter 10910 ---- Process: 54.55%
# Iter 10920 ---- Process: 54.60%
# Iter 10930 ---- Process: 54.65%
# Iter 10940 ---- Process: 54.70%
# Iter 10950 ---- Process: 54.75%
# Iter 10960 ---- Process: 54.80%
# Iter 10970 ---- Process: 54.85%
# Iter 10980 ---- Process: 54.90%
# Iter 10990 ---- Process: 54.95%
# Iter 11000 ---- Process: 55.00%
# Iter 11010 ---- Process: 55.05%
# Iter 11020 ---- Process: 55.10%
# Iter 11030 ---- Process: 55.15%
# Iter 11040 ---- Process: 55.20%
# Iter 11050 ---- Process: 55.25%
# Iter 11060 ---- Process: 55.30%
# Iter 11070 ---- Process: 55.35%
# Iter 11080 ---- Process: 55.40%
# Iter 11090 ---- Process: 55.45%
# Iter 11100 ---- Process: 55.50%
# Iter 11110 ---- Process: 55.55%
# Iter 11120 ---- Process: 55.60%
# Iter 11130 ---- Process: 55.65%
# Iter 11140 ---- Process: 55.70%
# Iter 11150 ---- Process: 55.75%
# Iter 11160 ---- Process: 55.80%
# Iter 11170 ---- Process: 55.85%
# Iter 11180 ---- Process: 55.90%
# Iter 11190 ---- Process: 55.95%
# Iter 11200 ---- Process: 56.00%
# Iter 11210 ---- Process: 56.05%
# Iter 11220 ---- Process: 56.10%
# Iter 11230 ---- Process: 56.15%
# Iter 11240 ---- Process: 56.20%
# Iter 11250 ---- Process: 56.25%
# Iter 11260 ---- Process: 56.30%
# Iter 11270 ---- Process: 56.35%
# Iter 11280 ---- Process: 56.40%
# Iter 11290 ---- Process: 56.45%
# Iter 11300 ---- Process: 56.50%
# Iter 11310 ---- Process: 56.55%
# Iter 11320 ---- Process: 56.60%
# Iter 11330 ---- Process: 56.65%
# Iter 11340 ---- Process: 56.70%
# Iter 11350 ---- Process: 56.75%
# Iter 11360 ---- Process: 56.80%
# Iter 11370 ---- Process: 56.85%
# Iter 11380 ---- Process: 56.90%
# Iter 11390 ---- Process: 56.95%
# Iter 11400 ---- Process: 57.00%
# Iter 11410 ---- Process: 57.05%
# Iter 11420 ---- Process: 57.10%
# Iter 11430 ---- Process: 57.15%
# Iter 11440 ---- Process: 57.20%
# Iter 11450 ---- Process: 57.25%
# Iter 11460 ---- Process: 57.30%
# Iter 11470 ---- Process: 57.35%
# Iter 11480 ---- Process: 57.40%
# Iter 11490 ---- Process: 57.45%
# Iter 11500 ---- Process: 57.50%
# Iter 11510 ---- Process: 57.55%
# Iter 11520 ---- Process: 57.60%
# Iter 11530 ---- Process: 57.65%
# Iter 11540 ---- Process: 57.70%
# Iter 11550 ---- Process: 57.75%
# Iter 11560 ---- Process: 57.80%
# Iter 11570 ---- Process: 57.85%
# Iter 11580 ---- Process: 57.90%
# Iter 11590 ---- Process: 57.95%
# Iter 11600 ---- Process: 58.00%
# Iter 11610 ---- Process: 58.05%
# Iter 11620 ---- Process: 58.10%
# Iter 11630 ---- Process: 58.15%
# Iter 11640 ---- Process: 58.20%
# Iter 11650 ---- Process: 58.25%
# Iter 11660 ---- Process: 58.30%
# Iter 11670 ---- Process: 58.35%
# Iter 11680 ---- Process: 58.40%
# Iter 11690 ---- Process: 58.45%
# Iter 11700 ---- Process: 58.50%
# Iter 11710 ---- Process: 58.55%
# Iter 11720 ---- Process: 58.60%
# Iter 11730 ---- Process: 58.65%
# Iter 11740 ---- Process: 58.70%
# Iter 11750 ---- Process: 58.75%
# Iter 11760 ---- Process: 58.80%
# Iter 11770 ---- Process: 58.85%
# Iter 11780 ---- Process: 58.90%
# Iter 11790 ---- Process: 58.95%
# Iter 11800 ---- Process: 59.00%
# Iter 11810 ---- Process: 59.05%
# Iter 11820 ---- Process: 59.10%
# Iter 11830 ---- Process: 59.15%
# Iter 11840 ---- Process: 59.20%
# Iter 11850 ---- Process: 59.25%
# Iter 11860 ---- Process: 59.30%
# Iter 11870 ---- Process: 59.35%
# Iter 11880 ---- Process: 59.40%
# Iter 11890 ---- Process: 59.45%
# Iter 11900 ---- Process: 59.50%
# Iter 11910 ---- Process: 59.55%
# Iter 11920 ---- Process: 59.60%
# Iter 11930 ---- Process: 59.65%
# Iter 11940 ---- Process: 59.70%
# Iter 11950 ---- Process: 59.75%
# Iter 11960 ---- Process: 59.80%
# Iter 11970 ---- Process: 59.85%
# Iter 11980 ---- Process: 59.90%
# Iter 11990 ---- Process: 59.95%
# Iter 12000 ---- Process: 60.00%
# Iter 12010 ---- Process: 60.05%
# Iter 12020 ---- Process: 60.10%
# Iter 12030 ---- Process: 60.15%
# Iter 12040 ---- Process: 60.20%
# Iter 12050 ---- Process: 60.25%
# Iter 12060 ---- Process: 60.30%
# Iter 12070 ---- Process: 60.35%
# Iter 12080 ---- Process: 60.40%
# Iter 12090 ---- Process: 60.45%
# Iter 12100 ---- Process: 60.50%
# Iter 12110 ---- Process: 60.55%
# Iter 12120 ---- Process: 60.60%
# Iter 12130 ---- Process: 60.65%
# Iter 12140 ---- Process: 60.70%
# Iter 12150 ---- Process: 60.75%
# Iter 12160 ---- Process: 60.80%
# Iter 12170 ---- Process: 60.85%
# Iter 12180 ---- Process: 60.90%
# Iter 12190 ---- Process: 60.95%
# Iter 12200 ---- Process: 61.00%
# Iter 12210 ---- Process: 61.05%
# Iter 12220 ---- Process: 61.10%
# Iter 12230 ---- Process: 61.15%
# Iter 12240 ---- Process: 61.20%
# Iter 12250 ---- Process: 61.25%
# Iter 12260 ---- Process: 61.30%
# Iter 12270 ---- Process: 61.35%
# Iter 12280 ---- Process: 61.40%
# Iter 12290 ---- Process: 61.45%
# Iter 12300 ---- Process: 61.50%
# Iter 12310 ---- Process: 61.55%
# Iter 12320 ---- Process: 61.60%
# Iter 12330 ---- Process: 61.65%
# Iter 12340 ---- Process: 61.70%
# Iter 12350 ---- Process: 61.75%
# Iter 12360 ---- Process: 61.80%
# Iter 12370 ---- Process: 61.85%
# Iter 12380 ---- Process: 61.90%
# Iter 12390 ---- Process: 61.95%
# Iter 12400 ---- Process: 62.00%
# Iter 12410 ---- Process: 62.05%
# Iter 12420 ---- Process: 62.10%
# Iter 12430 ---- Process: 62.15%
# Iter 12440 ---- Process: 62.20%
# Iter 12450 ---- Process: 62.25%
# Iter 12460 ---- Process: 62.30%
# Iter 12470 ---- Process: 62.35%
# Iter 12480 ---- Process: 62.40%
# Iter 12490 ---- Process: 62.45%
# Iter 12500 ---- Process: 62.50%
# Iter 12510 ---- Process: 62.55%
# Iter 12520 ---- Process: 62.60%
# Iter 12530 ---- Process: 62.65%
# Iter 12540 ---- Process: 62.70%
# Iter 12550 ---- Process: 62.75%
# Iter 12560 ---- Process: 62.80%
# Iter 12570 ---- Process: 62.85%
# Iter 12580 ---- Process: 62.90%
# Iter 12590 ---- Process: 62.95%
# Iter 12600 ---- Process: 63.00%
# Iter 12610 ---- Process: 63.05%
# Iter 12620 ---- Process: 63.10%
# Iter 12630 ---- Process: 63.15%
# Iter 12640 ---- Process: 63.20%
# Iter 12650 ---- Process: 63.25%
# Iter 12660 ---- Process: 63.30%
# Iter 12670 ---- Process: 63.35%
# Iter 12680 ---- Process: 63.40%
# Iter 12690 ---- Process: 63.45%
# Iter 12700 ---- Process: 63.50%
# Iter 12710 ---- Process: 63.55%
# Iter 12720 ---- Process: 63.60%
# Iter 12730 ---- Process: 63.65%
# Iter 12740 ---- Process: 63.70%
# Iter 12750 ---- Process: 63.75%
# Iter 12760 ---- Process: 63.80%
# Iter 12770 ---- Process: 63.85%
# Iter 12780 ---- Process: 63.90%
# Iter 12790 ---- Process: 63.95%
# Iter 12800 ---- Process: 64.00%
# Iter 12810 ---- Process: 64.05%
# Iter 12820 ---- Process: 64.10%
# Iter 12830 ---- Process: 64.15%
# Iter 12840 ---- Process: 64.20%
# Iter 12850 ---- Process: 64.25%
# Iter 12860 ---- Process: 64.30%
# Iter 12870 ---- Process: 64.35%
# Iter 12880 ---- Process: 64.40%
# Iter 12890 ---- Process: 64.45%
# Iter 12900 ---- Process: 64.50%
# Iter 12910 ---- Process: 64.55%
# Iter 12920 ---- Process: 64.60%
# Iter 12930 ---- Process: 64.65%
# Iter 12940 ---- Process: 64.70%
# Iter 12950 ---- Process: 64.75%
# Iter 12960 ---- Process: 64.80%
# Iter 12970 ---- Process: 64.85%
# Iter 12980 ---- Process: 64.90%
# Iter 12990 ---- Process: 64.95%
# Iter 13000 ---- Process: 65.00%
# Iter 13010 ---- Process: 65.05%
# Iter 13020 ---- Process: 65.10%
# Iter 13030 ---- Process: 65.15%
# Iter 13040 ---- Process: 65.20%
# Iter 13050 ---- Process: 65.25%
# Iter 13060 ---- Process: 65.30%
# Iter 13070 ---- Process: 65.35%
# Iter 13080 ---- Process: 65.40%
# Iter 13090 ---- Process: 65.45%
# Iter 13100 ---- Process: 65.50%
# Iter 13110 ---- Process: 65.55%
# Iter 13120 ---- Process: 65.60%
# Iter 13130 ---- Process: 65.65%
# Iter 13140 ---- Process: 65.70%
# Iter 13150 ---- Process: 65.75%
# Iter 13160 ---- Process: 65.80%
# Iter 13170 ---- Process: 65.85%
# Iter 13180 ---- Process: 65.90%
# Iter 13190 ---- Process: 65.95%
# Iter 13200 ---- Process: 66.00%
# Iter 13210 ---- Process: 66.05%
# Iter 13220 ---- Process: 66.10%
# Iter 13230 ---- Process: 66.15%
# Iter 13240 ---- Process: 66.20%
# Iter 13250 ---- Process: 66.25%
# Iter 13260 ---- Process: 66.30%
# Iter 13270 ---- Process: 66.35%
# Iter 13280 ---- Process: 66.40%
# Iter 13290 ---- Process: 66.45%
# Iter 13300 ---- Process: 66.50%
# Iter 13310 ---- Process: 66.55%
# Iter 13320 ---- Process: 66.60%
# Iter 13330 ---- Process: 66.65%
# Iter 13340 ---- Process: 66.70%
# Iter 13350 ---- Process: 66.75%
# Iter 13360 ---- Process: 66.80%
# Iter 13370 ---- Process: 66.85%
# Iter 13380 ---- Process: 66.90%
# Iter 13390 ---- Process: 66.95%
# Iter 13400 ---- Process: 67.00%
# Iter 13410 ---- Process: 67.05%
# Iter 13420 ---- Process: 67.10%
# Iter 13430 ---- Process: 67.15%
# Iter 13440 ---- Process: 67.20%
# Iter 13450 ---- Process: 67.25%
# Iter 13460 ---- Process: 67.30%
# Iter 13470 ---- Process: 67.35%
# Iter 13480 ---- Process: 67.40%
# Iter 13490 ---- Process: 67.45%
# Iter 13500 ---- Process: 67.50%
# Iter 13510 ---- Process: 67.55%
# Iter 13520 ---- Process: 67.60%
# Iter 13530 ---- Process: 67.65%
# Iter 13540 ---- Process: 67.70%
# Iter 13550 ---- Process: 67.75%
# Iter 13560 ---- Process: 67.80%
# Iter 13570 ---- Process: 67.85%
# Iter 13580 ---- Process: 67.90%
# Iter 13590 ---- Process: 67.95%
# Iter 13600 ---- Process: 68.00%
# Iter 13610 ---- Process: 68.05%
# Iter 13620 ---- Process: 68.10%
# Iter 13630 ---- Process: 68.15%
# Iter 13640 ---- Process: 68.20%
# Iter 13650 ---- Process: 68.25%
# Iter 13660 ---- Process: 68.30%
# Iter 13670 ---- Process: 68.35%
# Iter 13680 ---- Process: 68.40%
# Iter 13690 ---- Process: 68.45%
# Iter 13700 ---- Process: 68.50%
# Iter 13710 ---- Process: 68.55%
# Iter 13720 ---- Process: 68.60%
# Iter 13730 ---- Process: 68.65%
# Iter 13740 ---- Process: 68.70%
# Iter 13750 ---- Process: 68.75%
# Iter 13760 ---- Process: 68.80%
# Iter 13770 ---- Process: 68.85%
# Iter 13780 ---- Process: 68.90%
# Iter 13790 ---- Process: 68.95%
# Iter 13800 ---- Process: 69.00%
# Iter 13810 ---- Process: 69.05%
# Iter 13820 ---- Process: 69.10%
# Iter 13830 ---- Process: 69.15%
# Iter 13840 ---- Process: 69.20%
# Iter 13850 ---- Process: 69.25%
# Iter 13860 ---- Process: 69.30%
# Iter 13870 ---- Process: 69.35%
# Iter 13880 ---- Process: 69.40%
# Iter 13890 ---- Process: 69.45%
# Iter 13900 ---- Process: 69.50%
# Iter 13910 ---- Process: 69.55%
# Iter 13920 ---- Process: 69.60%
# Iter 13930 ---- Process: 69.65%
# Iter 13940 ---- Process: 69.70%
# Iter 13950 ---- Process: 69.75%
# Iter 13960 ---- Process: 69.80%
# Iter 13970 ---- Process: 69.85%
# Iter 13980 ---- Process: 69.90%
# Iter 13990 ---- Process: 69.95%
# Iter 14000 ---- Process: 70.00%
# Iter 14010 ---- Process: 70.05%
# Iter 14020 ---- Process: 70.10%
# Iter 14030 ---- Process: 70.15%
# Iter 14040 ---- Process: 70.20%
# Iter 14050 ---- Process: 70.25%
# Iter 14060 ---- Process: 70.30%
# Iter 14070 ---- Process: 70.35%
# Iter 14080 ---- Process: 70.40%
# Iter 14090 ---- Process: 70.45%
# Iter 14100 ---- Process: 70.50%
# Iter 14110 ---- Process: 70.55%
# Iter 14120 ---- Process: 70.60%
# Iter 14130 ---- Process: 70.65%
# Iter 14140 ---- Process: 70.70%
# Iter 14150 ---- Process: 70.75%
# Iter 14160 ---- Process: 70.80%
# Iter 14170 ---- Process: 70.85%
# Iter 14180 ---- Process: 70.90%
# Iter 14190 ---- Process: 70.95%
# Iter 14200 ---- Process: 71.00%
# Iter 14210 ---- Process: 71.05%
# Iter 14220 ---- Process: 71.10%
# Iter 14230 ---- Process: 71.15%
# Iter 14240 ---- Process: 71.20%
# Iter 14250 ---- Process: 71.25%
# Iter 14260 ---- Process: 71.30%
# Iter 14270 ---- Process: 71.35%
# Iter 14280 ---- Process: 71.40%
# Iter 14290 ---- Process: 71.45%
# Iter 14300 ---- Process: 71.50%
# Iter 14310 ---- Process: 71.55%
# Iter 14320 ---- Process: 71.60%
# Iter 14330 ---- Process: 71.65%
# Iter 14340 ---- Process: 71.70%
# Iter 14350 ---- Process: 71.75%
# Iter 14360 ---- Process: 71.80%
# Iter 14370 ---- Process: 71.85%
# Iter 14380 ---- Process: 71.90%
# Iter 14390 ---- Process: 71.95%
# Iter 14400 ---- Process: 72.00%
# Iter 14410 ---- Process: 72.05%
# Iter 14420 ---- Process: 72.10%
# Iter 14430 ---- Process: 72.15%
# Iter 14440 ---- Process: 72.20%
# Iter 14450 ---- Process: 72.25%
# Iter 14460 ---- Process: 72.30%
# Iter 14470 ---- Process: 72.35%
# Iter 14480 ---- Process: 72.40%
# Iter 14490 ---- Process: 72.45%
# Iter 14500 ---- Process: 72.50%
# Iter 14510 ---- Process: 72.55%
# Iter 14520 ---- Process: 72.60%
# Iter 14530 ---- Process: 72.65%
# Iter 14540 ---- Process: 72.70%
# Iter 14550 ---- Process: 72.75%
# Iter 14560 ---- Process: 72.80%
# Iter 14570 ---- Process: 72.85%
# Iter 14580 ---- Process: 72.90%
# Iter 14590 ---- Process: 72.95%
# Iter 14600 ---- Process: 73.00%
# Iter 14610 ---- Process: 73.05%
# Iter 14620 ---- Process: 73.10%
# Iter 14630 ---- Process: 73.15%
# Iter 14640 ---- Process: 73.20%
# Iter 14650 ---- Process: 73.25%
# Iter 14660 ---- Process: 73.30%
# Iter 14670 ---- Process: 73.35%
# Iter 14680 ---- Process: 73.40%
# Iter 14690 ---- Process: 73.45%
# Iter 14700 ---- Process: 73.50%
# Iter 14710 ---- Process: 73.55%
# Iter 14720 ---- Process: 73.60%
# Iter 14730 ---- Process: 73.65%
# Iter 14740 ---- Process: 73.70%
# Iter 14750 ---- Process: 73.75%
# Iter 14760 ---- Process: 73.80%
# Iter 14770 ---- Process: 73.85%
# Iter 14780 ---- Process: 73.90%
# Iter 14790 ---- Process: 73.95%
# Iter 14800 ---- Process: 74.00%
# Iter 14810 ---- Process: 74.05%
# Iter 14820 ---- Process: 74.10%
# Iter 14830 ---- Process: 74.15%
# Iter 14840 ---- Process: 74.20%
# Iter 14850 ---- Process: 74.25%
# Iter 14860 ---- Process: 74.30%
# Iter 14870 ---- Process: 74.35%
# Iter 14880 ---- Process: 74.40%
# Iter 14890 ---- Process: 74.45%
# Iter 14900 ---- Process: 74.50%
# Iter 14910 ---- Process: 74.55%
# Iter 14920 ---- Process: 74.60%
# Iter 14930 ---- Process: 74.65%
# Iter 14940 ---- Process: 74.70%
# Iter 14950 ---- Process: 74.75%
# Iter 14960 ---- Process: 74.80%
# Iter 14970 ---- Process: 74.85%
# Iter 14980 ---- Process: 74.90%
# Iter 14990 ---- Process: 74.95%
# Iter 15000 ---- Process: 75.00%
# Iter 15010 ---- Process: 75.05%
# Iter 15020 ---- Process: 75.10%
# Iter 15030 ---- Process: 75.15%
# Iter 15040 ---- Process: 75.20%
# Iter 15050 ---- Process: 75.25%
# Iter 15060 ---- Process: 75.30%
# Iter 15070 ---- Process: 75.35%
# Iter 15080 ---- Process: 75.40%
# Iter 15090 ---- Process: 75.45%
# Iter 15100 ---- Process: 75.50%
# Iter 15110 ---- Process: 75.55%
# Iter 15120 ---- Process: 75.60%
# Iter 15130 ---- Process: 75.65%
# Iter 15140 ---- Process: 75.70%
# Iter 15150 ---- Process: 75.75%
# Iter 15160 ---- Process: 75.80%
# Iter 15170 ---- Process: 75.85%
# Iter 15180 ---- Process: 75.90%
# Iter 15190 ---- Process: 75.95%
# Iter 15200 ---- Process: 76.00%
# Iter 15210 ---- Process: 76.05%
# Iter 15220 ---- Process: 76.10%
# Iter 15230 ---- Process: 76.15%
# Iter 15240 ---- Process: 76.20%
# Iter 15250 ---- Process: 76.25%
# Iter 15260 ---- Process: 76.30%
# Iter 15270 ---- Process: 76.35%
# Iter 15280 ---- Process: 76.40%
# Iter 15290 ---- Process: 76.45%
# Iter 15300 ---- Process: 76.50%
# Iter 15310 ---- Process: 76.55%
# Iter 15320 ---- Process: 76.60%
# Iter 15330 ---- Process: 76.65%
# Iter 15340 ---- Process: 76.70%
# Iter 15350 ---- Process: 76.75%
# Iter 15360 ---- Process: 76.80%
# Iter 15370 ---- Process: 76.85%
# Iter 15380 ---- Process: 76.90%
# Iter 15390 ---- Process: 76.95%
# Iter 15400 ---- Process: 77.00%
# Iter 15410 ---- Process: 77.05%
# Iter 15420 ---- Process: 77.10%
# Iter 15430 ---- Process: 77.15%
# Iter 15440 ---- Process: 77.20%
# Iter 15450 ---- Process: 77.25%
# Iter 15460 ---- Process: 77.30%
# Iter 15470 ---- Process: 77.35%
# Iter 15480 ---- Process: 77.40%
# Iter 15490 ---- Process: 77.45%
# Iter 15500 ---- Process: 77.50%
# Iter 15510 ---- Process: 77.55%
# Iter 15520 ---- Process: 77.60%
# Iter 15530 ---- Process: 77.65%
# Iter 15540 ---- Process: 77.70%
# Iter 15550 ---- Process: 77.75%
# Iter 15560 ---- Process: 77.80%
# Iter 15570 ---- Process: 77.85%
# Iter 15580 ---- Process: 77.90%
# Iter 15590 ---- Process: 77.95%
# Iter 15600 ---- Process: 78.00%
# Iter 15610 ---- Process: 78.05%
# Iter 15620 ---- Process: 78.10%
# Iter 15630 ---- Process: 78.15%
# Iter 15640 ---- Process: 78.20%
# Iter 15650 ---- Process: 78.25%
# Iter 15660 ---- Process: 78.30%
# Iter 15670 ---- Process: 78.35%
# Iter 15680 ---- Process: 78.40%
# Iter 15690 ---- Process: 78.45%
# Iter 15700 ---- Process: 78.50%
# Iter 15710 ---- Process: 78.55%
# Iter 15720 ---- Process: 78.60%
# Iter 15730 ---- Process: 78.65%
# Iter 15740 ---- Process: 78.70%
# Iter 15750 ---- Process: 78.75%
# Iter 15760 ---- Process: 78.80%
# Iter 15770 ---- Process: 78.85%
# Iter 15780 ---- Process: 78.90%
# Iter 15790 ---- Process: 78.95%
# Iter 15800 ---- Process: 79.00%
# Iter 15810 ---- Process: 79.05%
# Iter 15820 ---- Process: 79.10%
# Iter 15830 ---- Process: 79.15%
# Iter 15840 ---- Process: 79.20%
# Iter 15850 ---- Process: 79.25%
# Iter 15860 ---- Process: 79.30%
# Iter 15870 ---- Process: 79.35%
# Iter 15880 ---- Process: 79.40%
# Iter 15890 ---- Process: 79.45%
# Iter 15900 ---- Process: 79.50%
# Iter 15910 ---- Process: 79.55%
# Iter 15920 ---- Process: 79.60%
# Iter 15930 ---- Process: 79.65%
# Iter 15940 ---- Process: 79.70%
# Iter 15950 ---- Process: 79.75%
# Iter 15960 ---- Process: 79.80%
# Iter 15970 ---- Process: 79.85%
# Iter 15980 ---- Process: 79.90%
# Iter 15990 ---- Process: 79.95%
# Iter 16000 ---- Process: 80.00%
# Iter 16010 ---- Process: 80.05%
# Iter 16020 ---- Process: 80.10%
# Iter 16030 ---- Process: 80.15%
# Iter 16040 ---- Process: 80.20%
# Iter 16050 ---- Process: 80.25%
# Iter 16060 ---- Process: 80.30%
# Iter 16070 ---- Process: 80.35%
# Iter 16080 ---- Process: 80.40%
# Iter 16090 ---- Process: 80.45%
# Iter 16100 ---- Process: 80.50%
# Iter 16110 ---- Process: 80.55%
# Iter 16120 ---- Process: 80.60%
# Iter 16130 ---- Process: 80.65%
# Iter 16140 ---- Process: 80.70%
# Iter 16150 ---- Process: 80.75%
# Iter 16160 ---- Process: 80.80%
# Iter 16170 ---- Process: 80.85%
# Iter 16180 ---- Process: 80.90%
# Iter 16190 ---- Process: 80.95%
# Iter 16200 ---- Process: 81.00%
# Iter 16210 ---- Process: 81.05%
# Iter 16220 ---- Process: 81.10%
# Iter 16230 ---- Process: 81.15%
# Iter 16240 ---- Process: 81.20%
# Iter 16250 ---- Process: 81.25%
# Iter 16260 ---- Process: 81.30%
# Iter 16270 ---- Process: 81.35%
# Iter 16280 ---- Process: 81.40%
# Iter 16290 ---- Process: 81.45%
# Iter 16300 ---- Process: 81.50%
# Iter 16310 ---- Process: 81.55%
# Iter 16320 ---- Process: 81.60%
# Iter 16330 ---- Process: 81.65%
# Iter 16340 ---- Process: 81.70%
# Iter 16350 ---- Process: 81.75%
# Iter 16360 ---- Process: 81.80%
# Iter 16370 ---- Process: 81.85%
# Iter 16380 ---- Process: 81.90%
# Iter 16390 ---- Process: 81.95%
# Iter 16400 ---- Process: 82.00%
# Iter 16410 ---- Process: 82.05%
# Iter 16420 ---- Process: 82.10%
# Iter 16430 ---- Process: 82.15%
# Iter 16440 ---- Process: 82.20%
# Iter 16450 ---- Process: 82.25%
# Iter 16460 ---- Process: 82.30%
# Iter 16470 ---- Process: 82.35%
# Iter 16480 ---- Process: 82.40%
# Iter 16490 ---- Process: 82.45%
# Iter 16500 ---- Process: 82.50%
# Iter 16510 ---- Process: 82.55%
# Iter 16520 ---- Process: 82.60%
# Iter 16530 ---- Process: 82.65%
# Iter 16540 ---- Process: 82.70%
# Iter 16550 ---- Process: 82.75%
# Iter 16560 ---- Process: 82.80%
# Iter 16570 ---- Process: 82.85%
# Iter 16580 ---- Process: 82.90%
# Iter 16590 ---- Process: 82.95%
# Iter 16600 ---- Process: 83.00%
# Iter 16610 ---- Process: 83.05%
# Iter 16620 ---- Process: 83.10%
# Iter 16630 ---- Process: 83.15%
# Iter 16640 ---- Process: 83.20%
# Iter 16650 ---- Process: 83.25%
# Iter 16660 ---- Process: 83.30%
# Iter 16670 ---- Process: 83.35%
# Iter 16680 ---- Process: 83.40%
# Iter 16690 ---- Process: 83.45%
# Iter 16700 ---- Process: 83.50%
# Iter 16710 ---- Process: 83.55%
# Iter 16720 ---- Process: 83.60%
# Iter 16730 ---- Process: 83.65%
# Iter 16740 ---- Process: 83.70%
# Iter 16750 ---- Process: 83.75%
# Iter 16760 ---- Process: 83.80%
# Iter 16770 ---- Process: 83.85%
# Iter 16780 ---- Process: 83.90%
# Iter 16790 ---- Process: 83.95%
# Iter 16800 ---- Process: 84.00%
# Iter 16810 ---- Process: 84.05%
# Iter 16820 ---- Process: 84.10%
# Iter 16830 ---- Process: 84.15%
# Iter 16840 ---- Process: 84.20%
# Iter 16850 ---- Process: 84.25%
# Iter 16860 ---- Process: 84.30%
# Iter 16870 ---- Process: 84.35%
# Iter 16880 ---- Process: 84.40%
# Iter 16890 ---- Process: 84.45%
# Iter 16900 ---- Process: 84.50%
# Iter 16910 ---- Process: 84.55%
# Iter 16920 ---- Process: 84.60%
# Iter 16930 ---- Process: 84.65%
# Iter 16940 ---- Process: 84.70%
# Iter 16950 ---- Process: 84.75%
# Iter 16960 ---- Process: 84.80%
# Iter 16970 ---- Process: 84.85%
# Iter 16980 ---- Process: 84.90%
# Iter 16990 ---- Process: 84.95%
# Iter 17000 ---- Process: 85.00%
# Iter 17010 ---- Process: 85.05%
# Iter 17020 ---- Process: 85.10%
# Iter 17030 ---- Process: 85.15%
# Iter 17040 ---- Process: 85.20%
# Iter 17050 ---- Process: 85.25%
# Iter 17060 ---- Process: 85.30%
# Iter 17070 ---- Process: 85.35%
# Iter 17080 ---- Process: 85.40%
# Iter 17090 ---- Process: 85.45%
# Iter 17100 ---- Process: 85.50%
# Iter 17110 ---- Process: 85.55%
# Iter 17120 ---- Process: 85.60%
# Iter 17130 ---- Process: 85.65%
# Iter 17140 ---- Process: 85.70%
# Iter 17150 ---- Process: 85.75%
# Iter 17160 ---- Process: 85.80%
# Iter 17170 ---- Process: 85.85%
# Iter 17180 ---- Process: 85.90%
# Iter 17190 ---- Process: 85.95%
# Iter 17200 ---- Process: 86.00%
# Iter 17210 ---- Process: 86.05%
# Iter 17220 ---- Process: 86.10%
# Iter 17230 ---- Process: 86.15%
# Iter 17240 ---- Process: 86.20%
# Iter 17250 ---- Process: 86.25%
# Iter 17260 ---- Process: 86.30%
# Iter 17270 ---- Process: 86.35%
# Iter 17280 ---- Process: 86.40%
# Iter 17290 ---- Process: 86.45%
# Iter 17300 ---- Process: 86.50%
# Iter 17310 ---- Process: 86.55%
# Iter 17320 ---- Process: 86.60%
# Iter 17330 ---- Process: 86.65%
# Iter 17340 ---- Process: 86.70%
# Iter 17350 ---- Process: 86.75%
# Iter 17360 ---- Process: 86.80%
# Iter 17370 ---- Process: 86.85%
# Iter 17380 ---- Process: 86.90%
# Iter 17390 ---- Process: 86.95%
# Iter 17400 ---- Process: 87.00%
# Iter 17410 ---- Process: 87.05%
# Iter 17420 ---- Process: 87.10%
# Iter 17430 ---- Process: 87.15%
# Iter 17440 ---- Process: 87.20%
# Iter 17450 ---- Process: 87.25%
# Iter 17460 ---- Process: 87.30%
# Iter 17470 ---- Process: 87.35%
# Iter 17480 ---- Process: 87.40%
# Iter 17490 ---- Process: 87.45%
# Iter 17500 ---- Process: 87.50%
# Iter 17510 ---- Process: 87.55%
# Iter 17520 ---- Process: 87.60%
# Iter 17530 ---- Process: 87.65%
# Iter 17540 ---- Process: 87.70%
# Iter 17550 ---- Process: 87.75%
# Iter 17560 ---- Process: 87.80%
# Iter 17570 ---- Process: 87.85%
# Iter 17580 ---- Process: 87.90%
# Iter 17590 ---- Process: 87.95%
# Iter 17600 ---- Process: 88.00%
# Iter 17610 ---- Process: 88.05%
# Iter 17620 ---- Process: 88.10%
# Iter 17630 ---- Process: 88.15%
# Iter 17640 ---- Process: 88.20%
# Iter 17650 ---- Process: 88.25%
# Iter 17660 ---- Process: 88.30%
# Iter 17670 ---- Process: 88.35%
# Iter 17680 ---- Process: 88.40%
# Iter 17690 ---- Process: 88.45%
# Iter 17700 ---- Process: 88.50%
# Iter 17710 ---- Process: 88.55%
# Iter 17720 ---- Process: 88.60%
# Iter 17730 ---- Process: 88.65%
# Iter 17740 ---- Process: 88.70%
# Iter 17750 ---- Process: 88.75%
# Iter 17760 ---- Process: 88.80%
# Iter 17770 ---- Process: 88.85%
# Iter 17780 ---- Process: 88.90%
# Iter 17790 ---- Process: 88.95%
# Iter 17800 ---- Process: 89.00%
# Iter 17810 ---- Process: 89.05%
# Iter 17820 ---- Process: 89.10%
# Iter 17830 ---- Process: 89.15%
# Iter 17840 ---- Process: 89.20%
# Iter 17850 ---- Process: 89.25%
# Iter 17860 ---- Process: 89.30%
# Iter 17870 ---- Process: 89.35%
# Iter 17880 ---- Process: 89.40%
# Iter 17890 ---- Process: 89.45%
# Iter 17900 ---- Process: 89.50%
# Iter 17910 ---- Process: 89.55%
# Iter 17920 ---- Process: 89.60%
# Iter 17930 ---- Process: 89.65%
# Iter 17940 ---- Process: 89.70%
# Iter 17950 ---- Process: 89.75%
# Iter 17960 ---- Process: 89.80%
# Iter 17970 ---- Process: 89.85%
# Iter 17980 ---- Process: 89.90%
# Iter 17990 ---- Process: 89.95%
# Iter 18000 ---- Process: 90.00%
# Iter 18010 ---- Process: 90.05%
# Iter 18020 ---- Process: 90.10%
# Iter 18030 ---- Process: 90.15%
# Iter 18040 ---- Process: 90.20%
# Iter 18050 ---- Process: 90.25%
# Iter 18060 ---- Process: 90.30%
# Iter 18070 ---- Process: 90.35%
# Iter 18080 ---- Process: 90.40%
# Iter 18090 ---- Process: 90.45%
# Iter 18100 ---- Process: 90.50%
# Iter 18110 ---- Process: 90.55%
# Iter 18120 ---- Process: 90.60%
# Iter 18130 ---- Process: 90.65%
# Iter 18140 ---- Process: 90.70%
# Iter 18150 ---- Process: 90.75%
# Iter 18160 ---- Process: 90.80%
# Iter 18170 ---- Process: 90.85%
# Iter 18180 ---- Process: 90.90%
# Iter 18190 ---- Process: 90.95%
# Iter 18200 ---- Process: 91.00%
# Iter 18210 ---- Process: 91.05%
# Iter 18220 ---- Process: 91.10%
# Iter 18230 ---- Process: 91.15%
# Iter 18240 ---- Process: 91.20%
# Iter 18250 ---- Process: 91.25%
# Iter 18260 ---- Process: 91.30%
# Iter 18270 ---- Process: 91.35%
# Iter 18280 ---- Process: 91.40%
# Iter 18290 ---- Process: 91.45%
# Iter 18300 ---- Process: 91.50%
# Iter 18310 ---- Process: 91.55%
# Iter 18320 ---- Process: 91.60%
# Iter 18330 ---- Process: 91.65%
# Iter 18340 ---- Process: 91.70%
# Iter 18350 ---- Process: 91.75%
# Iter 18360 ---- Process: 91.80%
# Iter 18370 ---- Process: 91.85%
# Iter 18380 ---- Process: 91.90%
# Iter 18390 ---- Process: 91.95%
# Iter 18400 ---- Process: 92.00%
# Iter 18410 ---- Process: 92.05%
# Iter 18420 ---- Process: 92.10%
# Iter 18430 ---- Process: 92.15%
# Iter 18440 ---- Process: 92.20%
# Iter 18450 ---- Process: 92.25%
# Iter 18460 ---- Process: 92.30%
# Iter 18470 ---- Process: 92.35%
# Iter 18480 ---- Process: 92.40%
# Iter 18490 ---- Process: 92.45%
# Iter 18500 ---- Process: 92.50%
# Iter 18510 ---- Process: 92.55%
# Iter 18520 ---- Process: 92.60%
# Iter 18530 ---- Process: 92.65%
# Iter 18540 ---- Process: 92.70%
# Iter 18550 ---- Process: 92.75%
# Iter 18560 ---- Process: 92.80%
# Iter 18570 ---- Process: 92.85%
# Iter 18580 ---- Process: 92.90%
# Iter 18590 ---- Process: 92.95%
# Iter 18600 ---- Process: 93.00%
# Iter 18610 ---- Process: 93.05%
# Iter 18620 ---- Process: 93.10%
# Iter 18630 ---- Process: 93.15%
# Iter 18640 ---- Process: 93.20%
# Iter 18650 ---- Process: 93.25%
# Iter 18660 ---- Process: 93.30%
# Iter 18670 ---- Process: 93.35%
# Iter 18680 ---- Process: 93.40%
# Iter 18690 ---- Process: 93.45%
# Iter 18700 ---- Process: 93.50%
# Iter 18710 ---- Process: 93.55%
# Iter 18720 ---- Process: 93.60%
# Iter 18730 ---- Process: 93.65%
# Iter 18740 ---- Process: 93.70%
# Iter 18750 ---- Process: 93.75%
# Iter 18760 ---- Process: 93.80%
# Iter 18770 ---- Process: 93.85%
# Iter 18780 ---- Process: 93.90%
# Iter 18790 ---- Process: 93.95%
# Iter 18800 ---- Process: 94.00%
# Iter 18810 ---- Process: 94.05%
# Iter 18820 ---- Process: 94.10%
# Iter 18830 ---- Process: 94.15%
# Iter 18840 ---- Process: 94.20%
# Iter 18850 ---- Process: 94.25%
# Iter 18860 ---- Process: 94.30%
# Iter 18870 ---- Process: 94.35%
# Iter 18880 ---- Process: 94.40%
# Iter 18890 ---- Process: 94.45%
# Iter 18900 ---- Process: 94.50%
# Iter 18910 ---- Process: 94.55%
# Iter 18920 ---- Process: 94.60%
# Iter 18930 ---- Process: 94.65%
# Iter 18940 ---- Process: 94.70%
# Iter 18950 ---- Process: 94.75%
# Iter 18960 ---- Process: 94.80%
# Iter 18970 ---- Process: 94.85%
# Iter 18980 ---- Process: 94.90%
# Iter 18990 ---- Process: 94.95%
# Iter 19000 ---- Process: 95.00%
# Iter 19010 ---- Process: 95.05%
# Iter 19020 ---- Process: 95.10%
# Iter 19030 ---- Process: 95.15%
# Iter 19040 ---- Process: 95.20%
# Iter 19050 ---- Process: 95.25%
# Iter 19060 ---- Process: 95.30%
# Iter 19070 ---- Process: 95.35%
# Iter 19080 ---- Process: 95.40%
# Iter 19090 ---- Process: 95.45%
# Iter 19100 ---- Process: 95.50%
# Iter 19110 ---- Process: 95.55%
# Iter 19120 ---- Process: 95.60%
# Iter 19130 ---- Process: 95.65%
# Iter 19140 ---- Process: 95.70%
# Iter 19150 ---- Process: 95.75%
# Iter 19160 ---- Process: 95.80%
# Iter 19170 ---- Process: 95.85%
# Iter 19180 ---- Process: 95.90%
# Iter 19190 ---- Process: 95.95%
# Iter 19200 ---- Process: 96.00%
# Iter 19210 ---- Process: 96.05%
# Iter 19220 ---- Process: 96.10%
# Iter 19230 ---- Process: 96.15%
# Iter 19240 ---- Process: 96.20%
# Iter 19250 ---- Process: 96.25%
# Iter 19260 ---- Process: 96.30%
# Iter 19270 ---- Process: 96.35%
# Iter 19280 ---- Process: 96.40%
# Iter 19290 ---- Process: 96.45%
# Iter 19300 ---- Process: 96.50%
# Iter 19310 ---- Process: 96.55%
# Iter 19320 ---- Process: 96.60%
# Iter 19330 ---- Process: 96.65%
# Iter 19340 ---- Process: 96.70%
# Iter 19350 ---- Process: 96.75%
# Iter 19360 ---- Process: 96.80%
# Iter 19370 ---- Process: 96.85%
# Iter 19380 ---- Process: 96.90%
# Iter 19390 ---- Process: 96.95%
# Iter 19400 ---- Process: 97.00%
# Iter 19410 ---- Process: 97.05%
# Iter 19420 ---- Process: 97.10%
# Iter 19430 ---- Process: 97.15%
# Iter 19440 ---- Process: 97.20%
# Iter 19450 ---- Process: 97.25%
# Iter 19460 ---- Process: 97.30%
# Iter 19470 ---- Process: 97.35%
# Iter 19480 ---- Process: 97.40%
# Iter 19490 ---- Process: 97.45%
# Iter 19500 ---- Process: 97.50%
# Iter 19510 ---- Process: 97.55%
# Iter 19520 ---- Process: 97.60%
# Iter 19530 ---- Process: 97.65%
# Iter 19540 ---- Process: 97.70%
# Iter 19550 ---- Process: 97.75%
# Iter 19560 ---- Process: 97.80%
# Iter 19570 ---- Process: 97.85%
# Iter 19580 ---- Process: 97.90%
# Iter 19590 ---- Process: 97.95%
# Iter 19600 ---- Process: 98.00%
# Iter 19610 ---- Process: 98.05%
# Iter 19620 ---- Process: 98.10%
# Iter 19630 ---- Process: 98.15%
# Iter 19640 ---- Process: 98.20%
# Iter 19650 ---- Process: 98.25%
# Iter 19660 ---- Process: 98.30%
# Iter 19670 ---- Process: 98.35%
# Iter 19680 ---- Process: 98.40%
# Iter 19690 ---- Process: 98.45%
# Iter 19700 ---- Process: 98.50%
# Iter 19710 ---- Process: 98.55%
# Iter 19720 ---- Process: 98.60%
# Iter 19730 ---- Process: 98.65%
# Iter 19740 ---- Process: 98.70%
# Iter 19750 ---- Process: 98.75%
# Iter 19760 ---- Process: 98.80%
# Iter 19770 ---- Process: 98.85%
# Iter 19780 ---- Process: 98.90%
# Iter 19790 ---- Process: 98.95%
# Iter 19800 ---- Process: 99.00%
# Iter 19810 ---- Process: 99.05%
# Iter 19820 ---- Process: 99.10%
# Iter 19830 ---- Process: 99.15%
# Iter 19840 ---- Process: 99.20%
# Iter 19850 ---- Process: 99.25%
# Iter 19860 ---- Process: 99.30%
# Iter 19870 ---- Process: 99.35%
# Iter 19880 ---- Process: 99.40%
# Iter 19890 ---- Process: 99.45%
# Iter 19900 ---- Process: 99.50%
# Iter 19910 ---- Process: 99.55%
# Iter 19920 ---- Process: 99.60%
# Iter 19930 ---- Process: 99.65%
# Iter 19940 ---- Process: 99.70%
# Iter 19950 ---- Process: 99.75%
# Iter 19960 ---- Process: 99.80%
# Iter 19970 ---- Process: 99.85%
# Iter 19980 ---- Process: 99.90%
# Iter 19990 ---- Process: 99.95%

# %%
RList = np.zeros([(num_epoches/10)])
rmseList = np.zeros([(num_epoches/10)])
maxeList = np.zeros([(num_epoches/10)])
mapeList = np.zeros([(num_epoches/10)])
for i in range(kind):
    out = np.array(outlist[i])
    tmp = out.T.reshape((1,test_batch_size))
    RList[i] = np.corrcoef(tmp[0,:],test_y.T[0,:])[0,1]
    rmseList[i] = rmse(tmp[0,:],test_y.T[0,:])
    maxeList[i] = maxe(tmp[0,:],test_y.T[0,:])
    mapeList[i] = mape(tmp[0,:],test_y.T[0,:])

# %%
prefix = './gefcom-result/PB/'
postfix = '-tao:' + str(tao) + '.csv'
DataFrame(RList).to_csv(prefix + 'R' + postfix)
DataFrame(rmseList).to_csv(prefix + 'RMSE' + postfix)
DataFrame(maxeList).to_csv(prefix + 'MAXE' + postfix)
DataFrame(mapeList).to_csv(prefix + 'MAPE' + postfix)

# %%
out = out * 25000
test_y = test_y*25000

# %%
out = out.reshape((test_batch_size,1))
pred_nd_load = np.concatenate([test_y,out],axis = 1)
DataFrame(pred_nd_load).to_csv(prefix + 'pred_nd_load' + postfix)

# %%
print np.mean(mapeList[-1001:-1])
rmseList
# Out:
# 0.0208188262517
# array([ 0.73018799,  0.21414685,  0.58408069, ...,  0.01157452,
#         0.02484291,  0.02554603])

# %%
time2 = time.time()
print time2-time1
# Out:
# 672.236491919
