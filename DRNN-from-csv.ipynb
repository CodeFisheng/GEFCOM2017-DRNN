# %% [markdown]
# ###

# %% [markdown]
# # Deep Learning (RNN) Demo for Load Forecasting

# %% [markdown]
# ### Step 1: Import all the packages needed

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mp
import random as rd
import argparse
import os, sys
import csv
import math
import time
import matplotlib.pyplot as pl

# %% [markdown]
# ### Step 2: setting all global parameters -- sec 2 network configuration

# %%
time1 = time.time() # set up counter to record run time
data_dir = './data/' # directory contains input data
num_epoches = 10000 # training epoches for each customer samples
day_steps = 24
n_steps = day_steps # input size
test_batch_size = 4*7*day_steps # days of a batch
validation_batch_size = 0*day_steps
train_batch_size = 7*day_steps
feature_size = 1 # same time of a week
n_hidden = 30 # input size
num_layers = 2
n_output = 1
Rs = 20

# %% [markdown]
# ### Step 4: define data generating function code.
# which generate a batch of batch-size large sequence data. the data is feature_size dims width and is a time series of float32 of steps steps. inputs and outputs are:
#
# inputs:
# ----n_batch: number of samples in a batch
# ----steps: the sequence length of a sample data
# ----feature_size: dimensions of a single time step data frame
#
# outputs:
# ----X inputs, shape(n_batch,steps,feature_size)
# ----Y outputs should be, shape(n_batch,)

# %%
def train_data_gen(totaltraindays,x_data,y_data,steps = 48, n_batch = train_batch_size):
    X = np.zeros((n_batch,steps,feature_size))
    Y = np.zeros((n_batch,feature_size))
    rang = range(totaltraindays) # test day sample range
    train_days_list = rd.sample(rang,n_batch) # pick unduplicated n indexes as examples
    #print totaltraindays
    tmpX = [x_data[i,0-steps:] for i in train_days_list]
    tmpY = [y_data[i,:] for i in train_days_list]
    X = np.array(tmpX).reshape(n_batch,steps,feature_size)
    Y = np.array(tmpY).reshape(n_batch,feature_size)
    return (X,Y)

# %%
def test_data_gen(x_data,y_data,steps = 48, n_batch = test_batch_size):
    X = np.zeros((n_batch,steps,feature_size))
    Y = np.zeros((n_batch,feature_size))
    #print x_data[:,0-steps:].shape,y_data.shape
    #print n_batch, steps
    X = x_data[:,0-steps:].reshape(n_batch,steps,feature_size)
    Y = y_data.reshape(n_batch,feature_size)
    return (X,Y)

# %% [markdown]
# ### Step 5: construct RNN model

# %%
# create placeholder for x and y
#with tf.device('/gpu:0'):
x = tf.placeholder("float",[None,n_steps,feature_size])
istate = tf.placeholder("float",[None,num_layers*2*n_hidden])
y = tf.placeholder("float",[None,n_output])


# Define weights
weights = {
    'hidden': tf.Variable(tf.random_normal([feature_size, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_output]))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_output]))
}
def RNN(_X, _istate, _weights, _biases):
    # input shape: (batch_size, n_steps, n_input)
    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    # Reshape to prepare input to hidden activation
    _X = tf.reshape(_X, [-1, feature_size]) # (n_steps*batch_size, n_input)
    # Linear activation
    _X = tf.matmul(_X, _weights['hidden']) + _biases['hidden']

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    stacked_lstm_cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell]*num_layers)

    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(0, n_steps, _X) # n_steps * (batch_size, n_hidden)

    # Get lstm cell output
    outputs, states = tf.nn.rnn(stacked_lstm_cell, _X, initial_state=_istate)

    # Linear activation
    # Get inner loop last output
    return tf.matmul(outputs[-1], _weights['out']) + _biases['out']

pred = RNN(x, istate, weights, biases)
#cost function 
cost = tf.reduce_mean(tf.pow(pred-y,2)) # cost function of this batch of data
#compute parameter updates
#optimizer = tf.train.GradientDescentOptimizer(0.2).minimize(cost)
optimizer = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(cost)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7fd87ffd7750>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
def maxe(predictions, targets):
    return max(abs(predictions-targets))

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
## iterating among all customers to find current training customer
#cus_list = [4,5,8,9]
#cus_list = [8,9,11,18,29,45,48,49,58,60,64,65,66,68]
time1 = time.time()
for i in range(0,1):
    print i
    outlist = np.zeros([(num_epoches/10),test_batch_size])
    kind = 0
    ii = i
    test_x_name = data_dir + 'test_x_' + str(ii) + '.csv'
    test_y_name = data_dir + 'test_y_' + str(ii) + '.csv'
    train_x_name = data_dir + 'train_x_' + str(ii) + '.csv'
    train_y_name = data_dir + 'train_y_' + str(ii) + '.csv'
    tmp_data = np.array(pd.read_csv(test_x_name,header = None))
    test_x_data = tmp_data[:,1:]
    # print test_x_data.dtype  data are stored as float64 double precision format
    tmp_data = np.array(pd.read_csv(test_y_name,header = None))
    test_y_data = tmp_data[:,1:]
    tmp_data = np.array(pd.read_csv(train_x_name,header = None))
    train_x_data = tmp_data[:,1:]
    tmp_data = np.array(pd.read_csv(train_y_name,header = None))
    train_y_data = tmp_data[:,1:]
    #log them
    #test_x_data = np.log(test_x_data)
    #test_y_data = np.log(test_y_data)
    #train_x_data = np.log(train_x_data)
    #train_y_data = np.log(train_y_data)
    
    traindays = train_y_data.shape[0]
    # generate test data
    test_x,test_y = test_data_gen(test_x_data,test_y_data,n_steps)
    test_x = test_x.reshape(test_batch_size,n_steps,feature_size)
    ### Execute
    # Initializing the variables
    init = tf.initialize_all_variables()
    with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
        # Create a summary to monitor cost function
        #tf.scalar_summary("loss", cost)
        # Merge all summaries to a single operator
        #merged_summary_op = tf.merge_all_summaries()

        # tensorboard info.# Set logs writer into folder /tmp/tensorflow_logs
        #summary_writer = tf.train.SummaryWriter('/tmp/tensorflow_logs', graph_def=sess.graph_def)

        #initialize all variables in the model
        sess.run(init)
        for k in range(num_epoches):
            #Generate Data for each epoch
            #What this does is it creates a list of of elements of length seq_len, each of size [batch_size,input_size]
            #this is required to feed data into rnn.rnn
            #print traindays
            X,Y = train_data_gen(traindays,train_x_data,train_y_data,n_steps)
            X = X.reshape(train_batch_size,n_steps,feature_size)


            #Create the dictionary of inputs to feed into sess.run
            #if k < 0:
            #    sess.run(optimizer2,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})
            #else:
            sess.run(optimizer,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})   
            #perform an update on the parameters

            # Write logs at every iteration
            #if k>50 & k%10 == 0:
            #    summary_str = sess.run(merged_summary_op, feed_dict={x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
            #    summary_writer.add_summary(summary_str, k)
            
            #if k % 10 == 0:
            if k % 10 == 0:
                output_tmp_ex = sess.run(pred,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )  
                print "Iter " + str(k) + " ---- Process: " + "{:.2f}".format(100*float(k)/float(num_epoches)) + "%"
                outp_test = output_tmp_ex
                outlist[kind,:] = outp_test.copy().T
                #print outp_test[0:3]
                kind = kind + 1
            #    print ktmp
            #if k % 10 == 0:
            #    output_tmp_ex = sess.run(pred,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
            #    print "Iter " + str(k)# + ", Minibatch Loss ---- Train = " + "{:.6f}".format(loss1) + "; Test = " + "{:.6f}".format(loss2)
        #print "haha{}".format(outp)
            #    ktmp = np.corrcoef(output_tmp_ex.T,test_y.T)[0,1]
            #    accuracy1.append(ktmp)
            #    print ktmp
# Out:
# 0
# Iter 0 ---- Process: 0.00%
# Iter 10 ---- Process: 0.10%
# Iter 20 ---- Process: 0.20%
# Iter 30 ---- Process: 0.30%
# Iter 40 ---- Process: 0.40%
# Iter 50 ---- Process: 0.50%
# Iter 60 ---- Process: 0.60%
# Iter 70 ---- Process: 0.70%
# Iter 80 ---- Process: 0.80%
# Iter 90 ---- Process: 0.90%
# Iter 100 ---- Process: 1.00%
# Iter 110 ---- Process: 1.10%
# Iter 120 ---- Process: 1.20%
# Iter 130 ---- Process: 1.30%
# Iter 140 ---- Process: 1.40%
# Iter 150 ---- Process: 1.50%
# Iter 160 ---- Process: 1.60%
# Iter 170 ---- Process: 1.70%
# Iter 180 ---- Process: 1.80%
# Iter 190 ---- Process: 1.90%
# Iter 200 ---- Process: 2.00%
# Iter 210 ---- Process: 2.10%
# Iter 220 ---- Process: 2.20%
# Iter 230 ---- Process: 2.30%
# Iter 240 ---- Process: 2.40%
# Iter 250 ---- Process: 2.50%
# Iter 260 ---- Process: 2.60%
# Iter 270 ---- Process: 2.70%
# Iter 280 ---- Process: 2.80%
# Iter 290 ---- Process: 2.90%
# Iter 300 ---- Process: 3.00%
# Iter 310 ---- Process: 3.10%
# Iter 320 ---- Process: 3.20%
# Iter 330 ---- Process: 3.30%
# Iter 340 ---- Process: 3.40%
# Iter 350 ---- Process: 3.50%
# Iter 360 ---- Process: 3.60%
# Iter 370 ---- Process: 3.70%
# Iter 380 ---- Process: 3.80%
# Iter 390 ---- Process: 3.90%
# Iter 400 ---- Process: 4.00%
# Iter 410 ---- Process: 4.10%
# Iter 420 ---- Process: 4.20%
# Iter 430 ---- Process: 4.30%
# Iter 440 ---- Process: 4.40%
# Iter 450 ---- Process: 4.50%
# Iter 460 ---- Process: 4.60%
# Iter 470 ---- Process: 4.70%
# Iter 480 ---- Process: 4.80%
# Iter 490 ---- Process: 4.90%
# Iter 500 ---- Process: 5.00%
# Iter 510 ---- Process: 5.10%
# Iter 520 ---- Process: 5.20%
# Iter 530 ---- Process: 5.30%
# Iter 540 ---- Process: 5.40%
# Iter 550 ---- Process: 5.50%
# Iter 560 ---- Process: 5.60%
# Iter 570 ---- Process: 5.70%
# Iter 580 ---- Process: 5.80%
# Iter 590 ---- Process: 5.90%
# Iter 600 ---- Process: 6.00%
# Iter 610 ---- Process: 6.10%
# Iter 620 ---- Process: 6.20%
# Iter 630 ---- Process: 6.30%
# Iter 640 ---- Process: 6.40%
# Iter 650 ---- Process: 6.50%
# Iter 660 ---- Process: 6.60%
# Iter 670 ---- Process: 6.70%
# Iter 680 ---- Process: 6.80%
# Iter 690 ---- Process: 6.90%
# Iter 700 ---- Process: 7.00%
# Iter 710 ---- Process: 7.10%
# Iter 720 ---- Process: 7.20%
# Iter 730 ---- Process: 7.30%
# Iter 740 ---- Process: 7.40%
# Iter 750 ---- Process: 7.50%
# Iter 760 ---- Process: 7.60%
# Iter 770 ---- Process: 7.70%
# Iter 780 ---- Process: 7.80%
# Iter 790 ---- Process: 7.90%
# Iter 800 ---- Process: 8.00%
# Iter 810 ---- Process: 8.10%
# Iter 820 ---- Process: 8.20%
# Iter 830 ---- Process: 8.30%
# Iter 840 ---- Process: 8.40%
# Iter 850 ---- Process: 8.50%
# Iter 860 ---- Process: 8.60%
# Iter 870 ---- Process: 8.70%
# Iter 880 ---- Process: 8.80%
# Iter 890 ---- Process: 8.90%
# Iter 900 ---- Process: 9.00%
# Iter 910 ---- Process: 9.10%
# Iter 920 ---- Process: 9.20%
# Iter 930 ---- Process: 9.30%
# Iter 940 ---- Process: 9.40%
# Iter 950 ---- Process: 9.50%
# Iter 960 ---- Process: 9.60%
# Iter 970 ---- Process: 9.70%
# Iter 980 ---- Process: 9.80%
# Iter 990 ---- Process: 9.90%
# Iter 1000 ---- Process: 10.00%
# Iter 1010 ---- Process: 10.10%
# Iter 1020 ---- Process: 10.20%
# Iter 1030 ---- Process: 10.30%
# Iter 1040 ---- Process: 10.40%
# Iter 1050 ---- Process: 10.50%
# Iter 1060 ---- Process: 10.60%
# Iter 1070 ---- Process: 10.70%
# Iter 1080 ---- Process: 10.80%
# Iter 1090 ---- Process: 10.90%
# Iter 1100 ---- Process: 11.00%
# Iter 1110 ---- Process: 11.10%
# Iter 1120 ---- Process: 11.20%
# Iter 1130 ---- Process: 11.30%
# Iter 1140 ---- Process: 11.40%
# Iter 1150 ---- Process: 11.50%
# Iter 1160 ---- Process: 11.60%
# Iter 1170 ---- Process: 11.70%
# Iter 1180 ---- Process: 11.80%
# Iter 1190 ---- Process: 11.90%
# Iter 1200 ---- Process: 12.00%
# Iter 1210 ---- Process: 12.10%
# Iter 1220 ---- Process: 12.20%
# Iter 1230 ---- Process: 12.30%
# Iter 1240 ---- Process: 12.40%
# Iter 1250 ---- Process: 12.50%
# Iter 1260 ---- Process: 12.60%
# Iter 1270 ---- Process: 12.70%
# Iter 1280 ---- Process: 12.80%
# Iter 1290 ---- Process: 12.90%
# Iter 1300 ---- Process: 13.00%
# Iter 1310 ---- Process: 13.10%
# Iter 1320 ---- Process: 13.20%
# Iter 1330 ---- Process: 13.30%
# Iter 1340 ---- Process: 13.40%
# Iter 1350 ---- Process: 13.50%
# Iter 1360 ---- Process: 13.60%
# Iter 1370 ---- Process: 13.70%
# Iter 1380 ---- Process: 13.80%
# Iter 1390 ---- Process: 13.90%
# Iter 1400 ---- Process: 14.00%
# Iter 1410 ---- Process: 14.10%
# Iter 1420 ---- Process: 14.20%
# Iter 1430 ---- Process: 14.30%
# Iter 1440 ---- Process: 14.40%
# Iter 1450 ---- Process: 14.50%
# Iter 1460 ---- Process: 14.60%
# Iter 1470 ---- Process: 14.70%
# Iter 1480 ---- Process: 14.80%
# Iter 1490 ---- Process: 14.90%
# Iter 1500 ---- Process: 15.00%
# Iter 1510 ---- Process: 15.10%
# Iter 1520 ---- Process: 15.20%
# Iter 1530 ---- Process: 15.30%
# Iter 1540 ---- Process: 15.40%
# Iter 1550 ---- Process: 15.50%
# Iter 1560 ---- Process: 15.60%
# Iter 1570 ---- Process: 15.70%
# Iter 1580 ---- Process: 15.80%
# Iter 1590 ---- Process: 15.90%
# Iter 1600 ---- Process: 16.00%
# Iter 1610 ---- Process: 16.10%
# Iter 1620 ---- Process: 16.20%
# Iter 1630 ---- Process: 16.30%
# Iter 1640 ---- Process: 16.40%
# Iter 1650 ---- Process: 16.50%
# Iter 1660 ---- Process: 16.60%
# Iter 1670 ---- Process: 16.70%
# Iter 1680 ---- Process: 16.80%
# Iter 1690 ---- Process: 16.90%
# Iter 1700 ---- Process: 17.00%
# Iter 1710 ---- Process: 17.10%
# Iter 1720 ---- Process: 17.20%
# Iter 1730 ---- Process: 17.30%
# Iter 1740 ---- Process: 17.40%
# Iter 1750 ---- Process: 17.50%
# Iter 1760 ---- Process: 17.60%
# Iter 1770 ---- Process: 17.70%
# Iter 1780 ---- Process: 17.80%
# Iter 1790 ---- Process: 17.90%
# Iter 1800 ---- Process: 18.00%
# Iter 1810 ---- Process: 18.10%
# Iter 1820 ---- Process: 18.20%
# Iter 1830 ---- Process: 18.30%
# Iter 1840 ---- Process: 18.40%
# Iter 1850 ---- Process: 18.50%
# Iter 1860 ---- Process: 18.60%
# Iter 1870 ---- Process: 18.70%
# Iter 1880 ---- Process: 18.80%
# Iter 1890 ---- Process: 18.90%
# Iter 1900 ---- Process: 19.00%
# Iter 1910 ---- Process: 19.10%
# Iter 1920 ---- Process: 19.20%
# Iter 1930 ---- Process: 19.30%
# Iter 1940 ---- Process: 19.40%
# Iter 1950 ---- Process: 19.50%
# Iter 1960 ---- Process: 19.60%
# Iter 1970 ---- Process: 19.70%
# Iter 1980 ---- Process: 19.80%
# Iter 1990 ---- Process: 19.90%
# Iter 2000 ---- Process: 20.00%
# Iter 2010 ---- Process: 20.10%
# Iter 2020 ---- Process: 20.20%
# Iter 2030 ---- Process: 20.30%
# Iter 2040 ---- Process: 20.40%
# Iter 2050 ---- Process: 20.50%
# Iter 2060 ---- Process: 20.60%
# Iter 2070 ---- Process: 20.70%
# Iter 2080 ---- Process: 20.80%
# Iter 2090 ---- Process: 20.90%
# Iter 2100 ---- Process: 21.00%
# Iter 2110 ---- Process: 21.10%
# Iter 2120 ---- Process: 21.20%
# Iter 2130 ---- Process: 21.30%
# Iter 2140 ---- Process: 21.40%
# Iter 2150 ---- Process: 21.50%
# Iter 2160 ---- Process: 21.60%
# Iter 2170 ---- Process: 21.70%
# Iter 2180 ---- Process: 21.80%
# Iter 2190 ---- Process: 21.90%
# Iter 2200 ---- Process: 22.00%
# Iter 2210 ---- Process: 22.10%
# Iter 2220 ---- Process: 22.20%
# Iter 2230 ---- Process: 22.30%
# Iter 2240 ---- Process: 22.40%
# Iter 2250 ---- Process: 22.50%
# Iter 2260 ---- Process: 22.60%
# Iter 2270 ---- Process: 22.70%
# Iter 2280 ---- Process: 22.80%
# Iter 2290 ---- Process: 22.90%
# Iter 2300 ---- Process: 23.00%
# Iter 2310 ---- Process: 23.10%
# Iter 2320 ---- Process: 23.20%
# Iter 2330 ---- Process: 23.30%
# Iter 2340 ---- Process: 23.40%
# Iter 2350 ---- Process: 23.50%
# Iter 2360 ---- Process: 23.60%
# Iter 2370 ---- Process: 23.70%
# Iter 2380 ---- Process: 23.80%
# Iter 2390 ---- Process: 23.90%
# Iter 2400 ---- Process: 24.00%
# Iter 2410 ---- Process: 24.10%
# Iter 2420 ---- Process: 24.20%
# Iter 2430 ---- Process: 24.30%
# Iter 2440 ---- Process: 24.40%
# Iter 2450 ---- Process: 24.50%
# Iter 2460 ---- Process: 24.60%
# Iter 2470 ---- Process: 24.70%
# Iter 2480 ---- Process: 24.80%
# Iter 2490 ---- Process: 24.90%
# Iter 2500 ---- Process: 25.00%
# Iter 2510 ---- Process: 25.10%
# Iter 2520 ---- Process: 25.20%
# Iter 2530 ---- Process: 25.30%
# Iter 2540 ---- Process: 25.40%
# Iter 2550 ---- Process: 25.50%
# Iter 2560 ---- Process: 25.60%
# Iter 2570 ---- Process: 25.70%
# Iter 2580 ---- Process: 25.80%
# Iter 2590 ---- Process: 25.90%
# Iter 2600 ---- Process: 26.00%
# Iter 2610 ---- Process: 26.10%
# Iter 2620 ---- Process: 26.20%
# Iter 2630 ---- Process: 26.30%
# Iter 2640 ---- Process: 26.40%
# Iter 2650 ---- Process: 26.50%
# Iter 2660 ---- Process: 26.60%
# Iter 2670 ---- Process: 26.70%
# Iter 2680 ---- Process: 26.80%
# Iter 2690 ---- Process: 26.90%
# Iter 2700 ---- Process: 27.00%
# Iter 2710 ---- Process: 27.10%
# Iter 2720 ---- Process: 27.20%
# Iter 2730 ---- Process: 27.30%
# Iter 2740 ---- Process: 27.40%
# Iter 2750 ---- Process: 27.50%
# Iter 2760 ---- Process: 27.60%
# Iter 2770 ---- Process: 27.70%
# Iter 2780 ---- Process: 27.80%
# Iter 2790 ---- Process: 27.90%
# Iter 2800 ---- Process: 28.00%
# Iter 2810 ---- Process: 28.10%
# Iter 2820 ---- Process: 28.20%
# Iter 2830 ---- Process: 28.30%
# Iter 2840 ---- Process: 28.40%
# Iter 2850 ---- Process: 28.50%
# Iter 2860 ---- Process: 28.60%
# Iter 2870 ---- Process: 28.70%
# Iter 2880 ---- Process: 28.80%
# Iter 2890 ---- Process: 28.90%
# Iter 2900 ---- Process: 29.00%
# Iter 2910 ---- Process: 29.10%
# Iter 2920 ---- Process: 29.20%
# Iter 2930 ---- Process: 29.30%
# Iter 2940 ---- Process: 29.40%
# Iter 2950 ---- Process: 29.50%
# Iter 2960 ---- Process: 29.60%
# Iter 2970 ---- Process: 29.70%
# Iter 2980 ---- Process: 29.80%
# Iter 2990 ---- Process: 29.90%
# Iter 3000 ---- Process: 30.00%
# Iter 3010 ---- Process: 30.10%
# Iter 3020 ---- Process: 30.20%
# Iter 3030 ---- Process: 30.30%
# Iter 3040 ---- Process: 30.40%
# Iter 3050 ---- Process: 30.50%
# Iter 3060 ---- Process: 30.60%
# Iter 3070 ---- Process: 30.70%
# Iter 3080 ---- Process: 30.80%
# Iter 3090 ---- Process: 30.90%
# Iter 3100 ---- Process: 31.00%
# Iter 3110 ---- Process: 31.10%
# Iter 3120 ---- Process: 31.20%
# Iter 3130 ---- Process: 31.30%
# Iter 3140 ---- Process: 31.40%
# Iter 3150 ---- Process: 31.50%
# Iter 3160 ---- Process: 31.60%
# Iter 3170 ---- Process: 31.70%
# Iter 3180 ---- Process: 31.80%
# Iter 3190 ---- Process: 31.90%
# Iter 3200 ---- Process: 32.00%
# Iter 3210 ---- Process: 32.10%
# Iter 3220 ---- Process: 32.20%
# Iter 3230 ---- Process: 32.30%
# Iter 3240 ---- Process: 32.40%
# Iter 3250 ---- Process: 32.50%
# Iter 3260 ---- Process: 32.60%
# Iter 3270 ---- Process: 32.70%
# Iter 3280 ---- Process: 32.80%
# Iter 3290 ---- Process: 32.90%
# Iter 3300 ---- Process: 33.00%
# Iter 3310 ---- Process: 33.10%
# Iter 3320 ---- Process: 33.20%
# Iter 3330 ---- Process: 33.30%
# Iter 3340 ---- Process: 33.40%
# Iter 3350 ---- Process: 33.50%
# Iter 3360 ---- Process: 33.60%
# Iter 3370 ---- Process: 33.70%
# Iter 3380 ---- Process: 33.80%
# Iter 3390 ---- Process: 33.90%
# Iter 3400 ---- Process: 34.00%
# Iter 3410 ---- Process: 34.10%
# Iter 3420 ---- Process: 34.20%
# Iter 3430 ---- Process: 34.30%
# Iter 3440 ---- Process: 34.40%
# Iter 3450 ---- Process: 34.50%
# Iter 3460 ---- Process: 34.60%
# Iter 3470 ---- Process: 34.70%
# Iter 3480 ---- Process: 34.80%
# Iter 3490 ---- Process: 34.90%
# Iter 3500 ---- Process: 35.00%
# Iter 3510 ---- Process: 35.10%
# Iter 3520 ---- Process: 35.20%
# Iter 3530 ---- Process: 35.30%
# Iter 3540 ---- Process: 35.40%
# Iter 3550 ---- Process: 35.50%
# Iter 3560 ---- Process: 35.60%
# Iter 3570 ---- Process: 35.70%
# Iter 3580 ---- Process: 35.80%
# Iter 3590 ---- Process: 35.90%
# Iter 3600 ---- Process: 36.00%
# Iter 3610 ---- Process: 36.10%
# Iter 3620 ---- Process: 36.20%
# Iter 3630 ---- Process: 36.30%
# Iter 3640 ---- Process: 36.40%
# Iter 3650 ---- Process: 36.50%
# Iter 3660 ---- Process: 36.60%
# Iter 3670 ---- Process: 36.70%
# Iter 3680 ---- Process: 36.80%
# Iter 3690 ---- Process: 36.90%
# Iter 3700 ---- Process: 37.00%
# Iter 3710 ---- Process: 37.10%
# Iter 3720 ---- Process: 37.20%
# Iter 3730 ---- Process: 37.30%
# Iter 3740 ---- Process: 37.40%
# Iter 3750 ---- Process: 37.50%
# Iter 3760 ---- Process: 37.60%
# Iter 3770 ---- Process: 37.70%
# Iter 3780 ---- Process: 37.80%
# Iter 3790 ---- Process: 37.90%
# Iter 3800 ---- Process: 38.00%
# Iter 3810 ---- Process: 38.10%
# Iter 3820 ---- Process: 38.20%
# Iter 3830 ---- Process: 38.30%
# Iter 3840 ---- Process: 38.40%
# Iter 3850 ---- Process: 38.50%
# Iter 3860 ---- Process: 38.60%
# Iter 3870 ---- Process: 38.70%
# Iter 3880 ---- Process: 38.80%
# Iter 3890 ---- Process: 38.90%
# Iter 3900 ---- Process: 39.00%
# Iter 3910 ---- Process: 39.10%
# Iter 3920 ---- Process: 39.20%
# Iter 3930 ---- Process: 39.30%
# Iter 3940 ---- Process: 39.40%
# Iter 3950 ---- Process: 39.50%
# Iter 3960 ---- Process: 39.60%
# Iter 3970 ---- Process: 39.70%
# Iter 3980 ---- Process: 39.80%
# Iter 3990 ---- Process: 39.90%
# Iter 4000 ---- Process: 40.00%
# Iter 4010 ---- Process: 40.10%
# Iter 4020 ---- Process: 40.20%
# Iter 4030 ---- Process: 40.30%
# Iter 4040 ---- Process: 40.40%
# Iter 4050 ---- Process: 40.50%
# Iter 4060 ---- Process: 40.60%
# Iter 4070 ---- Process: 40.70%
# Iter 4080 ---- Process: 40.80%
# Iter 4090 ---- Process: 40.90%
# Iter 4100 ---- Process: 41.00%
# Iter 4110 ---- Process: 41.10%
# Iter 4120 ---- Process: 41.20%
# Iter 4130 ---- Process: 41.30%
# Iter 4140 ---- Process: 41.40%
# Iter 4150 ---- Process: 41.50%
# Iter 4160 ---- Process: 41.60%
# Iter 4170 ---- Process: 41.70%
# Iter 4180 ---- Process: 41.80%
# Iter 4190 ---- Process: 41.90%
# Iter 4200 ---- Process: 42.00%
# Iter 4210 ---- Process: 42.10%
# Iter 4220 ---- Process: 42.20%
# Iter 4230 ---- Process: 42.30%
# Iter 4240 ---- Process: 42.40%
# Iter 4250 ---- Process: 42.50%
# Iter 4260 ---- Process: 42.60%
# Iter 4270 ---- Process: 42.70%
# Iter 4280 ---- Process: 42.80%
# Iter 4290 ---- Process: 42.90%
# Iter 4300 ---- Process: 43.00%
# Iter 4310 ---- Process: 43.10%
# Iter 4320 ---- Process: 43.20%
# Iter 4330 ---- Process: 43.30%
# Iter 4340 ---- Process: 43.40%
# Iter 4350 ---- Process: 43.50%
# Iter 4360 ---- Process: 43.60%
# Iter 4370 ---- Process: 43.70%
# Iter 4380 ---- Process: 43.80%
# Iter 4390 ---- Process: 43.90%
# Iter 4400 ---- Process: 44.00%
# Iter 4410 ---- Process: 44.10%
# Iter 4420 ---- Process: 44.20%
# Iter 4430 ---- Process: 44.30%
# Iter 4440 ---- Process: 44.40%
# Iter 4450 ---- Process: 44.50%
# Iter 4460 ---- Process: 44.60%
# Iter 4470 ---- Process: 44.70%
# Iter 4480 ---- Process: 44.80%
# Iter 4490 ---- Process: 44.90%
# Iter 4500 ---- Process: 45.00%
# Iter 4510 ---- Process: 45.10%
# Iter 4520 ---- Process: 45.20%
# Iter 4530 ---- Process: 45.30%
# Iter 4540 ---- Process: 45.40%
# Iter 4550 ---- Process: 45.50%
# Iter 4560 ---- Process: 45.60%
# Iter 4570 ---- Process: 45.70%
# Iter 4580 ---- Process: 45.80%
# Iter 4590 ---- Process: 45.90%
# Iter 4600 ---- Process: 46.00%
# Iter 4610 ---- Process: 46.10%
# Iter 4620 ---- Process: 46.20%
# Iter 4630 ---- Process: 46.30%
# Iter 4640 ---- Process: 46.40%
# Iter 4650 ---- Process: 46.50%
# Iter 4660 ---- Process: 46.60%
# Iter 4670 ---- Process: 46.70%
# Iter 4680 ---- Process: 46.80%
# Iter 4690 ---- Process: 46.90%
# Iter 4700 ---- Process: 47.00%
# Iter 4710 ---- Process: 47.10%
# Iter 4720 ---- Process: 47.20%
# Iter 4730 ---- Process: 47.30%
# Iter 4740 ---- Process: 47.40%
# Iter 4750 ---- Process: 47.50%
# Iter 4760 ---- Process: 47.60%
# Iter 4770 ---- Process: 47.70%
# Iter 4780 ---- Process: 47.80%
# Iter 4790 ---- Process: 47.90%
# Iter 4800 ---- Process: 48.00%
# Iter 4810 ---- Process: 48.10%
# Iter 4820 ---- Process: 48.20%
# Iter 4830 ---- Process: 48.30%
# Iter 4840 ---- Process: 48.40%
# Iter 4850 ---- Process: 48.50%
# Iter 4860 ---- Process: 48.60%
# Iter 4870 ---- Process: 48.70%
# Iter 4880 ---- Process: 48.80%
# Iter 4890 ---- Process: 48.90%
# Iter 4900 ---- Process: 49.00%
# Iter 4910 ---- Process: 49.10%
# Iter 4920 ---- Process: 49.20%
# Iter 4930 ---- Process: 49.30%
# Iter 4940 ---- Process: 49.40%
# Iter 4950 ---- Process: 49.50%
# Iter 4960 ---- Process: 49.60%
# Iter 4970 ---- Process: 49.70%
# Iter 4980 ---- Process: 49.80%
# Iter 4990 ---- Process: 49.90%
# Iter 5000 ---- Process: 50.00%
# Iter 5010 ---- Process: 50.10%
# Iter 5020 ---- Process: 50.20%
# Iter 5030 ---- Process: 50.30%
# Iter 5040 ---- Process: 50.40%
# Iter 5050 ---- Process: 50.50%
# Iter 5060 ---- Process: 50.60%
# Iter 5070 ---- Process: 50.70%
# Iter 5080 ---- Process: 50.80%
# Iter 5090 ---- Process: 50.90%
# Iter 5100 ---- Process: 51.00%
# Iter 5110 ---- Process: 51.10%
# Iter 5120 ---- Process: 51.20%
# Iter 5130 ---- Process: 51.30%
# Iter 5140 ---- Process: 51.40%
# Iter 5150 ---- Process: 51.50%
# Iter 5160 ---- Process: 51.60%
# Iter 5170 ---- Process: 51.70%
# Iter 5180 ---- Process: 51.80%
# Iter 5190 ---- Process: 51.90%
# Iter 5200 ---- Process: 52.00%
# Iter 5210 ---- Process: 52.10%
# Iter 5220 ---- Process: 52.20%
# Iter 5230 ---- Process: 52.30%
# Iter 5240 ---- Process: 52.40%
# Iter 5250 ---- Process: 52.50%
# Iter 5260 ---- Process: 52.60%
# Iter 5270 ---- Process: 52.70%
# Iter 5280 ---- Process: 52.80%
# Iter 5290 ---- Process: 52.90%
# Iter 5300 ---- Process: 53.00%
# Iter 5310 ---- Process: 53.10%
# Iter 5320 ---- Process: 53.20%
# Iter 5330 ---- Process: 53.30%
# Iter 5340 ---- Process: 53.40%
# Iter 5350 ---- Process: 53.50%
# Iter 5360 ---- Process: 53.60%
# Iter 5370 ---- Process: 53.70%
# Iter 5380 ---- Process: 53.80%
# Iter 5390 ---- Process: 53.90%
# Iter 5400 ---- Process: 54.00%
# Iter 5410 ---- Process: 54.10%
# Iter 5420 ---- Process: 54.20%
# Iter 5430 ---- Process: 54.30%
# Iter 5440 ---- Process: 54.40%
# Iter 5450 ---- Process: 54.50%
# Iter 5460 ---- Process: 54.60%
# Iter 5470 ---- Process: 54.70%
# Iter 5480 ---- Process: 54.80%
# Iter 5490 ---- Process: 54.90%
# Iter 5500 ---- Process: 55.00%
# Iter 5510 ---- Process: 55.10%
# Iter 5520 ---- Process: 55.20%
# Iter 5530 ---- Process: 55.30%
# Iter 5540 ---- Process: 55.40%
# Iter 5550 ---- Process: 55.50%
# Iter 5560 ---- Process: 55.60%
# Iter 5570 ---- Process: 55.70%
# Iter 5580 ---- Process: 55.80%
# Iter 5590 ---- Process: 55.90%
# Iter 5600 ---- Process: 56.00%
# Iter 5610 ---- Process: 56.10%
# Iter 5620 ---- Process: 56.20%
# Iter 5630 ---- Process: 56.30%
# Iter 5640 ---- Process: 56.40%
# Iter 5650 ---- Process: 56.50%
# Iter 5660 ---- Process: 56.60%
# Iter 5670 ---- Process: 56.70%
# Iter 5680 ---- Process: 56.80%
# Iter 5690 ---- Process: 56.90%
# Iter 5700 ---- Process: 57.00%
# Iter 5710 ---- Process: 57.10%
# Iter 5720 ---- Process: 57.20%
# Iter 5730 ---- Process: 57.30%
# Iter 5740 ---- Process: 57.40%
# Iter 5750 ---- Process: 57.50%
# Iter 5760 ---- Process: 57.60%
# Iter 5770 ---- Process: 57.70%
# Iter 5780 ---- Process: 57.80%
# Iter 5790 ---- Process: 57.90%
# Iter 5800 ---- Process: 58.00%
# Iter 5810 ---- Process: 58.10%
# Iter 5820 ---- Process: 58.20%
# Iter 5830 ---- Process: 58.30%
# Iter 5840 ---- Process: 58.40%
# Iter 5850 ---- Process: 58.50%
# Iter 5860 ---- Process: 58.60%
# Iter 5870 ---- Process: 58.70%
# Iter 5880 ---- Process: 58.80%
# Iter 5890 ---- Process: 58.90%
# Iter 5900 ---- Process: 59.00%
# Iter 5910 ---- Process: 59.10%
# Iter 5920 ---- Process: 59.20%
# Iter 5930 ---- Process: 59.30%
# Iter 5940 ---- Process: 59.40%
# Iter 5950 ---- Process: 59.50%
# Iter 5960 ---- Process: 59.60%
# Iter 5970 ---- Process: 59.70%
# Iter 5980 ---- Process: 59.80%
# Iter 5990 ---- Process: 59.90%
# Iter 6000 ---- Process: 60.00%
# Iter 6010 ---- Process: 60.10%
# Iter 6020 ---- Process: 60.20%
# Iter 6030 ---- Process: 60.30%
# Iter 6040 ---- Process: 60.40%
# Iter 6050 ---- Process: 60.50%
# Iter 6060 ---- Process: 60.60%
# Iter 6070 ---- Process: 60.70%
# Iter 6080 ---- Process: 60.80%
# Iter 6090 ---- Process: 60.90%
# Iter 6100 ---- Process: 61.00%
# Iter 6110 ---- Process: 61.10%
# Iter 6120 ---- Process: 61.20%
# Iter 6130 ---- Process: 61.30%
# Iter 6140 ---- Process: 61.40%
# Iter 6150 ---- Process: 61.50%
# Iter 6160 ---- Process: 61.60%
# Iter 6170 ---- Process: 61.70%
# Iter 6180 ---- Process: 61.80%
# Iter 6190 ---- Process: 61.90%
# Iter 6200 ---- Process: 62.00%
# Iter 6210 ---- Process: 62.10%
# Iter 6220 ---- Process: 62.20%
# Iter 6230 ---- Process: 62.30%
# Iter 6240 ---- Process: 62.40%
# Iter 6250 ---- Process: 62.50%
# Iter 6260 ---- Process: 62.60%
# Iter 6270 ---- Process: 62.70%
# Iter 6280 ---- Process: 62.80%
# Iter 6290 ---- Process: 62.90%
# Iter 6300 ---- Process: 63.00%
# Iter 6310 ---- Process: 63.10%
# Iter 6320 ---- Process: 63.20%
# Iter 6330 ---- Process: 63.30%
# Iter 6340 ---- Process: 63.40%
# Iter 6350 ---- Process: 63.50%
# Iter 6360 ---- Process: 63.60%
# Iter 6370 ---- Process: 63.70%
# Iter 6380 ---- Process: 63.80%
# Iter 6390 ---- Process: 63.90%
# Iter 6400 ---- Process: 64.00%
# Iter 6410 ---- Process: 64.10%
# Iter 6420 ---- Process: 64.20%
# Iter 6430 ---- Process: 64.30%
# Iter 6440 ---- Process: 64.40%
# Iter 6450 ---- Process: 64.50%
# Iter 6460 ---- Process: 64.60%
# Iter 6470 ---- Process: 64.70%
# Iter 6480 ---- Process: 64.80%
# Iter 6490 ---- Process: 64.90%
# Iter 6500 ---- Process: 65.00%
# Iter 6510 ---- Process: 65.10%
# Iter 6520 ---- Process: 65.20%
# Iter 6530 ---- Process: 65.30%
# Iter 6540 ---- Process: 65.40%
# Iter 6550 ---- Process: 65.50%
# Iter 6560 ---- Process: 65.60%
# Iter 6570 ---- Process: 65.70%
# Iter 6580 ---- Process: 65.80%
# Iter 6590 ---- Process: 65.90%
# Iter 6600 ---- Process: 66.00%
# Iter 6610 ---- Process: 66.10%
# Iter 6620 ---- Process: 66.20%
# Iter 6630 ---- Process: 66.30%
# Iter 6640 ---- Process: 66.40%
# Iter 6650 ---- Process: 66.50%
# Iter 6660 ---- Process: 66.60%
# Iter 6670 ---- Process: 66.70%
# Iter 6680 ---- Process: 66.80%
# Iter 6690 ---- Process: 66.90%
# Iter 6700 ---- Process: 67.00%
# Iter 6710 ---- Process: 67.10%
# Iter 6720 ---- Process: 67.20%
# Iter 6730 ---- Process: 67.30%
# Iter 6740 ---- Process: 67.40%
# Iter 6750 ---- Process: 67.50%
# Iter 6760 ---- Process: 67.60%
# Iter 6770 ---- Process: 67.70%
# Iter 6780 ---- Process: 67.80%
# Iter 6790 ---- Process: 67.90%
# Iter 6800 ---- Process: 68.00%
# Iter 6810 ---- Process: 68.10%
# Iter 6820 ---- Process: 68.20%
# Iter 6830 ---- Process: 68.30%
# Iter 6840 ---- Process: 68.40%
# Iter 6850 ---- Process: 68.50%
# Iter 6860 ---- Process: 68.60%
# Iter 6870 ---- Process: 68.70%
# Iter 6880 ---- Process: 68.80%
# Iter 6890 ---- Process: 68.90%
# Iter 6900 ---- Process: 69.00%
# Iter 6910 ---- Process: 69.10%
# Iter 6920 ---- Process: 69.20%
# Iter 6930 ---- Process: 69.30%
# Iter 6940 ---- Process: 69.40%
# Iter 6950 ---- Process: 69.50%
# Iter 6960 ---- Process: 69.60%
# Iter 6970 ---- Process: 69.70%
# Iter 6980 ---- Process: 69.80%
# Iter 6990 ---- Process: 69.90%
# Iter 7000 ---- Process: 70.00%
# Iter 7010 ---- Process: 70.10%
# Iter 7020 ---- Process: 70.20%
# Iter 7030 ---- Process: 70.30%
# Iter 7040 ---- Process: 70.40%
# Iter 7050 ---- Process: 70.50%
# Iter 7060 ---- Process: 70.60%
# Iter 7070 ---- Process: 70.70%
# Iter 7080 ---- Process: 70.80%
# Iter 7090 ---- Process: 70.90%
# Iter 7100 ---- Process: 71.00%
# Iter 7110 ---- Process: 71.10%
# Iter 7120 ---- Process: 71.20%
# Iter 7130 ---- Process: 71.30%
# Iter 7140 ---- Process: 71.40%
# Iter 7150 ---- Process: 71.50%
# Iter 7160 ---- Process: 71.60%
# Iter 7170 ---- Process: 71.70%
# Iter 7180 ---- Process: 71.80%
# Iter 7190 ---- Process: 71.90%
# Iter 7200 ---- Process: 72.00%
# Iter 7210 ---- Process: 72.10%
# Iter 7220 ---- Process: 72.20%
# Iter 7230 ---- Process: 72.30%
# Iter 7240 ---- Process: 72.40%
# Iter 7250 ---- Process: 72.50%
# Iter 7260 ---- Process: 72.60%
# Iter 7270 ---- Process: 72.70%
# Iter 7280 ---- Process: 72.80%
# Iter 7290 ---- Process: 72.90%
# Iter 7300 ---- Process: 73.00%
# Iter 7310 ---- Process: 73.10%
# Iter 7320 ---- Process: 73.20%
# Iter 7330 ---- Process: 73.30%
# Iter 7340 ---- Process: 73.40%
# Iter 7350 ---- Process: 73.50%
# Iter 7360 ---- Process: 73.60%
# Iter 7370 ---- Process: 73.70%
# Iter 7380 ---- Process: 73.80%
# Iter 7390 ---- Process: 73.90%
# Iter 7400 ---- Process: 74.00%
# Iter 7410 ---- Process: 74.10%
# Iter 7420 ---- Process: 74.20%
# Iter 7430 ---- Process: 74.30%
# Iter 7440 ---- Process: 74.40%
# Iter 7450 ---- Process: 74.50%
# Iter 7460 ---- Process: 74.60%
# Iter 7470 ---- Process: 74.70%
# Iter 7480 ---- Process: 74.80%
# Iter 7490 ---- Process: 74.90%
# Iter 7500 ---- Process: 75.00%
# Iter 7510 ---- Process: 75.10%
# Iter 7520 ---- Process: 75.20%
# Iter 7530 ---- Process: 75.30%
# Iter 7540 ---- Process: 75.40%
# Iter 7550 ---- Process: 75.50%
# Iter 7560 ---- Process: 75.60%
# Iter 7570 ---- Process: 75.70%
# Iter 7580 ---- Process: 75.80%
# Iter 7590 ---- Process: 75.90%
# Iter 7600 ---- Process: 76.00%
# Iter 7610 ---- Process: 76.10%
# Iter 7620 ---- Process: 76.20%
# Iter 7630 ---- Process: 76.30%
# Iter 7640 ---- Process: 76.40%
# Iter 7650 ---- Process: 76.50%
# Iter 7660 ---- Process: 76.60%
# Iter 7670 ---- Process: 76.70%
# Iter 7680 ---- Process: 76.80%
# Iter 7690 ---- Process: 76.90%
# Iter 7700 ---- Process: 77.00%
# Iter 7710 ---- Process: 77.10%
# Iter 7720 ---- Process: 77.20%
# Iter 7730 ---- Process: 77.30%
# Iter 7740 ---- Process: 77.40%
# Iter 7750 ---- Process: 77.50%
# Iter 7760 ---- Process: 77.60%
# Iter 7770 ---- Process: 77.70%
# Iter 7780 ---- Process: 77.80%
# Iter 7790 ---- Process: 77.90%
# Iter 7800 ---- Process: 78.00%
# Iter 7810 ---- Process: 78.10%
# Iter 7820 ---- Process: 78.20%
# Iter 7830 ---- Process: 78.30%
# Iter 7840 ---- Process: 78.40%
# Iter 7850 ---- Process: 78.50%
# Iter 7860 ---- Process: 78.60%
# Iter 7870 ---- Process: 78.70%
# Iter 7880 ---- Process: 78.80%
# Iter 7890 ---- Process: 78.90%
# Iter 7900 ---- Process: 79.00%
# Iter 7910 ---- Process: 79.10%
# Iter 7920 ---- Process: 79.20%
# Iter 7930 ---- Process: 79.30%
# Iter 7940 ---- Process: 79.40%
# Iter 7950 ---- Process: 79.50%
# Iter 7960 ---- Process: 79.60%
# Iter 7970 ---- Process: 79.70%
# Iter 7980 ---- Process: 79.80%
# Iter 7990 ---- Process: 79.90%
# Iter 8000 ---- Process: 80.00%
# Iter 8010 ---- Process: 80.10%
# Iter 8020 ---- Process: 80.20%
# Iter 8030 ---- Process: 80.30%
# Iter 8040 ---- Process: 80.40%
# Iter 8050 ---- Process: 80.50%
# Iter 8060 ---- Process: 80.60%
# Iter 8070 ---- Process: 80.70%
# Iter 8080 ---- Process: 80.80%
# Iter 8090 ---- Process: 80.90%
# Iter 8100 ---- Process: 81.00%
# Iter 8110 ---- Process: 81.10%
# Iter 8120 ---- Process: 81.20%
# Iter 8130 ---- Process: 81.30%
# Iter 8140 ---- Process: 81.40%
# Iter 8150 ---- Process: 81.50%
# Iter 8160 ---- Process: 81.60%
# Iter 8170 ---- Process: 81.70%
# Iter 8180 ---- Process: 81.80%
# Iter 8190 ---- Process: 81.90%
# Iter 8200 ---- Process: 82.00%
# Iter 8210 ---- Process: 82.10%
# Iter 8220 ---- Process: 82.20%
# Iter 8230 ---- Process: 82.30%
# Iter 8240 ---- Process: 82.40%
# Iter 8250 ---- Process: 82.50%
# Iter 8260 ---- Process: 82.60%
# Iter 8270 ---- Process: 82.70%
# Iter 8280 ---- Process: 82.80%
# Iter 8290 ---- Process: 82.90%
# Iter 8300 ---- Process: 83.00%
# Iter 8310 ---- Process: 83.10%
# Iter 8320 ---- Process: 83.20%
# Iter 8330 ---- Process: 83.30%
# Iter 8340 ---- Process: 83.40%
# Iter 8350 ---- Process: 83.50%
# Iter 8360 ---- Process: 83.60%
# Iter 8370 ---- Process: 83.70%
# Iter 8380 ---- Process: 83.80%
# Iter 8390 ---- Process: 83.90%
# Iter 8400 ---- Process: 84.00%
# Iter 8410 ---- Process: 84.10%
# Iter 8420 ---- Process: 84.20%
# Iter 8430 ---- Process: 84.30%
# Iter 8440 ---- Process: 84.40%
# Iter 8450 ---- Process: 84.50%
# Iter 8460 ---- Process: 84.60%
# Iter 8470 ---- Process: 84.70%
# Iter 8480 ---- Process: 84.80%
# Iter 8490 ---- Process: 84.90%
# Iter 8500 ---- Process: 85.00%
# Iter 8510 ---- Process: 85.10%
# Iter 8520 ---- Process: 85.20%
# Iter 8530 ---- Process: 85.30%
# Iter 8540 ---- Process: 85.40%
# Iter 8550 ---- Process: 85.50%
# Iter 8560 ---- Process: 85.60%
# Iter 8570 ---- Process: 85.70%
# Iter 8580 ---- Process: 85.80%
# Iter 8590 ---- Process: 85.90%
# Iter 8600 ---- Process: 86.00%
# Iter 8610 ---- Process: 86.10%
# Iter 8620 ---- Process: 86.20%
# Iter 8630 ---- Process: 86.30%
# Iter 8640 ---- Process: 86.40%
# Iter 8650 ---- Process: 86.50%
# Iter 8660 ---- Process: 86.60%
# Iter 8670 ---- Process: 86.70%
# Iter 8680 ---- Process: 86.80%
# Iter 8690 ---- Process: 86.90%
# Iter 8700 ---- Process: 87.00%
# Iter 8710 ---- Process: 87.10%
# Iter 8720 ---- Process: 87.20%
# Iter 8730 ---- Process: 87.30%
# Iter 8740 ---- Process: 87.40%
# Iter 8750 ---- Process: 87.50%
# Iter 8760 ---- Process: 87.60%
# Iter 8770 ---- Process: 87.70%
# Iter 8780 ---- Process: 87.80%
# Iter 8790 ---- Process: 87.90%
# Iter 8800 ---- Process: 88.00%
# Iter 8810 ---- Process: 88.10%
# Iter 8820 ---- Process: 88.20%
# Iter 8830 ---- Process: 88.30%
# Iter 8840 ---- Process: 88.40%
# Iter 8850 ---- Process: 88.50%
# Iter 8860 ---- Process: 88.60%
# Iter 8870 ---- Process: 88.70%
# Iter 8880 ---- Process: 88.80%
# Iter 8890 ---- Process: 88.90%
# Iter 8900 ---- Process: 89.00%
# Iter 8910 ---- Process: 89.10%
# Iter 8920 ---- Process: 89.20%
# Iter 8930 ---- Process: 89.30%
# Iter 8940 ---- Process: 89.40%
# Iter 8950 ---- Process: 89.50%
# Iter 8960 ---- Process: 89.60%
# Iter 8970 ---- Process: 89.70%
# Iter 8980 ---- Process: 89.80%
# Iter 8990 ---- Process: 89.90%
# Iter 9000 ---- Process: 90.00%
# Iter 9010 ---- Process: 90.10%
# Iter 9020 ---- Process: 90.20%
# Iter 9030 ---- Process: 90.30%
# Iter 9040 ---- Process: 90.40%
# Iter 9050 ---- Process: 90.50%
# Iter 9060 ---- Process: 90.60%
# Iter 9070 ---- Process: 90.70%
# Iter 9080 ---- Process: 90.80%
# Iter 9090 ---- Process: 90.90%
# Iter 9100 ---- Process: 91.00%
# Iter 9110 ---- Process: 91.10%
# Iter 9120 ---- Process: 91.20%
# Iter 9130 ---- Process: 91.30%
# Iter 9140 ---- Process: 91.40%
# Iter 9150 ---- Process: 91.50%
# Iter 9160 ---- Process: 91.60%
# Iter 9170 ---- Process: 91.70%
# Iter 9180 ---- Process: 91.80%
# Iter 9190 ---- Process: 91.90%
# Iter 9200 ---- Process: 92.00%
# Iter 9210 ---- Process: 92.10%
# Iter 9220 ---- Process: 92.20%
# Iter 9230 ---- Process: 92.30%
# Iter 9240 ---- Process: 92.40%
# Iter 9250 ---- Process: 92.50%
# Iter 9260 ---- Process: 92.60%
# Iter 9270 ---- Process: 92.70%
# Iter 9280 ---- Process: 92.80%
# Iter 9290 ---- Process: 92.90%
# Iter 9300 ---- Process: 93.00%
# Iter 9310 ---- Process: 93.10%
# Iter 9320 ---- Process: 93.20%
# Iter 9330 ---- Process: 93.30%
# Iter 9340 ---- Process: 93.40%
# Iter 9350 ---- Process: 93.50%
# Iter 9360 ---- Process: 93.60%
# Iter 9370 ---- Process: 93.70%
# Iter 9380 ---- Process: 93.80%
# Iter 9390 ---- Process: 93.90%
# Iter 9400 ---- Process: 94.00%
# Iter 9410 ---- Process: 94.10%
# Iter 9420 ---- Process: 94.20%
# Iter 9430 ---- Process: 94.30%
# Iter 9440 ---- Process: 94.40%
# Iter 9450 ---- Process: 94.50%
# Iter 9460 ---- Process: 94.60%
# Iter 9470 ---- Process: 94.70%
# Iter 9480 ---- Process: 94.80%
# Iter 9490 ---- Process: 94.90%
# Iter 9500 ---- Process: 95.00%
# Iter 9510 ---- Process: 95.10%
# Iter 9520 ---- Process: 95.20%
# Iter 9530 ---- Process: 95.30%
# Iter 9540 ---- Process: 95.40%
# Iter 9550 ---- Process: 95.50%
# Iter 9560 ---- Process: 95.60%
# Iter 9570 ---- Process: 95.70%
# Iter 9580 ---- Process: 95.80%
# Iter 9590 ---- Process: 95.90%
# Iter 9600 ---- Process: 96.00%
# Iter 9610 ---- Process: 96.10%
# Iter 9620 ---- Process: 96.20%
# Iter 9630 ---- Process: 96.30%
# Iter 9640 ---- Process: 96.40%
# Iter 9650 ---- Process: 96.50%
# Iter 9660 ---- Process: 96.60%
# Iter 9670 ---- Process: 96.70%
# Iter 9680 ---- Process: 96.80%
# Iter 9690 ---- Process: 96.90%
# Iter 9700 ---- Process: 97.00%
# Iter 9710 ---- Process: 97.10%
# Iter 9720 ---- Process: 97.20%
# Iter 9730 ---- Process: 97.30%
# Iter 9740 ---- Process: 97.40%
# Iter 9750 ---- Process: 97.50%
# Iter 9760 ---- Process: 97.60%
# Iter 9770 ---- Process: 97.70%
# Iter 9780 ---- Process: 97.80%
# Iter 9790 ---- Process: 97.90%
# Iter 9800 ---- Process: 98.00%
# Iter 9810 ---- Process: 98.10%
# Iter 9820 ---- Process: 98.20%
# Iter 9830 ---- Process: 98.30%
# Iter 9840 ---- Process: 98.40%
# Iter 9850 ---- Process: 98.50%
# Iter 9860 ---- Process: 98.60%
# Iter 9870 ---- Process: 98.70%
# Iter 9880 ---- Process: 98.80%
# Iter 9890 ---- Process: 98.90%
# Iter 9900 ---- Process: 99.00%
# Iter 9910 ---- Process: 99.10%
# Iter 9920 ---- Process: 99.20%
# Iter 9930 ---- Process: 99.30%
# Iter 9940 ---- Process: 99.40%
# Iter 9950 ---- Process: 99.50%
# Iter 9960 ---- Process: 99.60%
# Iter 9970 ---- Process: 99.70%
# Iter 9980 ---- Process: 99.80%
# Iter 9990 ---- Process: 99.90%

# %%
RList = np.zeros([(num_epoches/10)])
rmseList = np.zeros([(num_epoches/10)])
maxeList = np.zeros([(num_epoches/10)])
for i in range(kind):
    out = np.array(outlist[i])
    tmp = out.T.reshape((1,test_batch_size))
    RList[i] = np.corrcoef(tmp[0,:],test_y.T[0,:])[0,1]
    rmseList[i] = rmse(tmp[0,:],test_y.T[0,:])
    maxeList[i] = maxe(tmp[0,:],test_y.T[0,:])

# %%
prefix = './gefcom-result/'
postfix = '-' + str(num_layers) + '-' + str(n_hidden) + '.csv'
DataFrame(RList).to_csv(prefix + 'R' + postfix)
DataFrame(rmseList).to_csv(prefix + 'RMSE' + postfix)
DataFrame(maxeList).to_csv(prefix + 'MAXE' + postfix)

# %%
out = out * 20000

# %%
DataFrame(out).to_csv(prefix + 'out.csv')

# %%
np.mean(RList[-101:-1])
# Out:
# 0.99821928180275277

# %%
time2 = time.time()
print time2-time1
# Out:
# 526.068176985
