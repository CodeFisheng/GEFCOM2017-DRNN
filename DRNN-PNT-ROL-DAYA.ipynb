# %% [markdown]
# ###

# %% [markdown]
# # Deep Learning (RNN) Demo for Load Forecasting

# %% [markdown]
# ## SEC 1: Import all the packages needed

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib as mp
import random as rd
import argparse
import os, sys
import csv
import math
import time
import matplotlib.pyplot as pl

# %% [markdown]
# ## SEC 2: Load demand data from excel file

# %% [markdown]
# define class for dataset

# %%
class County:
    def __init__(self,parsename):
        self.parsename = parsename
        dataframe = xls.parse(parsename)
        self.date = dataframe['Date']
        self.hour = dataframe['Hr_End']
        self.demand = dataframe['RT_Demand']
        self.drybulb = dataframe['Dry_Bulb']
        self.dewpnt = dataframe['Dew_Point']
    def disp_all(self):
        print self.dataframe
    def get_all(self):
        return self.dataframe

# %% [markdown]
# load data

# %%
xls = pd.ExcelFile('smd_hourly.xls')
INC = County('ISO NE CA')
ME = County('ME')
NH = County('NH')
VT = County('VT')
CT = County('CT')
RI = County('RI')
SEMA = County('SEMA')
WCMA = County('WCMA')
NEMA = County('NEMA')

# %%
#print INC.date[-8*24:-1]

# %% [markdown]
# ## SEC 3: setting all global parameters

# %%
data_dir = './data/' # directory contains input data
num_epoches = 30000 # training epoches for each customer samples
day_steps = 24
n_steps = day_steps # input size
test_batch_size = day_steps # days of a batch
validation_batch_size = 0*day_steps
train_batch_size = day_steps
feature_size = 1 # same time of a week
n_hidden = 30 # input size
num_layers = 3
n_output = 1
totalen = np.array(INC.demand).shape[0]

# %% [markdown]
# ## SEC 4: split dataset into training, cross-validation, and test

# %% [markdown]
# concatenate data into database

# %%
# DEMAND MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.demand)
demand_mat = tmp.reshape([1,tmp.shape[0],1])
demand_mat = demand_mat/25000
#demand_mat = np.concatenate([demand_mat,np.array(ME.demand).reshape([1,np.array(ME.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NH.demand).reshape([1,np.array(NH.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(VT.demand).reshape([1,np.array(VT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(CT.demand).reshape([1,np.array(CT.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(RI.demand).reshape([1,np.array(RI.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(SEMA.demand).reshape([1,np.array(SEMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(WCMA.demand).reshape([1,np.array(WCMA.demand).shape[0],1])],axis = 0)
#demand_mat = np.concatenate([demand_mat,np.array(NEMA.demand).reshape([1,np.array(NEMA.demand).shape[0],1])],axis = 0)
print demand_mat.shape
# DRY BULB MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.drybulb)
drybulb_mat = tmp.reshape([1,tmp.shape[0],1])
drybulb_mat = drybulb_mat/100
#drybulb_mat = np.concatenate([drybulb_mat,np.array(ME.drybulb).reshape([1,np.array(ME.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NH.drybulb).reshape([1,np.array(NH.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(VT.drybulb).reshape([1,np.array(VT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(CT.drybulb).reshape([1,np.array(CT.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(RI.drybulb).reshape([1,np.array(RI.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(SEMA.drybulb).reshape([1,np.array(SEMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(WCMA.drybulb).reshape([1,np.array(WCMA.drybulb).shape[0],1])],axis = 0)
#drybulb_mat = np.concatenate([drybulb_mat,np.array(NEMA.drybulb).reshape([1,np.array(NEMA.drybulb).shape[0],1])],axis = 0)
#print drybulb_mat.shape
# DEW PNT MATRIX 9 X LENGTH, 9: INC is total, index with 0, other substations are from 1 -> 8
tmp = np.array(INC.dewpnt)
dewpnt_mat = tmp.reshape([1,tmp.shape[0],1])
dewpnt_mat = dewpnt_mat/100
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(ME.dewpnt).reshape([1,np.array(ME.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NH.dewpnt).reshape([1,np.array(NH.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(VT.dewpnt).reshape([1,np.array(VT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(CT.dewpnt).reshape([1,np.array(CT.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(RI.dewpnt).reshape([1,np.array(RI.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(SEMA.dewpnt).reshape([1,np.array(SEMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(WCMA.dewpnt).reshape([1,np.array(WCMA.dewpnt).shape[0],1])],axis = 0)
#dewpnt_mat = np.concatenate([dewpnt_mat,np.array(NEMA.dewpnt).reshape([1,np.array(NEMA.dewpnt).shape[0],1])],axis = 0)
#print dewpnt_mat.shape

#db = np.concatenate([demand_mat,dewpnt_mat,drybulb_mat],axis = 2)
#db = np.concatenate([demand_mat,dewpnt_mat],axis = 2)
db = demand_mat

print db.shape
# Out:
# (1, 5856, 1)
# (1, 5856, 1)

# %% [markdown]
# split into 3 parts using part array

# %%
#define id arrays
test_id = np.array(test_batch_size)
valid_id = np.array(validation_batch_size)
train_id = np.array(totalen-test_batch_size-validation_batch_size-n_steps)

#give values to id arrays
rang = range(n_steps,totalen-test_batch_size)
valid_id = rd.sample(rang,validation_batch_size)
test_id = np.array(range(totalen-test_batch_size,totalen))
train_id = set(range(n_steps,totalen-test_batch_size))-set(valid_id)

#sort three id array
valid_id = np.sort(valid_id)
test_id = np.sort(test_id)
train_id = np.array(list(train_id))

# %% [markdown]
# ### Step 4: define data generating function code.
# which generate a batch of batch-size large sequence data. the data is feature_size dims width and is a time series of float32 of steps steps. inputs and outputs are:
#
# inputs:
# ----n_batch: number of samples in a batch
# ----steps: the sequence length of a sample data
# ----feature_size: dimensions of a single time step data frame
#
# outputs:
# ----X inputs, shape(n_batch,steps,feature_size)
# ----Y outputs should be, shape(n_batch,)

# %%
def train_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps,train_id.shape[0])
    train_rd = rd.sample(rang,train_batch_size)
    train_rd = np.sort(train_rd)
    for i in train_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
def valid_data_gen():
    X = np.zeros((train_batch_size,n_steps,feature_size))
    Y = np.zeros((train_batch_size,feature_size))
    count = 0
    rang = range(n_steps,valid_id.shape[0])
    valid_rd = rd.sample(rang,train_batch_size)
    valid_rd = np.sort(valid_rd)
    for i in valid_rd:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
def test_data_gen():
    X = np.zeros((test_batch_size,n_steps,feature_size))
    Y = np.zeros((test_batch_size,feature_size))
    count = 0
    for i in test_id:
        Y[count] = db[:,i,:]
        X[count] = db[:,i-n_steps:i,:]
        count = count + 1
    return (X,Y)

# %%
# code testing
"""
(x,y) = test_data_gen()
print x.shape
x = x.reshape(test_batch_size,n_steps,feature_size)
print x[0,:,:]
"""
"""
count = 0
X = np.zeros((test_batch_size,n_steps,feature_size))
Y = np.zeros((test_batch_size,feature_size))
for i in test_id:
    print i
    Y[0] = db[:,i,:]
    X[0] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
"""
X = np.zeros((train_batch_size,n_steps,feature_size))
Y = np.zeros((train_batch_size,feature_size))
count = 0
rang = range(n_steps,train_id.shape[0])
train_rd = rd.sample(rang,train_batch_size)
train_rd = np.sort(train_rd)
for i in train_id:
    Y[count] = db[:,i,:]
    X[count] = db[:,i-n_steps:i,:]
    count = count + 1
    if count == 3:
        break
print Y
print Y.shape
print X
print X.shape
"""
# Out:
# '\nX = np.zeros((train_batch_size,n_steps,feature_size))\nY = np.zeros((train_batch_size,feature_size))\ncount = 0\nrang = range(n_steps,train_id.shape[0])\ntrain_rd = rd.sample(rang,train_batch_size)\ntrain_rd = np.sort(train_rd)\nfor i in train_id:\n    Y[count] = db[:,i,:]\n    X[count] = db[:,i-n_steps:i,:]\n    count = count + 1\n    if count == 3:\n        break\nprint Y\nprint Y.shape\nprint X\nprint X.shape\n'

# %% [markdown]
# ### Step 5: construct RNN model

# %%
# create placeholder for x and y
#with tf.device('/gpu:0'):
x = tf.placeholder("float",[None,n_steps,feature_size])
istate = tf.placeholder("float",[None,num_layers*2*n_hidden])
y = tf.placeholder("float",[None,n_output])


# Define weights
weights = {
    'hidden': tf.Variable(tf.random_normal([feature_size, n_hidden])), # Hidden layer weights
    'out': tf.Variable(tf.random_normal([n_hidden, n_output]))
}
biases = {
    'hidden': tf.Variable(tf.random_normal([n_hidden])),
    'out': tf.Variable(tf.random_normal([n_output]))
}
def RNN(_X, _istate, _weights, _biases):
    # input shape: (batch_size, n_steps, n_input)
    _X = tf.transpose(_X, [1, 0, 2])  # permute n_steps and batch_size
    # Reshape to prepare input to hidden activation
    _X = tf.reshape(_X, [-1, feature_size]) # (n_steps*batch_size, n_input)
    # Linear activation
    _X = tf.matmul(_X, _weights['hidden']) + _biases['hidden']

    # Define a lstm cell with tensorflow
    lstm_cell = tf.nn.rnn_cell.BasicLSTMCell(n_hidden, forget_bias=1.0)
    stacked_lstm_cell = tf.nn.rnn_cell.MultiRNNCell([lstm_cell]*num_layers)

    # Split data because rnn cell needs a list of inputs for the RNN inner loop
    _X = tf.split(0, n_steps, _X) # n_steps * (batch_size, n_hidden)

    # Get lstm cell output
    outputs, states = tf.nn.rnn(stacked_lstm_cell, _X, initial_state=_istate)

    # Linear activation
    # Get inner loop last output
    return tf.matmul(outputs[-1], _weights['out']) + _biases['out']

pred = RNN(x, istate, weights, biases)
#cost function 
cost = tf.reduce_mean(tf.pow(pred[:,0]-y[:,0],2)) # cost function of this batch of data
#compute parameter updates
#optimizer = tf.train.GradientDescentOptimizer(0.2).minimize(cost)
optimizer = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(cost)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell.BasicLSTMCell object at 0x7fd60a440c90>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.

# %%
def maxe(predictions, targets):
    return max(abs(predictions-targets))

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
def mape(predictions, targets):
    return np.mean(abs(predictions-targets)/targets)

# %%
outlist = np.zeros([(num_epoches/10),test_batch_size])
kind = 0
time1 = time.time()
# generate test data
test_x,test_y = test_data_gen()
test_x = test_x.reshape(test_batch_size,n_steps,feature_size)
print test_x.shape
print test_y.shape
### Execute
# Initializing the variables
init = tf.initialize_all_variables()
# Out:
# (24, 24, 1)
# (24, 1)

# %%
def pred_tomorrow(dx, dy, dstate):
    pred_y = np.zeros((test_batch_size/24,24,feature_size))
    Xupdate = np.zeros((test_batch_size/24,1,feature_size))
    for timeslot in range(24):
        Xmat = np.zeros((test_batch_size/24,n_steps,feature_size))
        Ymat = np.zeros((test_batch_size/24,feature_size))
        tmpXmat = np.zeros((1,n_steps,feature_size))
        tmpYmat = np.zeros((1,feature_size))
        count = 0
        for row in (r for r in range(test_batch_size) if np.mod(r,24)==timeslot):
            tmpXmat = dx[row,:,:]
            tmpYmat = dy[row,:]
            Xmat[count,:,:] = tmpXmat
            Ymat[count,:] = tmpYmat
            count = count + 1
        #print Xmat
        if timeslot > 0:
            #print 'Xupdate'
            #print Xupdate.reshape((test_batch_size/24,1))
            #print 'Xmat'
            #print Xmat[:,-1,:]
            Xmat[:,-1,:] = Xupdate.reshape((test_batch_size/24,1))
            #print 'Xmat new'
            #print Xmat[:,-1,:]
        #print Ymat
        #print Xmat
        output_tmp_ex = sess.run(pred,feed_dict = {x:Xmat,y:Ymat,istate:dstate})
        tmpout = output_tmp_ex[:,0]
        #print tmpout
        Xupdate = tmpout.reshape((test_batch_size/24,1,feature_size))
        #print Xupdate
        pred_y[:,timeslot,:] = Xupdate.reshape((test_batch_size/24,1))
    pred_y = pred_y.reshape((test_batch_size,1))
    return pred_y

# %%
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    # Create a summary to monitor cost function
    #tf.scalar_summary("loss", cost)
    # Merge all summaries to a single operator
    #merged_summary_op = tf.merge_all_summaries()

    # tensorboard info.# Set logs writer into folder /tmp/tensorflow_logs
    #summary_writer = tf.train.SummaryWriter('/tmp/tensorflow_logs', graph_def=sess.graph_def)

    #initialize all variables in the model
    sess.run(init)
    for k in range(num_epoches):
        #Generate Data for each epoch
        #What this does is it creates a list of of elements of length seq_len, each of size [batch_size,input_size]
        #this is required to feed data into rnn.rnn
        #print traindays
        X,Y = train_data_gen()
        X = X.reshape(train_batch_size,n_steps,feature_size)


        #Create the dictionary of inputs to feed into sess.run
        #if k < 0:
        #    sess.run(optimizer2,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})
        #else:
        sess.run(optimizer,feed_dict={x:X,y:Y,istate:np.zeros((train_batch_size,num_layers*2*n_hidden))})   
        #perform an update on the parameters
        #cost1 = sess.run(cost,feed_dict = {x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #print "Iter " + str(k) + ", Minibatch Loss ---- Train = " + str(cost1)
        # Write logs at every iteration
        #if k>50 & k%10 == 0:
        #    summary_str = sess.run(merged_summary_op, feed_dict={x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))} )
        #    summary_writer.add_summary(summary_str, k)
        
        ## every N times, assess the current model on validation sample sets
        ## code to be added. |MingHao|
        ## new opt, valid_x, valid_y
        
        ## every 10 times, output prediction result, to further visualize test performance on test set
        #if k % 10 == 0:
        if k % 10 == 0:
            #output_tmp_ex = pred_tomorrow(test_x,test_y,np.zeros((test_batch_size/24,num_layers*2*n_hidden)))
            output_tmp_ex = sess.run(pred, feed_dict={x:test_x,y:test_y,istate:np.zeros((test_batch_size,num_layers*2*n_hidden))})
            print "Iter " + str(k) + " ---- Process: " + "{:.2f}".format(100*float(k)/float(num_epoches)) + "%"
            outp_test = output_tmp_ex[:,0]
            outlist[kind,:] = outp_test.copy().T
            kind = kind + 1
# Out:
# Iter 0 ---- Process: 0.00%
# Iter 10 ---- Process: 0.03%
# Iter 20 ---- Process: 0.07%
# Iter 30 ---- Process: 0.10%
# Iter 40 ---- Process: 0.13%
# Iter 50 ---- Process: 0.17%
# Iter 60 ---- Process: 0.20%
# Iter 70 ---- Process: 0.23%
# Iter 80 ---- Process: 0.27%
# Iter 90 ---- Process: 0.30%
# Iter 100 ---- Process: 0.33%
# Iter 110 ---- Process: 0.37%
# Iter 120 ---- Process: 0.40%
# Iter 130 ---- Process: 0.43%
# Iter 140 ---- Process: 0.47%
# Iter 150 ---- Process: 0.50%
# Iter 160 ---- Process: 0.53%
# Iter 170 ---- Process: 0.57%
# Iter 180 ---- Process: 0.60%
# Iter 190 ---- Process: 0.63%
# Iter 200 ---- Process: 0.67%
# Iter 210 ---- Process: 0.70%
# Iter 220 ---- Process: 0.73%
# Iter 230 ---- Process: 0.77%
# Iter 240 ---- Process: 0.80%
# Iter 250 ---- Process: 0.83%
# Iter 260 ---- Process: 0.87%
# Iter 270 ---- Process: 0.90%
# Iter 280 ---- Process: 0.93%
# Iter 290 ---- Process: 0.97%
# Iter 300 ---- Process: 1.00%
# Iter 310 ---- Process: 1.03%
# Iter 320 ---- Process: 1.07%
# Iter 330 ---- Process: 1.10%
# Iter 340 ---- Process: 1.13%
# Iter 350 ---- Process: 1.17%
# Iter 360 ---- Process: 1.20%
# Iter 370 ---- Process: 1.23%
# Iter 380 ---- Process: 1.27%
# Iter 390 ---- Process: 1.30%
# Iter 400 ---- Process: 1.33%
# Iter 410 ---- Process: 1.37%
# Iter 420 ---- Process: 1.40%
# Iter 430 ---- Process: 1.43%
# Iter 440 ---- Process: 1.47%
# Iter 450 ---- Process: 1.50%
# Iter 460 ---- Process: 1.53%
# Iter 470 ---- Process: 1.57%
# Iter 480 ---- Process: 1.60%
# Iter 490 ---- Process: 1.63%
# Iter 500 ---- Process: 1.67%
# Iter 510 ---- Process: 1.70%
# Iter 520 ---- Process: 1.73%
# Iter 530 ---- Process: 1.77%
# Iter 540 ---- Process: 1.80%
# Iter 550 ---- Process: 1.83%
# Iter 560 ---- Process: 1.87%
# Iter 570 ---- Process: 1.90%
# Iter 580 ---- Process: 1.93%
# Iter 590 ---- Process: 1.97%
# Iter 600 ---- Process: 2.00%
# Iter 610 ---- Process: 2.03%
# Iter 620 ---- Process: 2.07%
# Iter 630 ---- Process: 2.10%
# Iter 640 ---- Process: 2.13%
# Iter 650 ---- Process: 2.17%
# Iter 660 ---- Process: 2.20%
# Iter 670 ---- Process: 2.23%
# Iter 680 ---- Process: 2.27%
# Iter 690 ---- Process: 2.30%
# Iter 700 ---- Process: 2.33%
# Iter 710 ---- Process: 2.37%
# Iter 720 ---- Process: 2.40%
# Iter 730 ---- Process: 2.43%
# Iter 740 ---- Process: 2.47%
# Iter 750 ---- Process: 2.50%
# Iter 760 ---- Process: 2.53%
# Iter 770 ---- Process: 2.57%
# Iter 780 ---- Process: 2.60%
# Iter 790 ---- Process: 2.63%
# Iter 800 ---- Process: 2.67%
# Iter 810 ---- Process: 2.70%
# Iter 820 ---- Process: 2.73%
# Iter 830 ---- Process: 2.77%
# Iter 840 ---- Process: 2.80%
# Iter 850 ---- Process: 2.83%
# Iter 860 ---- Process: 2.87%
# Iter 870 ---- Process: 2.90%
# Iter 880 ---- Process: 2.93%
# Iter 890 ---- Process: 2.97%
# Iter 900 ---- Process: 3.00%
# Iter 910 ---- Process: 3.03%
# Iter 920 ---- Process: 3.07%
# Iter 930 ---- Process: 3.10%
# Iter 940 ---- Process: 3.13%
# Iter 950 ---- Process: 3.17%
# Iter 960 ---- Process: 3.20%
# Iter 970 ---- Process: 3.23%
# Iter 980 ---- Process: 3.27%
# Iter 990 ---- Process: 3.30%
# Iter 1000 ---- Process: 3.33%
# Iter 1010 ---- Process: 3.37%
# Iter 1020 ---- Process: 3.40%
# Iter 1030 ---- Process: 3.43%
# Iter 1040 ---- Process: 3.47%
# Iter 1050 ---- Process: 3.50%
# Iter 1060 ---- Process: 3.53%
# Iter 1070 ---- Process: 3.57%
# Iter 1080 ---- Process: 3.60%
# Iter 1090 ---- Process: 3.63%
# Iter 1100 ---- Process: 3.67%
# Iter 1110 ---- Process: 3.70%
# Iter 1120 ---- Process: 3.73%
# Iter 1130 ---- Process: 3.77%
# Iter 1140 ---- Process: 3.80%
# Iter 1150 ---- Process: 3.83%
# Iter 1160 ---- Process: 3.87%
# Iter 1170 ---- Process: 3.90%
# Iter 1180 ---- Process: 3.93%
# Iter 1190 ---- Process: 3.97%
# Iter 1200 ---- Process: 4.00%
# Iter 1210 ---- Process: 4.03%
# Iter 1220 ---- Process: 4.07%
# Iter 1230 ---- Process: 4.10%
# Iter 1240 ---- Process: 4.13%
# Iter 1250 ---- Process: 4.17%
# Iter 1260 ---- Process: 4.20%
# Iter 1270 ---- Process: 4.23%
# Iter 1280 ---- Process: 4.27%
# Iter 1290 ---- Process: 4.30%
# Iter 1300 ---- Process: 4.33%
# Iter 1310 ---- Process: 4.37%
# Iter 1320 ---- Process: 4.40%
# Iter 1330 ---- Process: 4.43%
# Iter 1340 ---- Process: 4.47%
# Iter 1350 ---- Process: 4.50%
# Iter 1360 ---- Process: 4.53%
# Iter 1370 ---- Process: 4.57%
# Iter 1380 ---- Process: 4.60%
# Iter 1390 ---- Process: 4.63%
# Iter 1400 ---- Process: 4.67%
# Iter 1410 ---- Process: 4.70%
# Iter 1420 ---- Process: 4.73%
# Iter 1430 ---- Process: 4.77%
# Iter 1440 ---- Process: 4.80%
# Iter 1450 ---- Process: 4.83%
# Iter 1460 ---- Process: 4.87%
# Iter 1470 ---- Process: 4.90%
# Iter 1480 ---- Process: 4.93%
# Iter 1490 ---- Process: 4.97%
# Iter 1500 ---- Process: 5.00%
# Iter 1510 ---- Process: 5.03%
# Iter 1520 ---- Process: 5.07%
# Iter 1530 ---- Process: 5.10%
# Iter 1540 ---- Process: 5.13%
# Iter 1550 ---- Process: 5.17%
# Iter 1560 ---- Process: 5.20%
# Iter 1570 ---- Process: 5.23%
# Iter 1580 ---- Process: 5.27%
# Iter 1590 ---- Process: 5.30%
# Iter 1600 ---- Process: 5.33%
# Iter 1610 ---- Process: 5.37%
# Iter 1620 ---- Process: 5.40%
# Iter 1630 ---- Process: 5.43%
# Iter 1640 ---- Process: 5.47%
# Iter 1650 ---- Process: 5.50%
# Iter 1660 ---- Process: 5.53%
# Iter 1670 ---- Process: 5.57%
# Iter 1680 ---- Process: 5.60%
# Iter 1690 ---- Process: 5.63%
# Iter 1700 ---- Process: 5.67%
# Iter 1710 ---- Process: 5.70%
# Iter 1720 ---- Process: 5.73%
# Iter 1730 ---- Process: 5.77%
# Iter 1740 ---- Process: 5.80%
# Iter 1750 ---- Process: 5.83%
# Iter 1760 ---- Process: 5.87%
# Iter 1770 ---- Process: 5.90%
# Iter 1780 ---- Process: 5.93%
# Iter 1790 ---- Process: 5.97%
# Iter 1800 ---- Process: 6.00%
# Iter 1810 ---- Process: 6.03%
# Iter 1820 ---- Process: 6.07%
# Iter 1830 ---- Process: 6.10%
# Iter 1840 ---- Process: 6.13%
# Iter 1850 ---- Process: 6.17%
# Iter 1860 ---- Process: 6.20%
# Iter 1870 ---- Process: 6.23%
# Iter 1880 ---- Process: 6.27%
# Iter 1890 ---- Process: 6.30%
# Iter 1900 ---- Process: 6.33%
# Iter 1910 ---- Process: 6.37%
# Iter 1920 ---- Process: 6.40%
# Iter 1930 ---- Process: 6.43%
# Iter 1940 ---- Process: 6.47%
# Iter 1950 ---- Process: 6.50%
# Iter 1960 ---- Process: 6.53%
# Iter 1970 ---- Process: 6.57%
# Iter 1980 ---- Process: 6.60%
# Iter 1990 ---- Process: 6.63%
# Iter 2000 ---- Process: 6.67%
# Iter 2010 ---- Process: 6.70%
# Iter 2020 ---- Process: 6.73%
# Iter 2030 ---- Process: 6.77%
# Iter 2040 ---- Process: 6.80%
# Iter 2050 ---- Process: 6.83%
# Iter 2060 ---- Process: 6.87%
# Iter 2070 ---- Process: 6.90%
# Iter 2080 ---- Process: 6.93%
# Iter 2090 ---- Process: 6.97%
# Iter 2100 ---- Process: 7.00%
# Iter 2110 ---- Process: 7.03%
# Iter 2120 ---- Process: 7.07%
# Iter 2130 ---- Process: 7.10%
# Iter 2140 ---- Process: 7.13%
# Iter 2150 ---- Process: 7.17%
# Iter 2160 ---- Process: 7.20%
# Iter 2170 ---- Process: 7.23%
# Iter 2180 ---- Process: 7.27%
# Iter 2190 ---- Process: 7.30%
# Iter 2200 ---- Process: 7.33%
# Iter 2210 ---- Process: 7.37%
# Iter 2220 ---- Process: 7.40%
# Iter 2230 ---- Process: 7.43%
# Iter 2240 ---- Process: 7.47%
# Iter 2250 ---- Process: 7.50%
# Iter 2260 ---- Process: 7.53%
# Iter 2270 ---- Process: 7.57%
# Iter 2280 ---- Process: 7.60%
# Iter 2290 ---- Process: 7.63%
# Iter 2300 ---- Process: 7.67%
# Iter 2310 ---- Process: 7.70%
# Iter 2320 ---- Process: 7.73%
# Iter 2330 ---- Process: 7.77%
# Iter 2340 ---- Process: 7.80%
# Iter 2350 ---- Process: 7.83%
# Iter 2360 ---- Process: 7.87%
# Iter 2370 ---- Process: 7.90%
# Iter 2380 ---- Process: 7.93%
# Iter 2390 ---- Process: 7.97%
# Iter 2400 ---- Process: 8.00%
# Iter 2410 ---- Process: 8.03%
# Iter 2420 ---- Process: 8.07%
# Iter 2430 ---- Process: 8.10%
# Iter 2440 ---- Process: 8.13%
# Iter 2450 ---- Process: 8.17%
# Iter 2460 ---- Process: 8.20%
# Iter 2470 ---- Process: 8.23%
# Iter 2480 ---- Process: 8.27%
# Iter 2490 ---- Process: 8.30%
# Iter 2500 ---- Process: 8.33%
# Iter 2510 ---- Process: 8.37%
# Iter 2520 ---- Process: 8.40%
# Iter 2530 ---- Process: 8.43%
# Iter 2540 ---- Process: 8.47%
# Iter 2550 ---- Process: 8.50%
# Iter 2560 ---- Process: 8.53%
# Iter 2570 ---- Process: 8.57%
# Iter 2580 ---- Process: 8.60%
# Iter 2590 ---- Process: 8.63%
# Iter 2600 ---- Process: 8.67%
# Iter 2610 ---- Process: 8.70%
# Iter 2620 ---- Process: 8.73%
# Iter 2630 ---- Process: 8.77%
# Iter 2640 ---- Process: 8.80%
# Iter 2650 ---- Process: 8.83%
# Iter 2660 ---- Process: 8.87%
# Iter 2670 ---- Process: 8.90%
# Iter 2680 ---- Process: 8.93%
# Iter 2690 ---- Process: 8.97%
# Iter 2700 ---- Process: 9.00%
# Iter 2710 ---- Process: 9.03%
# Iter 2720 ---- Process: 9.07%
# Iter 2730 ---- Process: 9.10%
# Iter 2740 ---- Process: 9.13%
# Iter 2750 ---- Process: 9.17%
# Iter 2760 ---- Process: 9.20%
# Iter 2770 ---- Process: 9.23%
# Iter 2780 ---- Process: 9.27%
# Iter 2790 ---- Process: 9.30%
# Iter 2800 ---- Process: 9.33%
# Iter 2810 ---- Process: 9.37%
# Iter 2820 ---- Process: 9.40%
# Iter 2830 ---- Process: 9.43%
# Iter 2840 ---- Process: 9.47%
# Iter 2850 ---- Process: 9.50%
# Iter 2860 ---- Process: 9.53%
# Iter 2870 ---- Process: 9.57%
# Iter 2880 ---- Process: 9.60%
# Iter 2890 ---- Process: 9.63%
# Iter 2900 ---- Process: 9.67%
# Iter 2910 ---- Process: 9.70%
# Iter 2920 ---- Process: 9.73%
# Iter 2930 ---- Process: 9.77%
# Iter 2940 ---- Process: 9.80%
# Iter 2950 ---- Process: 9.83%
# Iter 2960 ---- Process: 9.87%
# Iter 2970 ---- Process: 9.90%
# Iter 2980 ---- Process: 9.93%
# Iter 2990 ---- Process: 9.97%
# Iter 3000 ---- Process: 10.00%
# Iter 3010 ---- Process: 10.03%
# Iter 3020 ---- Process: 10.07%
# Iter 3030 ---- Process: 10.10%
# Iter 3040 ---- Process: 10.13%
# Iter 3050 ---- Process: 10.17%
# Iter 3060 ---- Process: 10.20%
# Iter 3070 ---- Process: 10.23%
# Iter 3080 ---- Process: 10.27%
# Iter 3090 ---- Process: 10.30%
# Iter 3100 ---- Process: 10.33%
# Iter 3110 ---- Process: 10.37%
# Iter 3120 ---- Process: 10.40%
# Iter 3130 ---- Process: 10.43%
# Iter 3140 ---- Process: 10.47%
# Iter 3150 ---- Process: 10.50%
# Iter 3160 ---- Process: 10.53%
# Iter 3170 ---- Process: 10.57%
# Iter 3180 ---- Process: 10.60%
# Iter 3190 ---- Process: 10.63%
# Iter 3200 ---- Process: 10.67%
# Iter 3210 ---- Process: 10.70%
# Iter 3220 ---- Process: 10.73%
# Iter 3230 ---- Process: 10.77%
# Iter 3240 ---- Process: 10.80%
# Iter 3250 ---- Process: 10.83%
# Iter 3260 ---- Process: 10.87%
# Iter 3270 ---- Process: 10.90%
# Iter 3280 ---- Process: 10.93%
# Iter 3290 ---- Process: 10.97%
# Iter 3300 ---- Process: 11.00%
# Iter 3310 ---- Process: 11.03%
# Iter 3320 ---- Process: 11.07%
# Iter 3330 ---- Process: 11.10%
# Iter 3340 ---- Process: 11.13%
# Iter 3350 ---- Process: 11.17%
# Iter 3360 ---- Process: 11.20%
# Iter 3370 ---- Process: 11.23%
# Iter 3380 ---- Process: 11.27%
# Iter 3390 ---- Process: 11.30%
# Iter 3400 ---- Process: 11.33%
# Iter 3410 ---- Process: 11.37%
# Iter 3420 ---- Process: 11.40%
# Iter 3430 ---- Process: 11.43%
# Iter 3440 ---- Process: 11.47%
# Iter 3450 ---- Process: 11.50%
# Iter 3460 ---- Process: 11.53%
# Iter 3470 ---- Process: 11.57%
# Iter 3480 ---- Process: 11.60%
# Iter 3490 ---- Process: 11.63%
# Iter 3500 ---- Process: 11.67%
# Iter 3510 ---- Process: 11.70%
# Iter 3520 ---- Process: 11.73%
# Iter 3530 ---- Process: 11.77%
# Iter 3540 ---- Process: 11.80%
# Iter 3550 ---- Process: 11.83%
# Iter 3560 ---- Process: 11.87%
# Iter 3570 ---- Process: 11.90%
# Iter 3580 ---- Process: 11.93%
# Iter 3590 ---- Process: 11.97%
# Iter 3600 ---- Process: 12.00%
# Iter 3610 ---- Process: 12.03%
# Iter 3620 ---- Process: 12.07%
# Iter 3630 ---- Process: 12.10%
# Iter 3640 ---- Process: 12.13%
# Iter 3650 ---- Process: 12.17%
# Iter 3660 ---- Process: 12.20%
# Iter 3670 ---- Process: 12.23%
# Iter 3680 ---- Process: 12.27%
# Iter 3690 ---- Process: 12.30%
# Iter 3700 ---- Process: 12.33%
# Iter 3710 ---- Process: 12.37%
# Iter 3720 ---- Process: 12.40%
# Iter 3730 ---- Process: 12.43%
# Iter 3740 ---- Process: 12.47%
# Iter 3750 ---- Process: 12.50%
# Iter 3760 ---- Process: 12.53%
# Iter 3770 ---- Process: 12.57%
# Iter 3780 ---- Process: 12.60%
# Iter 3790 ---- Process: 12.63%
# Iter 3800 ---- Process: 12.67%
# Iter 3810 ---- Process: 12.70%
# Iter 3820 ---- Process: 12.73%
# Iter 3830 ---- Process: 12.77%
# Iter 3840 ---- Process: 12.80%
# Iter 3850 ---- Process: 12.83%
# Iter 3860 ---- Process: 12.87%
# Iter 3870 ---- Process: 12.90%
# Iter 3880 ---- Process: 12.93%
# Iter 3890 ---- Process: 12.97%
# Iter 3900 ---- Process: 13.00%
# Iter 3910 ---- Process: 13.03%
# Iter 3920 ---- Process: 13.07%
# Iter 3930 ---- Process: 13.10%
# Iter 3940 ---- Process: 13.13%
# Iter 3950 ---- Process: 13.17%
# Iter 3960 ---- Process: 13.20%
# Iter 3970 ---- Process: 13.23%
# Iter 3980 ---- Process: 13.27%
# Iter 3990 ---- Process: 13.30%
# Iter 4000 ---- Process: 13.33%
# Iter 4010 ---- Process: 13.37%
# Iter 4020 ---- Process: 13.40%
# Iter 4030 ---- Process: 13.43%
# Iter 4040 ---- Process: 13.47%
# Iter 4050 ---- Process: 13.50%
# Iter 4060 ---- Process: 13.53%
# Iter 4070 ---- Process: 13.57%
# Iter 4080 ---- Process: 13.60%
# Iter 4090 ---- Process: 13.63%
# Iter 4100 ---- Process: 13.67%
# Iter 4110 ---- Process: 13.70%
# Iter 4120 ---- Process: 13.73%
# Iter 4130 ---- Process: 13.77%
# Iter 4140 ---- Process: 13.80%
# Iter 4150 ---- Process: 13.83%
# Iter 4160 ---- Process: 13.87%
# Iter 4170 ---- Process: 13.90%
# Iter 4180 ---- Process: 13.93%
# Iter 4190 ---- Process: 13.97%
# Iter 4200 ---- Process: 14.00%
# Iter 4210 ---- Process: 14.03%
# Iter 4220 ---- Process: 14.07%
# Iter 4230 ---- Process: 14.10%
# Iter 4240 ---- Process: 14.13%
# Iter 4250 ---- Process: 14.17%
# Iter 4260 ---- Process: 14.20%
# Iter 4270 ---- Process: 14.23%
# Iter 4280 ---- Process: 14.27%
# Iter 4290 ---- Process: 14.30%
# Iter 4300 ---- Process: 14.33%
# Iter 4310 ---- Process: 14.37%
# Iter 4320 ---- Process: 14.40%
# Iter 4330 ---- Process: 14.43%
# Iter 4340 ---- Process: 14.47%
# Iter 4350 ---- Process: 14.50%
# Iter 4360 ---- Process: 14.53%
# Iter 4370 ---- Process: 14.57%
# Iter 4380 ---- Process: 14.60%
# Iter 4390 ---- Process: 14.63%
# Iter 4400 ---- Process: 14.67%
# Iter 4410 ---- Process: 14.70%
# Iter 4420 ---- Process: 14.73%
# Iter 4430 ---- Process: 14.77%
# Iter 4440 ---- Process: 14.80%
# Iter 4450 ---- Process: 14.83%
# Iter 4460 ---- Process: 14.87%
# Iter 4470 ---- Process: 14.90%
# Iter 4480 ---- Process: 14.93%
# Iter 4490 ---- Process: 14.97%
# Iter 4500 ---- Process: 15.00%
# Iter 4510 ---- Process: 15.03%
# Iter 4520 ---- Process: 15.07%
# Iter 4530 ---- Process: 15.10%
# Iter 4540 ---- Process: 15.13%
# Iter 4550 ---- Process: 15.17%
# Iter 4560 ---- Process: 15.20%
# Iter 4570 ---- Process: 15.23%
# Iter 4580 ---- Process: 15.27%
# Iter 4590 ---- Process: 15.30%
# Iter 4600 ---- Process: 15.33%
# Iter 4610 ---- Process: 15.37%
# Iter 4620 ---- Process: 15.40%
# Iter 4630 ---- Process: 15.43%
# Iter 4640 ---- Process: 15.47%
# Iter 4650 ---- Process: 15.50%
# Iter 4660 ---- Process: 15.53%
# Iter 4670 ---- Process: 15.57%
# Iter 4680 ---- Process: 15.60%
# Iter 4690 ---- Process: 15.63%
# Iter 4700 ---- Process: 15.67%
# Iter 4710 ---- Process: 15.70%
# Iter 4720 ---- Process: 15.73%
# Iter 4730 ---- Process: 15.77%
# Iter 4740 ---- Process: 15.80%
# Iter 4750 ---- Process: 15.83%
# Iter 4760 ---- Process: 15.87%
# Iter 4770 ---- Process: 15.90%
# Iter 4780 ---- Process: 15.93%
# Iter 4790 ---- Process: 15.97%
# Iter 4800 ---- Process: 16.00%
# Iter 4810 ---- Process: 16.03%
# Iter 4820 ---- Process: 16.07%
# Iter 4830 ---- Process: 16.10%
# Iter 4840 ---- Process: 16.13%
# Iter 4850 ---- Process: 16.17%
# Iter 4860 ---- Process: 16.20%
# Iter 4870 ---- Process: 16.23%
# Iter 4880 ---- Process: 16.27%
# Iter 4890 ---- Process: 16.30%
# Iter 4900 ---- Process: 16.33%
# Iter 4910 ---- Process: 16.37%
# Iter 4920 ---- Process: 16.40%
# Iter 4930 ---- Process: 16.43%
# Iter 4940 ---- Process: 16.47%
# Iter 4950 ---- Process: 16.50%
# Iter 4960 ---- Process: 16.53%
# Iter 4970 ---- Process: 16.57%
# Iter 4980 ---- Process: 16.60%
# Iter 4990 ---- Process: 16.63%
# Iter 5000 ---- Process: 16.67%
# Iter 5010 ---- Process: 16.70%
# Iter 5020 ---- Process: 16.73%
# Iter 5030 ---- Process: 16.77%
# Iter 5040 ---- Process: 16.80%
# Iter 5050 ---- Process: 16.83%
# Iter 5060 ---- Process: 16.87%
# Iter 5070 ---- Process: 16.90%
# Iter 5080 ---- Process: 16.93%
# Iter 5090 ---- Process: 16.97%
# Iter 5100 ---- Process: 17.00%
# Iter 5110 ---- Process: 17.03%
# Iter 5120 ---- Process: 17.07%
# Iter 5130 ---- Process: 17.10%
# Iter 5140 ---- Process: 17.13%
# Iter 5150 ---- Process: 17.17%
# Iter 5160 ---- Process: 17.20%
# Iter 5170 ---- Process: 17.23%
# Iter 5180 ---- Process: 17.27%
# Iter 5190 ---- Process: 17.30%
# Iter 5200 ---- Process: 17.33%
# Iter 5210 ---- Process: 17.37%
# Iter 5220 ---- Process: 17.40%
# Iter 5230 ---- Process: 17.43%
# Iter 5240 ---- Process: 17.47%
# Iter 5250 ---- Process: 17.50%
# Iter 5260 ---- Process: 17.53%
# Iter 5270 ---- Process: 17.57%
# Iter 5280 ---- Process: 17.60%
# Iter 5290 ---- Process: 17.63%
# Iter 5300 ---- Process: 17.67%
# Iter 5310 ---- Process: 17.70%
# Iter 5320 ---- Process: 17.73%
# Iter 5330 ---- Process: 17.77%
# Iter 5340 ---- Process: 17.80%
# Iter 5350 ---- Process: 17.83%
# Iter 5360 ---- Process: 17.87%
# Iter 5370 ---- Process: 17.90%
# Iter 5380 ---- Process: 17.93%
# Iter 5390 ---- Process: 17.97%
# Iter 5400 ---- Process: 18.00%
# Iter 5410 ---- Process: 18.03%
# Iter 5420 ---- Process: 18.07%
# Iter 5430 ---- Process: 18.10%
# Iter 5440 ---- Process: 18.13%
# Iter 5450 ---- Process: 18.17%
# Iter 5460 ---- Process: 18.20%
# Iter 5470 ---- Process: 18.23%
# Iter 5480 ---- Process: 18.27%
# Iter 5490 ---- Process: 18.30%
# Iter 5500 ---- Process: 18.33%
# Iter 5510 ---- Process: 18.37%
# Iter 5520 ---- Process: 18.40%
# Iter 5530 ---- Process: 18.43%
# Iter 5540 ---- Process: 18.47%
# Iter 5550 ---- Process: 18.50%
# Iter 5560 ---- Process: 18.53%
# Iter 5570 ---- Process: 18.57%
# Iter 5580 ---- Process: 18.60%
# Iter 5590 ---- Process: 18.63%
# Iter 5600 ---- Process: 18.67%
# Iter 5610 ---- Process: 18.70%
# Iter 5620 ---- Process: 18.73%
# Iter 5630 ---- Process: 18.77%
# Iter 5640 ---- Process: 18.80%
# Iter 5650 ---- Process: 18.83%
# Iter 5660 ---- Process: 18.87%
# Iter 5670 ---- Process: 18.90%
# Iter 5680 ---- Process: 18.93%
# Iter 5690 ---- Process: 18.97%
# Iter 5700 ---- Process: 19.00%
# Iter 5710 ---- Process: 19.03%
# Iter 5720 ---- Process: 19.07%
# Iter 5730 ---- Process: 19.10%
# Iter 5740 ---- Process: 19.13%
# Iter 5750 ---- Process: 19.17%
# Iter 5760 ---- Process: 19.20%
# Iter 5770 ---- Process: 19.23%
# Iter 5780 ---- Process: 19.27%
# Iter 5790 ---- Process: 19.30%
# Iter 5800 ---- Process: 19.33%
# Iter 5810 ---- Process: 19.37%
# Iter 5820 ---- Process: 19.40%
# Iter 5830 ---- Process: 19.43%
# Iter 5840 ---- Process: 19.47%
# Iter 5850 ---- Process: 19.50%
# Iter 5860 ---- Process: 19.53%
# Iter 5870 ---- Process: 19.57%
# Iter 5880 ---- Process: 19.60%
# Iter 5890 ---- Process: 19.63%
# Iter 5900 ---- Process: 19.67%
# Iter 5910 ---- Process: 19.70%
# Iter 5920 ---- Process: 19.73%
# Iter 5930 ---- Process: 19.77%
# Iter 5940 ---- Process: 19.80%
# Iter 5950 ---- Process: 19.83%
# Iter 5960 ---- Process: 19.87%
# Iter 5970 ---- Process: 19.90%
# Iter 5980 ---- Process: 19.93%
# Iter 5990 ---- Process: 19.97%
# Iter 6000 ---- Process: 20.00%
# Iter 6010 ---- Process: 20.03%
# Iter 6020 ---- Process: 20.07%
# Iter 6030 ---- Process: 20.10%
# Iter 6040 ---- Process: 20.13%
# Iter 6050 ---- Process: 20.17%
# Iter 6060 ---- Process: 20.20%
# Iter 6070 ---- Process: 20.23%
# Iter 6080 ---- Process: 20.27%
# Iter 6090 ---- Process: 20.30%
# Iter 6100 ---- Process: 20.33%
# Iter 6110 ---- Process: 20.37%
# Iter 6120 ---- Process: 20.40%
# Iter 6130 ---- Process: 20.43%
# Iter 6140 ---- Process: 20.47%
# Iter 6150 ---- Process: 20.50%
# Iter 6160 ---- Process: 20.53%
# Iter 6170 ---- Process: 20.57%
# Iter 6180 ---- Process: 20.60%
# Iter 6190 ---- Process: 20.63%
# Iter 6200 ---- Process: 20.67%
# Iter 6210 ---- Process: 20.70%
# Iter 6220 ---- Process: 20.73%
# Iter 6230 ---- Process: 20.77%
# Iter 6240 ---- Process: 20.80%
# Iter 6250 ---- Process: 20.83%
# Iter 6260 ---- Process: 20.87%
# Iter 6270 ---- Process: 20.90%
# Iter 6280 ---- Process: 20.93%
# Iter 6290 ---- Process: 20.97%
# Iter 6300 ---- Process: 21.00%
# Iter 6310 ---- Process: 21.03%
# Iter 6320 ---- Process: 21.07%
# Iter 6330 ---- Process: 21.10%
# Iter 6340 ---- Process: 21.13%
# Iter 6350 ---- Process: 21.17%
# Iter 6360 ---- Process: 21.20%
# Iter 6370 ---- Process: 21.23%
# Iter 6380 ---- Process: 21.27%
# Iter 6390 ---- Process: 21.30%
# Iter 6400 ---- Process: 21.33%
# Iter 6410 ---- Process: 21.37%
# Iter 6420 ---- Process: 21.40%
# Iter 6430 ---- Process: 21.43%
# Iter 6440 ---- Process: 21.47%
# Iter 6450 ---- Process: 21.50%
# Iter 6460 ---- Process: 21.53%
# Iter 6470 ---- Process: 21.57%
# Iter 6480 ---- Process: 21.60%
# Iter 6490 ---- Process: 21.63%
# Iter 6500 ---- Process: 21.67%
# Iter 6510 ---- Process: 21.70%
# Iter 6520 ---- Process: 21.73%
# Iter 6530 ---- Process: 21.77%
# Iter 6540 ---- Process: 21.80%
# Iter 6550 ---- Process: 21.83%
# Iter 6560 ---- Process: 21.87%
# Iter 6570 ---- Process: 21.90%
# Iter 6580 ---- Process: 21.93%
# Iter 6590 ---- Process: 21.97%
# Iter 6600 ---- Process: 22.00%
# Iter 6610 ---- Process: 22.03%
# Iter 6620 ---- Process: 22.07%
# Iter 6630 ---- Process: 22.10%
# Iter 6640 ---- Process: 22.13%
# Iter 6650 ---- Process: 22.17%
# Iter 6660 ---- Process: 22.20%
# Iter 6670 ---- Process: 22.23%
# Iter 6680 ---- Process: 22.27%
# Iter 6690 ---- Process: 22.30%
# Iter 6700 ---- Process: 22.33%
# Iter 6710 ---- Process: 22.37%
# Iter 6720 ---- Process: 22.40%
# Iter 6730 ---- Process: 22.43%
# Iter 6740 ---- Process: 22.47%
# Iter 6750 ---- Process: 22.50%
# Iter 6760 ---- Process: 22.53%
# Iter 6770 ---- Process: 22.57%
# Iter 6780 ---- Process: 22.60%
# Iter 6790 ---- Process: 22.63%
# Iter 6800 ---- Process: 22.67%
# Iter 6810 ---- Process: 22.70%
# Iter 6820 ---- Process: 22.73%
# Iter 6830 ---- Process: 22.77%
# Iter 6840 ---- Process: 22.80%
# Iter 6850 ---- Process: 22.83%
# Iter 6860 ---- Process: 22.87%
# Iter 6870 ---- Process: 22.90%
# Iter 6880 ---- Process: 22.93%
# Iter 6890 ---- Process: 22.97%
# Iter 6900 ---- Process: 23.00%
# Iter 6910 ---- Process: 23.03%
# Iter 6920 ---- Process: 23.07%
# Iter 6930 ---- Process: 23.10%
# Iter 6940 ---- Process: 23.13%
# Iter 6950 ---- Process: 23.17%
# Iter 6960 ---- Process: 23.20%
# Iter 6970 ---- Process: 23.23%
# Iter 6980 ---- Process: 23.27%
# Iter 6990 ---- Process: 23.30%
# Iter 7000 ---- Process: 23.33%
# Iter 7010 ---- Process: 23.37%
# Iter 7020 ---- Process: 23.40%
# Iter 7030 ---- Process: 23.43%
# Iter 7040 ---- Process: 23.47%
# Iter 7050 ---- Process: 23.50%
# Iter 7060 ---- Process: 23.53%
# Iter 7070 ---- Process: 23.57%
# Iter 7080 ---- Process: 23.60%
# Iter 7090 ---- Process: 23.63%
# Iter 7100 ---- Process: 23.67%
# Iter 7110 ---- Process: 23.70%
# Iter 7120 ---- Process: 23.73%
# Iter 7130 ---- Process: 23.77%
# Iter 7140 ---- Process: 23.80%
# Iter 7150 ---- Process: 23.83%
# Iter 7160 ---- Process: 23.87%
# Iter 7170 ---- Process: 23.90%
# Iter 7180 ---- Process: 23.93%
# Iter 7190 ---- Process: 23.97%
# Iter 7200 ---- Process: 24.00%
# Iter 7210 ---- Process: 24.03%
# Iter 7220 ---- Process: 24.07%
# Iter 7230 ---- Process: 24.10%
# Iter 7240 ---- Process: 24.13%
# Iter 7250 ---- Process: 24.17%
# Iter 7260 ---- Process: 24.20%
# Iter 7270 ---- Process: 24.23%
# Iter 7280 ---- Process: 24.27%
# Iter 7290 ---- Process: 24.30%
# Iter 7300 ---- Process: 24.33%
# Iter 7310 ---- Process: 24.37%
# Iter 7320 ---- Process: 24.40%
# Iter 7330 ---- Process: 24.43%
# Iter 7340 ---- Process: 24.47%
# Iter 7350 ---- Process: 24.50%
# Iter 7360 ---- Process: 24.53%
# Iter 7370 ---- Process: 24.57%
# Iter 7380 ---- Process: 24.60%
# Iter 7390 ---- Process: 24.63%
# Iter 7400 ---- Process: 24.67%
# Iter 7410 ---- Process: 24.70%
# Iter 7420 ---- Process: 24.73%
# Iter 7430 ---- Process: 24.77%
# Iter 7440 ---- Process: 24.80%
# Iter 7450 ---- Process: 24.83%
# Iter 7460 ---- Process: 24.87%
# Iter 7470 ---- Process: 24.90%
# Iter 7480 ---- Process: 24.93%
# Iter 7490 ---- Process: 24.97%
# Iter 7500 ---- Process: 25.00%
# Iter 7510 ---- Process: 25.03%
# Iter 7520 ---- Process: 25.07%
# Iter 7530 ---- Process: 25.10%
# Iter 7540 ---- Process: 25.13%
# Iter 7550 ---- Process: 25.17%
# Iter 7560 ---- Process: 25.20%
# Iter 7570 ---- Process: 25.23%
# Iter 7580 ---- Process: 25.27%
# Iter 7590 ---- Process: 25.30%
# Iter 7600 ---- Process: 25.33%
# Iter 7610 ---- Process: 25.37%
# Iter 7620 ---- Process: 25.40%
# Iter 7630 ---- Process: 25.43%
# Iter 7640 ---- Process: 25.47%
# Iter 7650 ---- Process: 25.50%
# Iter 7660 ---- Process: 25.53%
# Iter 7670 ---- Process: 25.57%
# Iter 7680 ---- Process: 25.60%
# Iter 7690 ---- Process: 25.63%
# Iter 7700 ---- Process: 25.67%
# Iter 7710 ---- Process: 25.70%
# Iter 7720 ---- Process: 25.73%
# Iter 7730 ---- Process: 25.77%
# Iter 7740 ---- Process: 25.80%
# Iter 7750 ---- Process: 25.83%
# Iter 7760 ---- Process: 25.87%
# Iter 7770 ---- Process: 25.90%
# Iter 7780 ---- Process: 25.93%
# Iter 7790 ---- Process: 25.97%
# Iter 7800 ---- Process: 26.00%
# Iter 7810 ---- Process: 26.03%
# Iter 7820 ---- Process: 26.07%
# Iter 7830 ---- Process: 26.10%
# Iter 7840 ---- Process: 26.13%
# Iter 7850 ---- Process: 26.17%
# Iter 7860 ---- Process: 26.20%
# Iter 7870 ---- Process: 26.23%
# Iter 7880 ---- Process: 26.27%
# Iter 7890 ---- Process: 26.30%
# Iter 7900 ---- Process: 26.33%
# Iter 7910 ---- Process: 26.37%
# Iter 7920 ---- Process: 26.40%
# Iter 7930 ---- Process: 26.43%
# Iter 7940 ---- Process: 26.47%
# Iter 7950 ---- Process: 26.50%
# Iter 7960 ---- Process: 26.53%
# Iter 7970 ---- Process: 26.57%
# Iter 7980 ---- Process: 26.60%
# Iter 7990 ---- Process: 26.63%
# Iter 8000 ---- Process: 26.67%
# Iter 8010 ---- Process: 26.70%
# Iter 8020 ---- Process: 26.73%
# Iter 8030 ---- Process: 26.77%
# Iter 8040 ---- Process: 26.80%
# Iter 8050 ---- Process: 26.83%
# Iter 8060 ---- Process: 26.87%
# Iter 8070 ---- Process: 26.90%
# Iter 8080 ---- Process: 26.93%
# Iter 8090 ---- Process: 26.97%
# Iter 8100 ---- Process: 27.00%
# Iter 8110 ---- Process: 27.03%
# Iter 8120 ---- Process: 27.07%
# Iter 8130 ---- Process: 27.10%
# Iter 8140 ---- Process: 27.13%
# Iter 8150 ---- Process: 27.17%
# Iter 8160 ---- Process: 27.20%
# Iter 8170 ---- Process: 27.23%
# Iter 8180 ---- Process: 27.27%
# Iter 8190 ---- Process: 27.30%
# Iter 8200 ---- Process: 27.33%
# Iter 8210 ---- Process: 27.37%
# Iter 8220 ---- Process: 27.40%
# Iter 8230 ---- Process: 27.43%
# Iter 8240 ---- Process: 27.47%
# Iter 8250 ---- Process: 27.50%
# Iter 8260 ---- Process: 27.53%
# Iter 8270 ---- Process: 27.57%
# Iter 8280 ---- Process: 27.60%
# Iter 8290 ---- Process: 27.63%
# Iter 8300 ---- Process: 27.67%
# Iter 8310 ---- Process: 27.70%
# Iter 8320 ---- Process: 27.73%
# Iter 8330 ---- Process: 27.77%
# Iter 8340 ---- Process: 27.80%
# Iter 8350 ---- Process: 27.83%
# Iter 8360 ---- Process: 27.87%
# Iter 8370 ---- Process: 27.90%
# Iter 8380 ---- Process: 27.93%
# Iter 8390 ---- Process: 27.97%
# Iter 8400 ---- Process: 28.00%
# Iter 8410 ---- Process: 28.03%
# Iter 8420 ---- Process: 28.07%
# Iter 8430 ---- Process: 28.10%
# Iter 8440 ---- Process: 28.13%
# Iter 8450 ---- Process: 28.17%
# Iter 8460 ---- Process: 28.20%
# Iter 8470 ---- Process: 28.23%
# Iter 8480 ---- Process: 28.27%
# Iter 8490 ---- Process: 28.30%
# Iter 8500 ---- Process: 28.33%
# Iter 8510 ---- Process: 28.37%
# Iter 8520 ---- Process: 28.40%
# Iter 8530 ---- Process: 28.43%
# Iter 8540 ---- Process: 28.47%
# Iter 8550 ---- Process: 28.50%
# Iter 8560 ---- Process: 28.53%
# Iter 8570 ---- Process: 28.57%
# Iter 8580 ---- Process: 28.60%
# Iter 8590 ---- Process: 28.63%
# Iter 8600 ---- Process: 28.67%
# Iter 8610 ---- Process: 28.70%
# Iter 8620 ---- Process: 28.73%
# Iter 8630 ---- Process: 28.77%
# Iter 8640 ---- Process: 28.80%
# Iter 8650 ---- Process: 28.83%
# Iter 8660 ---- Process: 28.87%
# Iter 8670 ---- Process: 28.90%
# Iter 8680 ---- Process: 28.93%
# Iter 8690 ---- Process: 28.97%
# Iter 8700 ---- Process: 29.00%
# Iter 8710 ---- Process: 29.03%
# Iter 8720 ---- Process: 29.07%
# Iter 8730 ---- Process: 29.10%
# Iter 8740 ---- Process: 29.13%
# Iter 8750 ---- Process: 29.17%
# Iter 8760 ---- Process: 29.20%
# Iter 8770 ---- Process: 29.23%
# Iter 8780 ---- Process: 29.27%
# Iter 8790 ---- Process: 29.30%
# Iter 8800 ---- Process: 29.33%
# Iter 8810 ---- Process: 29.37%
# Iter 8820 ---- Process: 29.40%
# Iter 8830 ---- Process: 29.43%
# Iter 8840 ---- Process: 29.47%
# Iter 8850 ---- Process: 29.50%
# Iter 8860 ---- Process: 29.53%
# Iter 8870 ---- Process: 29.57%
# Iter 8880 ---- Process: 29.60%
# Iter 8890 ---- Process: 29.63%
# Iter 8900 ---- Process: 29.67%
# Iter 8910 ---- Process: 29.70%
# Iter 8920 ---- Process: 29.73%
# Iter 8930 ---- Process: 29.77%
# Iter 8940 ---- Process: 29.80%
# Iter 8950 ---- Process: 29.83%
# Iter 8960 ---- Process: 29.87%
# Iter 8970 ---- Process: 29.90%
# Iter 8980 ---- Process: 29.93%
# Iter 8990 ---- Process: 29.97%
# Iter 9000 ---- Process: 30.00%
# Iter 9010 ---- Process: 30.03%
# Iter 9020 ---- Process: 30.07%
# Iter 9030 ---- Process: 30.10%
# Iter 9040 ---- Process: 30.13%
# Iter 9050 ---- Process: 30.17%
# Iter 9060 ---- Process: 30.20%
# Iter 9070 ---- Process: 30.23%
# Iter 9080 ---- Process: 30.27%
# Iter 9090 ---- Process: 30.30%
# Iter 9100 ---- Process: 30.33%
# Iter 9110 ---- Process: 30.37%
# Iter 9120 ---- Process: 30.40%
# Iter 9130 ---- Process: 30.43%
# Iter 9140 ---- Process: 30.47%
# Iter 9150 ---- Process: 30.50%
# Iter 9160 ---- Process: 30.53%
# Iter 9170 ---- Process: 30.57%
# Iter 9180 ---- Process: 30.60%
# Iter 9190 ---- Process: 30.63%
# Iter 9200 ---- Process: 30.67%
# Iter 9210 ---- Process: 30.70%
# Iter 9220 ---- Process: 30.73%
# Iter 9230 ---- Process: 30.77%
# Iter 9240 ---- Process: 30.80%
# Iter 9250 ---- Process: 30.83%
# Iter 9260 ---- Process: 30.87%
# Iter 9270 ---- Process: 30.90%
# Iter 9280 ---- Process: 30.93%
# Iter 9290 ---- Process: 30.97%
# Iter 9300 ---- Process: 31.00%
# Iter 9310 ---- Process: 31.03%
# Iter 9320 ---- Process: 31.07%
# Iter 9330 ---- Process: 31.10%
# Iter 9340 ---- Process: 31.13%
# Iter 9350 ---- Process: 31.17%
# Iter 9360 ---- Process: 31.20%
# Iter 9370 ---- Process: 31.23%
# Iter 9380 ---- Process: 31.27%
# Iter 9390 ---- Process: 31.30%
# Iter 9400 ---- Process: 31.33%
# Iter 9410 ---- Process: 31.37%
# Iter 9420 ---- Process: 31.40%
# Iter 9430 ---- Process: 31.43%
# Iter 9440 ---- Process: 31.47%
# Iter 9450 ---- Process: 31.50%
# Iter 9460 ---- Process: 31.53%
# Iter 9470 ---- Process: 31.57%
# Iter 9480 ---- Process: 31.60%
# Iter 9490 ---- Process: 31.63%
# Iter 9500 ---- Process: 31.67%
# Iter 9510 ---- Process: 31.70%
# Iter 9520 ---- Process: 31.73%
# Iter 9530 ---- Process: 31.77%
# Iter 9540 ---- Process: 31.80%
# Iter 9550 ---- Process: 31.83%
# Iter 9560 ---- Process: 31.87%
# Iter 9570 ---- Process: 31.90%
# Iter 9580 ---- Process: 31.93%
# Iter 9590 ---- Process: 31.97%
# Iter 9600 ---- Process: 32.00%
# Iter 9610 ---- Process: 32.03%
# Iter 9620 ---- Process: 32.07%
# Iter 9630 ---- Process: 32.10%
# Iter 9640 ---- Process: 32.13%
# Iter 9650 ---- Process: 32.17%
# Iter 9660 ---- Process: 32.20%
# Iter 9670 ---- Process: 32.23%
# Iter 9680 ---- Process: 32.27%
# Iter 9690 ---- Process: 32.30%
# Iter 9700 ---- Process: 32.33%
# Iter 9710 ---- Process: 32.37%
# Iter 9720 ---- Process: 32.40%
# Iter 9730 ---- Process: 32.43%
# Iter 9740 ---- Process: 32.47%
# Iter 9750 ---- Process: 32.50%
# Iter 9760 ---- Process: 32.53%
# Iter 9770 ---- Process: 32.57%
# Iter 9780 ---- Process: 32.60%
# Iter 9790 ---- Process: 32.63%
# Iter 9800 ---- Process: 32.67%
# Iter 9810 ---- Process: 32.70%
# Iter 9820 ---- Process: 32.73%
# Iter 9830 ---- Process: 32.77%
# Iter 9840 ---- Process: 32.80%
# Iter 9850 ---- Process: 32.83%
# Iter 9860 ---- Process: 32.87%
# Iter 9870 ---- Process: 32.90%
# Iter 9880 ---- Process: 32.93%
# Iter 9890 ---- Process: 32.97%
# Iter 9900 ---- Process: 33.00%
# Iter 9910 ---- Process: 33.03%
# Iter 9920 ---- Process: 33.07%
# Iter 9930 ---- Process: 33.10%
# Iter 9940 ---- Process: 33.13%
# Iter 9950 ---- Process: 33.17%
# Iter 9960 ---- Process: 33.20%
# Iter 9970 ---- Process: 33.23%
# Iter 9980 ---- Process: 33.27%
# Iter 9990 ---- Process: 33.30%
# Iter 10000 ---- Process: 33.33%
# Iter 10010 ---- Process: 33.37%
# Iter 10020 ---- Process: 33.40%
# Iter 10030 ---- Process: 33.43%
# Iter 10040 ---- Process: 33.47%
# Iter 10050 ---- Process: 33.50%
# Iter 10060 ---- Process: 33.53%
# Iter 10070 ---- Process: 33.57%
# Iter 10080 ---- Process: 33.60%
# Iter 10090 ---- Process: 33.63%
# Iter 10100 ---- Process: 33.67%
# Iter 10110 ---- Process: 33.70%
# Iter 10120 ---- Process: 33.73%
# Iter 10130 ---- Process: 33.77%
# Iter 10140 ---- Process: 33.80%
# Iter 10150 ---- Process: 33.83%
# Iter 10160 ---- Process: 33.87%
# Iter 10170 ---- Process: 33.90%
# Iter 10180 ---- Process: 33.93%
# Iter 10190 ---- Process: 33.97%
# Iter 10200 ---- Process: 34.00%
# Iter 10210 ---- Process: 34.03%
# Iter 10220 ---- Process: 34.07%
# Iter 10230 ---- Process: 34.10%
# Iter 10240 ---- Process: 34.13%
# Iter 10250 ---- Process: 34.17%
# Iter 10260 ---- Process: 34.20%
# Iter 10270 ---- Process: 34.23%
# Iter 10280 ---- Process: 34.27%
# Iter 10290 ---- Process: 34.30%
# Iter 10300 ---- Process: 34.33%
# Iter 10310 ---- Process: 34.37%
# Iter 10320 ---- Process: 34.40%
# Iter 10330 ---- Process: 34.43%
# Iter 10340 ---- Process: 34.47%
# Iter 10350 ---- Process: 34.50%
# Iter 10360 ---- Process: 34.53%
# Iter 10370 ---- Process: 34.57%
# Iter 10380 ---- Process: 34.60%
# Iter 10390 ---- Process: 34.63%
# Iter 10400 ---- Process: 34.67%
# Iter 10410 ---- Process: 34.70%
# Iter 10420 ---- Process: 34.73%
# Iter 10430 ---- Process: 34.77%
# Iter 10440 ---- Process: 34.80%
# Iter 10450 ---- Process: 34.83%
# Iter 10460 ---- Process: 34.87%
# Iter 10470 ---- Process: 34.90%
# Iter 10480 ---- Process: 34.93%
# Iter 10490 ---- Process: 34.97%
# Iter 10500 ---- Process: 35.00%
# Iter 10510 ---- Process: 35.03%
# Iter 10520 ---- Process: 35.07%
# Iter 10530 ---- Process: 35.10%
# Iter 10540 ---- Process: 35.13%
# Iter 10550 ---- Process: 35.17%
# Iter 10560 ---- Process: 35.20%
# Iter 10570 ---- Process: 35.23%
# Iter 10580 ---- Process: 35.27%
# Iter 10590 ---- Process: 35.30%
# Iter 10600 ---- Process: 35.33%
# Iter 10610 ---- Process: 35.37%
# Iter 10620 ---- Process: 35.40%
# Iter 10630 ---- Process: 35.43%
# Iter 10640 ---- Process: 35.47%
# Iter 10650 ---- Process: 35.50%
# Iter 10660 ---- Process: 35.53%
# Iter 10670 ---- Process: 35.57%
# Iter 10680 ---- Process: 35.60%
# Iter 10690 ---- Process: 35.63%
# Iter 10700 ---- Process: 35.67%
# Iter 10710 ---- Process: 35.70%
# Iter 10720 ---- Process: 35.73%
# Iter 10730 ---- Process: 35.77%
# Iter 10740 ---- Process: 35.80%
# Iter 10750 ---- Process: 35.83%
# Iter 10760 ---- Process: 35.87%
# Iter 10770 ---- Process: 35.90%
# Iter 10780 ---- Process: 35.93%
# Iter 10790 ---- Process: 35.97%
# Iter 10800 ---- Process: 36.00%
# Iter 10810 ---- Process: 36.03%
# Iter 10820 ---- Process: 36.07%
# Iter 10830 ---- Process: 36.10%
# Iter 10840 ---- Process: 36.13%
# Iter 10850 ---- Process: 36.17%
# Iter 10860 ---- Process: 36.20%
# Iter 10870 ---- Process: 36.23%
# Iter 10880 ---- Process: 36.27%
# Iter 10890 ---- Process: 36.30%
# Iter 10900 ---- Process: 36.33%
# Iter 10910 ---- Process: 36.37%
# Iter 10920 ---- Process: 36.40%
# Iter 10930 ---- Process: 36.43%
# Iter 10940 ---- Process: 36.47%
# Iter 10950 ---- Process: 36.50%
# Iter 10960 ---- Process: 36.53%
# Iter 10970 ---- Process: 36.57%
# Iter 10980 ---- Process: 36.60%
# Iter 10990 ---- Process: 36.63%
# Iter 11000 ---- Process: 36.67%
# Iter 11010 ---- Process: 36.70%
# Iter 11020 ---- Process: 36.73%
# Iter 11030 ---- Process: 36.77%
# Iter 11040 ---- Process: 36.80%
# Iter 11050 ---- Process: 36.83%
# Iter 11060 ---- Process: 36.87%
# Iter 11070 ---- Process: 36.90%
# Iter 11080 ---- Process: 36.93%
# Iter 11090 ---- Process: 36.97%
# Iter 11100 ---- Process: 37.00%
# Iter 11110 ---- Process: 37.03%
# Iter 11120 ---- Process: 37.07%
# Iter 11130 ---- Process: 37.10%
# Iter 11140 ---- Process: 37.13%
# Iter 11150 ---- Process: 37.17%
# Iter 11160 ---- Process: 37.20%
# Iter 11170 ---- Process: 37.23%
# Iter 11180 ---- Process: 37.27%
# Iter 11190 ---- Process: 37.30%
# Iter 11200 ---- Process: 37.33%
# Iter 11210 ---- Process: 37.37%
# Iter 11220 ---- Process: 37.40%
# Iter 11230 ---- Process: 37.43%
# Iter 11240 ---- Process: 37.47%
# Iter 11250 ---- Process: 37.50%
# Iter 11260 ---- Process: 37.53%
# Iter 11270 ---- Process: 37.57%
# Iter 11280 ---- Process: 37.60%
# Iter 11290 ---- Process: 37.63%
# Iter 11300 ---- Process: 37.67%
# Iter 11310 ---- Process: 37.70%
# Iter 11320 ---- Process: 37.73%
# Iter 11330 ---- Process: 37.77%
# Iter 11340 ---- Process: 37.80%
# Iter 11350 ---- Process: 37.83%
# Iter 11360 ---- Process: 37.87%
# Iter 11370 ---- Process: 37.90%
# Iter 11380 ---- Process: 37.93%
# Iter 11390 ---- Process: 37.97%
# Iter 11400 ---- Process: 38.00%
# Iter 11410 ---- Process: 38.03%
# Iter 11420 ---- Process: 38.07%
# Iter 11430 ---- Process: 38.10%
# Iter 11440 ---- Process: 38.13%
# Iter 11450 ---- Process: 38.17%
# Iter 11460 ---- Process: 38.20%
# Iter 11470 ---- Process: 38.23%
# Iter 11480 ---- Process: 38.27%
# Iter 11490 ---- Process: 38.30%
# Iter 11500 ---- Process: 38.33%
# Iter 11510 ---- Process: 38.37%
# Iter 11520 ---- Process: 38.40%
# Iter 11530 ---- Process: 38.43%
# Iter 11540 ---- Process: 38.47%
# Iter 11550 ---- Process: 38.50%
# Iter 11560 ---- Process: 38.53%
# Iter 11570 ---- Process: 38.57%
# Iter 11580 ---- Process: 38.60%
# Iter 11590 ---- Process: 38.63%
# Iter 11600 ---- Process: 38.67%
# Iter 11610 ---- Process: 38.70%
# Iter 11620 ---- Process: 38.73%
# Iter 11630 ---- Process: 38.77%
# Iter 11640 ---- Process: 38.80%
# Iter 11650 ---- Process: 38.83%
# Iter 11660 ---- Process: 38.87%
# Iter 11670 ---- Process: 38.90%
# Iter 11680 ---- Process: 38.93%
# Iter 11690 ---- Process: 38.97%
# Iter 11700 ---- Process: 39.00%
# Iter 11710 ---- Process: 39.03%
# Iter 11720 ---- Process: 39.07%
# Iter 11730 ---- Process: 39.10%
# Iter 11740 ---- Process: 39.13%
# Iter 11750 ---- Process: 39.17%
# Iter 11760 ---- Process: 39.20%
# Iter 11770 ---- Process: 39.23%
# Iter 11780 ---- Process: 39.27%
# Iter 11790 ---- Process: 39.30%
# Iter 11800 ---- Process: 39.33%
# Iter 11810 ---- Process: 39.37%
# Iter 11820 ---- Process: 39.40%
# Iter 11830 ---- Process: 39.43%
# Iter 11840 ---- Process: 39.47%
# Iter 11850 ---- Process: 39.50%
# Iter 11860 ---- Process: 39.53%
# Iter 11870 ---- Process: 39.57%
# Iter 11880 ---- Process: 39.60%
# Iter 11890 ---- Process: 39.63%
# Iter 11900 ---- Process: 39.67%
# Iter 11910 ---- Process: 39.70%
# Iter 11920 ---- Process: 39.73%
# Iter 11930 ---- Process: 39.77%
# Iter 11940 ---- Process: 39.80%
# Iter 11950 ---- Process: 39.83%
# Iter 11960 ---- Process: 39.87%
# Iter 11970 ---- Process: 39.90%
# Iter 11980 ---- Process: 39.93%
# Iter 11990 ---- Process: 39.97%
# Iter 12000 ---- Process: 40.00%
# Iter 12010 ---- Process: 40.03%
# Iter 12020 ---- Process: 40.07%
# Iter 12030 ---- Process: 40.10%
# Iter 12040 ---- Process: 40.13%
# Iter 12050 ---- Process: 40.17%
# Iter 12060 ---- Process: 40.20%
# Iter 12070 ---- Process: 40.23%
# Iter 12080 ---- Process: 40.27%
# Iter 12090 ---- Process: 40.30%
# Iter 12100 ---- Process: 40.33%
# Iter 12110 ---- Process: 40.37%
# Iter 12120 ---- Process: 40.40%
# Iter 12130 ---- Process: 40.43%
# Iter 12140 ---- Process: 40.47%
# Iter 12150 ---- Process: 40.50%
# Iter 12160 ---- Process: 40.53%
# Iter 12170 ---- Process: 40.57%
# Iter 12180 ---- Process: 40.60%
# Iter 12190 ---- Process: 40.63%
# Iter 12200 ---- Process: 40.67%
# Iter 12210 ---- Process: 40.70%
# Iter 12220 ---- Process: 40.73%
# Iter 12230 ---- Process: 40.77%
# Iter 12240 ---- Process: 40.80%
# Iter 12250 ---- Process: 40.83%
# Iter 12260 ---- Process: 40.87%
# Iter 12270 ---- Process: 40.90%
# Iter 12280 ---- Process: 40.93%
# Iter 12290 ---- Process: 40.97%
# Iter 12300 ---- Process: 41.00%
# Iter 12310 ---- Process: 41.03%
# Iter 12320 ---- Process: 41.07%
# Iter 12330 ---- Process: 41.10%
# Iter 12340 ---- Process: 41.13%
# Iter 12350 ---- Process: 41.17%
# Iter 12360 ---- Process: 41.20%
# Iter 12370 ---- Process: 41.23%
# Iter 12380 ---- Process: 41.27%
# Iter 12390 ---- Process: 41.30%
# Iter 12400 ---- Process: 41.33%
# Iter 12410 ---- Process: 41.37%
# Iter 12420 ---- Process: 41.40%
# Iter 12430 ---- Process: 41.43%
# Iter 12440 ---- Process: 41.47%
# Iter 12450 ---- Process: 41.50%
# Iter 12460 ---- Process: 41.53%
# Iter 12470 ---- Process: 41.57%
# Iter 12480 ---- Process: 41.60%
# Iter 12490 ---- Process: 41.63%
# Iter 12500 ---- Process: 41.67%
# Iter 12510 ---- Process: 41.70%
# Iter 12520 ---- Process: 41.73%
# Iter 12530 ---- Process: 41.77%
# Iter 12540 ---- Process: 41.80%
# Iter 12550 ---- Process: 41.83%
# Iter 12560 ---- Process: 41.87%
# Iter 12570 ---- Process: 41.90%
# Iter 12580 ---- Process: 41.93%
# Iter 12590 ---- Process: 41.97%
# Iter 12600 ---- Process: 42.00%
# Iter 12610 ---- Process: 42.03%
# Iter 12620 ---- Process: 42.07%
# Iter 12630 ---- Process: 42.10%
# Iter 12640 ---- Process: 42.13%
# Iter 12650 ---- Process: 42.17%
# Iter 12660 ---- Process: 42.20%
# Iter 12670 ---- Process: 42.23%
# Iter 12680 ---- Process: 42.27%
# Iter 12690 ---- Process: 42.30%
# Iter 12700 ---- Process: 42.33%
# Iter 12710 ---- Process: 42.37%
# Iter 12720 ---- Process: 42.40%
# Iter 12730 ---- Process: 42.43%
# Iter 12740 ---- Process: 42.47%
# Iter 12750 ---- Process: 42.50%
# Iter 12760 ---- Process: 42.53%
# Iter 12770 ---- Process: 42.57%
# Iter 12780 ---- Process: 42.60%
# Iter 12790 ---- Process: 42.63%
# Iter 12800 ---- Process: 42.67%
# Iter 12810 ---- Process: 42.70%
# Iter 12820 ---- Process: 42.73%
# Iter 12830 ---- Process: 42.77%
# Iter 12840 ---- Process: 42.80%
# Iter 12850 ---- Process: 42.83%
# Iter 12860 ---- Process: 42.87%
# Iter 12870 ---- Process: 42.90%
# Iter 12880 ---- Process: 42.93%
# Iter 12890 ---- Process: 42.97%
# Iter 12900 ---- Process: 43.00%
# Iter 12910 ---- Process: 43.03%
# Iter 12920 ---- Process: 43.07%
# Iter 12930 ---- Process: 43.10%
# Iter 12940 ---- Process: 43.13%
# Iter 12950 ---- Process: 43.17%
# Iter 12960 ---- Process: 43.20%
# Iter 12970 ---- Process: 43.23%
# Iter 12980 ---- Process: 43.27%
# Iter 12990 ---- Process: 43.30%
# Iter 13000 ---- Process: 43.33%
# Iter 13010 ---- Process: 43.37%
# Iter 13020 ---- Process: 43.40%
# Iter 13030 ---- Process: 43.43%
# Iter 13040 ---- Process: 43.47%
# Iter 13050 ---- Process: 43.50%
# Iter 13060 ---- Process: 43.53%
# Iter 13070 ---- Process: 43.57%
# Iter 13080 ---- Process: 43.60%
# Iter 13090 ---- Process: 43.63%
# Iter 13100 ---- Process: 43.67%
# Iter 13110 ---- Process: 43.70%
# Iter 13120 ---- Process: 43.73%
# Iter 13130 ---- Process: 43.77%
# Iter 13140 ---- Process: 43.80%
# Iter 13150 ---- Process: 43.83%
# Iter 13160 ---- Process: 43.87%
# Iter 13170 ---- Process: 43.90%
# Iter 13180 ---- Process: 43.93%
# Iter 13190 ---- Process: 43.97%
# Iter 13200 ---- Process: 44.00%
# Iter 13210 ---- Process: 44.03%
# Iter 13220 ---- Process: 44.07%
# Iter 13230 ---- Process: 44.10%
# Iter 13240 ---- Process: 44.13%
# Iter 13250 ---- Process: 44.17%
# Iter 13260 ---- Process: 44.20%
# Iter 13270 ---- Process: 44.23%
# Iter 13280 ---- Process: 44.27%
# Iter 13290 ---- Process: 44.30%
# Iter 13300 ---- Process: 44.33%
# Iter 13310 ---- Process: 44.37%
# Iter 13320 ---- Process: 44.40%
# Iter 13330 ---- Process: 44.43%
# Iter 13340 ---- Process: 44.47%
# Iter 13350 ---- Process: 44.50%
# Iter 13360 ---- Process: 44.53%
# Iter 13370 ---- Process: 44.57%
# Iter 13380 ---- Process: 44.60%
# Iter 13390 ---- Process: 44.63%
# Iter 13400 ---- Process: 44.67%
# Iter 13410 ---- Process: 44.70%
# Iter 13420 ---- Process: 44.73%
# Iter 13430 ---- Process: 44.77%
# Iter 13440 ---- Process: 44.80%
# Iter 13450 ---- Process: 44.83%
# Iter 13460 ---- Process: 44.87%
# Iter 13470 ---- Process: 44.90%
# Iter 13480 ---- Process: 44.93%
# Iter 13490 ---- Process: 44.97%
# Iter 13500 ---- Process: 45.00%
# Iter 13510 ---- Process: 45.03%
# Iter 13520 ---- Process: 45.07%
# Iter 13530 ---- Process: 45.10%
# Iter 13540 ---- Process: 45.13%
# Iter 13550 ---- Process: 45.17%
# Iter 13560 ---- Process: 45.20%
# Iter 13570 ---- Process: 45.23%
# Iter 13580 ---- Process: 45.27%
# Iter 13590 ---- Process: 45.30%
# Iter 13600 ---- Process: 45.33%
# Iter 13610 ---- Process: 45.37%
# Iter 13620 ---- Process: 45.40%
# Iter 13630 ---- Process: 45.43%
# Iter 13640 ---- Process: 45.47%
# Iter 13650 ---- Process: 45.50%
# Iter 13660 ---- Process: 45.53%
# Iter 13670 ---- Process: 45.57%
# Iter 13680 ---- Process: 45.60%
# Iter 13690 ---- Process: 45.63%
# Iter 13700 ---- Process: 45.67%
# Iter 13710 ---- Process: 45.70%
# Iter 13720 ---- Process: 45.73%
# Iter 13730 ---- Process: 45.77%
# Iter 13740 ---- Process: 45.80%
# Iter 13750 ---- Process: 45.83%
# Iter 13760 ---- Process: 45.87%
# Iter 13770 ---- Process: 45.90%
# Iter 13780 ---- Process: 45.93%
# Iter 13790 ---- Process: 45.97%
# Iter 13800 ---- Process: 46.00%
# Iter 13810 ---- Process: 46.03%
# Iter 13820 ---- Process: 46.07%
# Iter 13830 ---- Process: 46.10%
# Iter 13840 ---- Process: 46.13%
# Iter 13850 ---- Process: 46.17%
# Iter 13860 ---- Process: 46.20%
# Iter 13870 ---- Process: 46.23%
# Iter 13880 ---- Process: 46.27%
# Iter 13890 ---- Process: 46.30%
# Iter 13900 ---- Process: 46.33%
# Iter 13910 ---- Process: 46.37%
# Iter 13920 ---- Process: 46.40%
# Iter 13930 ---- Process: 46.43%
# Iter 13940 ---- Process: 46.47%
# Iter 13950 ---- Process: 46.50%
# Iter 13960 ---- Process: 46.53%
# Iter 13970 ---- Process: 46.57%
# Iter 13980 ---- Process: 46.60%
# Iter 13990 ---- Process: 46.63%
# Iter 14000 ---- Process: 46.67%
# Iter 14010 ---- Process: 46.70%
# Iter 14020 ---- Process: 46.73%
# Iter 14030 ---- Process: 46.77%
# Iter 14040 ---- Process: 46.80%
# Iter 14050 ---- Process: 46.83%
# Iter 14060 ---- Process: 46.87%
# Iter 14070 ---- Process: 46.90%
# Iter 14080 ---- Process: 46.93%
# Iter 14090 ---- Process: 46.97%
# Iter 14100 ---- Process: 47.00%
# Iter 14110 ---- Process: 47.03%
# Iter 14120 ---- Process: 47.07%
# Iter 14130 ---- Process: 47.10%
# Iter 14140 ---- Process: 47.13%
# Iter 14150 ---- Process: 47.17%
# Iter 14160 ---- Process: 47.20%
# Iter 14170 ---- Process: 47.23%
# Iter 14180 ---- Process: 47.27%
# Iter 14190 ---- Process: 47.30%
# Iter 14200 ---- Process: 47.33%
# Iter 14210 ---- Process: 47.37%
# Iter 14220 ---- Process: 47.40%
# Iter 14230 ---- Process: 47.43%
# Iter 14240 ---- Process: 47.47%
# Iter 14250 ---- Process: 47.50%
# Iter 14260 ---- Process: 47.53%
# Iter 14270 ---- Process: 47.57%
# Iter 14280 ---- Process: 47.60%
# Iter 14290 ---- Process: 47.63%
# Iter 14300 ---- Process: 47.67%
# Iter 14310 ---- Process: 47.70%
# Iter 14320 ---- Process: 47.73%
# Iter 14330 ---- Process: 47.77%
# Iter 14340 ---- Process: 47.80%
# Iter 14350 ---- Process: 47.83%
# Iter 14360 ---- Process: 47.87%
# Iter 14370 ---- Process: 47.90%
# Iter 14380 ---- Process: 47.93%
# Iter 14390 ---- Process: 47.97%
# Iter 14400 ---- Process: 48.00%
# Iter 14410 ---- Process: 48.03%
# Iter 14420 ---- Process: 48.07%
# Iter 14430 ---- Process: 48.10%
# Iter 14440 ---- Process: 48.13%
# Iter 14450 ---- Process: 48.17%
# Iter 14460 ---- Process: 48.20%
# Iter 14470 ---- Process: 48.23%
# Iter 14480 ---- Process: 48.27%
# Iter 14490 ---- Process: 48.30%
# Iter 14500 ---- Process: 48.33%
# Iter 14510 ---- Process: 48.37%
# Iter 14520 ---- Process: 48.40%
# Iter 14530 ---- Process: 48.43%
# Iter 14540 ---- Process: 48.47%
# Iter 14550 ---- Process: 48.50%
# Iter 14560 ---- Process: 48.53%
# Iter 14570 ---- Process: 48.57%
# Iter 14580 ---- Process: 48.60%
# Iter 14590 ---- Process: 48.63%
# Iter 14600 ---- Process: 48.67%
# Iter 14610 ---- Process: 48.70%
# Iter 14620 ---- Process: 48.73%
# Iter 14630 ---- Process: 48.77%
# Iter 14640 ---- Process: 48.80%
# Iter 14650 ---- Process: 48.83%
# Iter 14660 ---- Process: 48.87%
# Iter 14670 ---- Process: 48.90%
# Iter 14680 ---- Process: 48.93%
# Iter 14690 ---- Process: 48.97%
# Iter 14700 ---- Process: 49.00%
# Iter 14710 ---- Process: 49.03%
# Iter 14720 ---- Process: 49.07%
# Iter 14730 ---- Process: 49.10%
# Iter 14740 ---- Process: 49.13%
# Iter 14750 ---- Process: 49.17%
# Iter 14760 ---- Process: 49.20%
# Iter 14770 ---- Process: 49.23%
# Iter 14780 ---- Process: 49.27%
# Iter 14790 ---- Process: 49.30%
# Iter 14800 ---- Process: 49.33%
# Iter 14810 ---- Process: 49.37%
# Iter 14820 ---- Process: 49.40%
# Iter 14830 ---- Process: 49.43%
# Iter 14840 ---- Process: 49.47%
# Iter 14850 ---- Process: 49.50%
# Iter 14860 ---- Process: 49.53%
# Iter 14870 ---- Process: 49.57%
# Iter 14880 ---- Process: 49.60%
# Iter 14890 ---- Process: 49.63%
# Iter 14900 ---- Process: 49.67%
# Iter 14910 ---- Process: 49.70%
# Iter 14920 ---- Process: 49.73%
# Iter 14930 ---- Process: 49.77%
# Iter 14940 ---- Process: 49.80%
# Iter 14950 ---- Process: 49.83%
# Iter 14960 ---- Process: 49.87%
# Iter 14970 ---- Process: 49.90%
# Iter 14980 ---- Process: 49.93%
# Iter 14990 ---- Process: 49.97%
# Iter 15000 ---- Process: 50.00%
# Iter 15010 ---- Process: 50.03%
# Iter 15020 ---- Process: 50.07%
# Iter 15030 ---- Process: 50.10%
# Iter 15040 ---- Process: 50.13%
# Iter 15050 ---- Process: 50.17%
# Iter 15060 ---- Process: 50.20%
# Iter 15070 ---- Process: 50.23%
# Iter 15080 ---- Process: 50.27%
# Iter 15090 ---- Process: 50.30%
# Iter 15100 ---- Process: 50.33%
# Iter 15110 ---- Process: 50.37%
# Iter 15120 ---- Process: 50.40%
# Iter 15130 ---- Process: 50.43%
# Iter 15140 ---- Process: 50.47%
# Iter 15150 ---- Process: 50.50%
# Iter 15160 ---- Process: 50.53%
# Iter 15170 ---- Process: 50.57%
# Iter 15180 ---- Process: 50.60%
# Iter 15190 ---- Process: 50.63%
# Iter 15200 ---- Process: 50.67%
# Iter 15210 ---- Process: 50.70%
# Iter 15220 ---- Process: 50.73%
# Iter 15230 ---- Process: 50.77%
# Iter 15240 ---- Process: 50.80%
# Iter 15250 ---- Process: 50.83%
# Iter 15260 ---- Process: 50.87%
# Iter 15270 ---- Process: 50.90%
# Iter 15280 ---- Process: 50.93%
# Iter 15290 ---- Process: 50.97%
# Iter 15300 ---- Process: 51.00%
# Iter 15310 ---- Process: 51.03%
# Iter 15320 ---- Process: 51.07%
# Iter 15330 ---- Process: 51.10%
# Iter 15340 ---- Process: 51.13%
# Iter 15350 ---- Process: 51.17%
# Iter 15360 ---- Process: 51.20%
# Iter 15370 ---- Process: 51.23%
# Iter 15380 ---- Process: 51.27%
# Iter 15390 ---- Process: 51.30%
# Iter 15400 ---- Process: 51.33%
# Iter 15410 ---- Process: 51.37%
# Iter 15420 ---- Process: 51.40%
# Iter 15430 ---- Process: 51.43%
# ...
# Iter 25000 ---- Process: 83.33%
# Iter 25010 ---- Process: 83.37%
# Iter 25020 ---- Process: 83.40%
# Iter 25030 ---- Process: 83.43%
# Iter 25040 ---- Process: 83.47%
# Iter 25050 ---- Process: 83.50%
# Iter 25060 ---- Process: 83.53%
# Iter 25070 ---- Process: 83.57%
# Iter 25080 ---- Process: 83.60%
# Iter 25090 ---- Process: 83.63%
# Iter 25100 ---- Process: 83.67%
# Iter 25110 ---- Process: 83.70%
# Iter 25120 ---- Process: 83.73%
# Iter 25130 ---- Process: 83.77%
# Iter 25140 ---- Process: 83.80%
# Iter 25150 ---- Process: 83.83%
# Iter 25160 ---- Process: 83.87%
# Iter 25170 ---- Process: 83.90%
# Iter 25180 ---- Process: 83.93%
# Iter 25190 ---- Process: 83.97%
# Iter 25200 ---- Process: 84.00%
# Iter 25210 ---- Process: 84.03%
# Iter 25220 ---- Process: 84.07%
# Iter 25230 ---- Process: 84.10%
# Iter 25240 ---- Process: 84.13%
# Iter 25250 ---- Process: 84.17%
# Iter 25260 ---- Process: 84.20%
# Iter 25270 ---- Process: 84.23%
# Iter 25280 ---- Process: 84.27%
# Iter 25290 ---- Process: 84.30%
# Iter 25300 ---- Process: 84.33%
# Iter 25310 ---- Process: 84.37%
# Iter 25320 ---- Process: 84.40%
# Iter 25330 ---- Process: 84.43%
# Iter 25340 ---- Process: 84.47%
# Iter 25350 ---- Process: 84.50%
# Iter 25360 ---- Process: 84.53%
# Iter 25370 ---- Process: 84.57%
# Iter 25380 ---- Process: 84.60%
# Iter 25390 ---- Process: 84.63%
# Iter 25400 ---- Process: 84.67%
# Iter 25410 ---- Process: 84.70%
# Iter 25420 ---- Process: 84.73%
# Iter 25430 ---- Process: 84.77%
# Iter 25440 ---- Process: 84.80%
# Iter 25450 ---- Process: 84.83%
# Iter 25460 ---- Process: 84.87%
# Iter 25470 ---- Process: 84.90%
# Iter 25480 ---- Process: 84.93%
# Iter 25490 ---- Process: 84.97%
# Iter 25500 ---- Process: 85.00%
# Iter 25510 ---- Process: 85.03%
# Iter 25520 ---- Process: 85.07%
# Iter 25530 ---- Process: 85.10%
# Iter 25540 ---- Process: 85.13%
# Iter 25550 ---- Process: 85.17%
# Iter 25560 ---- Process: 85.20%
# Iter 25570 ---- Process: 85.23%
# Iter 25580 ---- Process: 85.27%
# Iter 25590 ---- Process: 85.30%
# Iter 25600 ---- Process: 85.33%
# Iter 25610 ---- Process: 85.37%
# Iter 25620 ---- Process: 85.40%
# Iter 25630 ---- Process: 85.43%
# Iter 25640 ---- Process: 85.47%
# Iter 25650 ---- Process: 85.50%
# Iter 25660 ---- Process: 85.53%
# Iter 25670 ---- Process: 85.57%
# Iter 25680 ---- Process: 85.60%
# Iter 25690 ---- Process: 85.63%
# Iter 25700 ---- Process: 85.67%
# Iter 25710 ---- Process: 85.70%
# Iter 25720 ---- Process: 85.73%
# Iter 25730 ---- Process: 85.77%
# Iter 25740 ---- Process: 85.80%
# Iter 25750 ---- Process: 85.83%
# Iter 25760 ---- Process: 85.87%
# Iter 25770 ---- Process: 85.90%
# Iter 25780 ---- Process: 85.93%
# Iter 25790 ---- Process: 85.97%
# Iter 25800 ---- Process: 86.00%
# Iter 25810 ---- Process: 86.03%
# Iter 25820 ---- Process: 86.07%
# Iter 25830 ---- Process: 86.10%
# Iter 25840 ---- Process: 86.13%
# Iter 25850 ---- Process: 86.17%
# Iter 25860 ---- Process: 86.20%
# Iter 25870 ---- Process: 86.23%
# Iter 25880 ---- Process: 86.27%
# Iter 25890 ---- Process: 86.30%
# Iter 25900 ---- Process: 86.33%
# Iter 25910 ---- Process: 86.37%
# Iter 25920 ---- Process: 86.40%
# Iter 25930 ---- Process: 86.43%
# Iter 25940 ---- Process: 86.47%
# Iter 25950 ---- Process: 86.50%
# Iter 25960 ---- Process: 86.53%
# Iter 25970 ---- Process: 86.57%
# Iter 25980 ---- Process: 86.60%
# Iter 25990 ---- Process: 86.63%
# Iter 26000 ---- Process: 86.67%
# Iter 26010 ---- Process: 86.70%
# Iter 26020 ---- Process: 86.73%
# Iter 26030 ---- Process: 86.77%
# Iter 26040 ---- Process: 86.80%
# Iter 26050 ---- Process: 86.83%
# Iter 26060 ---- Process: 86.87%
# Iter 26070 ---- Process: 86.90%
# Iter 26080 ---- Process: 86.93%
# Iter 26090 ---- Process: 86.97%
# Iter 26100 ---- Process: 87.00%
# Iter 26110 ---- Process: 87.03%
# Iter 26120 ---- Process: 87.07%
# Iter 26130 ---- Process: 87.10%
# Iter 26140 ---- Process: 87.13%
# Iter 26150 ---- Process: 87.17%
# Iter 26160 ---- Process: 87.20%
# Iter 26170 ---- Process: 87.23%
# Iter 26180 ---- Process: 87.27%
# Iter 26190 ---- Process: 87.30%
# Iter 26200 ---- Process: 87.33%
# Iter 26210 ---- Process: 87.37%
# Iter 26220 ---- Process: 87.40%
# Iter 26230 ---- Process: 87.43%
# Iter 26240 ---- Process: 87.47%
# Iter 26250 ---- Process: 87.50%
# Iter 26260 ---- Process: 87.53%
# Iter 26270 ---- Process: 87.57%
# Iter 26280 ---- Process: 87.60%
# Iter 26290 ---- Process: 87.63%
# Iter 26300 ---- Process: 87.67%
# Iter 26310 ---- Process: 87.70%
# Iter 26320 ---- Process: 87.73%
# Iter 26330 ---- Process: 87.77%
# Iter 26340 ---- Process: 87.80%
# Iter 26350 ---- Process: 87.83%
# Iter 26360 ---- Process: 87.87%
# Iter 26370 ---- Process: 87.90%
# Iter 26380 ---- Process: 87.93%
# Iter 26390 ---- Process: 87.97%
# Iter 26400 ---- Process: 88.00%
# Iter 26410 ---- Process: 88.03%
# Iter 26420 ---- Process: 88.07%
# Iter 26430 ---- Process: 88.10%
# Iter 26440 ---- Process: 88.13%
# Iter 26450 ---- Process: 88.17%
# Iter 26460 ---- Process: 88.20%
# Iter 26470 ---- Process: 88.23%
# Iter 26480 ---- Process: 88.27%
# Iter 26490 ---- Process: 88.30%
# Iter 26500 ---- Process: 88.33%
# Iter 26510 ---- Process: 88.37%
# Iter 26520 ---- Process: 88.40%
# Iter 26530 ---- Process: 88.43%
# Iter 26540 ---- Process: 88.47%
# Iter 26550 ---- Process: 88.50%
# Iter 26560 ---- Process: 88.53%
# Iter 26570 ---- Process: 88.57%
# Iter 26580 ---- Process: 88.60%
# Iter 26590 ---- Process: 88.63%
# Iter 26600 ---- Process: 88.67%
# Iter 26610 ---- Process: 88.70%
# Iter 26620 ---- Process: 88.73%
# Iter 26630 ---- Process: 88.77%
# Iter 26640 ---- Process: 88.80%
# Iter 26650 ---- Process: 88.83%
# Iter 26660 ---- Process: 88.87%
# Iter 26670 ---- Process: 88.90%
# Iter 26680 ---- Process: 88.93%
# Iter 26690 ---- Process: 88.97%
# Iter 26700 ---- Process: 89.00%
# Iter 26710 ---- Process: 89.03%
# Iter 26720 ---- Process: 89.07%
# Iter 26730 ---- Process: 89.10%
# Iter 26740 ---- Process: 89.13%
# Iter 26750 ---- Process: 89.17%
# Iter 26760 ---- Process: 89.20%
# Iter 26770 ---- Process: 89.23%
# Iter 26780 ---- Process: 89.27%
# Iter 26790 ---- Process: 89.30%
# Iter 26800 ---- Process: 89.33%
# Iter 26810 ---- Process: 89.37%
# Iter 26820 ---- Process: 89.40%
# Iter 26830 ---- Process: 89.43%
# Iter 26840 ---- Process: 89.47%
# Iter 26850 ---- Process: 89.50%
# Iter 26860 ---- Process: 89.53%
# Iter 26870 ---- Process: 89.57%
# Iter 26880 ---- Process: 89.60%
# Iter 26890 ---- Process: 89.63%
# Iter 26900 ---- Process: 89.67%
# Iter 26910 ---- Process: 89.70%
# Iter 26920 ---- Process: 89.73%
# Iter 26930 ---- Process: 89.77%
# Iter 26940 ---- Process: 89.80%
# Iter 26950 ---- Process: 89.83%
# Iter 26960 ---- Process: 89.87%
# Iter 26970 ---- Process: 89.90%
# Iter 26980 ---- Process: 89.93%
# Iter 26990 ---- Process: 89.97%
# Iter 27000 ---- Process: 90.00%
# Iter 27010 ---- Process: 90.03%
# Iter 27020 ---- Process: 90.07%
# Iter 27030 ---- Process: 90.10%
# Iter 27040 ---- Process: 90.13%
# Iter 27050 ---- Process: 90.17%
# Iter 27060 ---- Process: 90.20%
# Iter 27070 ---- Process: 90.23%
# Iter 27080 ---- Process: 90.27%
# Iter 27090 ---- Process: 90.30%
# Iter 27100 ---- Process: 90.33%
# Iter 27110 ---- Process: 90.37%
# Iter 27120 ---- Process: 90.40%
# Iter 27130 ---- Process: 90.43%
# Iter 27140 ---- Process: 90.47%
# Iter 27150 ---- Process: 90.50%
# Iter 27160 ---- Process: 90.53%
# Iter 27170 ---- Process: 90.57%
# Iter 27180 ---- Process: 90.60%
# Iter 27190 ---- Process: 90.63%
# Iter 27200 ---- Process: 90.67%
# Iter 27210 ---- Process: 90.70%
# Iter 27220 ---- Process: 90.73%
# Iter 27230 ---- Process: 90.77%
# Iter 27240 ---- Process: 90.80%
# Iter 27250 ---- Process: 90.83%
# Iter 27260 ---- Process: 90.87%
# Iter 27270 ---- Process: 90.90%
# Iter 27280 ---- Process: 90.93%
# Iter 27290 ---- Process: 90.97%
# Iter 27300 ---- Process: 91.00%
# Iter 27310 ---- Process: 91.03%
# Iter 27320 ---- Process: 91.07%
# Iter 27330 ---- Process: 91.10%
# Iter 27340 ---- Process: 91.13%
# Iter 27350 ---- Process: 91.17%
# Iter 27360 ---- Process: 91.20%
# Iter 27370 ---- Process: 91.23%
# Iter 27380 ---- Process: 91.27%
# Iter 27390 ---- Process: 91.30%
# Iter 27400 ---- Process: 91.33%
# Iter 27410 ---- Process: 91.37%
# Iter 27420 ---- Process: 91.40%
# Iter 27430 ---- Process: 91.43%
# Iter 27440 ---- Process: 91.47%
# Iter 27450 ---- Process: 91.50%
# Iter 27460 ---- Process: 91.53%
# Iter 27470 ---- Process: 91.57%
# Iter 27480 ---- Process: 91.60%
# Iter 27490 ---- Process: 91.63%
# Iter 27500 ---- Process: 91.67%
# Iter 27510 ---- Process: 91.70%
# Iter 27520 ---- Process: 91.73%
# Iter 27530 ---- Process: 91.77%
# Iter 27540 ---- Process: 91.80%
# Iter 27550 ---- Process: 91.83%
# Iter 27560 ---- Process: 91.87%
# Iter 27570 ---- Process: 91.90%
# Iter 27580 ---- Process: 91.93%
# Iter 27590 ---- Process: 91.97%
# Iter 27600 ---- Process: 92.00%
# Iter 27610 ---- Process: 92.03%
# Iter 27620 ---- Process: 92.07%
# Iter 27630 ---- Process: 92.10%
# Iter 27640 ---- Process: 92.13%
# Iter 27650 ---- Process: 92.17%
# Iter 27660 ---- Process: 92.20%
# Iter 27670 ---- Process: 92.23%
# Iter 27680 ---- Process: 92.27%
# Iter 27690 ---- Process: 92.30%
# Iter 27700 ---- Process: 92.33%
# Iter 27710 ---- Process: 92.37%
# Iter 27720 ---- Process: 92.40%
# Iter 27730 ---- Process: 92.43%
# Iter 27740 ---- Process: 92.47%
# Iter 27750 ---- Process: 92.50%
# Iter 27760 ---- Process: 92.53%
# Iter 27770 ---- Process: 92.57%
# Iter 27780 ---- Process: 92.60%
# Iter 27790 ---- Process: 92.63%
# Iter 27800 ---- Process: 92.67%
# Iter 27810 ---- Process: 92.70%
# Iter 27820 ---- Process: 92.73%
# Iter 27830 ---- Process: 92.77%
# Iter 27840 ---- Process: 92.80%
# Iter 27850 ---- Process: 92.83%
# Iter 27860 ---- Process: 92.87%
# Iter 27870 ---- Process: 92.90%
# Iter 27880 ---- Process: 92.93%
# Iter 27890 ---- Process: 92.97%
# Iter 27900 ---- Process: 93.00%
# Iter 27910 ---- Process: 93.03%
# Iter 27920 ---- Process: 93.07%
# Iter 27930 ---- Process: 93.10%
# Iter 27940 ---- Process: 93.13%
# Iter 27950 ---- Process: 93.17%
# Iter 27960 ---- Process: 93.20%
# Iter 27970 ---- Process: 93.23%
# Iter 27980 ---- Process: 93.27%
# Iter 27990 ---- Process: 93.30%
# Iter 28000 ---- Process: 93.33%
# Iter 28010 ---- Process: 93.37%
# Iter 28020 ---- Process: 93.40%
# Iter 28030 ---- Process: 93.43%
# Iter 28040 ---- Process: 93.47%
# Iter 28050 ---- Process: 93.50%
# Iter 28060 ---- Process: 93.53%
# Iter 28070 ---- Process: 93.57%
# Iter 28080 ---- Process: 93.60%
# Iter 28090 ---- Process: 93.63%
# Iter 28100 ---- Process: 93.67%
# Iter 28110 ---- Process: 93.70%
# Iter 28120 ---- Process: 93.73%
# Iter 28130 ---- Process: 93.77%
# Iter 28140 ---- Process: 93.80%
# Iter 28150 ---- Process: 93.83%
# Iter 28160 ---- Process: 93.87%
# Iter 28170 ---- Process: 93.90%
# Iter 28180 ---- Process: 93.93%
# Iter 28190 ---- Process: 93.97%
# Iter 28200 ---- Process: 94.00%
# Iter 28210 ---- Process: 94.03%
# Iter 28220 ---- Process: 94.07%
# Iter 28230 ---- Process: 94.10%
# Iter 28240 ---- Process: 94.13%
# Iter 28250 ---- Process: 94.17%
# Iter 28260 ---- Process: 94.20%
# Iter 28270 ---- Process: 94.23%
# Iter 28280 ---- Process: 94.27%
# Iter 28290 ---- Process: 94.30%
# Iter 28300 ---- Process: 94.33%
# Iter 28310 ---- Process: 94.37%
# Iter 28320 ---- Process: 94.40%
# Iter 28330 ---- Process: 94.43%
# Iter 28340 ---- Process: 94.47%
# Iter 28350 ---- Process: 94.50%
# Iter 28360 ---- Process: 94.53%
# Iter 28370 ---- Process: 94.57%
# Iter 28380 ---- Process: 94.60%
# Iter 28390 ---- Process: 94.63%
# Iter 28400 ---- Process: 94.67%
# Iter 28410 ---- Process: 94.70%
# Iter 28420 ---- Process: 94.73%
# Iter 28430 ---- Process: 94.77%
# Iter 28440 ---- Process: 94.80%
# Iter 28450 ---- Process: 94.83%
# Iter 28460 ---- Process: 94.87%
# Iter 28470 ---- Process: 94.90%
# Iter 28480 ---- Process: 94.93%
# Iter 28490 ---- Process: 94.97%
# Iter 28500 ---- Process: 95.00%
# Iter 28510 ---- Process: 95.03%
# Iter 28520 ---- Process: 95.07%
# Iter 28530 ---- Process: 95.10%
# Iter 28540 ---- Process: 95.13%
# Iter 28550 ---- Process: 95.17%
# Iter 28560 ---- Process: 95.20%
# Iter 28570 ---- Process: 95.23%
# Iter 28580 ---- Process: 95.27%
# Iter 28590 ---- Process: 95.30%
# Iter 28600 ---- Process: 95.33%
# Iter 28610 ---- Process: 95.37%
# Iter 28620 ---- Process: 95.40%
# Iter 28630 ---- Process: 95.43%
# Iter 28640 ---- Process: 95.47%
# Iter 28650 ---- Process: 95.50%
# Iter 28660 ---- Process: 95.53%
# Iter 28670 ---- Process: 95.57%
# Iter 28680 ---- Process: 95.60%
# Iter 28690 ---- Process: 95.63%
# Iter 28700 ---- Process: 95.67%
# Iter 28710 ---- Process: 95.70%
# Iter 28720 ---- Process: 95.73%
# Iter 28730 ---- Process: 95.77%
# Iter 28740 ---- Process: 95.80%
# Iter 28750 ---- Process: 95.83%
# Iter 28760 ---- Process: 95.87%
# Iter 28770 ---- Process: 95.90%
# Iter 28780 ---- Process: 95.93%
# Iter 28790 ---- Process: 95.97%
# Iter 28800 ---- Process: 96.00%
# Iter 28810 ---- Process: 96.03%
# Iter 28820 ---- Process: 96.07%
# Iter 28830 ---- Process: 96.10%
# Iter 28840 ---- Process: 96.13%
# Iter 28850 ---- Process: 96.17%
# Iter 28860 ---- Process: 96.20%
# Iter 28870 ---- Process: 96.23%
# Iter 28880 ---- Process: 96.27%
# Iter 28890 ---- Process: 96.30%
# Iter 28900 ---- Process: 96.33%
# Iter 28910 ---- Process: 96.37%
# Iter 28920 ---- Process: 96.40%
# Iter 28930 ---- Process: 96.43%
# Iter 28940 ---- Process: 96.47%
# Iter 28950 ---- Process: 96.50%
# Iter 28960 ---- Process: 96.53%
# Iter 28970 ---- Process: 96.57%
# Iter 28980 ---- Process: 96.60%
# Iter 28990 ---- Process: 96.63%
# Iter 29000 ---- Process: 96.67%
# Iter 29010 ---- Process: 96.70%
# Iter 29020 ---- Process: 96.73%
# Iter 29030 ---- Process: 96.77%
# Iter 29040 ---- Process: 96.80%
# Iter 29050 ---- Process: 96.83%
# Iter 29060 ---- Process: 96.87%
# Iter 29070 ---- Process: 96.90%
# Iter 29080 ---- Process: 96.93%
# Iter 29090 ---- Process: 96.97%
# Iter 29100 ---- Process: 97.00%
# Iter 29110 ---- Process: 97.03%
# Iter 29120 ---- Process: 97.07%
# Iter 29130 ---- Process: 97.10%
# Iter 29140 ---- Process: 97.13%
# Iter 29150 ---- Process: 97.17%
# Iter 29160 ---- Process: 97.20%
# Iter 29170 ---- Process: 97.23%
# Iter 29180 ---- Process: 97.27%
# Iter 29190 ---- Process: 97.30%
# Iter 29200 ---- Process: 97.33%
# Iter 29210 ---- Process: 97.37%
# Iter 29220 ---- Process: 97.40%
# Iter 29230 ---- Process: 97.43%
# Iter 29240 ---- Process: 97.47%
# Iter 29250 ---- Process: 97.50%
# Iter 29260 ---- Process: 97.53%
# Iter 29270 ---- Process: 97.57%
# Iter 29280 ---- Process: 97.60%
# Iter 29290 ---- Process: 97.63%
# Iter 29300 ---- Process: 97.67%
# Iter 29310 ---- Process: 97.70%
# Iter 29320 ---- Process: 97.73%
# Iter 29330 ---- Process: 97.77%
# Iter 29340 ---- Process: 97.80%
# Iter 29350 ---- Process: 97.83%
# Iter 29360 ---- Process: 97.87%
# Iter 29370 ---- Process: 97.90%
# Iter 29380 ---- Process: 97.93%
# Iter 29390 ---- Process: 97.97%
# Iter 29400 ---- Process: 98.00%
# Iter 29410 ---- Process: 98.03%
# Iter 29420 ---- Process: 98.07%
# Iter 29430 ---- Process: 98.10%
# Iter 29440 ---- Process: 98.13%
# Iter 29450 ---- Process: 98.17%
# Iter 29460 ---- Process: 98.20%
# Iter 29470 ---- Process: 98.23%
# Iter 29480 ---- Process: 98.27%
# Iter 29490 ---- Process: 98.30%
# Iter 29500 ---- Process: 98.33%
# Iter 29510 ---- Process: 98.37%
# Iter 29520 ---- Process: 98.40%
# Iter 29530 ---- Process: 98.43%
# Iter 29540 ---- Process: 98.47%
# Iter 29550 ---- Process: 98.50%
# Iter 29560 ---- Process: 98.53%
# Iter 29570 ---- Process: 98.57%
# Iter 29580 ---- Process: 98.60%
# Iter 29590 ---- Process: 98.63%
# Iter 29600 ---- Process: 98.67%
# Iter 29610 ---- Process: 98.70%
# Iter 29620 ---- Process: 98.73%
# Iter 29630 ---- Process: 98.77%
# Iter 29640 ---- Process: 98.80%
# Iter 29650 ---- Process: 98.83%
# Iter 29660 ---- Process: 98.87%
# Iter 29670 ---- Process: 98.90%
# Iter 29680 ---- Process: 98.93%
# Iter 29690 ---- Process: 98.97%
# Iter 29700 ---- Process: 99.00%
# Iter 29710 ---- Process: 99.03%
# Iter 29720 ---- Process: 99.07%
# Iter 29730 ---- Process: 99.10%
# Iter 29740 ---- Process: 99.13%
# Iter 29750 ---- Process: 99.17%
# Iter 29760 ---- Process: 99.20%
# Iter 29770 ---- Process: 99.23%
# Iter 29780 ---- Process: 99.27%
# Iter 29790 ---- Process: 99.30%
# Iter 29800 ---- Process: 99.33%
# Iter 29810 ---- Process: 99.37%
# Iter 29820 ---- Process: 99.40%
# Iter 29830 ---- Process: 99.43%
# Iter 29840 ---- Process: 99.47%
# Iter 29850 ---- Process: 99.50%
# Iter 29860 ---- Process: 99.53%
# Iter 29870 ---- Process: 99.57%
# Iter 29880 ---- Process: 99.60%
# Iter 29890 ---- Process: 99.63%
# Iter 29900 ---- Process: 99.67%
# Iter 29910 ---- Process: 99.70%
# Iter 29920 ---- Process: 99.73%
# Iter 29930 ---- Process: 99.77%
# Iter 29940 ---- Process: 99.80%
# Iter 29950 ---- Process: 99.83%
# Iter 29960 ---- Process: 99.87%
# Iter 29970 ---- Process: 99.90%
# Iter 29980 ---- Process: 99.93%
# Iter 29990 ---- Process: 99.97%

# %%
RList = np.zeros([(num_epoches/10)])
rmseList = np.zeros([(num_epoches/10)])
maxeList = np.zeros([(num_epoches/10)])
mapeList = np.zeros([(num_epoches/10)])
for i in range(kind):
    out = np.array(outlist[i])
    tmp = out.T.reshape((1,test_batch_size))
    RList[i] = np.corrcoef(tmp[0,:],test_y.T[0,:])[0,1]
    rmseList[i] = rmse(tmp[0,:],test_y.T[0,:])
    maxeList[i] = maxe(tmp[0,:],test_y.T[0,:])
    mapeList[i] = mape(tmp[0,:],test_y.T[0,:])

# %%
prefix = './gefcom-result/INCDA/'
postfix = '-' + str(num_layers) + '-' + str(n_hidden) + '.csv'
DataFrame(RList).to_csv(prefix + 'R' + postfix)
DataFrame(rmseList).to_csv(prefix + 'RMSE' + postfix)
DataFrame(maxeList).to_csv(prefix + 'MAXE' + postfix)
DataFrame(mapeList).to_csv(prefix + 'MAPE' + postfix)

# %%
out = out * 25000
test_y = test_y*25000

# %%
out = out.reshape((test_batch_size,1))
pred_nd_load = np.concatenate([test_y,out],axis = 1)
DataFrame(pred_nd_load).to_csv(prefix + 'pred_nd_load' + postfix)

# %%
print np.mean(rmseList[-1001:-1])
# Out:
# 0.0102585380681

# %%
print np.mean(mapeList[-1001:-1])
# Out:
# 0.0131358746339

# %%
time2 = time.time()
print time2-time1
# Out:
# 620.655131102
